# %% [markdown]
# # Safe Q-Learning (SQRL) for Satellite Rendezvous
#
# This notebook demonstrates training a Safe Q-Learning (SQRL) agent on the HCWSE2Env satellite rendezvous environment using the SafeGym package.
#
# ## Environment: HCWSE2Env
# - **State**: [x, y, vx, vy, theta, omega] - position, velocity, attitude
# - **Action**: [u_thrust, u_alpha] - thrust and rotational acceleration
# - **Dynamics**: Hill-Clohessy-Wiltshire (HCW) equations for relative motion
# - **Safety**: Position and velocity limits with safety constraints
#
# ## SQRL Algorithm
# - **Safety Critic**: Learns safety constraints
# - **Dual Critics**: Standard Q-learning with safety awareness
# - **Safe Action Selection**: Actions filtered by safety constraints
# - **Constraint Violation Tracking**: Monitors unsafe transitions

# %%
# Import required libraries
import os
import sys
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from datetime import datetime
import json
from collections import deque

# Add project root to path
project_root = os.path.dirname(os.path.abspath('.'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Import SafeGym components
from SafeGym.safegym.models.sqrl import SQRLAgent
from SafeGym.safegym.models.replaybuffer.replaybuffer import ReplayBuffer
from envs.arpod_HCW import HCWSE2Env

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Training configuration
config = {
    # Environment parameters
    'env_name': 'HCWSE2Env',
    'spawn_radius': (5.0, 25.0),  # (min, max) spawn distance in meters
    'max_episodes': 20000,
    'max_steps_per_episode': 1000,
    'render_frequency': 100,  # Render every N episodes
    
    # SQRL hyperparameters
    'gamma': 0.99,  # Discount factor for rewards
    'safe_gamma': 0.95,  # Discount factor for safety
    'tau': 0.005,  # Soft update rate for target networks
    'alpha': 0.2,  # Entropy regularization coefficient
    
    # SQRL safety hyperparameters
    'epsilon_safe': 0.1,  # Safety constraint threshold
    'nu': 0.1,  # Safety penalty coefficient
    
    # Learning rates
    'actor_lr': 3e-4,
    'critic_lr': 3e-4,
    'alpha_lr': 1e-4,
    'nu_lr': 1e-5,
    
    # Training parameters
    'buffer_size': 1000000,
    'batch_size': 256,
    'gradient_steps': 1,
    'update_frequency': 1,  # Update every N steps
    'target_update_frequency': 1,  # Update target networks every N updates
    
    # Network architecture
    'actor_net_arch': [256, 256,64],
    'critic_net_arch': [256, 256,64],
    'safety_critic_net_arch': [256, 256, 64],
    
    # Logging
    'log_frequency': 50,
    'save_frequency': 200,
    'eval_frequency': 100,
    'eval_episodes': 5,
}

print("Configuration:")
for key, value in config.items():
    print(f"  {key}: {value}")
# Out:
# Configuration:
#   env_name: HCWSE2Env
#   spawn_radius: (5.0, 25.0)
#   max_episodes: 20000
#   max_steps_per_episode: 1000
#   render_frequency: 100
#   gamma: 0.99
#   safe_gamma: 0.95
#   tau: 0.005
#   alpha: 0.2
#   epsilon_safe: 0.1
#   nu: 0.1
#   actor_lr: 0.0003
#   critic_lr: 0.0003
#   alpha_lr: 0.0001
#   nu_lr: 1e-05
#   buffer_size: 1000000
#   batch_size: 256
#   gradient_steps: 1
#   update_frequency: 1
#   target_update_frequency: 1
#   actor_net_arch: [256, 256, 64]
#   critic_net_arch: [256, 256, 64]
#   safety_critic_net_arch: [256, 256, 64]
#   log_frequency: 50
#   save_frequency: 200
#   eval_frequency: 100
#   eval_episodes: 5

# %%
# Curriculum scheduler - mirror SAC schedule for spawn_radius phases
curriculum_config = {
    'enabled': True,
    'milestones': [
        {'episode': 1, 'spawn_radius': (2.5, 5.0)},
        {'episode': 250000//(config.get('max_steps_per_episode',1000)), 'spawn_radius': (2.5, 10.0)},
        {'episode': 500000//(config.get('max_steps_per_episode',1000)), 'spawn_radius': (2.5, 20.0)},
        {'episode': 1000000//(config.get('max_steps_per_episode',1000)), 'spawn_radius': (2.5, 40.0)},
        {'episode': 2000000//(config.get('max_steps_per_episode',1000)), 'spawn_radius': (2.5, 60.0)},
        {'episode': 3000000//(config.get('max_steps_per_episode',1000)), 'spawn_radius': (2.5, 80.0)},
        {'episode': 4000000//(config.get('max_steps_per_episode',1000)), 'spawn_radius': (2.5, 100.0)},
        {'episode': 5000000//(config.get('max_steps_per_episode',1000)), 'spawn_radius': (10.0, 100.0)},
    ]
}

class CurriculumScheduler:
    def __init__(self, cfg):
        self.enabled = cfg.get('enabled', False)
        self.milestones = sorted(cfg.get('milestones', []), key=lambda m: m['episode'])
        self.current = None

    def step(self, episode):
        if not self.enabled or not self.milestones:
            return {}
        selected = None
        for m in self.milestones:
            if episode >= m['episode']:
                selected = m
            else:
                break
        if selected is None:
            return {}
        if selected != self.current:
            self.current = selected.copy()
            return {k: v for k, v in selected.items() if k != 'episode'}
        return {}

def apply_curriculum_to_env(env, params):
    if not params:
        return False
    applied = False
    if 'spawn_radius' in params:
        try:
            if hasattr(env, 'envs'):
                for e in env.envs:
                    try:
                        setattr(e.unwrapped, 'spawn_radius', params['spawn_radius'])
                    except Exception:
                        try:
                            setattr(e, 'spawn_radius', params['spawn_radius'])
                        except Exception:
                            pass
            else:
                try:
                    setattr(env.unwrapped, 'spawn_radius', params['spawn_radius'])
                except Exception:
                    try:
                        setattr(env, 'spawn_radius', params['spawn_radius'])
                    except Exception:
                        pass
            applied = True
        except Exception:
            applied = False
    return applied

curriculum = CurriculumScheduler(curriculum_config)
print('Curriculum scheduler created for SQRL. Enabled:', curriculum.enabled)
# Out:
# Curriculum scheduler created for SQRL. Enabled: True

# %%
# Create output directories
run_specs = "SQRL_SafeGym"
run_id = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"runs/sqrl_hcw_{run_id}_{run_specs}"
os.makedirs(output_dir, exist_ok=True)
os.makedirs(f"{output_dir}/models", exist_ok=True)
os.makedirs(f"{output_dir}/logs", exist_ok=True)
os.makedirs(f"{output_dir}/plots", exist_ok=True)

# Save configuration
with open(f"{output_dir}/config.json", 'w') as f:
    json.dump(config, f, indent=2)

print(f"Output directory: {output_dir}")
# Out:
# Output directory: runs/sqrl_hcw_20250924_045707_SQRL_SafeGym

# %%
# Create environment
env = HCWSE2Env(
    render_mode=None,  # Set to "human" for visualization
    spawn_radius=config['spawn_radius'],
)

print(f"Environment created:")
print(f"  Observation space: {env.observation_space}")
print(f"  Action space: {env.action_space}")
print(f"  Max episode steps: {env.max_steps}")
print(f"  Spawn radius: {config['spawn_radius']}")
# Out:
# Environment created:
#   Observation space: Box([-500.        -500.         -50.         -50.          -3.1415927
#    -5.       ], [500.        500.         50.         50.          3.1415927   5.       ], (6,), float32)
#   Action space: Box([ 0. -1.], 1.0, (2,), float32)
#   Max episode steps: 3000
#   Spawn radius: (5.0, 25.0)

# %%
# Create SQRL agent
agent = SQRLAgent(
    env=env,
    gamma=config['gamma'],
    safe_gamma=config['safe_gamma'],
    tau=config['tau'],
    alpha=config['alpha'],
    epsilon_safe=config['epsilon_safe'],
    actor_learning_rate=config['actor_lr'],
    critic_learning_rate=config['critic_lr'],
    buffer_size=config['buffer_size'],
    auto_entropy_tuning=True,
    nu=config['nu'],
    auto_nu_tuning=True,
    gradient_steps=config['gradient_steps'],
    policy_kwargs={
        'actor_net_arch': config['actor_net_arch'],
        'critic_net_arch': config['critic_net_arch'],
        'safety_critic_net_arch': config['safety_critic_net_arch'],
    },
    alpha_learning_rate=config['alpha_lr'],
    nu_learning_rate=config['nu_lr'],
)

print(f"SQRL Agent created:")
print(f"  Device: {agent.device}")
print(f"  Observation dim: {agent.obs_dim}")
print(f"  Action dim: {agent.action_dim}")
print(f"  Buffer size: {config['buffer_size']}")
print(f"  Safety threshold: {config['epsilon_safe']}")
# Out:
# SQRL Agent created:
#   Device: cuda
#   Observation dim: 6
#   Action dim: 2
#   Buffer size: 1000000
#   Safety threshold: 0.1

# %%
# Training metrics tracking
training_metrics = {
    'episode_rewards': [],
    'episode_lengths': [],
    'safety_violations': [],
    'unsafe_actions': [],
    'actor_losses': [],
    'critic_losses': [],
    'safety_critic_losses': [],
    'alpha_values': [],
    'nu_values': [],
    'success_rate': [],
    'avg_reward': [],
    'avg_length': [],
    'avg_safety_violations': [],
    'safety_violation_rate': [],  # Percentage of episodes with violations
    'consecutive_safe_episodes': [],  # Track consecutive safe episodes
    'safety_violation_types': [],  # Track types of violations
    'max_safety_violations_per_episode': [],  # Track worst episodes
}

# Evaluation metrics
eval_metrics = {
    'eval_rewards': [],
    'eval_lengths': [],
    'eval_safety_violations': [],
    'eval_success_rate': [],
    'eval_safety_violation_rate': [],
}

# Safety violation tracking
safety_stats = {
    'total_violations': 0,
    'total_episodes': 0,
    'consecutive_safe': 0,
    'max_consecutive_safe': 0,
    'violation_types': {
        'attitude_fail': 0,
        'velocity_fail': 0,
        'velocity_theta_fail': 0,
        'omega_fail': 0,
        'out_of_bounds': 0,
    }
}

print("Enhanced training metrics initialized with safety tracking")
# Out:
# Enhanced training metrics initialized with safety tracking

# %%
# Safety function - get unsafe signal from environment info
def compute_unsafe(info):
    """Extract unsafe signal from environment info dictionary."""
    return int(info.get("is_unsafe", 0))

print("Safety function defined - using is_unsafe from environment info")
# Out:
# Safety function defined - using is_unsafe from environment info

# %%
# Training loop
print("Starting SQRL training...")
print(f"Training for {config['max_episodes']} episodes")
print(f"Max steps per episode: {config['max_steps_per_episode']}")
print(f"Update frequency: {config['update_frequency']}")
print("-" * 50)

episode = 0
total_steps = 0
recent_rewards = deque(maxlen=100)
recent_lengths = deque(maxlen=100)
recent_safety_violations = deque(maxlen=100)

while episode < config['max_episodes']:
    episode += 1
    
    # Apply curriculum for this episode
    try:
        new_params = curriculum.step(episode) if 'curriculum' in globals() else {}
        if new_params:
            applied = apply_curriculum_to_env(env, new_params)
            if applied:
                print(f"[Curriculum] Episode {episode}: applied {new_params}")
            else:
                print(f"[Curriculum] Episode {episode}: could not apply in-place, please restart or re-create env with {new_params}")
    except Exception as e:
        print("[Curriculum] Error while applying curriculum:", e)

    # Reset environment
    obs, info = env.reset()
    episode_reward = 0
    episode_length = 0
    episode_safety_violations = 0
    
    # Episode loop
    for step in range(config['max_steps_per_episode']):
        total_steps += 1
        episode_length += 1
        
        # Select action
        action = agent.select_action(obs)
        
        # Take step
        next_obs, reward, terminated, truncated, info = env.step(action)
        
        # Get unsafe signal from environment info
        unsafe = compute_unsafe(info)
        
        if unsafe:
            episode_safety_violations += 1
        
        # Store transition in replay buffer
        agent.replay_buffer.push(
            state=obs,
            action=action,
            reward=reward,
            next_state=next_obs,
            terminated=terminated,
            truncated=truncated,
            unsafe=unsafe
        )
        
        episode_reward += reward
        obs = next_obs
        
        # Update agent
        if (total_steps % config['update_frequency'] == 0 and 
            len(agent.replay_buffer) >= config['batch_size']):
            
            # Train with safety-aware sampling
            agent.train(batch_size=config['batch_size'], pretrain=False)
            
        
        # Check termination
        if terminated or truncated:
            break
    
    # Record episode metrics
    recent_rewards.append(episode_reward)
    recent_lengths.append(episode_length)
    recent_safety_violations.append(episode_safety_violations)
    
    training_metrics['episode_rewards'].append(episode_reward)
    training_metrics['episode_lengths'].append(episode_length)
    training_metrics['safety_violations'].append(episode_safety_violations)
    
    # Calculate success rate (episode completed without safety violations)
    success = episode_safety_violations == 0 and episode_length >= 10
    training_metrics['success_rate'].append(float(success))
    
    # Update safety statistics
    safety_stats['total_episodes'] += 1
    safety_stats['total_violations'] += episode_safety_violations
    
    if episode_safety_violations == 0:
        safety_stats['consecutive_safe'] += 1
        safety_stats['max_consecutive_safe'] = max(safety_stats['max_consecutive_safe'], safety_stats['consecutive_safe'])
    else:
        safety_stats['consecutive_safe'] = 0
        
    # Track violation types from the last info
    if 'done_reason' in info:
        violation_type = info['done_reason']
        if violation_type in safety_stats['violation_types']:
            safety_stats['violation_types'][violation_type] += 1
    
    # Record safety metrics
    training_metrics['consecutive_safe_episodes'].append(safety_stats['consecutive_safe'])
    training_metrics['max_safety_violations_per_episode'].append(max(training_metrics['safety_violations']) if training_metrics['safety_violations'] else 0)
    
    # Logging
    if episode % config['log_frequency'] == 0:
        avg_reward = np.mean(recent_rewards)
        avg_length = np.mean(recent_lengths)
        avg_safety_violations = np.mean(recent_safety_violations)
        success_rate = np.mean(training_metrics['success_rate'][-100:])
        
        # Calculate safety violation rate (percentage of episodes with violations)
        recent_episodes = min(100, len(training_metrics['safety_violations']))
        recent_violation_episodes = sum(1 for v in training_metrics['safety_violations'][-recent_episodes:] if v > 0)
        safety_violation_rate = (recent_violation_episodes / recent_episodes) * 100
        
        training_metrics['avg_reward'].append(avg_reward)
        training_metrics['avg_length'].append(avg_length)
        training_metrics['avg_safety_violations'].append(avg_safety_violations)
        training_metrics['safety_violation_rate'].append(safety_violation_rate)
        
        # Safety alert system
        safety_alert = ""
        if episode_safety_violations > 0:
            safety_alert = f" ⚠️  SAFETY VIOLATION! ({episode_safety_violations} violations)"
        elif safety_violation_rate > 20:
            safety_alert = f" ⚠️  HIGH VIOLATION RATE: {safety_violation_rate:.1f}%"
        elif safety_stats['consecutive_safe'] > 50:
            safety_alert = f" ✅ {safety_stats['consecutive_safe']} consecutive safe episodes!"
        
        print(f"Episode {episode:4d} | "
              f"Reward: {episode_reward:8.2f} | "
              f"Avg Reward: {avg_reward:8.2f} | "
              f"Length: {episode_length:4d} | "
              f"Safety Violations: {episode_safety_violations:2d} | "
              f"Success Rate: {success_rate:.3f} | "
              f"Violation Rate: {safety_violation_rate:5.1f}%{safety_alert}")
        
        # Additional safety statistics every 200 episodes
        if episode % 200 == 0:
            print(f"\n📊 SAFETY STATISTICS (Episodes 1-{episode}):")
            print(f"   Total Violations: {safety_stats['total_violations']}")
            print(f"   Violation Rate: {(safety_stats['total_violations']/safety_stats['total_episodes']*100):.2f}%")
            print(f"   Max Consecutive Safe: {safety_stats['max_consecutive_safe']}")
            print(f"   Current Consecutive Safe: {safety_stats['consecutive_safe']}")
            print(f"   Violation Types:")
            for vtype, count in safety_stats['violation_types'].items():
                if count > 0:
                    print(f"     {vtype}: {count}")
            print()
    
    # Save model
    if episode % config['save_frequency'] == 0:
        torch.save({
            'episode': episode,
            'agent_state_dict': {
                'actor': agent.actor.state_dict(),
                'critic1': agent.critic1.state_dict(),
                'critic2': agent.critic2.state_dict(),
                'safety_critic': agent.safety_critic.state_dict(),
            },
            'optimizer_state_dict': {
                'actor': agent.actor_optimizer.state_dict(),
                'critic1': agent.critic1_optimizer.state_dict(),
                'critic2': agent.critic2_optimizer.state_dict(),
                'safety_critic': agent.safety_critic_optimizer.state_dict(),
            },
            'training_metrics': training_metrics,
        }, f"{output_dir}/models/agent_episode_{episode}.pth")
        
        # Save training metrics
        np.save(f"{output_dir}/logs/training_metrics.npy", training_metrics)
    
    # Evaluation
    if episode % config['eval_frequency'] == 0:
        eval_rewards = []
        eval_lengths = []
        eval_safety_violations = []
        eval_successes = []
        
        for eval_ep in range(config['eval_episodes']):
            eval_obs, eval_info = env.reset()
            eval_reward = 0
            eval_length = 0
            eval_safety_violations_ep = 0
            
            for _ in range(config['max_steps_per_episode']):
                eval_action = agent.select_action(eval_obs)
                eval_next_obs, eval_r, eval_term, eval_trunc, eval_info = env.step(eval_action)
                
                eval_unsafe = compute_unsafe(eval_info)
                if eval_unsafe:
                    eval_safety_violations_ep += 1
                
                eval_reward += eval_r
                eval_length += 1
                eval_obs = eval_next_obs
                
                if eval_term or eval_trunc:
                    break
            
            eval_rewards.append(eval_reward)
            eval_lengths.append(eval_length)
            eval_safety_violations.append(eval_safety_violations_ep)
            eval_successes.append(eval_safety_violations_ep == 0)
        
        eval_metrics['eval_rewards'].append(np.mean(eval_rewards))
        eval_metrics['eval_lengths'].append(np.mean(eval_lengths))
        eval_metrics['eval_safety_violations'].append(np.mean(eval_safety_violations))
        eval_metrics['eval_success_rate'].append(np.mean(eval_successes))
        
        # Calculate evaluation safety violation rate
        eval_violation_rate = (sum(1 for v in eval_safety_violations if v > 0) / len(eval_safety_violations)) * 100
        eval_metrics['eval_safety_violation_rate'].append(eval_violation_rate)
        
        # Safety status for evaluation
        eval_safety_status = ""
        if np.mean(eval_safety_violations) == 0:
            eval_safety_status = " ✅ ALL SAFE"
        elif eval_violation_rate > 50:
            eval_safety_status = " ⚠️  HIGH VIOLATIONS"
        else:
            eval_safety_status = " ⚠️  SOME VIOLATIONS"
        
        print(f"Evaluation | Avg Reward: {np.mean(eval_rewards):8.2f} | "
              f"Avg Length: {np.mean(eval_lengths):6.1f} | "
              f"Safety Violations: {np.mean(eval_safety_violations):6.1f} | "
              f"Success Rate: {np.mean(eval_successes):.3f} | "
              f"Violation Rate: {eval_violation_rate:5.1f}%{eval_safety_status}")

print("\nTraining completed!")
print(f"Total episodes: {episode}")
print(f"Total steps: {total_steps}")
print(f"Final average reward: {np.mean(recent_rewards):.2f}")
print(f"Final success rate: {np.mean(training_metrics['success_rate'][-100:]):.3f}")
# Out:
# Starting SQRL training...
# Training for 20000 episodes
# Max steps per episode: 1000
# Update frequency: 1
# --------------------------------------------------
# [Curriculum] Episode 1: applied {'spawn_radius': (2.5, 5.0)}
# Episode   50 | Reward:    11.17 | Avg Reward:  -195.77 | Length:  281 | Safety Violations:  1 | Success Rate: 0.700 | Violation Rate:  30.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode   50 | Reward:    11.17 | Avg Reward:  -195.77 | Length:  281 | Safety Violations:  1 | Success Rate: 0.700 | Violation Rate:  30.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode  100 | Reward:  -526.10 | Avg Reward:  -123.44 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.560 | Violation Rate:  44.0% ⚠️  HIGH VIOLATION RATE: 44.0%
# Episode  100 | Reward:  -526.10 | Avg Reward:  -123.44 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.560 | Violation Rate:  44.0% ⚠️  HIGH VIOLATION RATE: 44.0%
# Evaluation | Avg Reward:    -3.74 | Avg Length:  624.2 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    -3.74 | Avg Length:  624.2 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode  150 | Reward:   225.84 | Avg Reward:   -10.51 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.580 | Violation Rate:  42.0% ⚠️  HIGH VIOLATION RATE: 42.0%
# Episode  150 | Reward:   225.84 | Avg Reward:   -10.51 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.580 | Violation Rate:  42.0% ⚠️  HIGH VIOLATION RATE: 42.0%
# Episode  200 | Reward:   222.35 | Avg Reward:    47.17 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.640 | Violation Rate:  36.0% ⚠️  HIGH VIOLATION RATE: 36.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-200):
#    Total Violations: 80
#    Violation Rate: 40.00%
#    Max Consecutive Safe: 12
#    Current Consecutive Safe: 1
#    Violation Types:
#      attitude_fail: 34
#      velocity_fail: 19
#      velocity_theta_fail: 27
#
# Episode  200 | Reward:   222.35 | Avg Reward:    47.17 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.640 | Violation Rate:  36.0% ⚠️  HIGH VIOLATION RATE: 36.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-200):
#    Total Violations: 80
#    Violation Rate: 40.00%
#    Max Consecutive Safe: 12
#    Current Consecutive Safe: 1
#    Violation Types:
#      attitude_fail: 34
#      velocity_fail: 19
#      velocity_theta_fail: 27
#
# Evaluation | Avg Reward:     8.05 | Avg Length:  744.0 | Safety Violations:    0.4 | Success Rate: 0.600 | Violation Rate:  40.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:     8.05 | Avg Length:  744.0 | Safety Violations:    0.4 | Success Rate: 0.600 | Violation Rate:  40.0% ⚠️  SOME VIOLATIONS
# [Curriculum] Episode 250: applied {'spawn_radius': (2.5, 10.0)}
# [Curriculum] Episode 250: applied {'spawn_radius': (2.5, 10.0)}
# Episode  250 | Reward:    69.57 | Avg Reward:    58.30 | Length:  106 | Safety Violations:  0 | Success Rate: 0.640 | Violation Rate:  36.0% ⚠️  HIGH VIOLATION RATE: 36.0%
# Episode  250 | Reward:    69.57 | Avg Reward:    58.30 | Length:  106 | Safety Violations:  0 | Success Rate: 0.640 | Violation Rate:  36.0% ⚠️  HIGH VIOLATION RATE: 36.0%
# Episode  300 | Reward:     5.46 | Avg Reward:    36.68 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.750 | Violation Rate:  25.0% ⚠️  HIGH VIOLATION RATE: 25.0%
# Episode  300 | Reward:     5.46 | Avg Reward:    36.68 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.750 | Violation Rate:  25.0% ⚠️  HIGH VIOLATION RATE: 25.0%
# Evaluation | Avg Reward:   107.28 | Avg Length:  452.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:   107.28 | Avg Length:  452.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode  350 | Reward:   -13.36 | Avg Reward:    26.53 | Length:  347 | Safety Violations:  1 | Success Rate: 0.710 | Violation Rate:  29.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode  350 | Reward:   -13.36 | Avg Reward:    26.53 | Length:  347 | Safety Violations:  1 | Success Rate: 0.710 | Violation Rate:  29.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode  400 | Reward:    56.20 | Avg Reward:    40.24 | Length:   42 | Safety Violations:  0 | Success Rate: 0.710 | Violation Rate:  29.0% ⚠️  HIGH VIOLATION RATE: 29.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-400):
#    Total Violations: 134
#    Violation Rate: 33.50%
#    Max Consecutive Safe: 26
#    Current Consecutive Safe: 26
#    Violation Types:
#      attitude_fail: 51
#      velocity_fail: 44
#      velocity_theta_fail: 39
#
# Episode  400 | Reward:    56.20 | Avg Reward:    40.24 | Length:   42 | Safety Violations:  0 | Success Rate: 0.710 | Violation Rate:  29.0% ⚠️  HIGH VIOLATION RATE: 29.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-400):
#    Total Violations: 134
#    Violation Rate: 33.50%
#    Max Consecutive Safe: 26
#    Current Consecutive Safe: 26
#    Violation Types:
#      attitude_fail: 51
#      velocity_fail: 44
#      velocity_theta_fail: 39
#
# Evaluation | Avg Reward:    75.73 | Avg Length:  419.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    75.73 | Avg Length:  419.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode  450 | Reward:    91.33 | Avg Reward:    56.23 | Length:  258 | Safety Violations:  0 | Success Rate: 0.830 | Violation Rate:  17.0%
# Episode  450 | Reward:    91.33 | Avg Reward:    56.23 | Length:  258 | Safety Violations:  0 | Success Rate: 0.830 | Violation Rate:  17.0%
# [Curriculum] Episode 500: applied {'spawn_radius': (2.5, 20.0)}
# [Curriculum] Episode 500: applied {'spawn_radius': (2.5, 20.0)}
# Episode  500 | Reward:    59.91 | Avg Reward:    65.08 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode  500 | Reward:    59.91 | Avg Reward:    65.08 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Evaluation | Avg Reward:    59.66 | Avg Length:  642.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    59.66 | Avg Length:  642.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode  550 | Reward:    68.23 | Avg Reward:    64.28 | Length:  166 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode  550 | Reward:    68.23 | Avg Reward:    64.28 | Length:  166 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode  600 | Reward:    76.88 | Avg Reward:    68.58 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-600):
#    Total Violations: 146
#    Violation Rate: 24.33%
#    Max Consecutive Safe: 46
#    Current Consecutive Safe: 38
#    Violation Types:
#      attitude_fail: 62
#      velocity_fail: 45
#      velocity_theta_fail: 39
#
# Episode  600 | Reward:    76.88 | Avg Reward:    68.58 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-600):
#    Total Violations: 146
#    Violation Rate: 24.33%
#    Max Consecutive Safe: 46
#    Current Consecutive Safe: 38
#    Violation Types:
#      attitude_fail: 62
#      velocity_fail: 45
#      velocity_theta_fail: 39
#
# Evaluation | Avg Reward:    80.48 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    80.48 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode  650 | Reward:    78.45 | Avg Reward:    69.64 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode  650 | Reward:    78.45 | Avg Reward:    69.64 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode  700 | Reward:    71.17 | Avg Reward:    55.67 | Length:  138 | Safety Violations:  0 | Success Rate: 0.810 | Violation Rate:  19.0%
# Episode  700 | Reward:    71.17 | Avg Reward:    55.67 | Length:  138 | Safety Violations:  0 | Success Rate: 0.810 | Violation Rate:  19.0%
# Evaluation | Avg Reward:    74.53 | Avg Length:  640.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    74.53 | Avg Length:  640.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode  750 | Reward:    76.82 | Avg Reward:    57.08 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.800 | Violation Rate:  20.0%
# Episode  750 | Reward:    76.82 | Avg Reward:    57.08 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.800 | Violation Rate:  20.0%
# Episode  800 | Reward:    78.12 | Avg Reward:    67.61 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-800):
#    Total Violations: 174
#    Violation Rate: 21.75%
#    Max Consecutive Safe: 47
#    Current Consecutive Safe: 1
#    Violation Types:
#      attitude_fail: 68
#      velocity_fail: 66
#      velocity_theta_fail: 40
#
# Episode  800 | Reward:    78.12 | Avg Reward:    67.61 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-800):
#    Total Violations: 174
#    Violation Rate: 21.75%
#    Max Consecutive Safe: 47
#    Current Consecutive Safe: 1
#    Violation Types:
#      attitude_fail: 68
#      velocity_fail: 66
#      velocity_theta_fail: 40
#
# Evaluation | Avg Reward:    76.70 | Avg Length:  656.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    76.70 | Avg Length:  656.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode  850 | Reward:    66.67 | Avg Reward:    67.70 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode  850 | Reward:    66.67 | Avg Reward:    67.70 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode  900 | Reward:    78.01 | Avg Reward:    69.13 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode  900 | Reward:    78.01 | Avg Reward:    69.13 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Evaluation | Avg Reward:    74.41 | Avg Length:  654.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    74.41 | Avg Length:  654.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode  950 | Reward:    78.12 | Avg Reward:    71.11 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode  950 | Reward:    78.12 | Avg Reward:    71.11 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# [Curriculum] Episode 1000: applied {'spawn_radius': (2.5, 40.0)}
# [Curriculum] Episode 1000: applied {'spawn_radius': (2.5, 40.0)}
# Episode 1000 | Reward:    80.11 | Avg Reward:    72.00 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1000):
#    Total Violations: 181
#    Violation Rate: 18.10%
#    Max Consecutive Safe: 47
#    Current Consecutive Safe: 35
#    Violation Types:
#      attitude_fail: 71
#      velocity_fail: 70
#      velocity_theta_fail: 40
#
# Episode 1000 | Reward:    80.11 | Avg Reward:    72.00 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1000):
#    Total Violations: 181
#    Violation Rate: 18.10%
#    Max Consecutive Safe: 47
#    Current Consecutive Safe: 35
#    Violation Types:
#      attitude_fail: 71
#      velocity_fail: 70
#      velocity_theta_fail: 40
#
# Evaluation | Avg Reward:    80.17 | Avg Length:  712.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    80.17 | Avg Length:  712.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1050 | Reward:    26.02 | Avg Reward:    68.33 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 1050 | Reward:    26.02 | Avg Reward:    68.33 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 1100 | Reward:    95.83 | Avg Reward:    69.76 | Length:  271 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 1100 | Reward:    95.83 | Avg Reward:    69.76 | Length:  271 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Evaluation | Avg Reward:    79.61 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    79.61 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1150 | Reward:    76.80 | Avg Reward:    70.97 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 1150 | Reward:    76.80 | Avg Reward:    70.97 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 1200 | Reward:    72.82 | Avg Reward:    71.72 | Length:  185 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0% ✅ 57 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-1200):
#    Total Violations: 186
#    Violation Rate: 15.50%
#    Max Consecutive Safe: 67
#    Current Consecutive Safe: 57
#    Violation Types:
#      attitude_fail: 74
#      velocity_fail: 71
#      velocity_theta_fail: 41
#
# Episode 1200 | Reward:    72.82 | Avg Reward:    71.72 | Length:  185 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0% ✅ 57 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-1200):
#    Total Violations: 186
#    Violation Rate: 15.50%
#    Max Consecutive Safe: 67
#    Current Consecutive Safe: 57
#    Violation Types:
#      attitude_fail: 74
#      velocity_fail: 71
#      velocity_theta_fail: 41
#
# Evaluation | Avg Reward:    77.93 | Avg Length:  823.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    77.93 | Avg Length:  823.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1250 | Reward:    81.08 | Avg Reward:    76.11 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 107 consecutive safe episodes!
# Episode 1250 | Reward:    81.08 | Avg Reward:    76.11 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 107 consecutive safe episodes!
# Episode 1300 | Reward:    63.52 | Avg Reward:    75.13 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 157 consecutive safe episodes!
# Episode 1300 | Reward:    63.52 | Avg Reward:    75.13 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 157 consecutive safe episodes!
# Evaluation | Avg Reward:    77.20 | Avg Length:  657.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    77.20 | Avg Length:  657.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1350 | Reward:    95.30 | Avg Reward:    75.09 | Length:  457 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 1350 | Reward:    95.30 | Avg Reward:    75.09 | Length:  457 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 1400 | Reward:    24.43 | Avg Reward:    73.71 | Length:  865 | Safety Violations:  1 | Success Rate: 0.970 | Violation Rate:   3.0% ⚠️  SAFETY VIOLATION! (1 violations)
#
# 📊 SAFETY STATISTICS (Episodes 1-1400):
#    Total Violations: 189
#    Violation Rate: 13.50%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 0
#    Violation Types:
#      attitude_fail: 74
#      velocity_fail: 74
#      velocity_theta_fail: 41
#
# Episode 1400 | Reward:    24.43 | Avg Reward:    73.71 | Length:  865 | Safety Violations:  1 | Success Rate: 0.970 | Violation Rate:   3.0% ⚠️  SAFETY VIOLATION! (1 violations)
#
# 📊 SAFETY STATISTICS (Episodes 1-1400):
#    Total Violations: 189
#    Violation Rate: 13.50%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 0
#    Violation Types:
#      attitude_fail: 74
#      velocity_fail: 74
#      velocity_theta_fail: 41
#
# Evaluation | Avg Reward:    78.37 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    78.37 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1450 | Reward:    72.34 | Avg Reward:    70.01 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode 1450 | Reward:    72.34 | Avg Reward:    70.01 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode 1500 | Reward:    59.89 | Avg Reward:    70.07 | Length:   82 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode 1500 | Reward:    59.89 | Avg Reward:    70.07 | Length:   82 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Evaluation | Avg Reward:    76.86 | Avg Length:  666.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    76.86 | Avg Length:  666.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1550 | Reward:    78.59 | Avg Reward:    72.07 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 1550 | Reward:    78.59 | Avg Reward:    72.07 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 1600 | Reward:    80.97 | Avg Reward:    75.62 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0% ✅ 51 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-1600):
#    Total Violations: 199
#    Violation Rate: 12.44%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 51
#    Violation Types:
#      attitude_fail: 76
#      velocity_fail: 79
#      velocity_theta_fail: 44
#
# Episode 1600 | Reward:    80.97 | Avg Reward:    75.62 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0% ✅ 51 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-1600):
#    Total Violations: 199
#    Violation Rate: 12.44%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 51
#    Violation Types:
#      attitude_fail: 76
#      velocity_fail: 79
#      velocity_theta_fail: 44
#
# Evaluation | Avg Reward:    82.08 | Avg Length:  826.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    82.08 | Avg Length:  826.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1650 | Reward:    85.78 | Avg Reward:    77.23 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 1650 | Reward:    85.78 | Avg Reward:    77.23 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 1700 | Reward:    74.24 | Avg Reward:    71.23 | Length:  207 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode 1700 | Reward:    74.24 | Avg Reward:    71.23 | Length:  207 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Evaluation | Avg Reward:    77.12 | Avg Length:  636.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    77.12 | Avg Length:  636.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1750 | Reward:    82.13 | Avg Reward:    64.46 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode 1750 | Reward:    82.13 | Avg Reward:    64.46 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode 1800 | Reward:    84.40 | Avg Reward:    68.99 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1800):
#    Total Violations: 208
#    Violation Rate: 11.56%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 22
#    Violation Types:
#      attitude_fail: 82
#      velocity_fail: 82
#      velocity_theta_fail: 44
#
# Episode 1800 | Reward:    84.40 | Avg Reward:    68.99 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1800):
#    Total Violations: 208
#    Violation Rate: 11.56%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 22
#    Violation Types:
#      attitude_fail: 82
#      velocity_fail: 82
#      velocity_theta_fail: 44
#
# Evaluation | Avg Reward:    83.25 | Avg Length:  825.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    83.25 | Avg Length:  825.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1850 | Reward:    83.91 | Avg Reward:    58.46 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 1850 | Reward:    83.91 | Avg Reward:    58.46 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 1900 | Reward:    84.30 | Avg Reward:    52.65 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
# Episode 1900 | Reward:    84.30 | Avg Reward:    52.65 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
# Evaluation | Avg Reward:    80.49 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    80.49 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1950 | Reward:    72.60 | Avg Reward:    67.42 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.900 | Violation Rate:  10.0%
# Episode 1950 | Reward:    72.60 | Avg Reward:    67.42 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.900 | Violation Rate:  10.0%
# [Curriculum] Episode 2000: applied {'spawn_radius': (2.5, 60.0)}
# [Curriculum] Episode 2000: applied {'spawn_radius': (2.5, 60.0)}
# Episode 2000 | Reward:    84.68 | Avg Reward:    67.57 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2000):
#    Total Violations: 225
#    Violation Rate: 11.25%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 27
#    Violation Types:
#      attitude_fail: 86
#      velocity_fail: 92
#      velocity_theta_fail: 47
#
# Episode 2000 | Reward:    84.68 | Avg Reward:    67.57 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2000):
#    Total Violations: 225
#    Violation Rate: 11.25%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 27
#    Violation Types:
#      attitude_fail: 86
#      velocity_fail: 92
#      velocity_theta_fail: 47
#
# Evaluation | Avg Reward:    65.16 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    65.16 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2050 | Reward:    65.25 | Avg Reward:    68.24 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode 2050 | Reward:    65.25 | Avg Reward:    68.24 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode 2100 | Reward:    74.79 | Avg Reward:    58.25 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 64 consecutive safe episodes!
# Episode 2100 | Reward:    74.79 | Avg Reward:    58.25 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 64 consecutive safe episodes!
# Evaluation | Avg Reward:    85.22 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    85.22 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2150 | Reward:    71.17 | Avg Reward:    59.53 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode 2150 | Reward:    71.17 | Avg Reward:    59.53 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode 2200 | Reward:    89.85 | Avg Reward:    75.63 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0% ✅ 60 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-2200):
#    Total Violations: 231
#    Violation Rate: 10.50%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 60
#    Violation Types:
#      attitude_fail: 87
#      velocity_fail: 95
#      velocity_theta_fail: 49
#
# Episode 2200 | Reward:    89.85 | Avg Reward:    75.63 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0% ✅ 60 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-2200):
#    Total Violations: 231
#    Violation Rate: 10.50%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 60
#    Violation Types:
#      attitude_fail: 87
#      velocity_fail: 95
#      velocity_theta_fail: 49
#
# Evaluation | Avg Reward:    87.70 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    87.70 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2250 | Reward:    81.50 | Avg Reward:    78.09 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 2250 | Reward:    81.50 | Avg Reward:    78.09 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 2300 | Reward:    80.40 | Avg Reward:    77.32 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0% ✅ 67 consecutive safe episodes!
# Episode 2300 | Reward:    80.40 | Avg Reward:    77.32 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0% ✅ 67 consecutive safe episodes!
# Evaluation | Avg Reward:    72.15 | Avg Length:  928.2 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    72.15 | Avg Length:  928.2 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode 2350 | Reward:    75.11 | Avg Reward:    69.20 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 2350 | Reward:    75.11 | Avg Reward:    69.20 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 2400 | Reward:    56.64 | Avg Reward:    52.64 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2400):
#    Total Violations: 238
#    Violation Rate: 9.92%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 18
#    Violation Types:
#      attitude_fail: 88
#      velocity_fail: 97
#      velocity_theta_fail: 53
#
# Episode 2400 | Reward:    56.64 | Avg Reward:    52.64 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2400):
#    Total Violations: 238
#    Violation Rate: 9.92%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 18
#    Violation Types:
#      attitude_fail: 88
#      velocity_fail: 97
#      velocity_theta_fail: 53
#
# Evaluation | Avg Reward:    80.77 | Avg Length:  841.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    80.77 | Avg Length:  841.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2450 | Reward:    84.45 | Avg Reward:    47.61 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 2450 | Reward:    84.45 | Avg Reward:    47.61 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 2500 | Reward:    74.23 | Avg Reward:    58.09 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 53 consecutive safe episodes!
# Episode 2500 | Reward:    74.23 | Avg Reward:    58.09 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 53 consecutive safe episodes!
# Evaluation | Avg Reward:    75.07 | Avg Length:  658.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    75.07 | Avg Length:  658.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2550 | Reward:    84.08 | Avg Reward:    71.43 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 2550 | Reward:    84.08 | Avg Reward:    71.43 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 2600 | Reward:    77.08 | Avg Reward:    80.57 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2600):
#    Total Violations: 244
#    Violation Rate: 9.38%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 18
#    Violation Types:
#      attitude_fail: 89
#      velocity_fail: 102
#      velocity_theta_fail: 53
#
# Episode 2600 | Reward:    77.08 | Avg Reward:    80.57 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2600):
#    Total Violations: 244
#    Violation Rate: 9.38%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 18
#    Violation Types:
#      attitude_fail: 89
#      velocity_fail: 102
#      velocity_theta_fail: 53
#
# Evaluation | Avg Reward:    53.50 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    53.50 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2650 | Reward:    14.05 | Avg Reward:    74.02 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 2650 | Reward:    14.05 | Avg Reward:    74.02 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 2700 | Reward:    86.77 | Avg Reward:    76.71 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 55 consecutive safe episodes!
# Episode 2700 | Reward:    86.77 | Avg Reward:    76.71 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 55 consecutive safe episodes!
# Evaluation | Avg Reward:    77.45 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    77.45 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2750 | Reward:    87.16 | Avg Reward:    87.15 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 105 consecutive safe episodes!
# Episode 2750 | Reward:    87.16 | Avg Reward:    87.15 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 105 consecutive safe episodes!
# Episode 2800 | Reward:    86.44 | Avg Reward:    84.19 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 155 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-2800):
#    Total Violations: 246
#    Violation Rate: 8.79%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 155
#    Violation Types:
#      attitude_fail: 89
#      velocity_fail: 104
#      velocity_theta_fail: 53
#
# Episode 2800 | Reward:    86.44 | Avg Reward:    84.19 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 155 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-2800):
#    Total Violations: 246
#    Violation Rate: 8.79%
#    Max Consecutive Safe: 164
#    Current Consecutive Safe: 155
#    Violation Types:
#      attitude_fail: 89
#      velocity_fail: 104
#      velocity_theta_fail: 53
#
# Evaluation | Avg Reward:    86.91 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    86.91 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2850 | Reward:    79.89 | Avg Reward:    83.75 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 205 consecutive safe episodes!
# Episode 2850 | Reward:    79.89 | Avg Reward:    83.75 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 205 consecutive safe episodes!
# Episode 2900 | Reward:    81.75 | Avg Reward:    84.25 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 2900 | Reward:    81.75 | Avg Reward:    84.25 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Evaluation | Avg Reward:    84.73 | Avg Length:  816.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    84.73 | Avg Length:  816.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2950 | Reward:    83.13 | Avg Reward:    80.04 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0% ✅ 78 consecutive safe episodes!
# Episode 2950 | Reward:    83.13 | Avg Reward:    80.04 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0% ✅ 78 consecutive safe episodes!
# [Curriculum] Episode 3000: applied {'spawn_radius': (2.5, 80.0)}
# [Curriculum] Episode 3000: applied {'spawn_radius': (2.5, 80.0)}
# Episode 3000 | Reward:    87.28 | Avg Reward:    79.66 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3000):
#    Total Violations: 250
#    Violation Rate: 8.33%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 9
#    Violation Types:
#      attitude_fail: 92
#      velocity_fail: 105
#      velocity_theta_fail: 53
#
# Episode 3000 | Reward:    87.28 | Avg Reward:    79.66 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3000):
#    Total Violations: 250
#    Violation Rate: 8.33%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 9
#    Violation Types:
#      attitude_fail: 92
#      velocity_fail: 105
#      velocity_theta_fail: 53
#
# Evaluation | Avg Reward:    80.25 | Avg Length:  814.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    80.25 | Avg Length:  814.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3050 | Reward:    78.12 | Avg Reward:    77.41 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 3050 | Reward:    78.12 | Avg Reward:    77.41 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 3100 | Reward:    87.08 | Avg Reward:    70.41 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 3100 | Reward:    87.08 | Avg Reward:    70.41 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Evaluation | Avg Reward:    84.85 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    84.85 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3150 | Reward:  -100.99 | Avg Reward:    18.97 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 3150 | Reward:  -100.99 | Avg Reward:    18.97 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 3200 | Reward:    67.30 | Avg Reward:     7.13 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 64 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-3200):
#    Total Violations: 255
#    Violation Rate: 7.97%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 64
#    Violation Types:
#      attitude_fail: 95
#      velocity_fail: 105
#      velocity_theta_fail: 55
#
# Episode 3200 | Reward:    67.30 | Avg Reward:     7.13 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 64 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-3200):
#    Total Violations: 255
#    Violation Rate: 7.97%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 64
#    Violation Types:
#      attitude_fail: 95
#      velocity_fail: 105
#      velocity_theta_fail: 55
#
# Evaluation | Avg Reward:    75.87 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    75.87 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3250 | Reward:    71.92 | Avg Reward:    58.65 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 3250 | Reward:    71.92 | Avg Reward:    58.65 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 3300 | Reward:    78.35 | Avg Reward:    73.21 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 3300 | Reward:    78.35 | Avg Reward:    73.21 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Evaluation | Avg Reward:    80.71 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    80.71 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3350 | Reward:    67.38 | Avg Reward:    74.85 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 3350 | Reward:    67.38 | Avg Reward:    74.85 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 3400 | Reward:    57.90 | Avg Reward:    73.67 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3400):
#    Total Violations: 261
#    Violation Rate: 7.68%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 7
#    Violation Types:
#      attitude_fail: 96
#      velocity_fail: 108
#      velocity_theta_fail: 57
#
# Episode 3400 | Reward:    57.90 | Avg Reward:    73.67 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3400):
#    Total Violations: 261
#    Violation Rate: 7.68%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 7
#    Violation Types:
#      attitude_fail: 96
#      velocity_fail: 108
#      velocity_theta_fail: 57
#
# Evaluation | Avg Reward:    38.92 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    38.92 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3450 | Reward:    77.28 | Avg Reward:    72.29 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 57 consecutive safe episodes!
# Episode 3450 | Reward:    77.28 | Avg Reward:    72.29 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 57 consecutive safe episodes!
# Episode 3500 | Reward:    67.13 | Avg Reward:    71.85 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 107 consecutive safe episodes!
# Episode 3500 | Reward:    67.13 | Avg Reward:    71.85 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 107 consecutive safe episodes!
# Evaluation | Avg Reward:    70.59 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    70.59 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3550 | Reward:    80.31 | Avg Reward:    71.47 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 3550 | Reward:    80.31 | Avg Reward:    71.47 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 3600 | Reward:    83.23 | Avg Reward:    71.69 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3600):
#    Total Violations: 264
#    Violation Rate: 7.33%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 16
#    Violation Types:
#      attitude_fail: 96
#      velocity_fail: 109
#      velocity_theta_fail: 59
#
# Episode 3600 | Reward:    83.23 | Avg Reward:    71.69 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3600):
#    Total Violations: 264
#    Violation Rate: 7.33%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 16
#    Violation Types:
#      attitude_fail: 96
#      velocity_fail: 109
#      velocity_theta_fail: 59
#
# Evaluation | Avg Reward:    83.12 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    83.12 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3650 | Reward:    86.15 | Avg Reward:    73.88 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 3650 | Reward:    86.15 | Avg Reward:    73.88 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 3700 | Reward:    82.72 | Avg Reward:    78.88 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 3700 | Reward:    82.72 | Avg Reward:    78.88 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Evaluation | Avg Reward:    73.91 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    73.91 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3750 | Reward:    85.15 | Avg Reward:    76.44 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 3750 | Reward:    85.15 | Avg Reward:    76.44 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 3800 | Reward:    83.68 | Avg Reward:    70.85 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3800):
#    Total Violations: 271
#    Violation Rate: 7.13%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 19
#    Violation Types:
#      attitude_fail: 101
#      velocity_fail: 109
#      velocity_theta_fail: 61
#
# Episode 3800 | Reward:    83.68 | Avg Reward:    70.85 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3800):
#    Total Violations: 271
#    Violation Rate: 7.13%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 19
#    Violation Types:
#      attitude_fail: 101
#      velocity_fail: 109
#      velocity_theta_fail: 61
#
# Evaluation | Avg Reward:    82.51 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    82.51 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3850 | Reward:    85.41 | Avg Reward:    74.00 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 3850 | Reward:    85.41 | Avg Reward:    74.00 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 3900 | Reward:    76.25 | Avg Reward:    75.74 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 3900 | Reward:    76.25 | Avg Reward:    75.74 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Evaluation | Avg Reward:    78.22 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    78.22 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3950 | Reward:    83.20 | Avg Reward:    72.52 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0% ✅ 52 consecutive safe episodes!
# Episode 3950 | Reward:    83.20 | Avg Reward:    72.52 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0% ✅ 52 consecutive safe episodes!
# [Curriculum] Episode 4000: applied {'spawn_radius': (2.5, 100.0)}
# [Curriculum] Episode 4000: applied {'spawn_radius': (2.5, 100.0)}
# Episode 4000 | Reward:    85.42 | Avg Reward:    77.94 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 102 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-4000):
#    Total Violations: 275
#    Violation Rate: 6.88%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 102
#    Violation Types:
#      attitude_fail: 101
#      velocity_fail: 112
#      velocity_theta_fail: 62
#
# Episode 4000 | Reward:    85.42 | Avg Reward:    77.94 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 102 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-4000):
#    Total Violations: 275
#    Violation Rate: 6.88%
#    Max Consecutive Safe: 222
#    Current Consecutive Safe: 102
#    Violation Types:
#      attitude_fail: 101
#      velocity_fail: 112
#      velocity_theta_fail: 62
#
# Evaluation | Avg Reward:    84.88 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    84.88 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 4050 | Reward:    83.41 | Avg Reward:    77.70 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 152 consecutive safe episodes!
# Episode 4050 | Reward:    83.41 | Avg Reward:    77.70 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 152 consecutive safe episodes!
# Episode 4100 | Reward:    76.04 | Avg Reward:    74.71 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 202 consecutive safe episodes!
# Episode 4100 | Reward:    76.04 | Avg Reward:    74.71 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 202 consecutive safe episodes!
# Evaluation | Avg Reward:    76.54 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    76.54 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 4150 | Reward:    81.45 | Avg Reward:    77.25 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 252 consecutive safe episodes!
# Episode 4150 | Reward:    81.45 | Avg Reward:    77.25 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 252 consecutive safe episodes!
# ...
# Evaluation | Avg Reward:   111.85 | Avg Length:  273.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 18750 | Reward:   107.32 | Avg Reward:   106.29 | Length:  261 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 18750 | Reward:   107.32 | Avg Reward:   106.29 | Length:  261 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 18800 | Reward:   106.43 | Avg Reward:   105.56 | Length:  255 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-18800):
#    Total Violations: 554
#    Violation Rate: 2.95%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 1
#    Violation Types:
#      attitude_fail: 204
#      velocity_fail: 242
#      velocity_theta_fail: 108
#
# Episode 18800 | Reward:   106.43 | Avg Reward:   105.56 | Length:  255 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-18800):
#    Total Violations: 554
#    Violation Rate: 2.95%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 1
#    Violation Types:
#      attitude_fail: 204
#      velocity_fail: 242
#      velocity_theta_fail: 108
#
# Evaluation | Avg Reward:    84.98 | Avg Length:  396.6 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    84.98 | Avg Length:  396.6 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode 18850 | Reward:    76.80 | Avg Reward:   104.12 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 18850 | Reward:    76.80 | Avg Reward:   104.12 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 18900 | Reward:   104.38 | Avg Reward:   106.58 | Length:  258 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 94 consecutive safe episodes!
# Episode 18900 | Reward:   104.38 | Avg Reward:   106.58 | Length:  258 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 94 consecutive safe episodes!
# Evaluation | Avg Reward:   104.55 | Avg Length:  401.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:   104.55 | Avg Length:  401.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 18950 | Reward:   121.40 | Avg Reward:   110.23 | Length:  267 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 144 consecutive safe episodes!
# Episode 18950 | Reward:   121.40 | Avg Reward:   110.23 | Length:  267 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 144 consecutive safe episodes!
# Episode 19000 | Reward:   118.71 | Avg Reward:   108.32 | Length:  267 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-19000):
#    Total Violations: 556
#    Violation Rate: 2.93%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 20
#    Violation Types:
#      attitude_fail: 206
#      velocity_fail: 242
#      velocity_theta_fail: 108
#
# Episode 19000 | Reward:   118.71 | Avg Reward:   108.32 | Length:  267 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-19000):
#    Total Violations: 556
#    Violation Rate: 2.93%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 20
#    Violation Types:
#      attitude_fail: 206
#      velocity_fail: 242
#      velocity_theta_fail: 108
#
# Evaluation | Avg Reward:   116.39 | Avg Length:  272.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:   116.39 | Avg Length:  272.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 19050 | Reward:    89.25 | Avg Reward:   107.46 | Length:  229 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 70 consecutive safe episodes!
# Episode 19050 | Reward:    89.25 | Avg Reward:   107.46 | Length:  229 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 70 consecutive safe episodes!
# Episode 19100 | Reward:    87.50 | Avg Reward:    88.06 | Length:  230 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 120 consecutive safe episodes!
# Episode 19100 | Reward:    87.50 | Avg Reward:    88.06 | Length:  230 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 120 consecutive safe episodes!
# Evaluation | Avg Reward:   106.54 | Avg Length:  260.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:   106.54 | Avg Length:  260.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 19150 | Reward:   149.51 | Avg Reward:    86.94 | Length:  309 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 170 consecutive safe episodes!
# Episode 19150 | Reward:   149.51 | Avg Reward:    86.94 | Length:  309 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 170 consecutive safe episodes!
# Episode 19200 | Reward:   102.42 | Avg Reward:   108.15 | Length:  236 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 220 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-19200):
#    Total Violations: 556
#    Violation Rate: 2.90%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 220
#    Violation Types:
#      attitude_fail: 206
#      velocity_fail: 242
#      velocity_theta_fail: 108
#
# Episode 19200 | Reward:   102.42 | Avg Reward:   108.15 | Length:  236 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 220 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-19200):
#    Total Violations: 556
#    Violation Rate: 2.90%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 220
#    Violation Types:
#      attitude_fail: 206
#      velocity_fail: 242
#      velocity_theta_fail: 108
#
# Evaluation | Avg Reward:   112.47 | Avg Length:  267.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:   112.47 | Avg Length:  267.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 19250 | Reward:   122.28 | Avg Reward:   106.84 | Length:  278 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 270 consecutive safe episodes!
# Episode 19250 | Reward:   122.28 | Avg Reward:   106.84 | Length:  278 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 270 consecutive safe episodes!
# Episode 19300 | Reward:    80.53 | Avg Reward:   106.83 | Length:  208 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 320 consecutive safe episodes!
# Episode 19300 | Reward:    80.53 | Avg Reward:   106.83 | Length:  208 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 320 consecutive safe episodes!
# Evaluation | Avg Reward:    96.25 | Avg Length:  316.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    96.25 | Avg Length:  316.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 19350 | Reward:   130.48 | Avg Reward:   108.51 | Length:  281 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 370 consecutive safe episodes!
# Episode 19350 | Reward:   130.48 | Avg Reward:   108.51 | Length:  281 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 370 consecutive safe episodes!
# Episode 19400 | Reward:    82.59 | Avg Reward:   107.63 | Length:  224 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 420 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-19400):
#    Total Violations: 556
#    Violation Rate: 2.87%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 420
#    Violation Types:
#      attitude_fail: 206
#      velocity_fail: 242
#      velocity_theta_fail: 108
#
# Episode 19400 | Reward:    82.59 | Avg Reward:   107.63 | Length:  224 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 420 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-19400):
#    Total Violations: 556
#    Violation Rate: 2.87%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 420
#    Violation Types:
#      attitude_fail: 206
#      velocity_fail: 242
#      velocity_theta_fail: 108
#
# Evaluation | Avg Reward:   112.48 | Avg Length:  319.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:   112.48 | Avg Length:  319.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 19450 | Reward:    75.58 | Avg Reward:   105.73 | Length:  236 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 470 consecutive safe episodes!
# Episode 19450 | Reward:    75.58 | Avg Reward:   105.73 | Length:  236 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 470 consecutive safe episodes!
# Episode 19500 | Reward:   136.68 | Avg Reward:   102.39 | Length:  302 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 19500 | Reward:   136.68 | Avg Reward:   102.39 | Length:  302 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Evaluation | Avg Reward:    58.16 | Avg Length:  422.2 | Safety Violations:    0.4 | Success Rate: 0.600 | Violation Rate:  40.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    58.16 | Avg Length:  422.2 | Safety Violations:    0.4 | Success Rate: 0.600 | Violation Rate:  40.0% ⚠️  SOME VIOLATIONS
# Episode 19550 | Reward:   112.66 | Avg Reward:    99.09 | Length:  252 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 19550 | Reward:   112.66 | Avg Reward:    99.09 | Length:  252 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 19600 | Reward:   145.21 | Avg Reward:   100.05 | Length:  314 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 73 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-19600):
#    Total Violations: 559
#    Violation Rate: 2.85%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 73
#    Violation Types:
#      attitude_fail: 207
#      velocity_fail: 242
#      velocity_theta_fail: 110
#
# Episode 19600 | Reward:   145.21 | Avg Reward:   100.05 | Length:  314 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 73 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-19600):
#    Total Violations: 559
#    Violation Rate: 2.85%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 73
#    Violation Types:
#      attitude_fail: 207
#      velocity_fail: 242
#      velocity_theta_fail: 110
#
# Evaluation | Avg Reward:   115.28 | Avg Length:  272.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:   115.28 | Avg Length:  272.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 19650 | Reward:   128.08 | Avg Reward:   102.77 | Length:  292 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 19650 | Reward:   128.08 | Avg Reward:   102.77 | Length:  292 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 19700 | Reward:   113.92 | Avg Reward:   103.02 | Length:  264 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 95 consecutive safe episodes!
# Episode 19700 | Reward:   113.92 | Avg Reward:   103.02 | Length:  264 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 95 consecutive safe episodes!
# Evaluation | Avg Reward:    88.50 | Avg Length:  220.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    88.50 | Avg Length:  220.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 19750 | Reward:    93.42 | Avg Reward:   100.20 | Length:  208 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 19750 | Reward:    93.42 | Avg Reward:   100.20 | Length:  208 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 19800 | Reward:    76.68 | Avg Reward:   100.10 | Length:  210 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-19800):
#    Total Violations: 566
#    Violation Rate: 2.86%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 13
#    Violation Types:
#      attitude_fail: 207
#      velocity_fail: 249
#      velocity_theta_fail: 110
#
# Episode 19800 | Reward:    76.68 | Avg Reward:   100.10 | Length:  210 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-19800):
#    Total Violations: 566
#    Violation Rate: 2.86%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 13
#    Violation Types:
#      attitude_fail: 207
#      velocity_fail: 249
#      velocity_theta_fail: 110
#
# Evaluation | Avg Reward:   106.93 | Avg Length:  242.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:   106.93 | Avg Length:  242.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 19850 | Reward:    78.13 | Avg Reward:   104.73 | Length:  187 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 19850 | Reward:    78.13 | Avg Reward:   104.73 | Length:  187 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 19900 | Reward:   105.70 | Avg Reward:   106.51 | Length:  239 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 53 consecutive safe episodes!
# Episode 19900 | Reward:   105.70 | Avg Reward:   106.51 | Length:  239 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 53 consecutive safe episodes!
# Evaluation | Avg Reward:    99.93 | Avg Length:  244.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    99.93 | Avg Length:  244.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 19950 | Reward:   142.11 | Avg Reward:   107.72 | Length:  325 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 19950 | Reward:   142.11 | Avg Reward:   107.72 | Length:  325 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 20000 | Reward:    96.51 | Avg Reward:   103.48 | Length:  237 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-20000):
#    Total Violations: 572
#    Violation Rate: 2.86%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 7
#    Violation Types:
#      attitude_fail: 208
#      velocity_fail: 254
#      velocity_theta_fail: 110
#
# Episode 20000 | Reward:    96.51 | Avg Reward:   103.48 | Length:  237 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-20000):
#    Total Violations: 572
#    Violation Rate: 2.86%
#    Max Consecutive Safe: 1103
#    Current Consecutive Safe: 7
#    Violation Types:
#      attitude_fail: 208
#      velocity_fail: 254
#      velocity_theta_fail: 110
#
# Evaluation | Avg Reward:    29.72 | Avg Length:  416.4 | Safety Violations:    0.8 | Success Rate: 0.200 | Violation Rate:  80.0% ⚠️  HIGH VIOLATIONS
#
# Training completed!
# Total episodes: 20000
# Total steps: 15916977
# Final average reward: 103.48
# Final success rate: 0.960
# Evaluation | Avg Reward:    29.72 | Avg Length:  416.4 | Safety Violations:    0.8 | Success Rate: 0.200 | Violation Rate:  80.0% ⚠️  HIGH VIOLATIONS
#
# Training completed!
# Total episodes: 20000
# Total steps: 15916977
# Final average reward: 103.48
# Final success rate: 0.960

# %%
# Plot training results
fig, axes = plt.subplots(3, 3, figsize=(20, 16))
fig.suptitle('SQRL Training Results with Safety Analysis', fontsize=16)

# Episode rewards
axes[0, 0].plot(training_metrics['episode_rewards'], alpha=0.3, color='blue')
if training_metrics['avg_reward']:
    axes[0, 0].plot(np.arange(0, len(training_metrics['avg_reward'])) * config['log_frequency'], 
                    training_metrics['avg_reward'], color='red', linewidth=2)
axes[0, 0].set_title('Episode Rewards')
axes[0, 0].set_xlabel('Episode')
axes[0, 0].set_ylabel('Reward')
axes[0, 0].grid(True)

# Episode lengths
axes[0, 1].plot(training_metrics['episode_lengths'], alpha=0.3, color='green')
if training_metrics['avg_length']:
    axes[0, 1].plot(np.arange(0, len(training_metrics['avg_length'])) * config['log_frequency'], 
                    training_metrics['avg_length'], color='red', linewidth=2)
axes[0, 1].set_title('Episode Lengths')
axes[0, 1].set_xlabel('Episode')
axes[0, 1].set_ylabel('Steps')
axes[0, 1].grid(True)

# Safety violations per episode
axes[0, 2].plot(training_metrics['safety_violations'], alpha=0.3, color='orange')
if training_metrics['avg_safety_violations']:
    axes[0, 2].plot(np.arange(0, len(training_metrics['avg_safety_violations'])) * config['log_frequency'], 
                    training_metrics['avg_safety_violations'], color='red', linewidth=2)
axes[0, 2].set_title('Safety Violations per Episode')
axes[0, 2].set_xlabel('Episode')
axes[0, 2].set_ylabel('Violations')
axes[0, 2].grid(True)

# Safety violation rate (percentage of episodes with violations)
if training_metrics['safety_violation_rate']:
    axes[1, 0].plot(np.arange(0, len(training_metrics['safety_violation_rate'])) * config['log_frequency'], 
                    training_metrics['safety_violation_rate'], color='red', linewidth=2)
    axes[1, 0].axhline(y=20, color='orange', linestyle='--', alpha=0.7, label='Warning Threshold (20%)')
    axes[1, 0].axhline(y=5, color='green', linestyle='--', alpha=0.7, label='Good Threshold (5%)')
axes[1, 0].set_title('Safety Violation Rate (%)')
axes[1, 0].set_xlabel('Episode')
axes[1, 0].set_ylabel('Violation Rate (%)')
axes[1, 0].grid(True)
axes[1, 0].legend()
axes[1, 0].set_ylim(0, 100)

# Consecutive safe episodes
if training_metrics['consecutive_safe_episodes']:
    axes[1, 1].plot(training_metrics['consecutive_safe_episodes'], color='green', linewidth=2)
    axes[1, 1].axhline(y=50, color='orange', linestyle='--', alpha=0.7, label='Good Streak (50)')
    axes[1, 1].axhline(y=100, color='green', linestyle='--', alpha=0.7, label='Excellent Streak (100)')
axes[1, 1].set_title('Consecutive Safe Episodes')
axes[1, 1].set_xlabel('Episode')
axes[1, 1].set_ylabel('Consecutive Safe')
axes[1, 1].grid(True)
axes[1, 1].legend()

# Safety violation types (pie chart)
if safety_stats['violation_types']:
    violation_counts = [count for count in safety_stats['violation_types'].values() if count > 0]
    violation_labels = [label for label, count in safety_stats['violation_types'].items() if count > 0]
    if violation_counts:
        axes[1, 2].pie(violation_counts, labels=violation_labels, autopct='%1.1f%%', startangle=90)
        axes[1, 2].set_title('Safety Violation Types Distribution')
    else:
        axes[1, 2].text(0.5, 0.5, 'No Violations!', ha='center', va='center', transform=axes[1, 2].transAxes, fontsize=14)
        axes[1, 2].set_title('Safety Violation Types Distribution')

# Success rate
if training_metrics['success_rate']:
    # Calculate rolling average
    window = 100
    success_rate_rolling = []
    for i in range(len(training_metrics['success_rate'])):
        start_idx = max(0, i - window + 1)
        success_rate_rolling.append(np.mean(training_metrics['success_rate'][start_idx:i+1]))
    
    axes[2, 0].plot(success_rate_rolling, color='purple', linewidth=2)
    axes[2, 0].set_title('Success Rate (Rolling Average)')
    axes[2, 0].set_xlabel('Episode')
    axes[2, 0].set_ylabel('Success Rate')
    axes[2, 0].grid(True)
    axes[2, 0].set_ylim(0, 1)

# Evaluation metrics
if eval_metrics['eval_rewards']:
    eval_episodes = np.arange(0, len(eval_metrics['eval_rewards'])) * config['eval_frequency']
    axes[2, 1].plot(eval_episodes, eval_metrics['eval_rewards'], 'o-', color='blue', label='Reward')
    axes[2, 1].set_title('Evaluation Rewards')
    axes[2, 1].set_xlabel('Episode')
    axes[2, 1].set_ylabel('Reward')
    axes[2, 1].grid(True)
    axes[2, 1].legend()

# Evaluation safety metrics
if eval_metrics['eval_safety_violation_rate']:
    axes[2, 2].plot(eval_episodes, eval_metrics['eval_safety_violation_rate'], 'o-', color='red', label='Violation Rate')
    axes[2, 2].axhline(y=20, color='orange', linestyle='--', alpha=0.7, label='Warning (20%)')
    axes[2, 2].axhline(y=5, color='green', linestyle='--', alpha=0.7, label='Good (5%)')
    axes[2, 2].set_title('Evaluation Safety Violation Rate')
    axes[2, 2].set_xlabel('Episode')
    axes[2, 2].set_ylabel('Violation Rate (%)')
    axes[2, 2].grid(True)
    axes[2, 2].legend()
    axes[2, 2].set_ylim(0, 100)
else:
    axes[2, 2].text(0.5, 0.5, 'No Evaluation Data', ha='center', va='center', transform=axes[2, 2].transAxes)
    axes[2, 2].set_title('Evaluation Safety Violation Rate')

plt.tight_layout()
plt.savefig(f"{output_dir}/plots/training_results.png", dpi=300, bbox_inches='tight')
plt.show()

print(f"Plots saved to {output_dir}/plots/")
# Out:
# Plots saved to runs/sqrl_hcw_20250924_045707_SQRL_SafeGym/plots/

# %%
# Safety Analysis Report
print("=" * 60)
print("🔍 DETAILED SAFETY ANALYSIS REPORT")
print("=" * 60)

# Overall safety statistics
total_episodes = len(training_metrics['episode_rewards'])
total_violations = sum(training_metrics['safety_violations'])
overall_violation_rate = (total_violations / total_episodes) * 100 if total_episodes > 0 else 0

print(f"\n📊 OVERALL SAFETY STATISTICS:")
print(f"   Total Episodes: {total_episodes}")
print(f"   Total Safety Violations: {total_violations}")
print(f"   Overall Violation Rate: {overall_violation_rate:.2f}%")
print(f"   Episodes with Violations: {sum(1 for v in training_metrics['safety_violations'] if v > 0)}")
print(f"   Episodes without Violations: {sum(1 for v in training_metrics['safety_violations'] if v == 0)}")

# Safety trends
if len(training_metrics['safety_violations']) > 100:
    first_half = training_metrics['safety_violations'][:len(training_metrics['safety_violations'])//2]
    second_half = training_metrics['safety_violations'][len(training_metrics['safety_violations'])//2:]
    
    first_half_rate = (sum(1 for v in first_half if v > 0) / len(first_half)) * 100
    second_half_rate = (sum(1 for v in second_half if v > 0) / len(second_half)) * 100
    
    print(f"\n📈 SAFETY IMPROVEMENT TRENDS:")
    print(f"   First Half Violation Rate: {first_half_rate:.2f}%")
    print(f"   Second Half Violation Rate: {second_half_rate:.2f}%")
    improvement = first_half_rate - second_half_rate
    if improvement > 0:
        print(f"   ✅ Safety Improved by {improvement:.2f} percentage points")
    elif improvement < 0:
        print(f"   ⚠️  Safety Degraded by {abs(improvement):.2f} percentage points")
    else:
        print(f"   ➡️  Safety remained constant")

# Consecutive safe episodes analysis
max_consecutive = max(training_metrics['consecutive_safe_episodes']) if training_metrics['consecutive_safe_episodes'] else 0
current_consecutive = training_metrics['consecutive_safe_episodes'][-1] if training_metrics['consecutive_safe_episodes'] else 0

print(f"\n🏆 CONSECUTIVE SAFE EPISODES:")
print(f"   Maximum Consecutive Safe: {max_consecutive}")
print(f"   Current Consecutive Safe: {current_consecutive}")

# Violation type analysis
print(f"\n🔍 VIOLATION TYPE BREAKDOWN:")
for vtype, count in safety_stats['violation_types'].items():
    if count > 0:
        percentage = (count / total_violations) * 100 if total_violations > 0 else 0
        print(f"   {vtype}: {count} ({percentage:.1f}%)")

# Safety recommendations
print(f"\n💡 SAFETY RECOMMENDATIONS:")
if overall_violation_rate > 20:
    print("   ⚠️  HIGH VIOLATION RATE - Consider:")
    print("      • Reducing learning rate")
    print("      • Increasing safety penalty weights")
    print("      • Adding more safety constraints")
elif overall_violation_rate > 5:
    print("   ⚠️  MODERATE VIOLATION RATE - Consider:")
    print("      • Fine-tuning safety parameters")
    print("      • Increasing training episodes")
elif overall_violation_rate > 0:
    print("   ✅ LOW VIOLATION RATE - Good progress!")
    print("      • Continue current approach")
    print("      • Monitor for any degradation")
else:
    print("   🎉 PERFECT SAFETY RECORD!")
    print("      • Excellent training results")
    print("      • Consider testing on more challenging scenarios")

# Recent performance
if len(training_metrics['safety_violations']) >= 50:
    recent_episodes = training_metrics['safety_violations'][-50:]
    recent_violation_rate = (sum(1 for v in recent_episodes if v > 0) / len(recent_episodes)) * 100
    print(f"\n📊 RECENT PERFORMANCE (Last 50 Episodes):")
    print(f"   Recent Violation Rate: {recent_violation_rate:.2f}%")
    if recent_violation_rate < overall_violation_rate:
        print("   ✅ Recent performance is better than overall average")
    elif recent_violation_rate > overall_violation_rate:
        print("   ⚠️  Recent performance is worse than overall average")

print("\n" + "=" * 60)
# Out:
# ============================================================
# 🔍 DETAILED SAFETY ANALYSIS REPORT
# ============================================================
#
# 📊 OVERALL SAFETY STATISTICS:
#    Total Episodes: 20000
#    Total Safety Violations: 572
#    Overall Violation Rate: 2.86%
#    Episodes with Violations: 572
#    Episodes without Violations: 19428
#
# 📈 SAFETY IMPROVEMENT TRENDS:
#    First Half Violation Rate: 3.03%
#    Second Half Violation Rate: 2.69%
#    ✅ Safety Improved by 0.34 percentage points
#
# 🏆 CONSECUTIVE SAFE EPISODES:
#    Maximum Consecutive Safe: 1103
#    Current Consecutive Safe: 7
#
# 🔍 VIOLATION TYPE BREAKDOWN:
#    attitude_fail: 208 (36.4%)
#    velocity_fail: 254 (44.4%)
#    velocity_theta_fail: 110 (19.2%)
#
# 💡 SAFETY RECOMMENDATIONS:
#    ✅ LOW VIOLATION RATE - Good progress!
#       • Continue current approach
#       • Monitor for any degradation
#
# 📊 RECENT PERFORMANCE (Last 50 Episodes):
#    Recent Violation Rate: 6.00%
#    ⚠️  Recent performance is worse than overall average
#
# ============================================================

# %%
# Test trained agent
print("Testing trained agent...")

# Create test environment with rendering
test_env = HCWSE2Env(
    render_mode="human",  # Enable rendering for visualization
    spawn_radius=config['spawn_radius'],
    pos_limit=100.0,
    v_limit=10.0,
    theta_limit=0.5,
    omega_limit=0.5,
)

# Test episodes
test_episodes = 3
test_results = []

for test_ep in range(test_episodes):
    print(f"\nTest Episode {test_ep + 1}/{test_episodes}")
    
    obs, info = test_env.reset()
    test_reward = 0
    test_length = 0
    test_safety_violations = 0
    
    for step in range(config['max_steps_per_episode']):
        action = agent.select_action(obs)
        next_obs, reward, terminated, truncated, info = test_env.step(action)
        
        test_unsafe = compute_unsafe(info)
        if test_unsafe:
            test_safety_violations += 1
        
        test_reward += reward
        test_length += 1
        obs = next_obs
        
        if terminated or truncated:
            break
    
    test_results.append({
        'episode': test_ep + 1,
        'reward': test_reward,
        'length': test_length,
        'safety_violations': test_safety_violations,
        'success': test_safety_violations == 0
    })
    
    print(f"  Reward: {test_reward:.2f}")
    print(f"  Length: {test_length}")
    print(f"  Safety Violations: {test_safety_violations}")
    print(f"  Success: {test_safety_violations == 0}")

test_env.close()

# Summary
avg_test_reward = np.mean([r['reward'] for r in test_results])
avg_test_length = np.mean([r['length'] for r in test_results])
avg_test_safety_violations = np.mean([r['safety_violations'] for r in test_results])
test_success_rate = np.mean([r['success'] for r in test_results])

print(f"\nTest Results Summary:")
print(f"  Average Reward: {avg_test_reward:.2f}")
print(f"  Average Length: {avg_test_length:.1f}")
print(f"  Average Safety Violations: {avg_test_safety_violations:.1f}")
print(f"  Success Rate: {test_success_rate:.3f}")
# Out:
# Testing trained agent...
#
# Test Episode 1/3
#   Reward: -50.08
#   Length: 1
#   Safety Violations: 0
#   Success: True
#
# Test Episode 2/3
#   Reward: -50.06
#   Length: 1
#   Safety Violations: 0
#   Success: True
#
# Test Episode 3/3
#   Reward: -50.08
#   Length: 1
#   Safety Violations: 0
#   Success: True
#
# Test Results Summary:
#   Average Reward: -50.07
#   Average Length: 1.0
#   Average Safety Violations: 0.0
#   Success Rate: 1.000

# %%
# Save final results
final_results = {
    'config': config,
    'training_metrics': training_metrics,
    'eval_metrics': eval_metrics,
    'test_results': test_results,
    'final_stats': {
        'total_episodes': episode,
        'total_steps': total_steps,
        'final_avg_reward': np.mean(recent_rewards) if recent_rewards else 0,
        'final_success_rate': np.mean(training_metrics['success_rate'][-100:]) if training_metrics['success_rate'] else 0,
        'test_avg_reward': avg_test_reward,
        'test_success_rate': test_success_rate,
    }
}

# Save results
with open(f"{output_dir}/final_results.json", 'w') as f:
    # Convert numpy arrays to lists for JSON serialization
    def convert_numpy(obj):
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, dict):
            return {key: convert_numpy(value) for key, value in obj.items()}
        elif isinstance(obj, list):
            return [convert_numpy(item) for item in obj]
        else:
            return obj
    
    json.dump(convert_numpy(final_results), f, indent=2)

print(f"\nResults saved to {output_dir}/")
print(f"Final model saved to {output_dir}/models/")
print(f"Training plots saved to {output_dir}/plots/")
print(f"Logs saved to {output_dir}/logs/")

print("\nSQRL Training Complete!")
print("=" * 50)
# Out:
# Results saved to runs/sqrl_hcw_20250924_045707_SQRL_SafeGym/
# Final model saved to runs/sqrl_hcw_20250924_045707_SQRL_SafeGym/models/
# Training plots saved to runs/sqrl_hcw_20250924_045707_SQRL_SafeGym/plots/
# Logs saved to runs/sqrl_hcw_20250924_045707_SQRL_SafeGym/logs/
#
# SQRL Training Complete!
# ==================================================
