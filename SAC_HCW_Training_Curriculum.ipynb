# %% [markdown]
# # Soft Actor-Critic (SAC) for Satellite Rendezvous
#
# This notebook demonstrates training a Soft Actor-Critic (SAC) agent on the HCWSE2Env satellite rendezvous environment using the SafeGym package.
#
# ## Environment: HCWSE2Env
# - **State**: [x, y, vx, vy, theta, omega] - position, velocity, attitude
# - **Action**: [u_thrust, u_alpha] - thrust and rotational acceleration
# - **Dynamics**: Hill-Clohessy-Wiltshire (HCW) equations for relative motion
# - **Safety**: Position and velocity limits with safety constraints
#
# ## SAC Algorithm
# - **Actor-Critic**: Continuous control with entropy regularization
# - **Dual Critics**: Twin Q-networks for robust value estimation
# - **Entropy Tuning**: Automatic temperature parameter adjustment
# - **Off-policy Learning**: Experience replay with soft updates

# %%
# Import required libraries
import os
import sys
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from datetime import datetime
import json
from collections import deque

# Add project root to path
project_root = os.path.dirname(os.path.abspath('.'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Import SafeGym components
from SafeGym.safegym.models.sac import SACAgent
from SafeGym.safegym.models.replaybuffer.replaybuffer import ReplayBuffer
from envs.arpod_HCW import HCWSE2Env

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Training configuration
config = {
    # Environment parameters
    'env_name': 'HCWSE2Env',
    'spawn_radius': (5.0, 25.0),  # (min, max) spawn distance in meters
    'max_episodes': 20000,
    'max_steps_per_episode': 1000,
    'render_frequency': 100,  # Render every N episodes
    
    # SAC hyperparameters
    'gamma': 0.99,  # Discount factor for rewards
    'tau': 0.005,  # Soft update rate for target networks
    'alpha': 0.2,  # Entropy regularization coefficient
    
    # Learning rates
    'actor_lr': 3e-4,
    'critic_lr': 3e-4,
    'alpha_lr': 1e-4,
    
    # Training parameters
    'buffer_size': 1000000,
    'batch_size': 256,
    'gradient_steps': 1,
    'update_frequency': 1,  # Update every N steps
    'target_update_frequency': 1,  # Update target networks every N updates
    
    # Network architecture
    'actor_net_arch': [256, 256,64],
    'critic_net_arch': [256, 256,64],
    
    # Logging
    'log_frequency': 50,
    'save_frequency': 200,
    'eval_frequency': 100,
    'eval_episodes': 5,
}

print("Configuration:")
for key, value in config.items():
    print(f"  {key}: {value}")
# Out:
# Configuration:
#   env_name: HCWSE2Env
#   spawn_radius: (5.0, 25.0)
#   max_episodes: 20000
#   max_steps_per_episode: 1000
#   render_frequency: 100
#   gamma: 0.99
#   tau: 0.005
#   alpha: 0.2
#   actor_lr: 0.0003
#   critic_lr: 0.0003
#   alpha_lr: 0.0001
#   buffer_size: 1000000
#   batch_size: 256
#   gradient_steps: 1
#   update_frequency: 1
#   target_update_frequency: 1
#   actor_net_arch: [256, 256, 64]
#   critic_net_arch: [256, 256, 64]
#   log_frequency: 50
#   save_frequency: 200
#   eval_frequency: 100
#   eval_episodes: 5

# %%
# Curriculum scheduler - phases taken from SAC_training.ipynb spawn_radius schedule
curriculum_config = {
    'enabled': True,
    # milestones keyed by episode number - these mirror spawn_radius increases in SAC_training.ipynb
    'milestones': [
        {'episode': 1,    'spawn_radius': (2.5, 5.0)},
        {'episode': 250000//(config.get('max_steps_per_episode',1000)) , 'spawn_radius': (2.5, 10.0)},
        {'episode': 500000//(config.get('max_steps_per_episode',1000)) , 'spawn_radius': (2.5, 20.0)},
        {'episode': 1000000//(config.get('max_steps_per_episode',1000)) , 'spawn_radius': (2.5, 40.0)},
        {'episode': 2000000//(config.get('max_steps_per_episode',1000)) , 'spawn_radius': (2.5, 60.0)},
        {'episode': 3000000//(config.get('max_steps_per_episode',1000)) , 'spawn_radius': (2.5, 80.0)},
        {'episode': 4000000//(config.get('max_steps_per_episode',1000)) , 'spawn_radius': (2.5, 100.0)},
        # final stabilized phase
        {'episode': 5000000//(config.get('max_steps_per_episode',1000)) , 'spawn_radius': (10.0, 100.0)},
    ]
}

class CurriculumScheduler:
    def __init__(self, cfg):
        self.enabled = cfg.get('enabled', False)
        # sort by episode
        self.milestones = sorted(cfg.get('milestones', []), key=lambda m: m['episode'])
        self.current = None

    def step(self, episode):
        if not self.enabled or not self.milestones:
            return {}
        selected = None
        for m in self.milestones:
            if episode >= m['episode']:
                selected = m
            else:
                break
        if selected is None:
            return {}
        if selected != self.current:
            self.current = selected.copy()
            params = {k: v for k, v in selected.items() if k != 'episode'}
            return params
        return {}

def apply_curriculum_to_env(env, params):
    """Try to apply curriculum params to the env in-place. Returns True if applied."""
    if not params:
        return False
    applied = False
    if 'spawn_radius' in params:
        try:
            # many env instances expose spawn_radius on the unwrapped env
            if hasattr(env, 'envs'):
                for e in env.envs:
                    try:
                        setattr(e.unwrapped, 'spawn_radius', params['spawn_radius'])
                    except Exception:
                        try:
                            setattr(e, 'spawn_radius', params['spawn_radius'])
                        except Exception:
                            pass
            else:
                try:
                    setattr(env.unwrapped, 'spawn_radius', params['spawn_radius'])
                except Exception:
                    try:
                        setattr(env, 'spawn_radius', params['spawn_radius'])
                    except Exception:
                        pass
            applied = True
        except Exception:
            applied = False
    return applied

# instantiate scheduler
curriculum = CurriculumScheduler(curriculum_config)
print("Curriculum scheduler created. Enabled:", curriculum.enabled)
# Out:
# Curriculum scheduler created. Enabled: True

# %%
# Create output directories
run_spec = "SAC_SafeGym"
run_id = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"runs/sac_hcw_{run_id}_{run_spec}"
os.makedirs(output_dir, exist_ok=True)
os.makedirs(f"{output_dir}/models", exist_ok=True)
os.makedirs(f"{output_dir}/logs", exist_ok=True)
os.makedirs(f"{output_dir}/plots", exist_ok=True)

# Save configuration
with open(f"{output_dir}/config.json", 'w') as f:
    json.dump(config, f, indent=2)

print(f"Output directory: {output_dir}")
# Out:
# Output directory: runs/sac_hcw_20250924_045713_SAC_SafeGym

# %%
# Create environment
env = HCWSE2Env(
    render_mode=None,  # Set to "human" for visualization
    spawn_radius=config['spawn_radius'],
)

print(f"Environment created:")
print(f"  Observation space: {env.observation_space}")
print(f"  Action space: {env.action_space}")
print(f"  Max episode steps: {env.max_steps}")
print(f"  Spawn radius: {config['spawn_radius']}")
# Out:
# Environment created:
#   Observation space: Box([-500.        -500.         -50.         -50.          -3.1415927
#    -5.       ], [500.        500.         50.         50.          3.1415927   5.       ], (6,), float32)
#   Action space: Box([ 0. -1.], 1.0, (2,), float32)
#   Max episode steps: 3000
#   Spawn radius: (5.0, 25.0)

# %%
# Create SAC agent
agent = SACAgent(
    env=env,
    gamma=config['gamma'],
    tau=config['tau'],
    alpha=config['alpha'],
    actor_learning_rate=config['actor_lr'],
    critic_learning_rate=config['critic_lr'],
    buffer_size=config['buffer_size'],
    auto_entropy_tuning=True,
    gradient_steps=config['gradient_steps'],
    policy_kwargs={
        'actor_net_arch': config['actor_net_arch'],
        'critic_net_arch': config['critic_net_arch'],
    },
    alpha_learning_rate=config['alpha_lr'],
)

print(f"SAC Agent created:")
print(f"  Device: {agent.device}")
print(f"  Observation dim: {agent.obs_dim}")
print(f"  Action dim: {agent.action_dim}")
print(f"  Buffer size: {config['buffer_size']}")
print(f"  Auto entropy tuning: {agent.auto_entropy_tuning}")
# Out:
# SAC Agent created:
#   Device: cuda
#   Observation dim: 6
#   Action dim: 2
#   Buffer size: 1000000
#   Auto entropy tuning: True

# %%
# Training metrics tracking
training_metrics = {
    'episode_rewards': [],
    'episode_lengths': [],
    'safety_violations': [],
    'actor_losses': [],
    'critic_losses': [],
    'alpha_values': [],
    'success_rate': [],
    'avg_reward': [],
    'avg_length': [],
    'avg_safety_violations': [],
    'safety_violation_rate': [],  # Percentage of episodes with violations
    'consecutive_safe_episodes': [],  # Track consecutive safe episodes
    'safety_violation_types': [],  # Track types of violations
    'max_safety_violations_per_episode': [],  # Track worst episodes
}

# Evaluation metrics
eval_metrics = {
    'eval_rewards': [],
    'eval_lengths': [],
    'eval_safety_violations': [],
    'eval_success_rate': [],
    'eval_safety_violation_rate': [],
}

# Safety violation tracking
safety_stats = {
    'total_violations': 0,
    'total_episodes': 0,
    'consecutive_safe': 0,
    'max_consecutive_safe': 0,
    'violation_types': {
        'attitude_fail': 0,
        'velocity_fail': 0,
        'velocity_theta_fail': 0,
        'omega_fail': 0,
        'out_of_bounds': 0,
    }
}

print("Enhanced training metrics initialized with safety tracking")
# Out:
# Enhanced training metrics initialized with safety tracking

# %%
# Safety function - get unsafe signal from environment info
def compute_unsafe(info):
    """Extract unsafe signal from environment info dictionary."""
    return int(info.get("is_unsafe", 0))

print("Safety function defined - using is_unsafe from environment info")
# Out:
# Safety function defined - using is_unsafe from environment info

# %%
# Training loop
print("Starting SAC training...")
print(f"Training for {config['max_episodes']} episodes")
print(f"Max steps per episode: {config['max_steps_per_episode']}")
print(f"Update frequency: {config['update_frequency']}")
print("-" * 50)

episode = 0
total_steps = 0
recent_rewards = deque(maxlen=100)
recent_lengths = deque(maxlen=100)
recent_safety_violations = deque(maxlen=100)

while episode < config['max_episodes']:
    episode += 1
    
    # Apply curriculum for this episode (may modify env.spawn_radius)
    try:
        new_params = curriculum.step(episode) if 'curriculum' in globals() else {}
        if new_params:
            applied = apply_curriculum_to_env(env, new_params)
            if applied:
                print(f"[Curriculum] Episode {episode}: applied {new_params}")
            else:
                print(f"[Curriculum] Episode {episode}: could not apply in-place, please restart or re-create env with {new_params}")
    except Exception as e:
        print("[Curriculum] Error while applying curriculum:", e)

    # Reset environment
    obs, info = env.reset()
    episode_reward = 0
    episode_length = 0
    episode_safety_violations = 0
    
    # Episode loop
    for step in range(config['max_steps_per_episode']):
        total_steps += 1
        episode_length += 1
        
        # Select action
        action = agent.select_action(obs)
        
        # Take step
        next_obs, reward, terminated, truncated, info = env.step(action)
        
        # Get unsafe signal from environment info
        unsafe = compute_unsafe(info)
        
        if unsafe:
            episode_safety_violations += 1
        
        # Store transition in replay buffer
        agent.replay_buffer.push(
            state=obs,
            action=action,
            reward=reward,
            next_state=next_obs,
            terminated=terminated,
            truncated=truncated,
            unsafe=unsafe
        )
        
        episode_reward += reward
        obs = next_obs
        
        # Update agent
        if (total_steps % config['update_frequency'] == 0 and 
            len(agent.replay_buffer) >= config['batch_size']):
            
            # Train SAC agent
            agent.train(batch_size=config['batch_size'])
        
        # Check termination
        if terminated or truncated:
            break
    
    # Record episode metrics
    recent_rewards.append(episode_reward)
    recent_lengths.append(episode_length)
    recent_safety_violations.append(episode_safety_violations)
    
    training_metrics['episode_rewards'].append(episode_reward)
    training_metrics['episode_lengths'].append(episode_length)
    training_metrics['safety_violations'].append(episode_safety_violations)
    
    # Calculate success rate (episode completed without safety violations)
    success = episode_safety_violations == 0 and episode_length >= 10
    training_metrics['success_rate'].append(float(success))
    
    # Update safety statistics
    safety_stats['total_episodes'] += 1
    safety_stats['total_violations'] += episode_safety_violations
    
    if episode_safety_violations == 0:
        safety_stats['consecutive_safe'] += 1
        safety_stats['max_consecutive_safe'] = max(safety_stats['max_consecutive_safe'], safety_stats['consecutive_safe'])
    else:
        safety_stats['consecutive_safe'] = 0
        
    # Track violation types from the last info
    if 'done_reason' in info:
        violation_type = info['done_reason']
        if violation_type in safety_stats['violation_types']:
            safety_stats['violation_types'][violation_type] += 1
    
    # Record safety metrics
    training_metrics['consecutive_safe_episodes'].append(safety_stats['consecutive_safe'])
    training_metrics['max_safety_violations_per_episode'].append(max(training_metrics['safety_violations']) if training_metrics['safety_violations'] else 0)
    
    # Logging
    if episode % config['log_frequency'] == 0:
        avg_reward = np.mean(recent_rewards)
        avg_length = np.mean(recent_lengths)
        avg_safety_violations = np.mean(recent_safety_violations)
        success_rate = np.mean(training_metrics['success_rate'][-100:])
        
        # Calculate safety violation rate (percentage of episodes with violations)
        recent_episodes = min(100, len(training_metrics['safety_violations']))
        recent_violation_episodes = sum(1 for v in training_metrics['safety_violations'][-recent_episodes:] if v > 0)
        safety_violation_rate = (recent_violation_episodes / recent_episodes) * 100
        
        training_metrics['avg_reward'].append(avg_reward)
        training_metrics['avg_length'].append(avg_length)
        training_metrics['avg_safety_violations'].append(avg_safety_violations)
        training_metrics['safety_violation_rate'].append(safety_violation_rate)
        
        # Safety alert system
        safety_alert = ""
        if episode_safety_violations > 0:
            safety_alert = f" ⚠️  SAFETY VIOLATION! ({episode_safety_violations} violations)"
        elif safety_violation_rate > 20:
            safety_alert = f" ⚠️  HIGH VIOLATION RATE: {safety_violation_rate:.1f}%"
        elif safety_stats['consecutive_safe'] > 50:
            safety_alert = f" ✅ {safety_stats['consecutive_safe']} consecutive safe episodes!"
        
        print(f"Episode {episode:4d} | "
              f"Reward: {episode_reward:8.2f} | "
              f"Avg Reward: {avg_reward:8.2f} | "
              f"Length: {episode_length:4d} | "
              f"Safety Violations: {episode_safety_violations:2d} | "
              f"Success Rate: {success_rate:.3f} | "
              f"Violation Rate: {safety_violation_rate:5.1f}%{safety_alert}")
        
        # Additional safety statistics every 200 episodes
        if episode % 200 == 0:
            print(f"\n📊 SAFETY STATISTICS (Episodes 1-{episode}):")
            print(f"   Total Violations: {safety_stats['total_violations']}")
            print(f"   Violation Rate: {(safety_stats['total_violations']/safety_stats['total_episodes']*100):.2f}%")
            print(f"   Max Consecutive Safe: {safety_stats['max_consecutive_safe']}")
            print(f"   Current Consecutive Safe: {safety_stats['consecutive_safe']}")
            print(f"   Violation Types:")
            for vtype, count in safety_stats['violation_types'].items():
                if count > 0:
                    print(f"     {vtype}: {count}")
            print()
    
    # Save model
    if episode % config['save_frequency'] == 0:
        torch.save({
            'episode': episode,
            'agent_state_dict': {
                'actor': agent.actor.state_dict(),
                'critic1': agent.critic1.state_dict(),
                'critic2': agent.critic2.state_dict(),
            },
            'optimizer_state_dict': {
                'actor': agent.actor_optimizer.state_dict(),
                'critic1': agent.critic1_optimizer.state_dict(),
                'critic2': agent.critic2_optimizer.state_dict(),
            },
            'training_metrics': training_metrics,
        }, f"{output_dir}/models/agent_episode_{episode}.pth")
        
        # Save training metrics
        np.save(f"{output_dir}/logs/training_metrics.npy", training_metrics)
    
    # Evaluation
    if episode % config['eval_frequency'] == 0:
        eval_rewards = []
        eval_lengths = []
        eval_safety_violations = []
        eval_successes = []
        
        for eval_ep in range(config['eval_episodes']):
            eval_obs, eval_info = env.reset()
            eval_reward = 0
            eval_length = 0
            eval_safety_violations_ep = 0
            
            for _ in range(config['max_steps_per_episode']):
                eval_action = agent.select_action(eval_obs)
                eval_next_obs, eval_r, eval_term, eval_trunc, eval_info = env.step(eval_action)
                
                eval_unsafe = compute_unsafe(eval_info)
                if eval_unsafe:
                    eval_safety_violations_ep += 1
                
                eval_reward += eval_r
                eval_length += 1
                eval_obs = eval_next_obs
                
                if eval_term or eval_trunc:
                    break
            
            eval_rewards.append(eval_reward)
            eval_lengths.append(eval_length)
            eval_safety_violations.append(eval_safety_violations_ep)
            eval_successes.append(eval_safety_violations_ep == 0)
        
        eval_metrics['eval_rewards'].append(np.mean(eval_rewards))
        eval_metrics['eval_lengths'].append(np.mean(eval_lengths))
        eval_metrics['eval_safety_violations'].append(np.mean(eval_safety_violations))
        eval_metrics['eval_success_rate'].append(np.mean(eval_successes))
        
        # Calculate evaluation safety violation rate
        eval_violation_rate = (sum(1 for v in eval_safety_violations if v > 0) / len(eval_safety_violations)) * 100
        eval_metrics['eval_safety_violation_rate'].append(eval_violation_rate)
        
        # Safety status for evaluation
        eval_safety_status = ""
        if np.mean(eval_safety_violations) == 0:
            eval_safety_status = " ✅ ALL SAFE"
        elif eval_violation_rate > 50:
            eval_safety_status = " ⚠️  HIGH VIOLATIONS"
        else:
            eval_safety_status = " ⚠️  SOME VIOLATIONS"
        
        print(f"Evaluation | Avg Reward: {np.mean(eval_rewards):8.2f} | "
              f"Avg Length: {np.mean(eval_lengths):6.1f} | "
              f"Safety Violations: {np.mean(eval_safety_violations):6.1f} | "
              f"Success Rate: {np.mean(eval_successes):.3f} | "
              f"Violation Rate: {eval_violation_rate:5.1f}%{eval_safety_status}")

print("\nTraining completed!")
print(f"Total episodes: {episode}")
print(f"Total steps: {total_steps}")
print(f"Final average reward: {np.mean(recent_rewards):.2f}")
print(f"Final success rate: {np.mean(training_metrics['success_rate'][-100:]):.3f}")
# Out:
# Starting SAC training...
# Training for 20000 episodes
# Max steps per episode: 1000
# Update frequency: 1
# --------------------------------------------------
# [Curriculum] Episode 1: applied {'spawn_radius': (2.5, 5.0)}
# Episode   50 | Reward:  -421.84 | Avg Reward:  -409.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.680 | Violation Rate:  32.0% ⚠️  HIGH VIOLATION RATE: 32.0%
# Episode   50 | Reward:  -421.84 | Avg Reward:  -409.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.680 | Violation Rate:  32.0% ⚠️  HIGH VIOLATION RATE: 32.0%
# Episode  100 | Reward:   -53.97 | Avg Reward:  -213.38 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.660 | Violation Rate:  34.0% ⚠️  HIGH VIOLATION RATE: 34.0%
# Episode  100 | Reward:   -53.97 | Avg Reward:  -213.38 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.660 | Violation Rate:  34.0% ⚠️  HIGH VIOLATION RATE: 34.0%
# Evaluation | Avg Reward:   103.47 | Avg Length:  675.6 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:   103.47 | Avg Length:  675.6 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode  150 | Reward:    -9.57 | Avg Reward:     8.70 | Length:  564 | Safety Violations:  1 | Success Rate: 0.670 | Violation Rate:  33.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode  150 | Reward:    -9.57 | Avg Reward:     8.70 | Length:  564 | Safety Violations:  1 | Success Rate: 0.670 | Violation Rate:  33.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode  200 | Reward:    80.89 | Avg Reward:    32.88 | Length:  163 | Safety Violations:  0 | Success Rate: 0.730 | Violation Rate:  27.0% ⚠️  HIGH VIOLATION RATE: 27.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-200):
#    Total Violations: 61
#    Violation Rate: 30.50%
#    Max Consecutive Safe: 13
#    Current Consecutive Safe: 7
#    Violation Types:
#      attitude_fail: 27
#      velocity_fail: 21
#      velocity_theta_fail: 13
#
# Episode  200 | Reward:    80.89 | Avg Reward:    32.88 | Length:  163 | Safety Violations:  0 | Success Rate: 0.730 | Violation Rate:  27.0% ⚠️  HIGH VIOLATION RATE: 27.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-200):
#    Total Violations: 61
#    Violation Rate: 30.50%
#    Max Consecutive Safe: 13
#    Current Consecutive Safe: 7
#    Violation Types:
#      attitude_fail: 27
#      velocity_fail: 21
#      velocity_theta_fail: 13
#
# Evaluation | Avg Reward:    26.69 | Avg Length:  263.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    26.69 | Avg Length:  263.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# [Curriculum] Episode 250: applied {'spawn_radius': (2.5, 10.0)}
# [Curriculum] Episode 250: applied {'spawn_radius': (2.5, 10.0)}
# Episode  250 | Reward:   -39.89 | Avg Reward:    40.68 | Length:  203 | Safety Violations:  1 | Success Rate: 0.830 | Violation Rate:  17.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode  250 | Reward:   -39.89 | Avg Reward:    40.68 | Length:  203 | Safety Violations:  1 | Success Rate: 0.830 | Violation Rate:  17.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode  300 | Reward:    69.72 | Avg Reward:    46.37 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.830 | Violation Rate:  17.0%
# Episode  300 | Reward:    69.72 | Avg Reward:    46.37 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.830 | Violation Rate:  17.0%
# Evaluation | Avg Reward:    60.39 | Avg Length:  520.6 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    60.39 | Avg Length:  520.6 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode  350 | Reward:    97.67 | Avg Reward:    55.25 | Length:  648 | Safety Violations:  0 | Success Rate: 0.850 | Violation Rate:  15.0%
# Episode  350 | Reward:    97.67 | Avg Reward:    55.25 | Length:  648 | Safety Violations:  0 | Success Rate: 0.850 | Violation Rate:  15.0%
# Episode  400 | Reward:    61.09 | Avg Reward:    65.16 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-400):
#    Total Violations: 86
#    Violation Rate: 21.50%
#    Max Consecutive Safe: 23
#    Current Consecutive Safe: 12
#    Violation Types:
#      attitude_fail: 36
#      velocity_fail: 32
#      velocity_theta_fail: 18
#
# Episode  400 | Reward:    61.09 | Avg Reward:    65.16 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-400):
#    Total Violations: 86
#    Violation Rate: 21.50%
#    Max Consecutive Safe: 23
#    Current Consecutive Safe: 12
#    Violation Types:
#      attitude_fail: 36
#      velocity_fail: 32
#      velocity_theta_fail: 18
#
# Evaluation | Avg Reward:    72.03 | Avg Length:  638.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    72.03 | Avg Length:  638.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode  450 | Reward:   -13.91 | Avg Reward:    65.85 | Length:  465 | Safety Violations:  1 | Success Rate: 0.920 | Violation Rate:   8.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode  450 | Reward:   -13.91 | Avg Reward:    65.85 | Length:  465 | Safety Violations:  1 | Success Rate: 0.920 | Violation Rate:   8.0% ⚠️  SAFETY VIOLATION! (1 violations)
# [Curriculum] Episode 500: applied {'spawn_radius': (2.5, 20.0)}
# [Curriculum] Episode 500: applied {'spawn_radius': (2.5, 20.0)}
# Episode  500 | Reward:    79.09 | Avg Reward:    63.17 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode  500 | Reward:    79.09 | Avg Reward:    63.17 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Evaluation | Avg Reward:    68.22 | Avg Length:  478.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    68.22 | Avg Length:  478.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode  550 | Reward:    66.72 | Avg Reward:    56.03 | Length:  139 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode  550 | Reward:    66.72 | Avg Reward:    56.03 | Length:  139 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode  600 | Reward:    55.79 | Avg Reward:    61.56 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-600):
#    Total Violations: 98
#    Violation Rate: 16.33%
#    Max Consecutive Safe: 44
#    Current Consecutive Safe: 44
#    Violation Types:
#      attitude_fail: 41
#      velocity_fail: 38
#      velocity_theta_fail: 19
#
# Episode  600 | Reward:    55.79 | Avg Reward:    61.56 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-600):
#    Total Violations: 98
#    Violation Rate: 16.33%
#    Max Consecutive Safe: 44
#    Current Consecutive Safe: 44
#    Violation Types:
#      attitude_fail: 41
#      velocity_fail: 38
#      velocity_theta_fail: 19
#
# Evaluation | Avg Reward:    49.27 | Avg Length:  816.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    49.27 | Avg Length:  816.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode  650 | Reward:    78.55 | Avg Reward:    66.02 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode  650 | Reward:    78.55 | Avg Reward:    66.02 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode  700 | Reward:   122.99 | Avg Reward:    63.97 | Length:  898 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode  700 | Reward:   122.99 | Avg Reward:    63.97 | Length:  898 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Evaluation | Avg Reward:    83.26 | Avg Length:  502.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    83.26 | Avg Length:  502.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode  750 | Reward:    57.46 | Avg Reward:    56.31 | Length:  106 | Safety Violations:  0 | Success Rate: 0.860 | Violation Rate:  14.0%
# Episode  750 | Reward:    57.46 | Avg Reward:    56.31 | Length:  106 | Safety Violations:  0 | Success Rate: 0.860 | Violation Rate:  14.0%
# Episode  800 | Reward:   -39.96 | Avg Reward:    53.98 | Length:   81 | Safety Violations:  1 | Success Rate: 0.850 | Violation Rate:  15.0% ⚠️  SAFETY VIOLATION! (1 violations)
#
# 📊 SAFETY STATISTICS (Episodes 1-800):
#    Total Violations: 120
#    Violation Rate: 15.00%
#    Max Consecutive Safe: 48
#    Current Consecutive Safe: 0
#    Violation Types:
#      attitude_fail: 51
#      velocity_fail: 47
#      velocity_theta_fail: 22
#
# Episode  800 | Reward:   -39.96 | Avg Reward:    53.98 | Length:   81 | Safety Violations:  1 | Success Rate: 0.850 | Violation Rate:  15.0% ⚠️  SAFETY VIOLATION! (1 violations)
#
# 📊 SAFETY STATISTICS (Episodes 1-800):
#    Total Violations: 120
#    Violation Rate: 15.00%
#    Max Consecutive Safe: 48
#    Current Consecutive Safe: 0
#    Violation Types:
#      attitude_fail: 51
#      velocity_fail: 47
#      velocity_theta_fail: 22
#
# Evaluation | Avg Reward:    77.08 | Avg Length:  373.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    77.08 | Avg Length:  373.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode  850 | Reward:    77.65 | Avg Reward:    65.05 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode  850 | Reward:    77.65 | Avg Reward:    65.05 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode  900 | Reward:    62.57 | Avg Reward:    67.13 | Length:  167 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode  900 | Reward:    62.57 | Avg Reward:    67.13 | Length:  167 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Evaluation | Avg Reward:    60.00 | Avg Length:  117.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    60.00 | Avg Length:  117.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode  950 | Reward:   -36.76 | Avg Reward:    61.08 | Length:   99 | Safety Violations:  1 | Success Rate: 0.890 | Violation Rate:  11.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode  950 | Reward:   -36.76 | Avg Reward:    61.08 | Length:   99 | Safety Violations:  1 | Success Rate: 0.890 | Violation Rate:  11.0% ⚠️  SAFETY VIOLATION! (1 violations)
# [Curriculum] Episode 1000: applied {'spawn_radius': (2.5, 40.0)}
# [Curriculum] Episode 1000: applied {'spawn_radius': (2.5, 40.0)}
# Episode 1000 | Reward:    50.73 | Avg Reward:    58.37 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.870 | Violation Rate:  13.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1000):
#    Total Violations: 139
#    Violation Rate: 13.90%
#    Max Consecutive Safe: 48
#    Current Consecutive Safe: 3
#    Violation Types:
#      attitude_fail: 58
#      velocity_fail: 52
#      velocity_theta_fail: 29
#
# Episode 1000 | Reward:    50.73 | Avg Reward:    58.37 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.870 | Violation Rate:  13.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1000):
#    Total Violations: 139
#    Violation Rate: 13.90%
#    Max Consecutive Safe: 48
#    Current Consecutive Safe: 3
#    Violation Types:
#      attitude_fail: 58
#      velocity_fail: 52
#      velocity_theta_fail: 29
#
# Evaluation | Avg Reward:    83.70 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    83.70 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1050 | Reward:   133.13 | Avg Reward:    58.82 | Length:  941 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode 1050 | Reward:   133.13 | Avg Reward:    58.82 | Length:  941 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode 1100 | Reward:    87.93 | Avg Reward:    62.25 | Length:  493 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 1100 | Reward:    87.93 | Avg Reward:    62.25 | Length:  493 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Evaluation | Avg Reward:    74.42 | Avg Length:  830.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    74.42 | Avg Length:  830.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1150 | Reward:    94.58 | Avg Reward:    62.49 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 1150 | Reward:    94.58 | Avg Reward:    62.49 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 1200 | Reward:   -26.10 | Avg Reward:    63.03 | Length:  253 | Safety Violations:  1 | Success Rate: 0.940 | Violation Rate:   6.0% ⚠️  SAFETY VIOLATION! (1 violations)
#
# 📊 SAFETY STATISTICS (Episodes 1-1200):
#    Total Violations: 149
#    Violation Rate: 12.42%
#    Max Consecutive Safe: 59
#    Current Consecutive Safe: 0
#    Violation Types:
#      attitude_fail: 59
#      velocity_fail: 60
#      velocity_theta_fail: 30
#
# Episode 1200 | Reward:   -26.10 | Avg Reward:    63.03 | Length:  253 | Safety Violations:  1 | Success Rate: 0.940 | Violation Rate:   6.0% ⚠️  SAFETY VIOLATION! (1 violations)
#
# 📊 SAFETY STATISTICS (Episodes 1-1200):
#    Total Violations: 149
#    Violation Rate: 12.42%
#    Max Consecutive Safe: 59
#    Current Consecutive Safe: 0
#    Violation Types:
#      attitude_fail: 59
#      velocity_fail: 60
#      velocity_theta_fail: 30
#
# Evaluation | Avg Reward:    79.15 | Avg Length:  823.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    79.15 | Avg Length:  823.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1250 | Reward:    56.12 | Avg Reward:    69.51 | Length:  123 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 1250 | Reward:    56.12 | Avg Reward:    69.51 | Length:  123 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 1300 | Reward:    69.82 | Avg Reward:    72.15 | Length:  117 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 1300 | Reward:    69.82 | Avg Reward:    72.15 | Length:  117 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Evaluation | Avg Reward:    96.22 | Avg Length:  735.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    96.22 | Avg Length:  735.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1350 | Reward:    89.91 | Avg Reward:    73.81 | Length:  398 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 1350 | Reward:    89.91 | Avg Reward:    73.81 | Length:  398 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 1400 | Reward:    50.91 | Avg Reward:    68.59 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1400):
#    Total Violations: 157
#    Violation Rate: 11.21%
#    Max Consecutive Safe: 59
#    Current Consecutive Safe: 16
#    Violation Types:
#      attitude_fail: 63
#      velocity_fail: 64
#      velocity_theta_fail: 30
#
# Episode 1400 | Reward:    50.91 | Avg Reward:    68.59 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1400):
#    Total Violations: 157
#    Violation Rate: 11.21%
#    Max Consecutive Safe: 59
#    Current Consecutive Safe: 16
#    Violation Types:
#      attitude_fail: 63
#      velocity_fail: 64
#      velocity_theta_fail: 30
#
# Evaluation | Avg Reward:    65.03 | Avg Length:  823.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    65.03 | Avg Length:  823.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1450 | Reward:   -16.35 | Avg Reward:    39.40 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode 1450 | Reward:   -16.35 | Avg Reward:    39.40 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode 1500 | Reward:    69.98 | Avg Reward:    28.20 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode 1500 | Reward:    69.98 | Avg Reward:    28.20 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Evaluation | Avg Reward:    54.13 | Avg Length:  875.8 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    54.13 | Avg Length:  875.8 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode 1550 | Reward:    17.75 | Avg Reward:    47.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 1550 | Reward:    17.75 | Avg Reward:    47.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 1600 | Reward:    54.90 | Avg Reward:    49.17 | Length:   50 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1600):
#    Total Violations: 164
#    Violation Rate: 10.25%
#    Max Consecutive Safe: 59
#    Current Consecutive Safe: 33
#    Violation Types:
#      attitude_fail: 67
#      velocity_fail: 67
#      velocity_theta_fail: 30
#
# Episode 1600 | Reward:    54.90 | Avg Reward:    49.17 | Length:   50 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1600):
#    Total Violations: 164
#    Violation Rate: 10.25%
#    Max Consecutive Safe: 59
#    Current Consecutive Safe: 33
#    Violation Types:
#      attitude_fail: 67
#      velocity_fail: 67
#      velocity_theta_fail: 30
#
# Evaluation | Avg Reward:    41.67 | Avg Length:  867.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    41.67 | Avg Length:  867.4 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1650 | Reward:    68.96 | Avg Reward:    50.12 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 83 consecutive safe episodes!
# Episode 1650 | Reward:    68.96 | Avg Reward:    50.12 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 83 consecutive safe episodes!
# Episode 1700 | Reward:    43.33 | Avg Reward:    57.05 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 1700 | Reward:    43.33 | Avg Reward:    57.05 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Evaluation | Avg Reward:    75.96 | Avg Length:  929.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    75.96 | Avg Length:  929.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1750 | Reward:    68.83 | Avg Reward:    55.82 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode 1750 | Reward:    68.83 | Avg Reward:    55.82 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode 1800 | Reward:    53.86 | Avg Reward:    57.72 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1800):
#    Total Violations: 174
#    Violation Rate: 9.67%
#    Max Consecutive Safe: 89
#    Current Consecutive Safe: 11
#    Violation Types:
#      attitude_fail: 71
#      velocity_fail: 70
#      velocity_theta_fail: 33
#
# Episode 1800 | Reward:    53.86 | Avg Reward:    57.72 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-1800):
#    Total Violations: 174
#    Violation Rate: 9.67%
#    Max Consecutive Safe: 89
#    Current Consecutive Safe: 11
#    Violation Types:
#      attitude_fail: 71
#      velocity_fail: 70
#      velocity_theta_fail: 33
#
# Evaluation | Avg Reward:    70.67 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    70.67 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 1850 | Reward:    62.26 | Avg Reward:    55.41 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 61 consecutive safe episodes!
# Episode 1850 | Reward:    62.26 | Avg Reward:    55.41 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 61 consecutive safe episodes!
# Episode 1900 | Reward:    68.93 | Avg Reward:    48.50 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 111 consecutive safe episodes!
# Episode 1900 | Reward:    68.93 | Avg Reward:    48.50 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 111 consecutive safe episodes!
# Evaluation | Avg Reward:    53.66 | Avg Length:  934.2 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    53.66 | Avg Length:  934.2 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode 1950 | Reward:    63.09 | Avg Reward:    49.53 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 1950 | Reward:    63.09 | Avg Reward:    49.53 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# [Curriculum] Episode 2000: applied {'spawn_radius': (2.5, 60.0)}
# [Curriculum] Episode 2000: applied {'spawn_radius': (2.5, 60.0)}
# Episode 2000 | Reward:    65.01 | Avg Reward:    56.76 | Length:  124 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2000):
#    Total Violations: 181
#    Violation Rate: 9.05%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 17
#    Violation Types:
#      attitude_fail: 71
#      velocity_fail: 75
#      velocity_theta_fail: 35
#
# Episode 2000 | Reward:    65.01 | Avg Reward:    56.76 | Length:  124 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2000):
#    Total Violations: 181
#    Violation Rate: 9.05%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 17
#    Violation Types:
#      attitude_fail: 71
#      velocity_fail: 75
#      velocity_theta_fail: 35
#
# Evaluation | Avg Reward:    13.26 | Avg Length:  492.2 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    13.26 | Avg Length:  492.2 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode 2050 | Reward:    73.76 | Avg Reward:    49.52 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.900 | Violation Rate:  10.0%
# Episode 2050 | Reward:    73.76 | Avg Reward:    49.52 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.900 | Violation Rate:  10.0%
# Episode 2100 | Reward:    64.55 | Avg Reward:    39.75 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.900 | Violation Rate:  10.0%
# Episode 2100 | Reward:    64.55 | Avg Reward:    39.75 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.900 | Violation Rate:  10.0%
# Evaluation | Avg Reward:    36.66 | Avg Length:  835.8 | Safety Violations:    0.4 | Success Rate: 0.600 | Violation Rate:  40.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    36.66 | Avg Length:  835.8 | Safety Violations:    0.4 | Success Rate: 0.600 | Violation Rate:  40.0% ⚠️  SOME VIOLATIONS
# Episode 2150 | Reward:    64.90 | Avg Reward:    47.30 | Length:  158 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 2150 | Reward:    64.90 | Avg Reward:    47.30 | Length:  158 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 2200 | Reward:   100.88 | Avg Reward:    48.58 | Length:  617 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2200):
#    Total Violations: 199
#    Violation Rate: 9.05%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 9
#    Violation Types:
#      attitude_fail: 75
#      velocity_fail: 87
#      velocity_theta_fail: 37
#
# Episode 2200 | Reward:   100.88 | Avg Reward:    48.58 | Length:  617 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2200):
#    Total Violations: 199
#    Violation Rate: 9.05%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 9
#    Violation Types:
#      attitude_fail: 75
#      velocity_fail: 87
#      velocity_theta_fail: 37
#
# Evaluation | Avg Reward:    35.12 | Avg Length:  650.8 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    35.12 | Avg Length:  650.8 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode 2250 | Reward:    59.14 | Avg Reward:    44.61 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.850 | Violation Rate:  15.0%
# Episode 2250 | Reward:    59.14 | Avg Reward:    44.61 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.850 | Violation Rate:  15.0%
# Episode 2300 | Reward:   -42.85 | Avg Reward:    47.61 | Length:  100 | Safety Violations:  1 | Success Rate: 0.860 | Violation Rate:  14.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode 2300 | Reward:   -42.85 | Avg Reward:    47.61 | Length:  100 | Safety Violations:  1 | Success Rate: 0.860 | Violation Rate:  14.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Evaluation | Avg Reward:    62.73 | Avg Length:  824.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    62.73 | Avg Length:  824.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2350 | Reward:    70.88 | Avg Reward:    52.32 | Length:  235 | Safety Violations:  0 | Success Rate: 0.880 | Violation Rate:  12.0%
# Episode 2350 | Reward:    70.88 | Avg Reward:    52.32 | Length:  235 | Safety Violations:  0 | Success Rate: 0.880 | Violation Rate:  12.0%
# Episode 2400 | Reward:    72.38 | Avg Reward:    57.86 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.890 | Violation Rate:  11.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2400):
#    Total Violations: 224
#    Violation Rate: 9.33%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 9
#    Violation Types:
#      attitude_fail: 82
#      velocity_fail: 103
#      velocity_theta_fail: 39
#
# Episode 2400 | Reward:    72.38 | Avg Reward:    57.86 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.890 | Violation Rate:  11.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2400):
#    Total Violations: 224
#    Violation Rate: 9.33%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 9
#    Violation Types:
#      attitude_fail: 82
#      velocity_fail: 103
#      velocity_theta_fail: 39
#
# Evaluation | Avg Reward:    61.08 | Avg Length:  649.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    61.08 | Avg Length:  649.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2450 | Reward:    86.97 | Avg Reward:    60.37 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode 2450 | Reward:    86.97 | Avg Reward:    60.37 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode 2500 | Reward:    64.97 | Avg Reward:    59.46 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
# Episode 2500 | Reward:    64.97 | Avg Reward:    59.46 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
# Evaluation | Avg Reward:    62.10 | Avg Length:  834.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    62.10 | Avg Length:  834.8 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2550 | Reward:    67.52 | Avg Reward:    54.64 | Length:   90 | Safety Violations:  0 | Success Rate: 0.890 | Violation Rate:  11.0%
# Episode 2550 | Reward:    67.52 | Avg Reward:    54.64 | Length:   90 | Safety Violations:  0 | Success Rate: 0.890 | Violation Rate:  11.0%
# Episode 2600 | Reward:    65.47 | Avg Reward:    53.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2600):
#    Total Violations: 242
#    Violation Rate: 9.31%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 1
#    Violation Types:
#      attitude_fail: 86
#      velocity_fail: 116
#      velocity_theta_fail: 40
#
# Episode 2600 | Reward:    65.47 | Avg Reward:    53.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2600):
#    Total Violations: 242
#    Violation Rate: 9.31%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 1
#    Violation Types:
#      attitude_fail: 86
#      velocity_fail: 116
#      velocity_theta_fail: 40
#
# Evaluation | Avg Reward:    45.62 | Avg Length:  835.6 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    45.62 | Avg Length:  835.6 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode 2650 | Reward:    69.87 | Avg Reward:    63.49 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 2650 | Reward:    69.87 | Avg Reward:    63.49 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 2700 | Reward:    55.83 | Avg Reward:    64.42 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 2700 | Reward:    55.83 | Avg Reward:    64.42 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Evaluation | Avg Reward:    64.00 | Avg Length:  650.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    64.00 | Avg Length:  650.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2750 | Reward:    55.59 | Avg Reward:    58.74 | Length:  156 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 2750 | Reward:    55.59 | Avg Reward:    58.74 | Length:  156 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 2800 | Reward:    68.73 | Avg Reward:    54.40 | Length:  198 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2800):
#    Total Violations: 252
#    Violation Rate: 9.00%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 8
#    Violation Types:
#      attitude_fail: 87
#      velocity_fail: 125
#      velocity_theta_fail: 40
#
# Episode 2800 | Reward:    68.73 | Avg Reward:    54.40 | Length:  198 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-2800):
#    Total Violations: 252
#    Violation Rate: 9.00%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 8
#    Violation Types:
#      attitude_fail: 87
#      velocity_fail: 125
#      velocity_theta_fail: 40
#
# Evaluation | Avg Reward:    50.91 | Avg Length:  535.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    50.91 | Avg Length:  535.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode 2850 | Reward:    54.85 | Avg Reward:    49.69 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode 2850 | Reward:    54.85 | Avg Reward:    49.69 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode 2900 | Reward:    61.30 | Avg Reward:    49.00 | Length:  157 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode 2900 | Reward:    61.30 | Avg Reward:    49.00 | Length:  157 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Evaluation | Avg Reward:    33.16 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    33.16 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 2950 | Reward:    57.69 | Avg Reward:    47.47 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.880 | Violation Rate:  12.0%
# Episode 2950 | Reward:    57.69 | Avg Reward:    47.47 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.880 | Violation Rate:  12.0%
# [Curriculum] Episode 3000: applied {'spawn_radius': (2.5, 80.0)}
# [Curriculum] Episode 3000: applied {'spawn_radius': (2.5, 80.0)}
# Episode 3000 | Reward:    83.98 | Avg Reward:    56.70 | Length:  561 | Safety Violations:  0 | Success Rate: 0.870 | Violation Rate:  13.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3000):
#    Total Violations: 272
#    Violation Rate: 9.07%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 13
#    Violation Types:
#      attitude_fail: 91
#      velocity_fail: 140
#      velocity_theta_fail: 41
#
# Episode 3000 | Reward:    83.98 | Avg Reward:    56.70 | Length:  561 | Safety Violations:  0 | Success Rate: 0.870 | Violation Rate:  13.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3000):
#    Total Violations: 272
#    Violation Rate: 9.07%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 13
#    Violation Types:
#      attitude_fail: 91
#      velocity_fail: 140
#      velocity_theta_fail: 41
#
# Evaluation | Avg Reward:    58.44 | Avg Length:  828.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    58.44 | Avg Length:  828.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3050 | Reward:   116.07 | Avg Reward:    63.27 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
# Episode 3050 | Reward:   116.07 | Avg Reward:    63.27 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
# Episode 3100 | Reward:   156.11 | Avg Reward:    68.52 | Length:  885 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode 3100 | Reward:   156.11 | Avg Reward:    68.52 | Length:  885 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Evaluation | Avg Reward:    41.63 | Avg Length:  826.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    41.63 | Avg Length:  826.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode 3150 | Reward:    58.12 | Avg Reward:    72.95 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 3150 | Reward:    58.12 | Avg Reward:    72.95 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 3200 | Reward:    47.06 | Avg Reward:    75.38 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3200):
#    Total Violations: 285
#    Violation Rate: 8.91%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 10
#    Violation Types:
#      attitude_fail: 93
#      velocity_fail: 149
#      velocity_theta_fail: 43
#
# Episode 3200 | Reward:    47.06 | Avg Reward:    75.38 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3200):
#    Total Violations: 285
#    Violation Rate: 8.91%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 10
#    Violation Types:
#      attitude_fail: 93
#      velocity_fail: 149
#      velocity_theta_fail: 43
#
# Evaluation | Avg Reward:    60.34 | Avg Length:  670.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    60.34 | Avg Length:  670.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3250 | Reward:    59.73 | Avg Reward:    69.27 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 3250 | Reward:    59.73 | Avg Reward:    69.27 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 3300 | Reward:   144.33 | Avg Reward:    56.97 | Length:  718 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode 3300 | Reward:   144.33 | Avg Reward:    56.97 | Length:  718 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Evaluation | Avg Reward:    75.56 | Avg Length:  421.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    75.56 | Avg Length:  421.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3350 | Reward:    58.29 | Avg Reward:    62.06 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 86 consecutive safe episodes!
# Episode 3350 | Reward:    58.29 | Avg Reward:    62.06 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 86 consecutive safe episodes!
# Episode 3400 | Reward:    69.95 | Avg Reward:    68.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3400):
#    Total Violations: 293
#    Violation Rate: 8.62%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 33
#    Violation Types:
#      attitude_fail: 96
#      velocity_fail: 153
#      velocity_theta_fail: 44
#
# Episode 3400 | Reward:    69.95 | Avg Reward:    68.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3400):
#    Total Violations: 293
#    Violation Rate: 8.62%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 33
#    Violation Types:
#      attitude_fail: 96
#      velocity_fail: 153
#      velocity_theta_fail: 44
#
# Evaluation | Avg Reward:    67.63 | Avg Length:  850.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    67.63 | Avg Length:  850.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3450 | Reward:   -48.51 | Avg Reward:    70.84 | Length:   67 | Safety Violations:  1 | Success Rate: 0.940 | Violation Rate:   6.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode 3450 | Reward:   -48.51 | Avg Reward:    70.84 | Length:   67 | Safety Violations:  1 | Success Rate: 0.940 | Violation Rate:   6.0% ⚠️  SAFETY VIOLATION! (1 violations)
# Episode 3500 | Reward:   115.71 | Avg Reward:    68.90 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 3500 | Reward:   115.71 | Avg Reward:    68.90 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Evaluation | Avg Reward:    56.70 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    56.70 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3550 | Reward:    59.08 | Avg Reward:    67.82 | Length:  130 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
# Episode 3550 | Reward:    59.08 | Avg Reward:    67.82 | Length:  130 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
# Episode 3600 | Reward:    71.66 | Avg Reward:    68.71 | Length:  197 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3600):
#    Total Violations: 307
#    Violation Rate: 8.53%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 13
#    Violation Types:
#      attitude_fail: 98
#      velocity_fail: 160
#      velocity_theta_fail: 49
#
# Episode 3600 | Reward:    71.66 | Avg Reward:    68.71 | Length:  197 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3600):
#    Total Violations: 307
#    Violation Rate: 8.53%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 13
#    Violation Types:
#      attitude_fail: 98
#      velocity_fail: 160
#      velocity_theta_fail: 49
#
# Evaluation | Avg Reward:    66.74 | Avg Length:  823.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    66.74 | Avg Length:  823.2 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3650 | Reward:    80.85 | Avg Reward:    62.86 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode 3650 | Reward:    80.85 | Avg Reward:    62.86 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.930 | Violation Rate:   7.0%
# Episode 3700 | Reward:    59.07 | Avg Reward:    65.66 | Length:  138 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Episode 3700 | Reward:    59.07 | Avg Reward:    65.66 | Length:  138 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
# Evaluation | Avg Reward:    46.87 | Avg Length:  499.0 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:    46.87 | Avg Length:  499.0 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode 3750 | Reward:    60.99 | Avg Reward:    68.73 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
# Episode 3750 | Reward:    60.99 | Avg Reward:    68.73 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.910 | Violation Rate:   9.0%
# Episode 3800 | Reward:    90.60 | Avg Reward:    63.72 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.890 | Violation Rate:  11.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3800):
#    Total Violations: 326
#    Violation Rate: 8.58%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 15
#    Violation Types:
#      attitude_fail: 100
#      velocity_fail: 177
#      velocity_theta_fail: 49
#
# Episode 3800 | Reward:    90.60 | Avg Reward:    63.72 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.890 | Violation Rate:  11.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-3800):
#    Total Violations: 326
#    Violation Rate: 8.58%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 15
#    Violation Types:
#      attitude_fail: 100
#      velocity_fail: 177
#      velocity_theta_fail: 49
#
# Evaluation | Avg Reward:    80.10 | Avg Length:  822.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    80.10 | Avg Length:  822.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3850 | Reward:    66.68 | Avg Reward:    72.89 | Length:  157 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 3850 | Reward:    66.68 | Avg Reward:    72.89 | Length:  157 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 3900 | Reward:    67.90 | Avg Reward:    73.47 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Episode 3900 | Reward:    67.90 | Avg Reward:    73.47 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.940 | Violation Rate:   6.0%
# Evaluation | Avg Reward:    69.96 | Avg Length:  859.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    69.96 | Avg Length:  859.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 3950 | Reward:    61.16 | Avg Reward:    62.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.890 | Violation Rate:  11.0%
# Episode 3950 | Reward:    61.16 | Avg Reward:    62.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.890 | Violation Rate:  11.0%
# [Curriculum] Episode 4000: applied {'spawn_radius': (2.5, 100.0)}
# [Curriculum] Episode 4000: applied {'spawn_radius': (2.5, 100.0)}
# Episode 4000 | Reward:    61.59 | Avg Reward:    63.71 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-4000):
#    Total Violations: 340
#    Violation Rate: 8.50%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 29
#    Violation Types:
#      attitude_fail: 102
#      velocity_fail: 189
#      velocity_theta_fail: 49
#
# Episode 4000 | Reward:    61.59 | Avg Reward:    63.71 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.920 | Violation Rate:   8.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-4000):
#    Total Violations: 340
#    Violation Rate: 8.50%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 29
#    Violation Types:
#      attitude_fail: 102
#      velocity_fail: 189
#      velocity_theta_fail: 49
#
# Evaluation | Avg Reward:    61.04 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    61.04 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 4050 | Reward:    61.66 | Avg Reward:    64.81 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 4050 | Reward:    61.66 | Avg Reward:    64.81 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.970 | Violation Rate:   3.0%
# Episode 4100 | Reward:    58.02 | Avg Reward:    66.24 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Episode 4100 | Reward:    58.02 | Avg Reward:    66.24 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.960 | Violation Rate:   4.0%
# Evaluation | Avg Reward:    63.89 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    63.89 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 4150 | Reward:    51.63 | Avg Reward:    64.96 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode 4150 | Reward:    51.63 | Avg Reward:    64.96 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
# Episode 4200 | Reward:    63.35 | Avg Reward:    64.95 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-4200):
#    Total Violations: 349
#    Violation Rate: 8.31%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 4
#    Violation Types:
#      attitude_fail: 106
#      velocity_fail: 192
#      velocity_theta_fail: 51
#
# Episode 4200 | Reward:    63.35 | Avg Reward:    64.95 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.950 | Violation Rate:   5.0%
#
# 📊 SAFETY STATISTICS (Episodes 1-4200):
#    Total Violations: 349
#    Violation Rate: 8.31%
#    Max Consecutive Safe: 127
#    Current Consecutive Safe: 4
#    Violation Types:
#      attitude_fail: 106
#      velocity_fail: 192
#      velocity_theta_fail: 51
#
# Evaluation | Avg Reward:    62.12 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# ...
#
# 📊 SAFETY STATISTICS (Episodes 1-17800):
#    Total Violations: 455
#    Violation Rate: 2.56%
#    Max Consecutive Safe: 5249
#    Current Consecutive Safe: 5249
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 237
#      velocity_theta_fail: 89
#
# Episode 17800 | Reward:    31.71 | Avg Reward:    13.94 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5249 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-17800):
#    Total Violations: 455
#    Violation Rate: 2.56%
#    Max Consecutive Safe: 5249
#    Current Consecutive Safe: 5249
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 237
#      velocity_theta_fail: 89
#
# Evaluation | Avg Reward:   -77.81 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:   -77.81 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 17850 | Reward:    37.81 | Avg Reward:    17.21 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5299 consecutive safe episodes!
# Episode 17850 | Reward:    37.81 | Avg Reward:    17.21 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5299 consecutive safe episodes!
# Episode 17900 | Reward:   -12.54 | Avg Reward:    20.37 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5349 consecutive safe episodes!
# Episode 17900 | Reward:   -12.54 | Avg Reward:    20.37 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5349 consecutive safe episodes!
# Evaluation | Avg Reward:     0.97 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:     0.97 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 17950 | Reward:    -1.79 | Avg Reward:    15.31 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5399 consecutive safe episodes!
# Episode 17950 | Reward:    -1.79 | Avg Reward:    15.31 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5399 consecutive safe episodes!
# Episode 18000 | Reward:     2.46 | Avg Reward:     9.53 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5449 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-18000):
#    Total Violations: 455
#    Violation Rate: 2.53%
#    Max Consecutive Safe: 5449
#    Current Consecutive Safe: 5449
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 237
#      velocity_theta_fail: 89
#
# Episode 18000 | Reward:     2.46 | Avg Reward:     9.53 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5449 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-18000):
#    Total Violations: 455
#    Violation Rate: 2.53%
#    Max Consecutive Safe: 5449
#    Current Consecutive Safe: 5449
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 237
#      velocity_theta_fail: 89
#
# Evaluation | Avg Reward:    33.98 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    33.98 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 18050 | Reward:  -250.61 | Avg Reward:    12.97 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5499 consecutive safe episodes!
# Episode 18050 | Reward:  -250.61 | Avg Reward:    12.97 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5499 consecutive safe episodes!
# Episode 18100 | Reward:    39.23 | Avg Reward:    14.46 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5549 consecutive safe episodes!
# Episode 18100 | Reward:    39.23 | Avg Reward:    14.46 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5549 consecutive safe episodes!
# Evaluation | Avg Reward:    24.71 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    24.71 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 18150 | Reward:   -23.09 | Avg Reward:   -19.16 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5599 consecutive safe episodes!
# Episode 18150 | Reward:   -23.09 | Avg Reward:   -19.16 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5599 consecutive safe episodes!
# Episode 18200 | Reward:   -48.74 | Avg Reward:   -23.35 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5649 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-18200):
#    Total Violations: 455
#    Violation Rate: 2.50%
#    Max Consecutive Safe: 5649
#    Current Consecutive Safe: 5649
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 237
#      velocity_theta_fail: 89
#
# Episode 18200 | Reward:   -48.74 | Avg Reward:   -23.35 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5649 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-18200):
#    Total Violations: 455
#    Violation Rate: 2.50%
#    Max Consecutive Safe: 5649
#    Current Consecutive Safe: 5649
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 237
#      velocity_theta_fail: 89
#
# Evaluation | Avg Reward:    32.62 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    32.62 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 18250 | Reward:    42.85 | Avg Reward:    15.17 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5699 consecutive safe episodes!
# Episode 18250 | Reward:    42.85 | Avg Reward:    15.17 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5699 consecutive safe episodes!
# Episode 18300 | Reward:    39.76 | Avg Reward:    28.51 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5749 consecutive safe episodes!
# Episode 18300 | Reward:    39.76 | Avg Reward:    28.51 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5749 consecutive safe episodes!
# Evaluation | Avg Reward:    23.94 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    23.94 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 18350 | Reward: -2455.34 | Avg Reward:    -0.34 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5799 consecutive safe episodes!
# Episode 18350 | Reward: -2455.34 | Avg Reward:    -0.34 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5799 consecutive safe episodes!
# Episode 18400 | Reward:  -589.77 | Avg Reward:  -704.42 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5849 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-18400):
#    Total Violations: 455
#    Violation Rate: 2.47%
#    Max Consecutive Safe: 5849
#    Current Consecutive Safe: 5849
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 237
#      velocity_theta_fail: 89
#      omega_fail: 5
#
# Episode 18400 | Reward:  -589.77 | Avg Reward:  -704.42 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5849 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-18400):
#    Total Violations: 455
#    Violation Rate: 2.47%
#    Max Consecutive Safe: 5849
#    Current Consecutive Safe: 5849
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 237
#      velocity_theta_fail: 89
#      omega_fail: 5
#
# Evaluation | Avg Reward:    22.47 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:    22.47 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 18450 | Reward:    22.37 | Avg Reward:  -742.00 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5899 consecutive safe episodes!
# Episode 18450 | Reward:    22.37 | Avg Reward:  -742.00 | Length: 1000 | Safety Violations:  0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ 5899 consecutive safe episodes!
# Episode 18500 | Reward:   -65.57 | Avg Reward:  -191.24 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 18500 | Reward:   -65.57 | Avg Reward:  -191.24 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Evaluation | Avg Reward:  -361.50 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:  -361.50 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 18550 | Reward:  -389.04 | Avg Reward:  -369.93 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 18550 | Reward:  -389.04 | Avg Reward:  -369.93 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 18600 | Reward:  -702.07 | Avg Reward:  -509.34 | Length:  889 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 81 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-18600):
#    Total Violations: 457
#    Violation Rate: 2.46%
#    Max Consecutive Safe: 5945
#    Current Consecutive Safe: 81
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 238
#      velocity_theta_fail: 90
#      omega_fail: 5
#      out_of_bounds: 24
#
# Episode 18600 | Reward:  -702.07 | Avg Reward:  -509.34 | Length:  889 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 81 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-18600):
#    Total Violations: 457
#    Violation Rate: 2.46%
#    Max Consecutive Safe: 5945
#    Current Consecutive Safe: 81
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 238
#      velocity_theta_fail: 90
#      omega_fail: 5
#      out_of_bounds: 24
#
# Evaluation | Avg Reward:  -421.85 | Avg Length:  821.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Evaluation | Avg Reward:  -421.85 | Avg Length:  821.4 | Safety Violations:    0.2 | Success Rate: 0.800 | Violation Rate:  20.0% ⚠️  SOME VIOLATIONS
# Episode 18650 | Reward:  -599.85 | Avg Reward:  -519.10 | Length:  814 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 18650 | Reward:  -599.85 | Avg Reward:  -519.10 | Length:  814 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0%
# Episode 18700 | Reward:  -581.33 | Avg Reward:  -493.49 | Length:  785 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 86 consecutive safe episodes!
# Episode 18700 | Reward:  -581.33 | Avg Reward:  -493.49 | Length:  785 | Safety Violations:  0 | Success Rate: 0.980 | Violation Rate:   2.0% ✅ 86 consecutive safe episodes!
# Evaluation | Avg Reward:  -452.02 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:  -452.02 | Avg Length: 1000.0 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 18750 | Reward:  -547.54 | Avg Reward:  -489.26 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 18750 | Reward:  -547.54 | Avg Reward:  -489.26 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 18800 | Reward:  -349.98 | Avg Reward:  -419.59 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 81 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-18800):
#    Total Violations: 460
#    Violation Rate: 2.45%
#    Max Consecutive Safe: 5945
#    Current Consecutive Safe: 81
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 238
#      velocity_theta_fail: 93
#      omega_fail: 5
#      out_of_bounds: 81
#
# Episode 18800 | Reward:  -349.98 | Avg Reward:  -419.59 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0% ✅ 81 consecutive safe episodes!
#
# 📊 SAFETY STATISTICS (Episodes 1-18800):
#    Total Violations: 460
#    Violation Rate: 2.45%
#    Max Consecutive Safe: 5945
#    Current Consecutive Safe: 81
#    Violation Types:
#      attitude_fail: 129
#      velocity_fail: 238
#      velocity_theta_fail: 93
#      omega_fail: 5
#      out_of_bounds: 81
#
# Evaluation | Avg Reward:  -435.68 | Avg Length:  947.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Evaluation | Avg Reward:  -435.68 | Avg Length:  947.6 | Safety Violations:    0.0 | Success Rate: 1.000 | Violation Rate:   0.0% ✅ ALL SAFE
# Episode 18850 | Reward:  -491.82 | Avg Reward:  -346.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# Episode 18850 | Reward:  -491.82 | Avg Reward:  -346.77 | Length: 1000 | Safety Violations:  0 | Success Rate: 0.990 | Violation Rate:   1.0%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 41
#      38 episode_length += 1
#      40 # Select action
# ---> 41 action = agent.select_action(obs)
#      43 # Take step
#      44 next_obs, reward, terminated, truncated, info = env.step(action)
#
# File ~/Projects/IAC/CleanArpod/SafeGym/safegym/models/sac.py:95, in SACAgent.select_action(self, state)
#      93 def select_action(self, state):
#      94     state = torch.FloatTensor(state).to(self.device).unsqueeze(0)
# ---> 95     action, _ = self.actor.sample(state=state)
#      96     action = action.cpu().detach().numpy()
#      97     return action[0]
#
# File ~/Projects/IAC/CleanArpod/SafeGym/safegym/models/nets/nets.py:119, in Actor.sample(self, state, deterministic)
#     116     single_sample = False
#     118 mean, std = self.forward(state)
# --> 119 normal = torch.distributions.Normal(
#     120     mean, std
#     121 )  # create a normal distribution
#     122 z = normal.rsample()  # sample an action around the mean
#     123 action = torch.tanh(
#     124     z
#     125 )  # restrict action space, needed for pendulum[-1,1]
#
# File ~/.local/lib/python3.12/site-packages/torch/distributions/normal.py:57, in Normal.__init__(self, loc, scale, validate_args)
#      55 else:
#      56     batch_shape = self.loc.size()
# ---> 57 super().__init__(batch_shape, validate_args=validate_args)
#
# File ~/.local/lib/python3.12/site-packages/torch/distributions/distribution.py:70, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      68         valid = constraint.check(value)
#      69         if not valid.all():
# ---> 70             raise ValueError(
#      71                 f"Expected parameter {param} "
#      72                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      73                 f"of distribution {repr(self)} "
#      74                 f"to satisfy the constraint {repr(constraint)}, "
#      75                 f"but found invalid values:\n{value}"
#      76             )
#      77 super().__init__()
#
# ValueError: Expected parameter scale (Tensor of shape (1, 2)) of distribution Normal(loc: torch.Size([1, 2]), scale: torch.Size([1, 2])) to satisfy the constraint GreaterThan(lower_bound=0.0), but found invalid values:
# tensor([[   nan, 0.8751]], device='cuda:0', grad_fn=<ExpBackward0>)

# %%
# Plot training results
fig, axes = plt.subplots(3, 3, figsize=(20, 16))
fig.suptitle('SAC Training Results with Safety Analysis', fontsize=16)

# Episode rewards
axes[0, 0].plot(training_metrics['episode_rewards'], alpha=0.3, color='blue')
if training_metrics['avg_reward']:
    axes[0, 0].plot(np.arange(0, len(training_metrics['avg_reward'])) * config['log_frequency'], 
                    training_metrics['avg_reward'], color='red', linewidth=2)
axes[0, 0].set_title('Episode Rewards')
axes[0, 0].set_xlabel('Episode')
axes[0, 0].set_ylabel('Reward')
axes[0, 0].grid(True)

# Episode lengths
axes[0, 1].plot(training_metrics['episode_lengths'], alpha=0.3, color='green')
if training_metrics['avg_length']:
    axes[0, 1].plot(np.arange(0, len(training_metrics['avg_length'])) * config['log_frequency'], 
                    training_metrics['avg_length'], color='red', linewidth=2)
axes[0, 1].set_title('Episode Lengths')
axes[0, 1].set_xlabel('Episode')
axes[0, 1].set_ylabel('Steps')
axes[0, 1].grid(True)

# Safety violations per episode
axes[0, 2].plot(training_metrics['safety_violations'], alpha=0.3, color='orange')
if training_metrics['avg_safety_violations']:
    axes[0, 2].plot(np.arange(0, len(training_metrics['avg_safety_violations'])) * config['log_frequency'], 
                    training_metrics['avg_safety_violations'], color='red', linewidth=2)
axes[0, 2].set_title('Safety Violations per Episode')
axes[0, 2].set_xlabel('Episode')
axes[0, 2].set_ylabel('Violations')
axes[0, 2].grid(True)

# Safety violation rate (percentage of episodes with violations)
if training_metrics['safety_violation_rate']:
    axes[1, 0].plot(np.arange(0, len(training_metrics['safety_violation_rate'])) * config['log_frequency'], 
                    training_metrics['safety_violation_rate'], color='red', linewidth=2)
    axes[1, 0].axhline(y=20, color='orange', linestyle='--', alpha=0.7, label='Warning Threshold (20%)')
    axes[1, 0].axhline(y=5, color='green', linestyle='--', alpha=0.7, label='Good Threshold (5%)')
axes[1, 0].set_title('Safety Violation Rate (%)')
axes[1, 0].set_xlabel('Episode')
axes[1, 0].set_ylabel('Violation Rate (%)')
axes[1, 0].grid(True)
axes[1, 0].legend()
axes[1, 0].set_ylim(0, 100)

# Consecutive safe episodes
if training_metrics['consecutive_safe_episodes']:
    axes[1, 1].plot(training_metrics['consecutive_safe_episodes'], color='green', linewidth=2)
    axes[1, 1].axhline(y=50, color='orange', linestyle='--', alpha=0.7, label='Good Streak (50)')
    axes[1, 1].axhline(y=100, color='green', linestyle='--', alpha=0.7, label='Excellent Streak (100)')
axes[1, 1].set_title('Consecutive Safe Episodes')
axes[1, 1].set_xlabel('Episode')
axes[1, 1].set_ylabel('Consecutive Safe')
axes[1, 1].grid(True)
axes[1, 1].legend()

# Safety violation types (pie chart)
if safety_stats['violation_types']:
    violation_counts = [count for count in safety_stats['violation_types'].values() if count > 0]
    violation_labels = [label for label, count in safety_stats['violation_types'].items() if count > 0]
    if violation_counts:
        axes[1, 2].pie(violation_counts, labels=violation_labels, autopct='%1.1f%%', startangle=90)
        axes[1, 2].set_title('Safety Violation Types Distribution')
    else:
        axes[1, 2].text(0.5, 0.5, 'No Violations!', ha='center', va='center', transform=axes[1, 2].transAxes, fontsize=14)
        axes[1, 2].set_title('Safety Violation Types Distribution')

# Success rate
if training_metrics['success_rate']:
    # Calculate rolling average
    window = 100
    success_rate_rolling = []
    for i in range(len(training_metrics['success_rate'])):
        start_idx = max(0, i - window + 1)
        success_rate_rolling.append(np.mean(training_metrics['success_rate'][start_idx:i+1]))
    
    axes[2, 0].plot(success_rate_rolling, color='purple', linewidth=2)
    axes[2, 0].set_title('Success Rate (Rolling Average)')
    axes[2, 0].set_xlabel('Episode')
    axes[2, 0].set_ylabel('Success Rate')
    axes[2, 0].grid(True)
    axes[2, 0].set_ylim(0, 1)

# Evaluation metrics
if eval_metrics['eval_rewards']:
    eval_episodes = np.arange(0, len(eval_metrics['eval_rewards'])) * config['eval_frequency']
    axes[2, 1].plot(eval_episodes, eval_metrics['eval_rewards'], 'o-', color='blue', label='Reward')
    axes[2, 1].set_title('Evaluation Rewards')
    axes[2, 1].set_xlabel('Episode')
    axes[2, 1].set_ylabel('Reward')
    axes[2, 1].grid(True)
    axes[2, 1].legend()

# Evaluation safety metrics
if eval_metrics['eval_safety_violation_rate']:
    axes[2, 2].plot(eval_episodes, eval_metrics['eval_safety_violation_rate'], 'o-', color='red', label='Violation Rate')
    axes[2, 2].axhline(y=20, color='orange', linestyle='--', alpha=0.7, label='Warning (20%)')
    axes[2, 2].axhline(y=5, color='green', linestyle='--', alpha=0.7, label='Good (5%)')
    axes[2, 2].set_title('Evaluation Safety Violation Rate')
    axes[2, 2].set_xlabel('Episode')
    axes[2, 2].set_ylabel('Violation Rate (%)')
    axes[2, 2].grid(True)
    axes[2, 2].legend()
    axes[2, 2].set_ylim(0, 100)
else:
    axes[2, 2].text(0.5, 0.5, 'No Evaluation Data', ha='center', va='center', transform=axes[2, 2].transAxes)
    axes[2, 2].set_title('Evaluation Safety Violation Rate')

plt.tight_layout()
plt.savefig(f"{output_dir}/plots/training_results.png", dpi=300, bbox_inches='tight')
plt.show()

print(f"Plots saved to {output_dir}/plots/")
# Out:
# Plots saved to runs/sac_hcw_20250924_045713_SAC_SafeGym/plots/

# %%
# Safety Analysis Report
print("=" * 60)
print("🔍 DETAILED SAFETY ANALYSIS REPORT")
print("=" * 60)

# Overall safety statistics
total_episodes = len(training_metrics['episode_rewards'])
total_violations = sum(training_metrics['safety_violations'])
overall_violation_rate = (total_violations / total_episodes) * 100 if total_episodes > 0 else 0

print(f"\n📊 OVERALL SAFETY STATISTICS:")
print(f"   Total Episodes: {total_episodes}")
print(f"   Total Safety Violations: {total_violations}")
print(f"   Overall Violation Rate: {overall_violation_rate:.2f}%")
print(f"   Episodes with Violations: {sum(1 for v in training_metrics['safety_violations'] if v > 0)}")
print(f"   Episodes without Violations: {sum(1 for v in training_metrics['safety_violations'] if v == 0)}")

# Safety trends
if len(training_metrics['safety_violations']) > 100:
    first_half = training_metrics['safety_violations'][:len(training_metrics['safety_violations'])//2]
    second_half = training_metrics['safety_violations'][len(training_metrics['safety_violations'])//2:]
    
    first_half_rate = (sum(1 for v in first_half if v > 0) / len(first_half)) * 100
    second_half_rate = (sum(1 for v in second_half if v > 0) / len(second_half)) * 100
    
    print(f"\n📈 SAFETY IMPROVEMENT TRENDS:")
    print(f"   First Half Violation Rate: {first_half_rate:.2f}%")
    print(f"   Second Half Violation Rate: {second_half_rate:.2f}%")
    improvement = first_half_rate - second_half_rate
    if improvement > 0:
        print(f"   ✅ Safety Improved by {improvement:.2f} percentage points")
    elif improvement < 0:
        print(f"   ⚠️  Safety Degraded by {abs(improvement):.2f} percentage points")
    else:
        print(f"   ➡️  Safety remained constant")

# Consecutive safe episodes analysis
max_consecutive = max(training_metrics['consecutive_safe_episodes']) if training_metrics['consecutive_safe_episodes'] else 0
current_consecutive = training_metrics['consecutive_safe_episodes'][-1] if training_metrics['consecutive_safe_episodes'] else 0

print(f"\n🏆 CONSECUTIVE SAFE EPISODES:")
print(f"   Maximum Consecutive Safe: {max_consecutive}")
print(f"   Current Consecutive Safe: {current_consecutive}")

# Violation type analysis
print(f"\n🔍 VIOLATION TYPE BREAKDOWN:")
for vtype, count in safety_stats['violation_types'].items():
    if count > 0:
        percentage = (count / total_violations) * 100 if total_violations > 0 else 0
        print(f"   {vtype}: {count} ({percentage:.1f}%)")

# Safety recommendations
print(f"\n💡 SAFETY RECOMMENDATIONS:")
if overall_violation_rate > 20:
    print("   ⚠️  HIGH VIOLATION RATE - Consider:")
    print("      • Reducing learning rate")
    print("      • Increasing safety penalty weights")
    print("      • Adding more safety constraints")
elif overall_violation_rate > 5:
    print("   ⚠️  MODERATE VIOLATION RATE - Consider:")
    print("      • Fine-tuning safety parameters")
    print("      • Increasing training episodes")
elif overall_violation_rate > 0:
    print("   ✅ LOW VIOLATION RATE - Good progress!")
    print("      • Continue current approach")
    print("      • Monitor for any degradation")
else:
    print("   🎉 PERFECT SAFETY RECORD!")
    print("      • Excellent training results")
    print("      • Consider testing on more challenging scenarios")

# Recent performance
if len(training_metrics['safety_violations']) >= 50:
    recent_episodes = training_metrics['safety_violations'][-50:]
    recent_violation_rate = (sum(1 for v in recent_episodes if v > 0) / len(recent_episodes)) * 100
    print(f"\n📊 RECENT PERFORMANCE (Last 50 Episodes):")
    print(f"   Recent Violation Rate: {recent_violation_rate:.2f}%")
    if recent_violation_rate < overall_violation_rate:
        print("   ✅ Recent performance is better than overall average")
    elif recent_violation_rate > overall_violation_rate:
        print("   ⚠️  Recent performance is worse than overall average")

print("\n" + "=" * 60)
# Out:
# ============================================================
# 🔍 DETAILED SAFETY ANALYSIS REPORT
# ============================================================
#
# 📊 OVERALL SAFETY STATISTICS:
#    Total Episodes: 18884
#    Total Safety Violations: 461
#    Overall Violation Rate: 2.44%
#    Episodes with Violations: 461
#    Episodes without Violations: 18423
#
# 📈 SAFETY IMPROVEMENT TRENDS:
#    First Half Violation Rate: 4.76%
#    Second Half Violation Rate: 0.13%
#    ✅ Safety Improved by 4.63 percentage points
#
# 🏆 CONSECUTIVE SAFE EPISODES:
#    Maximum Consecutive Safe: 5945
#    Current Consecutive Safe: 70
#
# 🔍 VIOLATION TYPE BREAKDOWN:
#    attitude_fail: 129 (28.0%)
#    velocity_fail: 238 (51.6%)
#    velocity_theta_fail: 94 (20.4%)
#    omega_fail: 5 (1.1%)
#    out_of_bounds: 90 (19.5%)
#
# 💡 SAFETY RECOMMENDATIONS:
#    ✅ LOW VIOLATION RATE - Good progress!
#       • Continue current approach
#       • Monitor for any degradation
#
# 📊 RECENT PERFORMANCE (Last 50 Episodes):
#    Recent Violation Rate: 0.00%
#    ✅ Recent performance is better than overall average
#
# ============================================================

# %%
# Test trained agent
print("Testing trained agent...")

# Create test environment with rendering
test_env = HCWSE2Env(
    render_mode="human",  # Enable rendering for visualization
    spawn_radius=config['spawn_radius'],
    pos_limit=100.0,
    v_limit=10.0,
    theta_limit=0.5,
    omega_limit=0.5,
)

# Test episodes
test_episodes = 3
test_results = []

for test_ep in range(test_episodes):
    print(f"\nTest Episode {test_ep + 1}/{test_episodes}")
    
    obs, info = test_env.reset()
    test_reward = 0
    test_length = 0
    test_safety_violations = 0
    
    for step in range(config['max_steps_per_episode']):
        action = agent.select_action(obs)
        next_obs, reward, terminated, truncated, info = test_env.step(action)
        
        test_unsafe = compute_unsafe(info)
        if test_unsafe:
            test_safety_violations += 1
        
        test_reward += reward
        test_length += 1
        obs = next_obs
        
        if terminated or truncated:
            break
    
    test_results.append({
        'episode': test_ep + 1,
        'reward': test_reward,
        'length': test_length,
        'safety_violations': test_safety_violations,
        'success': test_safety_violations == 0
    })
    
    print(f"  Reward: {test_reward:.2f}")
    print(f"  Length: {test_length}")
    print(f"  Safety Violations: {test_safety_violations}")
    print(f"  Success: {test_safety_violations == 0}")

test_env.close()

# Summary
avg_test_reward = np.mean([r['reward'] for r in test_results])
avg_test_length = np.mean([r['length'] for r in test_results])
avg_test_safety_violations = np.mean([r['safety_violations'] for r in test_results])
test_success_rate = np.mean([r['success'] for r in test_results])

print(f"\nTest Results Summary:")
print(f"  Average Reward: {avg_test_reward:.2f}")
print(f"  Average Length: {avg_test_length:.1f}")
print(f"  Average Safety Violations: {avg_test_safety_violations:.1f}")
print(f"  Success Rate: {test_success_rate:.3f}")
# Out:
# Testing trained agent...
#
# Test Episode 1/3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 27
#      24 test_safety_violations = 0
#      26 for step in range(config['max_steps_per_episode']):
# ---> 27     action = agent.select_action(obs)
#      28     next_obs, reward, terminated, truncated, info = test_env.step(action)
#      30     test_unsafe = compute_unsafe(info)
#
# File ~/Projects/IAC/CleanArpod/SafeGym/safegym/models/sac.py:95, in SACAgent.select_action(self, state)
#      93 def select_action(self, state):
#      94     state = torch.FloatTensor(state).to(self.device).unsqueeze(0)
# ---> 95     action, _ = self.actor.sample(state=state)
#      96     action = action.cpu().detach().numpy()
#      97     return action[0]
#
# File ~/Projects/IAC/CleanArpod/SafeGym/safegym/models/nets/nets.py:119, in Actor.sample(self, state, deterministic)
#     116     single_sample = False
#     118 mean, std = self.forward(state)
# --> 119 normal = torch.distributions.Normal(
#     120     mean, std
#     121 )  # create a normal distribution
#     122 z = normal.rsample()  # sample an action around the mean
#     123 action = torch.tanh(
#     124     z
#     125 )  # restrict action space, needed for pendulum[-1,1]
#
# File ~/.local/lib/python3.12/site-packages/torch/distributions/normal.py:57, in Normal.__init__(self, loc, scale, validate_args)
#      55 else:
#      56     batch_shape = self.loc.size()
# ---> 57 super().__init__(batch_shape, validate_args=validate_args)
#
# File ~/.local/lib/python3.12/site-packages/torch/distributions/distribution.py:70, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      68         valid = constraint.check(value)
#      69         if not valid.all():
# ---> 70             raise ValueError(
#      71                 f"Expected parameter {param} "
#      72                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      73                 f"of distribution {repr(self)} "
#      74                 f"to satisfy the constraint {repr(constraint)}, "
#      75                 f"but found invalid values:\n{value}"
#      76             )
#      77 super().__init__()
#
# ValueError: Expected parameter scale (Tensor of shape (1, 2)) of distribution Normal(loc: torch.Size([1, 2]), scale: torch.Size([1, 2])) to satisfy the constraint GreaterThan(lower_bound=0.0), but found invalid values:
# tensor([[   nan, 0.8751]], device='cuda:0', grad_fn=<ExpBackward0>)

# %%
# Save final results
final_results = {
    'config': config,
    'training_metrics': training_metrics,
    'eval_metrics': eval_metrics,
    'test_results': test_results,
    'final_stats': {
        'total_episodes': episode,
        'total_steps': total_steps,
        'final_avg_reward': np.mean(recent_rewards) if recent_rewards else 0,
        'final_success_rate': np.mean(training_metrics['success_rate'][-100:]) if training_metrics['success_rate'] else 0,
        'test_avg_reward': avg_test_reward,
        'test_success_rate': test_success_rate,
    }
}

# Save results
with open(f"{output_dir}/final_results.json", 'w') as f:
    # Convert numpy arrays to lists for JSON serialization
    def convert_numpy(obj):
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, dict):
            return {key: convert_numpy(value) for key, value in obj.items()}
        elif isinstance(obj, list):
            return [convert_numpy(item) for item in obj]
        else:
            return obj
    
    json.dump(convert_numpy(final_results), f, indent=2)

print(f"\nResults saved to {output_dir}/")
print(f"Final model saved to {output_dir}/models/")
print(f"Training plots saved to {output_dir}/plots/")
print(f"Logs saved to {output_dir}/logs/")

print("\nSAC Training Complete!")
print("=" * 50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 12
#       1 # Save final results
#       2 final_results = {
#       3     'config': config,
#       4     'training_metrics': training_metrics,
#       5     'eval_metrics': eval_metrics,
#       6     'test_results': test_results,
#       7     'final_stats': {
#       8         'total_episodes': episode,
#       9         'total_steps': total_steps,
#      10         'final_avg_reward': np.mean(recent_rewards) if recent_rewards else 0,
#      11         'final_success_rate': np.mean(training_metrics['success_rate'][-100:]) if training_metrics['success_rate'] else 0,
# ---> 12         'test_avg_reward': avg_test_reward,
#      13         'test_success_rate': test_success_rate,
#      14     }
#      15 }
#      17 # Save results
#      18 with open(f"{output_dir}/final_results.json", 'w') as f:
#      19     # Convert numpy arrays to lists for JSON serialization
#
# NameError: name 'avg_test_reward' is not defined
