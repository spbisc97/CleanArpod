# %%
import os
from datetime import datetime

from envs.arpod_HCW import HCWSE2Env
from stable_baselines3 import TD3
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import is_wrapped

run_specs="20kg_256x1024x64"
run_id = datetime.now().strftime("%Y%m%d_%H%M%S")
out_dir = os.path.join("runs", f"td3_arpod_{run_id}_{run_specs}")
os.makedirs(out_dir, exist_ok=True)
best_dir = os.path.join(out_dir, "best_models")
logs_dir = os.path.join(out_dir, "logs")
os.makedirs(best_dir, exist_ok=True)
os.makedirs(logs_dir, exist_ok=True)


n_envs = 12
seed = 42
spawn_radius=(2.5, 5.0)
env = DummyVecEnv([lambda: Monitor(HCWSE2Env(seed=seed,spawn_radius=spawn_radius), logs_dir)] * n_envs)
# env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)0)

policy_kwargs = dict(
    net_arch=dict(pi=[256, 1024,64], qf=[256, 1024,64])
)
model = TD3(
    policy="MlpPolicy",
    env=env,
    learning_rate=3e-4,
    buffer_size=int(1e6),
    learning_starts=20_000,
    batch_size=256,
    tau=0.005,
    gamma=0.999,
    train_freq=(64,"step"),
    gradient_steps=128,
    policy_kwargs=policy_kwargs,
    verbose=1,
    tensorboard_log=logs_dir,
    seed=seed
)
model.save(os.path.join(best_dir, "model_0M"))

# model_path = os.path.join(best_dir, "model_0M.zip")

# %%
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)

model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback])
model.save(os.path.join(out_dir, "model_1M"))
# Out:
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -648     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 7707     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 23184    |
# | train/             |          |
# |    actor_loss      | 3.26     |
# |    critic_loss     | 1.92     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 512      |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.35e+03  |
# |    ep_rew_mean     | -1.22e+03 |
# |    success_rate    | 0         |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 3405      |
# |    time_elapsed    | 10        |
# |    total_timesteps | 36000     |
# | train/             |           |
# |    actor_loss      | 8.29      |
# |    critic_loss     | 2.05      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2560      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.82e+03  |
# |    ep_rew_mean     | -2.04e+03 |
# |    success_rate    | 0         |
# | time/              |           |
# |    episodes        | 30        |
# |    fps             | 2270      |
# |    time_elapsed    | 29        |
# |    total_timesteps | 67536     |
# | train/             |           |
# |    actor_loss      | 18.5      |
# |    critic_loss     | 0.409     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7808      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.12e+03  |
# |    ep_rew_mean     | -1.66e+03 |
# |    success_rate    | 0         |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 1991      |
# |    time_elapsed    | 51        |
# |    total_timesteps | 102708    |
# | train/             |           |
# |    actor_loss      | 20.8      |
# |    critic_loss     | 1.84      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 13696     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.29e+03  |
# |    ep_rew_mean     | -1.28e+03 |
# |    success_rate    | 0         |
# | time/              |           |
# |    episodes        | 50        |
# |    fps             | 1886      |
# |    time_elapsed    | 72        |
# |    total_timesteps | 136920    |
# | train/             |           |
# |    actor_loss      | 20.3      |
# |    critic_loss     | 4.15      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 19456     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.41e+03  |
# |    ep_rew_mean     | -1.02e+03 |
# |    success_rate    | 0         |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 1844      |
# |    time_elapsed    | 90        |
# |    total_timesteps | 167184    |
# | train/             |           |
# |    actor_loss      | 19.7      |
# |    critic_loss     | 2.88      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 24448     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -829     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 1818     |
# |    time_elapsed    | 102      |
# |    total_timesteps | 186804   |
# | train/             |          |
# |    actor_loss      | 20       |
# |    critic_loss     | 4.39     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27776    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.56e+03 |
# |    ep_rew_mean     | -685     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 1790     |
# |    time_elapsed    | 120      |
# |    total_timesteps | 216000   |
# | train/             |          |
# |    actor_loss      | 19.5     |
# |    critic_loss     | 6.49     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32640    |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0002.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0003.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0004.png
# Eval num_timesteps=240000, episode_reward=318.85 +/- 18.09
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 319      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 240000   |
# | train/             |          |
# |    actor_loss      | 20.4     |
# |    critic_loss     | 1.58     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36608    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.61e+03 |
# |    ep_rew_mean     | -575     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 1709     |
# |    time_elapsed    | 144      |
# |    total_timesteps | 247536   |
# | train/             |          |
# |    actor_loss      | 19.5     |
# |    critic_loss     | 1.99     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37888    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.65e+03 |
# |    ep_rew_mean     | -488     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 1701     |
# |    time_elapsed    | 166      |
# |    total_timesteps | 282708   |
# | train/             |          |
# |    actor_loss      | 19.4     |
# |    critic_loss     | 0.361    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43776    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.84e+03 |
# |    ep_rew_mean     | -397     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 1699     |
# |    time_elapsed    | 186      |
# |    total_timesteps | 316920   |
# | train/             |          |
# |    actor_loss      | 17       |
# |    critic_loss     | 0.879    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49408    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.98e+03 |
# |    ep_rew_mean     | -185     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 1693     |
# |    time_elapsed    | 205      |
# |    total_timesteps | 347184   |
# | train/             |          |
# |    actor_loss      | 18.1     |
# |    critic_loss     | 1.46     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 54528    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3e+03    |
# |    ep_rew_mean     | 214      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 130      |
# |    fps             | 1693     |
# |    time_elapsed    | 216      |
# |    total_timesteps | 366804   |
# | train/             |          |
# |    actor_loss      | 17.1     |
# |    critic_loss     | 2.42     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 57728    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3e+03    |
# |    ep_rew_mean     | 296      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 1691     |
# |    time_elapsed    | 234      |
# |    total_timesteps | 396000   |
# | train/             |          |
# |    actor_loss      | 17.4     |
# |    critic_loss     | 0.54     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 62592    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3e+03    |
# |    ep_rew_mean     | 302      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 1690     |
# |    time_elapsed    | 252      |
# |    total_timesteps | 426972   |
# | train/             |          |
# |    actor_loss      | 16.8     |
# |    critic_loss     | 0.896    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 67712    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.87e+03 |
# |    ep_rew_mean     | 257      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 1689     |
# |    time_elapsed    | 266      |
# |    total_timesteps | 450408   |
# | train/             |          |
# |    actor_loss      | 19.1     |
# |    critic_loss     | 1.85     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 71680    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.85e+03 |
# |    ep_rew_mean     | 182      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 170      |
# |    fps             | 1687     |
# |    time_elapsed    | 279      |
# |    total_timesteps | 471912   |
# | train/             |          |
# |    actor_loss      | 19.9     |
# |    critic_loss     | 0.657    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75264    |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0006.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0007.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0008.png
# Eval num_timesteps=480000, episode_reward=-105.52 +/- 623.22
# Episode length: 2816.33 +/- 259.74
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2.82e+03 |
# |    mean_reward     | -106     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 480000   |
# | train/             |          |
# |    actor_loss      | 20       |
# |    critic_loss     | 3.89     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 76544    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.78e+03 |
# |    ep_rew_mean     | 123      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 1660     |
# |    time_elapsed    | 299      |
# |    total_timesteps | 496920   |
# | train/             |          |
# |    actor_loss      | 22.1     |
# |    critic_loss     | 10.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79488    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.72e+03 |
# |    ep_rew_mean     | 74.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 190      |
# |    fps             | 1662     |
# |    time_elapsed    | 313      |
# |    total_timesteps | 521124   |
# | train/             |          |
# |    actor_loss      | 22.3     |
# |    critic_loss     | 1.97     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 83456    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.7e+03  |
# |    ep_rew_mean     | 71.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 1662     |
# |    time_elapsed    | 330      |
# |    total_timesteps | 550188   |
# | train/             |          |
# |    actor_loss      | 24.7     |
# |    critic_loss     | 5.37     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 88320    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.65e+03 |
# |    ep_rew_mean     | 33.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 1663     |
# |    time_elapsed    | 347      |
# |    total_timesteps | 577488   |
# | train/             |          |
# |    actor_loss      | 23.9     |
# |    critic_loss     | 15.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 92800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.65e+03 |
# |    ep_rew_mean     | -10.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 1664     |
# |    time_elapsed    | 363      |
# |    total_timesteps | 604920   |
# | train/             |          |
# |    actor_loss      | 26.3     |
# |    critic_loss     | 3.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97408    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.58e+03 |
# |    ep_rew_mean     | -88.7    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 230      |
# |    fps             | 1664     |
# |    time_elapsed    | 375      |
# |    total_timesteps | 625080   |
# | train/             |          |
# |    actor_loss      | 29       |
# |    critic_loss     | 3.31     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100736   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.56e+03 |
# |    ep_rew_mean     | -133     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 1665     |
# |    time_elapsed    | 390      |
# |    total_timesteps | 650976   |
# | train/             |          |
# |    actor_loss      | 29.2     |
# |    critic_loss     | 4.72     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 105088   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.52e+03 |
# |    ep_rew_mean     | -203     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 1666     |
# |    time_elapsed    | 408      |
# |    total_timesteps | 680868   |
# | train/             |          |
# |    actor_loss      | 31.5     |
# |    critic_loss     | 7.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110080   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.59e+03 |
# |    ep_rew_mean     | -227     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 1667     |
# |    time_elapsed    | 425      |
# |    total_timesteps | 709416   |
# | train/             |          |
# |    actor_loss      | 36.1     |
# |    critic_loss     | 3.53     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 114816   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0009.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0010.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0011.png
# Eval num_timesteps=720000, episode_reward=-558.96 +/- 619.82
# Episode length: 2571.33 +/- 606.23
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2.57e+03 |
# |    mean_reward     | -559     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 720000   |
# | train/             |          |
# |    actor_loss      | 38       |
# |    critic_loss     | 2.61     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 116608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.59e+03 |
# |    ep_rew_mean     | -266     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 1651     |
# |    time_elapsed    | 443      |
# |    total_timesteps | 732372   |
# | train/             |          |
# |    actor_loss      | 39.6     |
# |    critic_loss     | 1.28     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118656   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.65e+03 |
# |    ep_rew_mean     | -309     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 1652     |
# |    time_elapsed    | 458      |
# |    total_timesteps | 757176   |
# | train/             |          |
# |    actor_loss      | 43.3     |
# |    critic_loss     | 15.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 122752   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.68e+03 |
# |    ep_rew_mean     | -384     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 290      |
# |    fps             | 1653     |
# |    time_elapsed    | 477      |
# |    total_timesteps | 789984   |
# | train/             |          |
# |    actor_loss      | 47.1     |
# |    critic_loss     | 31.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 128256   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.63e+03 |
# |    ep_rew_mean     | -460     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 1654     |
# |    time_elapsed    | 491      |
# |    total_timesteps | 812640   |
# | train/             |          |
# |    actor_loss      | 49.5     |
# |    critic_loss     | 12.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 132096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.62e+03 |
# |    ep_rew_mean     | -471     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 310      |
# |    fps             | 1654     |
# |    time_elapsed    | 503      |
# |    total_timesteps | 832608   |
# | train/             |          |
# |    actor_loss      | 50.2     |
# |    critic_loss     | 24.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 135424   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.6e+03  |
# |    ep_rew_mean     | -488     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 1656     |
# |    time_elapsed    | 521      |
# |    total_timesteps | 864168   |
# | train/             |          |
# |    actor_loss      | 55.1     |
# |    critic_loss     | 27.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 140672   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.55e+03 |
# |    ep_rew_mean     | -490     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 330      |
# |    fps             | 1657     |
# |    time_elapsed    | 532      |
# |    total_timesteps | 882096   |
# | train/             |          |
# |    actor_loss      | 55.6     |
# |    critic_loss     | 11.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 143616   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.42e+03 |
# |    ep_rew_mean     | -495     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 1657     |
# |    time_elapsed    | 542      |
# |    total_timesteps | 899412   |
# | train/             |          |
# |    actor_loss      | 57       |
# |    critic_loss     | 2.12     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 146560   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.42e+03 |
# |    ep_rew_mean     | -513     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 1659     |
# |    time_elapsed    | 558      |
# |    total_timesteps | 925884   |
# | train/             |          |
# |    actor_loss      | 61.5     |
# |    critic_loss     | 12.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 150912   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.43e+03 |
# |    ep_rew_mean     | -534     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 1660     |
# |    time_elapsed    | 573      |
# |    total_timesteps | 953016   |
# | train/             |          |
# |    actor_loss      | 63.8     |
# |    critic_loss     | 19.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 155392   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0012.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0013.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0014.png
# Eval num_timesteps=960000, episode_reward=-1148.29 +/- 188.01
# Episode length: 2592.33 +/- 338.15
# Success rate: 0.00%
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 2.59e+03  |
# |    mean_reward     | -1.15e+03 |
# |    success_rate    | 0         |
# | time/              |           |
# |    total_timesteps | 960000    |
# | train/             |           |
# |    actor_loss      | 63.9      |
# |    critic_loss     | 13.5      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 156544    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.42e+03 |
# |    ep_rew_mean     | -548     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 370      |
# |    fps             | 1646     |
# |    time_elapsed    | 590      |
# |    total_timesteps | 971868   |
# | train/             |          |
# |    actor_loss      | 65.8     |
# |    critic_loss     | 26.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 158592   |
# ---------------------------------

# %%
# > 1M steps, increase spawn radius
spawn_radius=(2.5, 10.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
    print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)
model.save(os.path.join(out_dir, "model_2M"))
# Out:
# Increasing spawn radius to  (2.5, 10.0)
# Increasing spawn radius to  (2.5, 10.0)
# Increasing spawn radius to  (2.5, 10.0)
# Increasing spawn radius to  (2.5, 10.0)
# Increasing spawn radius to  (2.5, 10.0)
# Increasing spawn radius to  (2.5, 10.0)
# Increasing spawn radius to  (2.5, 10.0)
# Increasing spawn radius to  (2.5, 10.0)
# Increasing spawn radius to  (2.5, 10.0)
# Increasing spawn radius to  (2.5, 10.0)
# Increasing spawn radius to  (2.5, 10.0)
# Increasing spawn radius to  (2.5, 10.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.37e+03 |
# |    ep_rew_mean     | -571     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 12705    |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1000992  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.35e+03 |
# |    ep_rew_mean     | -502     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 390      |
# |    fps             | 1700     |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1024356  |
# | train/             |          |
# |    actor_loss      | 70.5     |
# |    critic_loss     | 11       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 167296   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.34e+03 |
# |    ep_rew_mean     | -533     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 1664     |
# |    time_elapsed    | 26       |
# |    total_timesteps | 1044756  |
# | train/             |          |
# |    actor_loss      | 69.4     |
# |    critic_loss     | 11.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 170752   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.37e+03 |
# |    ep_rew_mean     | -604     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 410      |
# |    fps             | 1671     |
# |    time_elapsed    | 43       |
# |    total_timesteps | 1074108  |
# | train/             |          |
# |    actor_loss      | 67.5     |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 175616   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.32e+03 |
# |    ep_rew_mean     | -642     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 1659     |
# |    time_elapsed    | 57       |
# |    total_timesteps | 1095468  |
# | train/             |          |
# |    actor_loss      | 70.2     |
# |    critic_loss     | 15.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 179200   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | -654     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 430      |
# |    fps             | 1662     |
# |    time_elapsed    | 69       |
# |    total_timesteps | 1117008  |
# | train/             |          |
# |    actor_loss      | 74.7     |
# |    critic_loss     | 5.74     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 182784   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.4e+03  |
# |    ep_rew_mean     | -725     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 1662     |
# |    time_elapsed    | 81       |
# |    total_timesteps | 1136244  |
# | train/             |          |
# |    actor_loss      | 78.6     |
# |    critic_loss     | 28.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 185984   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.35e+03 |
# |    ep_rew_mean     | -757     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 1664     |
# |    time_elapsed    | 91       |
# |    total_timesteps | 1153320  |
# | train/             |          |
# |    actor_loss      | 84.2     |
# |    critic_loss     | 10.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 188800   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.31e+03 |
# |    ep_rew_mean     | -781     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 1662     |
# |    time_elapsed    | 107      |
# |    total_timesteps | 1178652  |
# | train/             |          |
# |    actor_loss      | 88.9     |
# |    critic_loss     | 44.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 193024   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.22e+03 |
# |    ep_rew_mean     | -707     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 470      |
# |    fps             | 1659     |
# |    time_elapsed    | 114      |
# |    total_timesteps | 1191180  |
# | train/             |          |
# |    actor_loss      | 92.8     |
# |    critic_loss     | 1.52     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 195200   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.2e+03  |
# |    ep_rew_mean     | -686     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 1663     |
# |    time_elapsed    | 132      |
# |    total_timesteps | 1220904  |
# | train/             |          |
# |    actor_loss      | 97.8     |
# |    critic_loss     | 24.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 200064   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.12e+03 |
# |    ep_rew_mean     | -704     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 490      |
# |    fps             | 1663     |
# |    time_elapsed    | 138      |
# |    total_timesteps | 1231752  |
# | train/             |          |
# |    actor_loss      | 101      |
# |    critic_loss     | 36.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 201856   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0015.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0016.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0017.png
# Eval num_timesteps=1240704, episode_reward=254.13 +/- 35.96
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 254      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 1240704  |
# | train/             |          |
# |    actor_loss      | 102      |
# |    critic_loss     | 22.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 203392   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.12e+03 |
# |    ep_rew_mean     | -658     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 1605     |
# |    time_elapsed    | 158      |
# |    total_timesteps | 1255836  |
# | train/             |          |
# |    actor_loss      | 105      |
# |    critic_loss     | 46.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 205952   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.03e+03 |
# |    ep_rew_mean     | -555     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 510      |
# |    fps             | 1607     |
# |    time_elapsed    | 167      |
# |    total_timesteps | 1269612  |
# | train/             |          |
# |    actor_loss      | 108      |
# |    critic_loss     | 35.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 208256   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.96e+03 |
# |    ep_rew_mean     | -496     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 1614     |
# |    time_elapsed    | 178      |
# |    total_timesteps | 1289472  |
# | train/             |          |
# |    actor_loss      | 105      |
# |    critic_loss     | 46.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 211456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.88e+03 |
# |    ep_rew_mean     | -440     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 530      |
# |    fps             | 1614     |
# |    time_elapsed    | 188      |
# |    total_timesteps | 1304424  |
# | train/             |          |
# |    actor_loss      | 105      |
# |    critic_loss     | 29.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 214016   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.84e+03 |
# |    ep_rew_mean     | -367     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 1615     |
# |    time_elapsed    | 194      |
# |    total_timesteps | 1315068  |
# | train/             |          |
# |    actor_loss      | 106      |
# |    critic_loss     | 6.09     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 215808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.8e+03  |
# |    ep_rew_mean     | -268     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 1618     |
# |    time_elapsed    | 205      |
# |    total_timesteps | 1332804  |
# | train/             |          |
# |    actor_loss      | 107      |
# |    critic_loss     | 33.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 218752   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.73e+03 |
# |    ep_rew_mean     | -185     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 1621     |
# |    time_elapsed    | 219      |
# |    total_timesteps | 1356624  |
# | train/             |          |
# |    actor_loss      | 111      |
# |    critic_loss     | 45.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 222720   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.69e+03 |
# |    ep_rew_mean     | -156     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 570      |
# |    fps             | 1622     |
# |    time_elapsed    | 221      |
# |    total_timesteps | 1360344  |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 6.61     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 223360   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.56e+03 |
# |    ep_rew_mean     | -94.2    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 1624     |
# |    time_elapsed    | 229      |
# |    total_timesteps | 1373556  |
# | train/             |          |
# |    actor_loss      | 114      |
# |    critic_loss     | 21.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 225536   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53e+03 |
# |    ep_rew_mean     | -107     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 590      |
# |    fps             | 1625     |
# |    time_elapsed    | 234      |
# |    total_timesteps | 1381608  |
# | train/             |          |
# |    actor_loss      | 114      |
# |    critic_loss     | 34.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 226816   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.34e+03 |
# |    ep_rew_mean     | -81.9    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 1624     |
# |    time_elapsed    | 237      |
# |    total_timesteps | 1387344  |
# | train/             |          |
# |    actor_loss      | 116      |
# |    critic_loss     | 75.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 227840   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.24e+03 |
# |    ep_rew_mean     | -114     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 610      |
# |    fps             | 1625     |
# |    time_elapsed    | 241      |
# |    total_timesteps | 1393632  |
# | train/             |          |
# |    actor_loss      | 118      |
# |    critic_loss     | 32.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 228864   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -151     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 1625     |
# |    time_elapsed    | 250      |
# |    total_timesteps | 1408716  |
# | train/             |          |
# |    actor_loss      | 123      |
# |    critic_loss     | 21.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 231424   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | -174     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 630      |
# |    fps             | 1625     |
# |    time_elapsed    | 255      |
# |    total_timesteps | 1415532  |
# | train/             |          |
# |    actor_loss      | 126      |
# |    critic_loss     | 36.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 232576   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | -165     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 640      |
# |    fps             | 1626     |
# |    time_elapsed    | 257      |
# |    total_timesteps | 1420224  |
# | train/             |          |
# |    actor_loss      | 125      |
# |    critic_loss     | 26.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 233344   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 926      |
# |    ep_rew_mean     | -196     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 1627     |
# |    time_elapsed    | 260      |
# |    total_timesteps | 1424856  |
# | train/             |          |
# |    actor_loss      | 125      |
# |    critic_loss     | 47.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 234112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 827      |
# |    ep_rew_mean     | -203     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 1629     |
# |    time_elapsed    | 263      |
# |    total_timesteps | 1430004  |
# | train/             |          |
# |    actor_loss      | 126      |
# |    critic_loss     | 57.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 234880   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 737      |
# |    ep_rew_mean     | -218     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 670      |
# |    fps             | 1628     |
# |    time_elapsed    | 267      |
# |    total_timesteps | 1435752  |
# | train/             |          |
# |    actor_loss      | 127      |
# |    critic_loss     | 45.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 235904   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 738      |
# |    ep_rew_mean     | -241     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 1629     |
# |    time_elapsed    | 270      |
# |    total_timesteps | 1441416  |
# | train/             |          |
# |    actor_loss      | 129      |
# |    critic_loss     | 28.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 236800   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 644      |
# |    ep_rew_mean     | -190     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 690      |
# |    fps             | 1630     |
# |    time_elapsed    | 273      |
# |    total_timesteps | 1446084  |
# | train/             |          |
# |    actor_loss      | 129      |
# |    critic_loss     | 27.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 237568   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 659      |
# |    ep_rew_mean     | -194     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 1630     |
# |    time_elapsed    | 275      |
# |    total_timesteps | 1450500  |
# | train/             |          |
# |    actor_loss      | 129      |
# |    critic_loss     | 40       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 238336   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 622      |
# |    ep_rew_mean     | -185     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 710      |
# |    fps             | 1629     |
# |    time_elapsed    | 279      |
# |    total_timesteps | 1456908  |
# | train/             |          |
# |    actor_loss      | 130      |
# |    critic_loss     | 25       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 239488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 565      |
# |    ep_rew_mean     | -145     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 1630     |
# |    time_elapsed    | 282      |
# |    total_timesteps | 1460964  |
# | train/             |          |
# |    actor_loss      | 129      |
# |    critic_loss     | 36.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 240128   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 525      |
# |    ep_rew_mean     | -114     |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 730      |
# |    fps             | 1630     |
# |    time_elapsed    | 284      |
# |    total_timesteps | 1464648  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 59.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 240768   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | -108     |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 1630     |
# |    time_elapsed    | 286      |
# |    total_timesteps | 1467948  |
# | train/             |          |
# |    actor_loss      | 130      |
# |    critic_loss     | 78.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 241280   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -107     |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 1631     |
# |    time_elapsed    | 288      |
# |    total_timesteps | 1471152  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 35.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 241792   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 496      |
# |    ep_rew_mean     | -114     |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 1630     |
# |    time_elapsed    | 290      |
# |    total_timesteps | 1474608  |
# | train/             |          |
# |    actor_loss      | 129      |
# |    critic_loss     | 58.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 242432   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 486      |
# |    ep_rew_mean     | -106     |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 770      |
# |    fps             | 1631     |
# |    time_elapsed    | 292      |
# |    total_timesteps | 1478076  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 26.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 242944   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0018.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0019.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0020.png
# Eval num_timesteps=1480704, episode_reward=42.22 +/- 120.97
# Episode length: 1056.33 +/- 1374.46
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.06e+03 |
# |    mean_reward     | 42.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 1480704  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 27.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 243328   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 430      |
# |    ep_rew_mean     | -72.6    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 1618     |
# |    time_elapsed    | 297      |
# |    total_timesteps | 1481628  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 43.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 243584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 402      |
# |    ep_rew_mean     | -64.3    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 790      |
# |    fps             | 1618     |
# |    time_elapsed    | 298      |
# |    total_timesteps | 1483860  |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 81.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 243968   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -63.6    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 1620     |
# |    time_elapsed    | 301      |
# |    total_timesteps | 1489560  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 32.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 244864   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 397      |
# |    ep_rew_mean     | -52.2    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 810      |
# |    fps             | 1621     |
# |    time_elapsed    | 306      |
# |    total_timesteps | 1497480  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 63.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 246144   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 430      |
# |    ep_rew_mean     | -40      |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 820      |
# |    fps             | 1622     |
# |    time_elapsed    | 313      |
# |    total_timesteps | 1509468  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 15.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 248192   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 445      |
# |    ep_rew_mean     | -52.4    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 830      |
# |    fps             | 1621     |
# |    time_elapsed    | 315      |
# |    total_timesteps | 1513032  |
# | train/             |          |
# |    actor_loss      | 134      |
# |    critic_loss     | 68       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 248832   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 498      |
# |    ep_rew_mean     | -56.3    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 840      |
# |    fps             | 1623     |
# |    time_elapsed    | 318      |
# |    total_timesteps | 1518252  |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 56.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 249600   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 489      |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 850      |
# |    fps             | 1622     |
# |    time_elapsed    | 320      |
# |    total_timesteps | 1520964  |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 38.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 250112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 860      |
# |    fps             | 1623     |
# |    time_elapsed    | 323      |
# |    total_timesteps | 1525920  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 40.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 250880   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 506      |
# |    ep_rew_mean     | -32.4    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 870      |
# |    fps             | 1623     |
# |    time_elapsed    | 328      |
# |    total_timesteps | 1533372  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 45.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 252160   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 536      |
# |    ep_rew_mean     | -29      |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 880      |
# |    fps             | 1624     |
# |    time_elapsed    | 334      |
# |    total_timesteps | 1544292  |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 20.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 253952   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 604      |
# |    ep_rew_mean     | -29.6    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 890      |
# |    fps             | 1624     |
# |    time_elapsed    | 338      |
# |    total_timesteps | 1550184  |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 74.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 254976   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 640      |
# |    ep_rew_mean     | -12.4    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 1624     |
# |    time_elapsed    | 340      |
# |    total_timesteps | 1554180  |
# | train/             |          |
# |    actor_loss      | 134      |
# |    critic_loss     | 52.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 255616   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 677      |
# |    ep_rew_mean     | -7.83    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 910      |
# |    fps             | 1623     |
# |    time_elapsed    | 344      |
# |    total_timesteps | 1559940  |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 50.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 256640   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 623      |
# |    ep_rew_mean     | -11.7    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 920      |
# |    fps             | 1624     |
# |    time_elapsed    | 346      |
# |    total_timesteps | 1563744  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 44.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 257280   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 594      |
# |    ep_rew_mean     | 2.1      |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 930      |
# |    fps             | 1624     |
# |    time_elapsed    | 349      |
# |    total_timesteps | 1569204  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 68.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 258176   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 598      |
# |    ep_rew_mean     | 14.9     |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 940      |
# |    fps             | 1625     |
# |    time_elapsed    | 355      |
# |    total_timesteps | 1578312  |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 87.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 259712   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 620      |
# |    ep_rew_mean     | 34.4     |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 950      |
# |    fps             | 1625     |
# |    time_elapsed    | 358      |
# |    total_timesteps | 1583160  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 41.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260480   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 629      |
# |    ep_rew_mean     | 42.1     |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 960      |
# |    fps             | 1626     |
# |    time_elapsed    | 364      |
# |    total_timesteps | 1593276  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 43.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262144   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 662      |
# |    ep_rew_mean     | 51.7     |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 970      |
# |    fps             | 1626     |
# |    time_elapsed    | 368      |
# |    total_timesteps | 1599912  |
# | train/             |          |
# |    actor_loss      | 134      |
# |    critic_loss     | 25.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263296   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 677      |
# |    ep_rew_mean     | 54       |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 980      |
# |    fps             | 1627     |
# |    time_elapsed    | 370      |
# |    total_timesteps | 1604208  |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 67.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263936   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 633      |
# |    ep_rew_mean     | 58.7     |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 990      |
# |    fps             | 1627     |
# |    time_elapsed    | 373      |
# |    total_timesteps | 1608612  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 26.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 264704   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 576      |
# |    ep_rew_mean     | 63.1     |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 1628     |
# |    time_elapsed    | 375      |
# |    total_timesteps | 1611996  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 23.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265216   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 590      |
# |    ep_rew_mean     | 70       |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 1010     |
# |    fps             | 1627     |
# |    time_elapsed    | 379      |
# |    total_timesteps | 1618080  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 32       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 266240   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 616      |
# |    ep_rew_mean     | 85.3     |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1020     |
# |    fps             | 1626     |
# |    time_elapsed    | 383      |
# |    total_timesteps | 1624548  |
# | train/             |          |
# |    actor_loss      | 134      |
# |    critic_loss     | 43.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267392   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 615      |
# |    ep_rew_mean     | 92.8     |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1030     |
# |    fps             | 1628     |
# |    time_elapsed    | 385      |
# |    total_timesteps | 1628904  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 49.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 268032   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 586      |
# |    ep_rew_mean     | 91.8     |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1040     |
# |    fps             | 1627     |
# |    time_elapsed    | 389      |
# |    total_timesteps | 1634580  |
# | train/             |          |
# |    actor_loss      | 134      |
# |    critic_loss     | 36.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269056   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 573      |
# |    ep_rew_mean     | 96.7     |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1050     |
# |    fps             | 1628     |
# |    time_elapsed    | 392      |
# |    total_timesteps | 1640412  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 36.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269952   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 566      |
# |    ep_rew_mean     | 93.2     |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 1060     |
# |    fps             | 1628     |
# |    time_elapsed    | 396      |
# |    total_timesteps | 1645524  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 49.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 270848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 538      |
# |    ep_rew_mean     | 101      |
# |    success_rate    | 0.44     |
# | time/              |          |
# |    episodes        | 1070     |
# |    fps             | 1627     |
# |    time_elapsed    | 398      |
# |    total_timesteps | 1649184  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 59.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 271488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 509      |
# |    ep_rew_mean     | 113      |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    episodes        | 1080     |
# |    fps             | 1627     |
# |    time_elapsed    | 401      |
# |    total_timesteps | 1653816  |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 30.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 272256   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 522      |
# |    ep_rew_mean     | 117      |
# |    success_rate    | 0.51     |
# | time/              |          |
# |    episodes        | 1090     |
# |    fps             | 1629     |
# |    time_elapsed    | 408      |
# |    total_timesteps | 1666548  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 58       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 274304   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 592      |
# |    ep_rew_mean     | 116      |
# |    success_rate    | 0.49     |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 1629     |
# |    time_elapsed    | 411      |
# |    total_timesteps | 1670796  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 71.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 275072   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 569      |
# |    ep_rew_mean     | 111      |
# |    success_rate    | 0.47     |
# | time/              |          |
# |    episodes        | 1110     |
# |    fps             | 1629     |
# |    time_elapsed    | 413      |
# |    total_timesteps | 1673964  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 61       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 275584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 543      |
# |    ep_rew_mean     | 106      |
# |    success_rate    | 0.45     |
# | time/              |          |
# |    episodes        | 1120     |
# |    fps             | 1629     |
# |    time_elapsed    | 415      |
# |    total_timesteps | 1677708  |
# | train/             |          |
# |    actor_loss      | 130      |
# |    critic_loss     | 72.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 276224   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 538      |
# |    ep_rew_mean     | 101      |
# |    success_rate    | 0.43     |
# | time/              |          |
# |    episodes        | 1130     |
# |    fps             | 1629     |
# |    time_elapsed    | 417      |
# |    total_timesteps | 1680732  |
# | train/             |          |
# |    actor_loss      | 134      |
# |    critic_loss     | 36.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 276736   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 532      |
# |    ep_rew_mean     | 94.4     |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1140     |
# |    fps             | 1629     |
# |    time_elapsed    | 419      |
# |    total_timesteps | 1684548  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 67.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 277376   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 503      |
# |    ep_rew_mean     | 91.6     |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1150     |
# |    fps             | 1629     |
# |    time_elapsed    | 421      |
# |    total_timesteps | 1686972  |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 58.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 277760   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 470      |
# |    ep_rew_mean     | 89.2     |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1160     |
# |    fps             | 1629     |
# |    time_elapsed    | 423      |
# |    total_timesteps | 1690704  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 66       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 278400   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 464      |
# |    ep_rew_mean     | 76.5     |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1170     |
# |    fps             | 1630     |
# |    time_elapsed    | 424      |
# |    total_timesteps | 1693308  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 32.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 278784   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 439      |
# |    ep_rew_mean     | 73.4     |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1180     |
# |    fps             | 1630     |
# |    time_elapsed    | 426      |
# |    total_timesteps | 1695708  |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 60       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 279168   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 413      |
# |    ep_rew_mean     | 73.5     |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1190     |
# |    fps             | 1630     |
# |    time_elapsed    | 428      |
# |    total_timesteps | 1699212  |
# | train/             |          |
# |    actor_loss      | 130      |
# |    critic_loss     | 39.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 279808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 351      |
# |    ep_rew_mean     | 62.6     |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 1629     |
# |    time_elapsed    | 430      |
# |    total_timesteps | 1701984  |
# | train/             |          |
# |    actor_loss      | 130      |
# |    critic_loss     | 60.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 280320   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 318      |
# |    ep_rew_mean     | 53.5     |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 1210     |
# |    fps             | 1630     |
# |    time_elapsed    | 430      |
# |    total_timesteps | 1703316  |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 40.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 280448   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | 46.3     |
# |    success_rate    | 0.3      |
# ...
# |    n_updates       | 315264   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 258      |
# |    ep_rew_mean     | 37.5     |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 2030     |
# |    fps             | 1634     |
# |    time_elapsed    | 561      |
# |    total_timesteps | 1918872  |
# | train/             |          |
# |    actor_loss      | 103      |
# |    critic_loss     | 46       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 316416   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 297      |
# |    ep_rew_mean     | 39.7     |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 2040     |
# |    fps             | 1634     |
# |    time_elapsed    | 564      |
# |    total_timesteps | 1922808  |
# | train/             |          |
# |    actor_loss      | 103      |
# |    critic_loss     | 44.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 317056   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 327      |
# |    ep_rew_mean     | 49.4     |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 2050     |
# |    fps             | 1635     |
# |    time_elapsed    | 570      |
# |    total_timesteps | 1933776  |
# | train/             |          |
# |    actor_loss      | 100      |
# |    critic_loss     | 57.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 318848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 358      |
# |    ep_rew_mean     | 54.1     |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2060     |
# |    fps             | 1635     |
# |    time_elapsed    | 572      |
# |    total_timesteps | 1936620  |
# | train/             |          |
# |    actor_loss      | 102      |
# |    critic_loss     | 32.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 319360   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 406      |
# |    ep_rew_mean     | 60.2     |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 2070     |
# |    fps             | 1636     |
# |    time_elapsed    | 574      |
# |    total_timesteps | 1939956  |
# | train/             |          |
# |    actor_loss      | 98.6     |
# |    critic_loss     | 30.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 319872   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 405      |
# |    ep_rew_mean     | 65       |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 2080     |
# |    fps             | 1636     |
# |    time_elapsed    | 576      |
# |    total_timesteps | 1943532  |
# | train/             |          |
# |    actor_loss      | 98.9     |
# |    critic_loss     | 44.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 320512   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 384      |
# |    ep_rew_mean     | 73       |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 2090     |
# |    fps             | 1635     |
# |    time_elapsed    | 578      |
# |    total_timesteps | 1947024  |
# | train/             |          |
# |    actor_loss      | 97.2     |
# |    critic_loss     | 41.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 321152   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 390      |
# |    ep_rew_mean     | 78.6     |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 1636     |
# |    time_elapsed    | 580      |
# |    total_timesteps | 1950300  |
# | train/             |          |
# |    actor_loss      | 97.4     |
# |    critic_loss     | 34.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 321664   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 428      |
# |    ep_rew_mean     | 71.6     |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 2110     |
# |    fps             | 1636     |
# |    time_elapsed    | 581      |
# |    total_timesteps | 1952088  |
# | train/             |          |
# |    actor_loss      | 97.9     |
# |    critic_loss     | 48       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 321920   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 443      |
# |    ep_rew_mean     | 65.4     |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2120     |
# |    fps             | 1636     |
# |    time_elapsed    | 583      |
# |    total_timesteps | 1955436  |
# | train/             |          |
# |    actor_loss      | 94.3     |
# |    critic_loss     | 29.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 322560   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 422      |
# |    ep_rew_mean     | 66.4     |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 2130     |
# |    fps             | 1636     |
# |    time_elapsed    | 584      |
# |    total_timesteps | 1957872  |
# | train/             |          |
# |    actor_loss      | 93.9     |
# |    critic_loss     | 32.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 322944   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 376      |
# |    ep_rew_mean     | 61       |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2140     |
# |    fps             | 1636     |
# |    time_elapsed    | 586      |
# |    total_timesteps | 1960092  |
# | train/             |          |
# |    actor_loss      | 94.5     |
# |    critic_loss     | 42.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 323328   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0024.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0025.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0026.png
# Eval num_timesteps=1960704, episode_reward=120.40 +/- 116.56
# Episode length: 101.67 +/- 36.71
# Success rate: 66.67%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 102      |
# |    mean_reward     | 120      |
# |    success_rate    | 0.667    |
# | time/              |          |
# |    total_timesteps | 1960704  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 355      |
# |    ep_rew_mean     | 54.3     |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2150     |
# |    fps             | 1634     |
# |    time_elapsed    | 588      |
# |    total_timesteps | 1962324  |
# | train/             |          |
# |    actor_loss      | 93.9     |
# |    critic_loss     | 52.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 323712   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 313      |
# |    ep_rew_mean     | 56       |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2160     |
# |    fps             | 1634     |
# |    time_elapsed    | 589      |
# |    total_timesteps | 1964652  |
# | train/             |          |
# |    actor_loss      | 93.8     |
# |    critic_loss     | 90.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 324096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 271      |
# |    ep_rew_mean     | 57.6     |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2170     |
# |    fps             | 1634     |
# |    time_elapsed    | 591      |
# |    total_timesteps | 1967112  |
# | train/             |          |
# |    actor_loss      | 92.4     |
# |    critic_loss     | 46.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 324480   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 62.7     |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 2180     |
# |    fps             | 1635     |
# |    time_elapsed    | 591      |
# |    total_timesteps | 1968336  |
# | train/             |          |
# |    actor_loss      | 91.8     |
# |    critic_loss     | 79.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 324608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 287      |
# |    ep_rew_mean     | 54.1     |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2190     |
# |    fps             | 1634     |
# |    time_elapsed    | 592      |
# |    total_timesteps | 1969296  |
# | train/             |          |
# |    actor_loss      | 92.8     |
# |    critic_loss     | 43.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 324864   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 246      |
# |    ep_rew_mean     | 48       |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 1635     |
# |    time_elapsed    | 593      |
# |    total_timesteps | 1971288  |
# | train/             |          |
# |    actor_loss      | 91.3     |
# |    critic_loss     | 59.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 325120   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 57.4     |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 2210     |
# |    fps             | 1634     |
# |    time_elapsed    | 595      |
# |    total_timesteps | 1973772  |
# | train/             |          |
# |    actor_loss      | 92.3     |
# |    critic_loss     | 36.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 325632   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 55.3     |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 2220     |
# |    fps             | 1635     |
# |    time_elapsed    | 597      |
# |    total_timesteps | 1977000  |
# | train/             |          |
# |    actor_loss      | 89.4     |
# |    critic_loss     | 33       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 326144   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 65.3     |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 2230     |
# |    fps             | 1635     |
# |    time_elapsed    | 598      |
# |    total_timesteps | 1979436  |
# | train/             |          |
# |    actor_loss      | 90.5     |
# |    critic_loss     | 48.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 326528   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 224      |
# |    ep_rew_mean     | 67.4     |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 2240     |
# |    fps             | 1635     |
# |    time_elapsed    | 600      |
# |    total_timesteps | 1982256  |
# | train/             |          |
# |    actor_loss      | 88.3     |
# |    critic_loss     | 31.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 327040   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 59.1     |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 2250     |
# |    fps             | 1635     |
# |    time_elapsed    | 601      |
# |    total_timesteps | 1983876  |
# | train/             |          |
# |    actor_loss      | 85.9     |
# |    critic_loss     | 49       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 327296   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 56.8     |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 2260     |
# |    fps             | 1636     |
# |    time_elapsed    | 601      |
# |    total_timesteps | 1985220  |
# | train/             |          |
# |    actor_loss      | 87.6     |
# |    critic_loss     | 47.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 327424   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 175      |
# |    ep_rew_mean     | 56.4     |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 2270     |
# |    fps             | 1635     |
# |    time_elapsed    | 602      |
# |    total_timesteps | 1986948  |
# | train/             |          |
# |    actor_loss      | 85.9     |
# |    critic_loss     | 63.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 327808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 166      |
# |    ep_rew_mean     | 56.1     |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 2280     |
# |    fps             | 1636     |
# |    time_elapsed    | 604      |
# |    total_timesteps | 1990200  |
# | train/             |          |
# |    actor_loss      | 86.7     |
# |    critic_loss     | 34.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 328320   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | 58.8     |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 2290     |
# |    fps             | 1636     |
# |    time_elapsed    | 607      |
# |    total_timesteps | 1995420  |
# | train/             |          |
# |    actor_loss      | 84.2     |
# |    critic_loss     | 39.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 329216   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | 63.6     |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 1636     |
# |    time_elapsed    | 610      |
# |    total_timesteps | 1999200  |
# | train/             |          |
# |    actor_loss      | 83.1     |
# |    critic_loss     | 41.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 329856   |
# ---------------------------------

# %%
# > 2M steps, increase spawn radius
spawn_radius=(2.5, 20.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)
model.save(os.path.join(out_dir, "model_3M"))
# Out:
# Increasing spawn radius to  (2.5, 20.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 279      |
# |    ep_rew_mean     | 56.2     |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2310     |
# |    fps             | 1932     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2005860  |
# | train/             |          |
# |    actor_loss      | 85.6     |
# |    critic_loss     | 46.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 330880   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 278      |
# |    ep_rew_mean     | 65.6     |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 2320     |
# |    fps             | 1748     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2009280  |
# | train/             |          |
# |    actor_loss      | 82.8     |
# |    critic_loss     | 40.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 331520   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 363      |
# |    ep_rew_mean     | 58.9     |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2330     |
# |    fps             | 1699     |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2022180  |
# | train/             |          |
# |    actor_loss      | 78.6     |
# |    critic_loss     | 40.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 333696   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 385      |
# |    ep_rew_mean     | 61       |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2340     |
# |    fps             | 1711     |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2025384  |
# | train/             |          |
# |    actor_loss      | 76.1     |
# |    critic_loss     | 56.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 334208   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 393      |
# |    ep_rew_mean     | 71.6     |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2350     |
# |    fps             | 1732     |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2028024  |
# | train/             |          |
# |    actor_loss      | 77.2     |
# |    critic_loss     | 52.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 334592   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 429      |
# |    ep_rew_mean     | 70.8     |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2360     |
# |    fps             | 1738     |
# |    time_elapsed    | 20       |
# |    total_timesteps | 2037468  |
# | train/             |          |
# |    actor_loss      | 73.2     |
# |    critic_loss     | 49.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 336128   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 525      |
# |    ep_rew_mean     | 69.8     |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 2370     |
# |    fps             | 1710     |
# |    time_elapsed    | 27       |
# |    total_timesteps | 2047800  |
# | train/             |          |
# |    actor_loss      | 69.7     |
# |    critic_loss     | 41.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 337920   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 593      |
# |    ep_rew_mean     | 65.1     |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 2380     |
# |    fps             | 1721     |
# |    time_elapsed    | 30       |
# |    total_timesteps | 2053512  |
# | train/             |          |
# |    actor_loss      | 67.8     |
# |    critic_loss     | 37.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 338816   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 582      |
# |    ep_rew_mean     | 67.8     |
# |    success_rate    | 0.26     |
# | time/              |          |
# |    episodes        | 2390     |
# |    fps             | 1716     |
# |    time_elapsed    | 32       |
# |    total_timesteps | 2058036  |
# | train/             |          |
# |    actor_loss      | 65.2     |
# |    critic_loss     | 45.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 339584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 617      |
# |    ep_rew_mean     | 70.3     |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 1715     |
# |    time_elapsed    | 36       |
# |    total_timesteps | 2063472  |
# | train/             |          |
# |    actor_loss      | 63.2     |
# |    critic_loss     | 48.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 340480   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 633      |
# |    ep_rew_mean     | 73       |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 2410     |
# |    fps             | 1699     |
# |    time_elapsed    | 44       |
# |    total_timesteps | 2077200  |
# | train/             |          |
# |    actor_loss      | 59.3     |
# |    critic_loss     | 21       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 342784   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 729      |
# |    ep_rew_mean     | 79.5     |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 2420     |
# |    fps             | 1692     |
# |    time_elapsed    | 52       |
# |    total_timesteps | 2091060  |
# | train/             |          |
# |    actor_loss      | 55       |
# |    critic_loss     | 34.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 345088   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 744      |
# |    ep_rew_mean     | 86.6     |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 2430     |
# |    fps             | 1688     |
# |    time_elapsed    | 55       |
# |    total_timesteps | 2094768  |
# | train/             |          |
# |    actor_loss      | 52.1     |
# |    critic_loss     | 37       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 345728   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 763      |
# |    ep_rew_mean     | 91.9     |
# |    success_rate    | 0.26     |
# | time/              |          |
# |    episodes        | 2440     |
# |    fps             | 1686     |
# |    time_elapsed    | 58       |
# |    total_timesteps | 2100072  |
# | train/             |          |
# |    actor_loss      | 52.8     |
# |    critic_loss     | 51.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 346624   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 927      |
# |    ep_rew_mean     | 100      |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 2450     |
# |    fps             | 1688     |
# |    time_elapsed    | 76       |
# |    total_timesteps | 2130384  |
# | train/             |          |
# |    actor_loss      | 45       |
# |    critic_loss     | 43.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 351616   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 110      |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 2460     |
# |    fps             | 1687     |
# |    time_elapsed    | 79       |
# |    total_timesteps | 2134944  |
# | train/             |          |
# |    actor_loss      | 44.2     |
# |    critic_loss     | 45       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 352384   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 993      |
# |    ep_rew_mean     | 123      |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 2470     |
# |    fps             | 1680     |
# |    time_elapsed    | 81       |
# |    total_timesteps | 2138172  |
# | train/             |          |
# |    actor_loss      | 41.3     |
# |    critic_loss     | 45.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 353024   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 933      |
# |    ep_rew_mean     | 123      |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 2480     |
# |    fps             | 1684     |
# |    time_elapsed    | 85       |
# |    total_timesteps | 2144772  |
# | train/             |          |
# |    actor_loss      | 38.5     |
# |    critic_loss     | 32.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 354048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 946      |
# |    ep_rew_mean     | 131      |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2490     |
# |    fps             | 1677     |
# |    time_elapsed    | 91       |
# |    total_timesteps | 2155128  |
# | train/             |          |
# |    actor_loss      | 36.4     |
# |    critic_loss     | 33.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 355840   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 977      |
# |    ep_rew_mean     | 139      |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 1673     |
# |    time_elapsed    | 99       |
# |    total_timesteps | 2168076  |
# | train/             |          |
# |    actor_loss      | 34.1     |
# |    critic_loss     | 36       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 358016   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+03 |
# |    ep_rew_mean     | 146      |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 2510     |
# |    fps             | 1675     |
# |    time_elapsed    | 102      |
# |    total_timesteps | 2172900  |
# | train/             |          |
# |    actor_loss      | 32.4     |
# |    critic_loss     | 21.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 358784   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 944      |
# |    ep_rew_mean     | 141      |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 2520     |
# |    fps             | 1678     |
# |    time_elapsed    | 105      |
# |    total_timesteps | 2178024  |
# | train/             |          |
# |    actor_loss      | 33.2     |
# |    critic_loss     | 53.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 359552   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 891      |
# |    ep_rew_mean     | 148      |
# |    success_rate    | 0.46     |
# | time/              |          |
# |    episodes        | 2530     |
# |    fps             | 1676     |
# |    time_elapsed    | 108      |
# |    total_timesteps | 2183328  |
# | train/             |          |
# |    actor_loss      | 31.5     |
# |    critic_loss     | 48.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 360448   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 879      |
# |    ep_rew_mean     | 151      |
# |    success_rate    | 0.48     |
# | time/              |          |
# |    episodes        | 2540     |
# |    fps             | 1676     |
# |    time_elapsed    | 111      |
# |    total_timesteps | 2187912  |
# | train/             |          |
# |    actor_loss      | 31.4     |
# |    critic_loss     | 47.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 361216   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 749      |
# |    ep_rew_mean     | 149      |
# |    success_rate    | 0.53     |
# | time/              |          |
# |    episodes        | 2550     |
# |    fps             | 1675     |
# |    time_elapsed    | 114      |
# |    total_timesteps | 2193348  |
# | train/             |          |
# |    actor_loss      | 30.1     |
# |    critic_loss     | 37.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 362112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 650      |
# |    ep_rew_mean     | 147      |
# |    success_rate    | 0.57     |
# | time/              |          |
# |    episodes        | 2560     |
# |    fps             | 1671     |
# |    time_elapsed    | 120      |
# |    total_timesteps | 2203152  |
# | train/             |          |
# |    actor_loss      | 29       |
# |    critic_loss     | 27.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 363776   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 646      |
# |    ep_rew_mean     | 140      |
# |    success_rate    | 0.56     |
# | time/              |          |
# |    episodes        | 2570     |
# |    fps             | 1672     |
# |    time_elapsed    | 125      |
# |    total_timesteps | 2211756  |
# | train/             |          |
# |    actor_loss      | 26.8     |
# |    critic_loss     | 33.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 365184   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 731      |
# |    ep_rew_mean     | 155      |
# |    success_rate    | 0.58     |
# | time/              |          |
# |    episodes        | 2580     |
# |    fps             | 1671     |
# |    time_elapsed    | 132      |
# |    total_timesteps | 2222244  |
# | train/             |          |
# |    actor_loss      | 24.1     |
# |    critic_loss     | 46.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 366976   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 757      |
# |    ep_rew_mean     | 160      |
# |    success_rate    | 0.59     |
# | time/              |          |
# |    episodes        | 2590     |
# |    fps             | 1667     |
# |    time_elapsed    | 135      |
# |    total_timesteps | 2228100  |
# | train/             |          |
# |    actor_loss      | 23.4     |
# |    critic_loss     | 23.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 368000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 750      |
# |    ep_rew_mean     | 168      |
# |    success_rate    | 0.64     |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 1668     |
# |    time_elapsed    | 139      |
# |    total_timesteps | 2233848  |
# | train/             |          |
# |    actor_loss      | 22.2     |
# |    critic_loss     | 38.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 368896   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 714      |
# |    ep_rew_mean     | 170      |
# |    success_rate    | 0.66     |
# | time/              |          |
# |    episodes        | 2610     |
# |    fps             | 1667     |
# |    time_elapsed    | 142      |
# |    total_timesteps | 2238264  |
# | train/             |          |
# |    actor_loss      | 20.4     |
# |    critic_loss     | 26.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 369664   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0027.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0028.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0029.png
# Eval num_timesteps=2241408, episode_reward=218.93 +/- 12.40
# Episode length: 326.67 +/- 146.38
# Success rate: 100.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 327      |
# |    mean_reward     | 219      |
# |    success_rate    | 1        |
# | time/              |          |
# |    total_timesteps | 2241408  |
# | train/             |          |
# |    actor_loss      | 22.1     |
# |    critic_loss     | 35.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 370176   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 698      |
# |    ep_rew_mean     | 175      |
# |    success_rate    | 0.69     |
# | time/              |          |
# |    episodes        | 2620     |
# |    fps             | 1652     |
# |    time_elapsed    | 147      |
# |    total_timesteps | 2244732  |
# | train/             |          |
# |    actor_loss      | 20.8     |
# |    critic_loss     | 35.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 370688   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 670      |
# |    ep_rew_mean     | 173      |
# |    success_rate    | 0.69     |
# | time/              |          |
# |    episodes        | 2630     |
# |    fps             | 1650     |
# |    time_elapsed    | 151      |
# |    total_timesteps | 2251380  |
# | train/             |          |
# |    actor_loss      | 18.9     |
# |    critic_loss     | 21.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 371840   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 665      |
# |    ep_rew_mean     | 179      |
# |    success_rate    | 0.72     |
# | time/              |          |
# |    episodes        | 2640     |
# |    fps             | 1653     |
# |    time_elapsed    | 158      |
# |    total_timesteps | 2263152  |
# | train/             |          |
# |    actor_loss      | 19.1     |
# |    critic_loss     | 30.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 373760   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 738      |
# |    ep_rew_mean     | 185      |
# |    success_rate    | 0.74     |
# | time/              |          |
# |    episodes        | 2650     |
# |    fps             | 1654     |
# |    time_elapsed    | 162      |
# |    total_timesteps | 2270964  |
# | train/             |          |
# |    actor_loss      | 20.1     |
# |    critic_loss     | 39.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 375040   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 748      |
# |    ep_rew_mean     | 189      |
# |    success_rate    | 0.76     |
# | time/              |          |
# |    episodes        | 2660     |
# |    fps             | 1654     |
# |    time_elapsed    | 165      |
# |    total_timesteps | 2274780  |
# | train/             |          |
# |    actor_loss      | 19.4     |
# |    critic_loss     | 24       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 375680   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 721      |
# |    ep_rew_mean     | 191      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 2670     |
# |    fps             | 1651     |
# |    time_elapsed    | 168      |
# |    total_timesteps | 2279268  |
# | train/             |          |
# |    actor_loss      | 20.6     |
# |    critic_loss     | 26.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 376448   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 665      |
# |    ep_rew_mean     | 183      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 2680     |
# |    fps             | 1650     |
# |    time_elapsed    | 170      |
# |    total_timesteps | 2282784  |
# | train/             |          |
# |    actor_loss      | 17.9     |
# |    critic_loss     | 33.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 377088   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 653      |
# |    ep_rew_mean     | 180      |
# |    success_rate    | 0.76     |
# | time/              |          |
# |    episodes        | 2690     |
# |    fps             | 1651     |
# |    time_elapsed    | 172      |
# |    total_timesteps | 2286036  |
# | train/             |          |
# |    actor_loss      | 17.7     |
# |    critic_loss     | 34.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 377600   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 603      |
# |    ep_rew_mean     | 178      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 1650     |
# |    time_elapsed    | 173      |
# |    total_timesteps | 2288064  |
# | train/             |          |
# |    actor_loss      | 18.5     |
# |    critic_loss     | 37.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 377984   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 544      |
# |    ep_rew_mean     | 184      |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 2710     |
# |    fps             | 1650     |
# |    time_elapsed    | 175      |
# |    total_timesteps | 2290380  |
# | train/             |          |
# |    actor_loss      | 18.9     |
# |    critic_loss     | 34.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 378368   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 537      |
# |    ep_rew_mean     | 185      |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 2720     |
# |    fps             | 1653     |
# |    time_elapsed    | 177      |
# |    total_timesteps | 2295480  |
# | train/             |          |
# |    actor_loss      | 16.4     |
# |    critic_loss     | 34.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 379136   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 535      |
# |    ep_rew_mean     | 187      |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 2730     |
# |    fps             | 1651     |
# |    time_elapsed    | 180      |
# |    total_timesteps | 2298972  |
# | train/             |          |
# |    actor_loss      | 14.5     |
# |    critic_loss     | 29.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 379776   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 512      |
# |    ep_rew_mean     | 183      |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 2740     |
# |    fps             | 1651     |
# |    time_elapsed    | 182      |
# |    total_timesteps | 2302860  |
# | train/             |          |
# |    actor_loss      | 15.9     |
# |    critic_loss     | 30.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 380416   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 419      |
# |    ep_rew_mean     | 174      |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    episodes        | 2750     |
# |    fps             | 1651     |
# |    time_elapsed    | 185      |
# |    total_timesteps | 2307180  |
# | train/             |          |
# |    actor_loss      | 15.1     |
# |    critic_loss     | 66.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 381184   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 399      |
# |    ep_rew_mean     | 167      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 2760     |
# |    fps             | 1651     |
# |    time_elapsed    | 187      |
# |    total_timesteps | 2311140  |
# | train/             |          |
# |    actor_loss      | 15.3     |
# |    critic_loss     | 26.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 381824   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 419      |
# |    ep_rew_mean     | 172      |
# |    success_rate    | 0.79     |
# | time/              |          |
# |    episodes        | 2770     |
# |    fps             | 1651     |
# |    time_elapsed    | 189      |
# |    total_timesteps | 2313588  |
# | train/             |          |
# |    actor_loss      | 15.5     |
# |    critic_loss     | 47.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 382208   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 396      |
# |    ep_rew_mean     | 178      |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 2780     |
# |    fps             | 1650     |
# |    time_elapsed    | 191      |
# |    total_timesteps | 2317236  |
# | train/             |          |
# |    actor_loss      | 14.4     |
# |    critic_loss     | 35.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 382848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 356      |
# |    ep_rew_mean     | 178      |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 2790     |
# |    fps             | 1652     |
# |    time_elapsed    | 192      |
# |    total_timesteps | 2319876  |
# | train/             |          |
# |    actor_loss      | 16.1     |
# |    critic_loss     | 33.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 383232   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 341      |
# |    ep_rew_mean     | 168      |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 1651     |
# |    time_elapsed    | 195      |
# |    total_timesteps | 2323644  |
# | train/             |          |
# |    actor_loss      | 16       |
# |    critic_loss     | 25.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 383872   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 345      |
# |    ep_rew_mean     | 169      |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    episodes        | 2810     |
# |    fps             | 1651     |
# |    time_elapsed    | 196      |
# |    total_timesteps | 2326608  |
# | train/             |          |
# |    actor_loss      | 15.9     |
# |    critic_loss     | 39.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 384384   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 342      |
# |    ep_rew_mean     | 171      |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 2820     |
# |    fps             | 1652     |
# |    time_elapsed    | 198      |
# |    total_timesteps | 2329188  |
# | train/             |          |
# |    actor_loss      | 18.3     |
# |    critic_loss     | 25.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 384768   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 349      |
# |    ep_rew_mean     | 169      |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    episodes        | 2830     |
# |    fps             | 1651     |
# |    time_elapsed    | 200      |
# |    total_timesteps | 2332908  |
# | train/             |          |
# |    actor_loss      | 15.4     |
# |    critic_loss     | 34.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 385408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 353      |
# |    ep_rew_mean     | 174      |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 2840     |
# |    fps             | 1651     |
# |    time_elapsed    | 203      |
# |    total_timesteps | 2337456  |
# | train/             |          |
# |    actor_loss      | 15.2     |
# |    critic_loss     | 52.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 386176   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 342      |
# |    ep_rew_mean     | 176      |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 2850     |
# |    fps             | 1652     |
# |    time_elapsed    | 205      |
# |    total_timesteps | 2340696  |
# | train/             |          |
# |    actor_loss      | 15.6     |
# |    critic_loss     | 29.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 386688   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 354      |
# |    ep_rew_mean     | 183      |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 2860     |
# |    fps             | 1651     |
# |    time_elapsed    | 207      |
# |    total_timesteps | 2344224  |
# | train/             |          |
# |    actor_loss      | 15.5     |
# |    critic_loss     | 24.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 387328   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 318      |
# |    ep_rew_mean     | 180      |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 2870     |
# |    fps             | 1652     |
# |    time_elapsed    | 210      |
# |    total_timesteps | 2348784  |
# | train/             |          |
# |    actor_loss      | 14.2     |
# |    critic_loss     | 35.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 388096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 349      |
# |    ep_rew_mean     | 183      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 2880     |
# |    fps             | 1652     |
# |    time_elapsed    | 212      |
# |    total_timesteps | 2352564  |
# | train/             |          |
# |    actor_loss      | 12.2     |
# |    critic_loss     | 26       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 388736   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 346      |
# |    ep_rew_mean     | 188      |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2890     |
# |    fps             | 1653     |
# |    time_elapsed    | 214      |
# |    total_timesteps | 2356740  |
# | train/             |          |
# |    actor_loss      | 13.1     |
# |    critic_loss     | 22.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 389376   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 339      |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 1652     |
# |    time_elapsed    | 216      |
# |    total_timesteps | 2359692  |
# | train/             |          |
# |    actor_loss      | 11.5     |
# |    critic_loss     | 31.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 389888   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 337      |
# |    ep_rew_mean     | 192      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 2910     |
# |    fps             | 1651     |
# |    time_elapsed    | 219      |
# |    total_timesteps | 2363280  |
# | train/             |          |
# |    actor_loss      | 9.82     |
# |    critic_loss     | 31.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 390528   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 341      |
# |    ep_rew_mean     | 192      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 2920     |
# |    fps             | 1652     |
# |    time_elapsed    | 222      |
# |    total_timesteps | 2368800  |
# | train/             |          |
# |    actor_loss      | 8.14     |
# |    critic_loss     | 38       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 391424   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 328      |
# |    ep_rew_mean     | 194      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2930     |
# |    fps             | 1653     |
# |    time_elapsed    | 223      |
# |    total_timesteps | 2371428  |
# | train/             |          |
# |    actor_loss      | 7.87     |
# |    critic_loss     | 49.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 391808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 194      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2940     |
# |    fps             | 1653     |
# |    time_elapsed    | 226      |
# |    total_timesteps | 2376024  |
# | train/             |          |
# |    actor_loss      | 6.07     |
# |    critic_loss     | 27.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 392576   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 365      |
# |    ep_rew_mean     | 203      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 2950     |
# |    fps             | 1653     |
# |    time_elapsed    | 229      |
# |    total_timesteps | 2381352  |
# | train/             |          |
# |    actor_loss      | 5.37     |
# |    critic_loss     | 35.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 393472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 382      |
# |    ep_rew_mean     | 206      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 2960     |
# |    fps             | 1654     |
# |    time_elapsed    | 233      |
# |    total_timesteps | 2387508  |
# | train/             |          |
# |    actor_loss      | 3.15     |
# |    critic_loss     | 40.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 394496   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 410      |
# |    ep_rew_mean     | 205      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 2970     |
# |    fps             | 1651     |
# |    time_elapsed    | 236      |
# |    total_timesteps | 2392488  |
# | train/             |          |
# |    actor_loss      | 3.7      |
# |    critic_loss     | 34.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 395392   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 393      |
# |    ep_rew_mean     | 204      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 2980     |
# |    fps             | 1651     |
# |    time_elapsed    | 239      |
# |    total_timesteps | 2396196  |
# | train/             |          |
# |    actor_loss      | -0.512   |
# |    critic_loss     | 43.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 396032   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 385      |
# |    ep_rew_mean     | 202      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2990     |
# |    fps             | 1651     |
# |    time_elapsed    | 241      |
# |    total_timesteps | 2400780  |
# | train/             |          |
# |    actor_loss      | 0.688    |
# |    critic_loss     | 28.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 396800   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 446      |
# |    ep_rew_mean     | 201      |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 1652     |
# |    time_elapsed    | 247      |
# |    total_timesteps | 2410368  |
# | train/             |          |
# |    actor_loss      | -4.06    |
# |    critic_loss     | 24.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 398336   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 483      |
# |    ep_rew_mean     | 205      |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3010     |
# |    fps             | 1652     |
# |    time_elapsed    | 253      |
# |    total_timesteps | 2419644  |
# | train/             |          |
# |    actor_loss      | -5.77    |
# |    critic_loss     | 32.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 399872   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 578      |
# |    ep_rew_mean     | 202      |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 3020     |
# |    fps             | 1653     |
# |    time_elapsed    | 258      |
# |    total_timesteps | 2428176  |
# | train/             |          |
# |    actor_loss      | -8.05    |
# |    critic_loss     | 37.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 401280   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 584      |
# |    ep_rew_mean     | 205      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 3030     |
# |    fps             | 1651     |
# |    time_elapsed    | 260      |
# |    total_timesteps | 2432340  |
# | train/             |          |
# |    actor_loss      | -9.78    |
# |    critic_loss     | 36.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 402048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 603      |
# |    ep_rew_mean     | 203      |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 3040     |
# |    fps             | 1653     |
# |    time_elapsed    | 263      |
# |    total_timesteps | 2437344  |
# | train/             |          |
# |    actor_loss      | -10.3    |
# |    critic_loss     | 30.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 402816   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 652      |
# |    ep_rew_mean     | 201      |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 3050     |
# |    fps             | 1653     |
# |    time_elapsed    | 268      |
# |    total_timesteps | 2445768  |
# | train/             |          |
# |    actor_loss      | -12.9    |
# |    critic_loss     | 26.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 404224   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 643      |
# |    ep_rew_mean     | 199      |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 3060     |
# |    fps             | 1653     |
# |    time_elapsed    | 271      |
# |    total_timesteps | 2449716  |
# | train/             |          |
# |    actor_loss      | -13.7    |
# |    critic_loss     | 26.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 404864   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 624      |
# |    ep_rew_mean     | 201      |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 3070     |
# |    fps             | 1651     |
# |    time_elapsed    | 274      |
# |    total_timesteps | 2455488  |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 29       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 405888   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 619      |
# |    ep_rew_mean     | 198      |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 3080     |
# |    fps             | 1652     |
# |    time_elapsed    | 279      |
# |    total_timesteps | 2462508  |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 22.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 407040   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 682      |
# |    ep_rew_mean     | 196      |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 3090     |
# |    fps             | 1652     |
# |    time_elapsed    | 285      |
# |    total_timesteps | 2472660  |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 24.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 408704   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 673      |
# |    ep_rew_mean     | 194      |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 1651     |
# |    time_elapsed    | 288      |
# |    total_timesteps | 2477712  |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 28.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 409600   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0030.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0031.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0032.png
# Eval num_timesteps=2481408, episode_reward=147.77 +/- 90.61
# Episode length: 434.67 +/- 353.57
# Success rate: 66.67%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 435      |
# |    mean_reward     | 148      |
# |    success_rate    | 0.667    |
# | time/              |          |
# |    total_timesteps | 2481408  |
# | train/             |          |
# |    actor_loss      | -15.8    |
# |    critic_loss     | 30.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 410112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 732      |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 3110     |
# |    fps             | 1644     |
# |    time_elapsed    | 294      |
# |    total_timesteps | 2486004  |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 30.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 410880   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 670      |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 3120     |
# |    fps             | 1643     |
# |    time_elapsed    | 297      |
# |    total_timesteps | 2490840  |
# | train/             |          |
# |    actor_loss      | -16.9    |
# |    critic_loss     | 25.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 411776   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 677      |
# |    ep_rew_mean     | 198      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 3130     |
# |    fps             | 1645     |
# |    time_elapsed    | 305      |
# |    total_timesteps | 2503524  |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 31.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 413824   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 712      |
# |    ep_rew_mean     | 194      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 3140     |
# |    fps             | 1643     |
# |    time_elapsed    | 310      |
# |    total_timesteps | 2511456  |
# | train/             |          |
# |    actor_loss      | -18      |
# |    critic_loss     | 25.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 415232   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 705      |
# |    ep_rew_mean     | 194      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 3150     |
# |    fps             | 1643     |
# |    time_elapsed    | 313      |
# |    total_timesteps | 2516952  |
# | train/             |          |
# |    actor_loss      | -16.4    |
# |    critic_loss     | 20.8     |
# ...
# |    ep_rew_mean     | 165      |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 4420     |
# |    fps             | 1641     |
# |    time_elapsed    | 516      |
# |    total_timesteps | 2849568  |
# | train/             |          |
# |    actor_loss      | -67.4    |
# |    critic_loss     | 15.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 471552   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 394      |
# |    ep_rew_mean     | 165      |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 4430     |
# |    fps             | 1641     |
# |    time_elapsed    | 517      |
# |    total_timesteps | 2851764  |
# | train/             |          |
# |    actor_loss      | -66.8    |
# |    critic_loss     | 22.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 471936   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 385      |
# |    ep_rew_mean     | 175      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 4440     |
# |    fps             | 1642     |
# |    time_elapsed    | 521      |
# |    total_timesteps | 2857644  |
# | train/             |          |
# |    actor_loss      | -67.8    |
# |    critic_loss     | 19.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 472832   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 398      |
# |    ep_rew_mean     | 188      |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 4450     |
# |    fps             | 1642     |
# |    time_elapsed    | 525      |
# |    total_timesteps | 2864136  |
# | train/             |          |
# |    actor_loss      | -68.4    |
# |    critic_loss     | 16.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 473984   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 431      |
# |    ep_rew_mean     | 195      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4460     |
# |    fps             | 1642     |
# |    time_elapsed    | 529      |
# |    total_timesteps | 2871420  |
# | train/             |          |
# |    actor_loss      | -69.4    |
# |    critic_loss     | 26.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 475136   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 452      |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 4470     |
# |    fps             | 1642     |
# |    time_elapsed    | 531      |
# |    total_timesteps | 2875224  |
# | train/             |          |
# |    actor_loss      | -72.1    |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 475776   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 459      |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 4480     |
# |    fps             | 1642     |
# |    time_elapsed    | 535      |
# |    total_timesteps | 2880480  |
# | train/             |          |
# |    actor_loss      | -72.2    |
# |    critic_loss     | 17.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 476672   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 472      |
# |    ep_rew_mean     | 198      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 4490     |
# |    fps             | 1642     |
# |    time_elapsed    | 537      |
# |    total_timesteps | 2883804  |
# | train/             |          |
# |    actor_loss      | -73.3    |
# |    critic_loss     | 16.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 477184   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 481      |
# |    ep_rew_mean     | 200      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 4500     |
# |    fps             | 1641     |
# |    time_elapsed    | 541      |
# |    total_timesteps | 2890788  |
# | train/             |          |
# |    actor_loss      | -74.1    |
# |    critic_loss     | 23.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 478464   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 491      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 4510     |
# |    fps             | 1642     |
# |    time_elapsed    | 544      |
# |    total_timesteps | 2895216  |
# | train/             |          |
# |    actor_loss      | -74.5    |
# |    critic_loss     | 23.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 479104   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 497      |
# |    ep_rew_mean     | 208      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 4520     |
# |    fps             | 1642     |
# |    time_elapsed    | 547      |
# |    total_timesteps | 2900016  |
# | train/             |          |
# |    actor_loss      | -76.9    |
# |    critic_loss     | 19.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 480000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 506      |
# |    ep_rew_mean     | 211      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 4530     |
# |    fps             | 1642     |
# |    time_elapsed    | 551      |
# |    total_timesteps | 2907804  |
# | train/             |          |
# |    actor_loss      | -79.1    |
# |    critic_loss     | 14.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 481280   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 552      |
# |    ep_rew_mean     | 211      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 4540     |
# |    fps             | 1642     |
# |    time_elapsed    | 555      |
# |    total_timesteps | 2913912  |
# | train/             |          |
# |    actor_loss      | -80.4    |
# |    critic_loss     | 22.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 482304   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 568      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 4550     |
# |    fps             | 1643     |
# |    time_elapsed    | 557      |
# |    total_timesteps | 2916852  |
# | train/             |          |
# |    actor_loss      | -80.7    |
# |    critic_loss     | 14.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 482688   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 525      |
# |    ep_rew_mean     | 204      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 4560     |
# |    fps             | 1643     |
# |    time_elapsed    | 559      |
# |    total_timesteps | 2920584  |
# | train/             |          |
# |    actor_loss      | -81.6    |
# |    critic_loss     | 18.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 483328   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 485      |
# |    ep_rew_mean     | 192      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 4570     |
# |    fps             | 1642     |
# |    time_elapsed    | 560      |
# |    total_timesteps | 2921868  |
# | train/             |          |
# |    actor_loss      | -81.9    |
# |    critic_loss     | 17.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 483584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 470      |
# |    ep_rew_mean     | 181      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 4580     |
# |    fps             | 1642     |
# |    time_elapsed    | 561      |
# |    total_timesteps | 2924340  |
# | train/             |          |
# |    actor_loss      | -82.4    |
# |    critic_loss     | 21.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 483968   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 438      |
# |    ep_rew_mean     | 175      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 4590     |
# |    fps             | 1642     |
# |    time_elapsed    | 563      |
# |    total_timesteps | 2927172  |
# | train/             |          |
# |    actor_loss      | -82.1    |
# |    critic_loss     | 19.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 484480   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | 172      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 4600     |
# |    fps             | 1642     |
# |    time_elapsed    | 565      |
# |    total_timesteps | 2930652  |
# | train/             |          |
# |    actor_loss      | -83.1    |
# |    critic_loss     | 13.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 484992   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 398      |
# |    ep_rew_mean     | 162      |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 4610     |
# |    fps             | 1642     |
# |    time_elapsed    | 568      |
# |    total_timesteps | 2934792  |
# | train/             |          |
# |    actor_loss      | -82.7    |
# |    critic_loss     | 21.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 485760   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 367      |
# |    ep_rew_mean     | 155      |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 4620     |
# |    fps             | 1642     |
# |    time_elapsed    | 571      |
# |    total_timesteps | 2939460  |
# | train/             |          |
# |    actor_loss      | -84      |
# |    critic_loss     | 14.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 486528   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 350      |
# |    ep_rew_mean     | 140      |
# |    success_rate    | 0.75     |
# | time/              |          |
# |    episodes        | 4630     |
# |    fps             | 1642     |
# |    time_elapsed    | 575      |
# |    total_timesteps | 2946540  |
# | train/             |          |
# |    actor_loss      | -83.5    |
# |    critic_loss     | 22.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 487680   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | 130      |
# |    success_rate    | 0.71     |
# | time/              |          |
# |    episodes        | 4640     |
# |    fps             | 1642     |
# |    time_elapsed    | 579      |
# |    total_timesteps | 2952348  |
# | train/             |          |
# |    actor_loss      | -84.5    |
# |    critic_loss     | 47.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 488704   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 350      |
# |    ep_rew_mean     | 96.6     |
# |    success_rate    | 0.69     |
# | time/              |          |
# |    episodes        | 4650     |
# |    fps             | 1643     |
# |    time_elapsed    | 583      |
# |    total_timesteps | 2960628  |
# | train/             |          |
# |    actor_loss      | -86.7    |
# |    critic_loss     | 21.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 489984   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0036.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0037.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0038.png
# Eval num_timesteps=2961408, episode_reward=183.62 +/- 38.01
# Episode length: 1044.67 +/- 1025.16
# Success rate: 66.67%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.04e+03 |
# |    mean_reward     | 184      |
# |    success_rate    | 0.667    |
# | time/              |          |
# |    total_timesteps | 2961408  |
# | train/             |          |
# |    actor_loss      | -86.8    |
# |    critic_loss     | 23.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 490112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 435      |
# |    ep_rew_mean     | 97.2     |
# |    success_rate    | 0.68     |
# | time/              |          |
# |    episodes        | 4660     |
# |    fps             | 1635     |
# |    time_elapsed    | 592      |
# |    total_timesteps | 2970708  |
# | train/             |          |
# |    actor_loss      | -86.7    |
# |    critic_loss     | 21.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 491776   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 446      |
# |    ep_rew_mean     | 108      |
# |    success_rate    | 0.72     |
# | time/              |          |
# |    episodes        | 4670     |
# |    fps             | 1635     |
# |    time_elapsed    | 598      |
# |    total_timesteps | 2980056  |
# | train/             |          |
# |    actor_loss      | -89.2    |
# |    critic_loss     | 19.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 493312   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 585      |
# |    ep_rew_mean     | 120      |
# |    success_rate    | 0.72     |
# | time/              |          |
# |    episodes        | 4680     |
# |    fps             | 1636     |
# |    time_elapsed    | 605      |
# |    total_timesteps | 2991396  |
# | train/             |          |
# |    actor_loss      | -88.6    |
# |    critic_loss     | 13.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 495232   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 598      |
# |    ep_rew_mean     | 124      |
# |    success_rate    | 0.73     |
# | time/              |          |
# |    episodes        | 4690     |
# |    fps             | 1636     |
# |    time_elapsed    | 609      |
# |    total_timesteps | 2999268  |
# | train/             |          |
# |    actor_loss      | -92      |
# |    critic_loss     | 21.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 496512   |
# ---------------------------------

# %%
# > 3M steps, increase spawn radius
spawn_radius=(2.5, 40.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_4M"))
# Out:
# Increasing spawn radius to  (2.5, 40.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 651      |
# |    ep_rew_mean     | 129      |
# |    success_rate    | 0.73     |
# | time/              |          |
# |    episodes        | 4700     |
# |    fps             | 1707     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3002928  |
# | train/             |          |
# |    actor_loss      | -90.7    |
# |    critic_loss     | 18.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 497152   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 722      |
# |    ep_rew_mean     | 142      |
# |    success_rate    | 0.76     |
# | time/              |          |
# |    episodes        | 4710     |
# |    fps             | 1930     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 3006708  |
# | train/             |          |
# |    actor_loss      | -90.2    |
# |    critic_loss     | 20.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 497664   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 754      |
# |    ep_rew_mean     | 149      |
# |    success_rate    | 0.78     |
# | time/              |          |
# |    episodes        | 4720     |
# |    fps             | 1778     |
# |    time_elapsed    | 5        |
# |    total_timesteps | 3011256  |
# | train/             |          |
# |    actor_loss      | -90      |
# |    critic_loss     | 13.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498432   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 772      |
# |    ep_rew_mean     | 165      |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 4730     |
# |    fps             | 1674     |
# |    time_elapsed    | 7        |
# |    total_timesteps | 3014592  |
# | train/             |          |
# |    actor_loss      | -90.6    |
# |    critic_loss     | 20.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499072   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 757      |
# |    ep_rew_mean     | 174      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 4740     |
# |    fps             | 1657     |
# |    time_elapsed    | 9        |
# |    total_timesteps | 3017604  |
# | train/             |          |
# |    actor_loss      | -89.6    |
# |    critic_loss     | 15.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 676      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 4750     |
# |    fps             | 1683     |
# |    time_elapsed    | 11       |
# |    total_timesteps | 3020988  |
# | train/             |          |
# |    actor_loss      | -91.3    |
# |    critic_loss     | 18.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 500096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 603      |
# |    ep_rew_mean     | 206      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 4760     |
# |    fps             | 1655     |
# |    time_elapsed    | 13       |
# |    total_timesteps | 3023772  |
# | train/             |          |
# |    actor_loss      | -89.9    |
# |    critic_loss     | 17.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 500608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 604      |
# |    ep_rew_mean     | 206      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 4770     |
# |    fps             | 1692     |
# |    time_elapsed    | 14       |
# |    total_timesteps | 3027408  |
# | train/             |          |
# |    actor_loss      | -90.9    |
# |    critic_loss     | 22.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 501120   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 490      |
# |    ep_rew_mean     | 204      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 4780     |
# |    fps             | 1654     |
# |    time_elapsed    | 20       |
# |    total_timesteps | 3035328  |
# | train/             |          |
# |    actor_loss      | -90.2    |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 502528   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 511      |
# |    ep_rew_mean     | 206      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 4790     |
# |    fps             | 1666     |
# |    time_elapsed    | 22       |
# |    total_timesteps | 3038820  |
# | train/             |          |
# |    actor_loss      | -91.1    |
# |    critic_loss     | 14.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 503040   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 479      |
# |    ep_rew_mean     | 204      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 4800     |
# |    fps             | 1667     |
# |    time_elapsed    | 24       |
# |    total_timesteps | 3043512  |
# | train/             |          |
# |    actor_loss      | -91.4    |
# |    critic_loss     | 27.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 503808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 418      |
# |    ep_rew_mean     | 202      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 4810     |
# |    fps             | 1648     |
# |    time_elapsed    | 27       |
# |    total_timesteps | 3047568  |
# | train/             |          |
# |    actor_loss      | -93.1    |
# |    critic_loss     | 21.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 504576   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 401      |
# |    ep_rew_mean     | 201      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 4820     |
# |    fps             | 1651     |
# |    time_elapsed    | 30       |
# |    total_timesteps | 3052176  |
# | train/             |          |
# |    actor_loss      | -91.2    |
# |    critic_loss     | 15.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 505344   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 411      |
# |    ep_rew_mean     | 200      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 4830     |
# |    fps             | 1651     |
# |    time_elapsed    | 33       |
# |    total_timesteps | 3056808  |
# | train/             |          |
# |    actor_loss      | -90.6    |
# |    critic_loss     | 18.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 506112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 418      |
# |    ep_rew_mean     | 200      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 4840     |
# |    fps             | 1652     |
# |    time_elapsed    | 36       |
# |    total_timesteps | 3062280  |
# | train/             |          |
# |    actor_loss      | -91      |
# |    critic_loss     | 14.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 507008   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 437      |
# |    ep_rew_mean     | 199      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 4850     |
# |    fps             | 1660     |
# |    time_elapsed    | 39       |
# |    total_timesteps | 3067260  |
# | train/             |          |
# |    actor_loss      | -89      |
# |    critic_loss     | 21.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 507776   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 449      |
# |    ep_rew_mean     | 203      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 4860     |
# |    fps             | 1662     |
# |    time_elapsed    | 41       |
# |    total_timesteps | 3070440  |
# | train/             |          |
# |    actor_loss      | -89      |
# |    critic_loss     | 15.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 508288   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 443      |
# |    ep_rew_mean     | 203      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 4870     |
# |    fps             | 1663     |
# |    time_elapsed    | 45       |
# |    total_timesteps | 3077364  |
# | train/             |          |
# |    actor_loss      | -89.7    |
# |    critic_loss     | 21.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 509440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 455      |
# |    ep_rew_mean     | 183      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 4880     |
# |    fps             | 1655     |
# |    time_elapsed    | 47       |
# |    total_timesteps | 3080844  |
# | train/             |          |
# |    actor_loss      | -90      |
# |    critic_loss     | 18.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 510080   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 446      |
# |    ep_rew_mean     | 182      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 4890     |
# |    fps             | 1656     |
# |    time_elapsed    | 49       |
# |    total_timesteps | 3083952  |
# | train/             |          |
# |    actor_loss      | -90.1    |
# |    critic_loss     | 18.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 510592   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 440      |
# |    ep_rew_mean     | 174      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 4900     |
# |    fps             | 1663     |
# |    time_elapsed    | 51       |
# |    total_timesteps | 3087348  |
# | train/             |          |
# |    actor_loss      | -89.7    |
# |    critic_loss     | 23.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 511104   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 426      |
# |    ep_rew_mean     | 173      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 4910     |
# |    fps             | 1656     |
# |    time_elapsed    | 53       |
# |    total_timesteps | 3090744  |
# | train/             |          |
# |    actor_loss      | -90.1    |
# |    critic_loss     | 21.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 511744   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 429      |
# |    ep_rew_mean     | 171      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 4920     |
# |    fps             | 1663     |
# |    time_elapsed    | 54       |
# |    total_timesteps | 3093468  |
# | train/             |          |
# |    actor_loss      | -89.8    |
# |    critic_loss     | 14.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 512128   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 413      |
# |    ep_rew_mean     | 167      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4930     |
# |    fps             | 1653     |
# |    time_elapsed    | 57       |
# |    total_timesteps | 3096804  |
# | train/             |          |
# |    actor_loss      | -90.2    |
# |    critic_loss     | 16.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 512768   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | 162      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 4940     |
# |    fps             | 1654     |
# |    time_elapsed    | 59       |
# |    total_timesteps | 3100728  |
# | train/             |          |
# |    actor_loss      | -90.8    |
# |    critic_loss     | 26.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 513408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 408      |
# |    ep_rew_mean     | 158      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 4950     |
# |    fps             | 1655     |
# |    time_elapsed    | 62       |
# |    total_timesteps | 3105504  |
# | train/             |          |
# |    actor_loss      | -91.1    |
# |    critic_loss     | 26.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 514176   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 403      |
# |    ep_rew_mean     | 156      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 4960     |
# |    fps             | 1655     |
# |    time_elapsed    | 65       |
# |    total_timesteps | 3110172  |
# | train/             |          |
# |    actor_loss      | -91.8    |
# |    critic_loss     | 20.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 514944   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 422      |
# |    ep_rew_mean     | 146      |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 4970     |
# |    fps             | 1652     |
# |    time_elapsed    | 67       |
# |    total_timesteps | 3113760  |
# | train/             |          |
# |    actor_loss      | -90.4    |
# |    critic_loss     | 17.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 515584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 403      |
# |    ep_rew_mean     | 157      |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    episodes        | 4980     |
# |    fps             | 1655     |
# |    time_elapsed    | 71       |
# |    total_timesteps | 3120108  |
# | train/             |          |
# |    actor_loss      | -92.6    |
# |    critic_loss     | 17.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 516608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | 152      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 4990     |
# |    fps             | 1649     |
# |    time_elapsed    | 74       |
# |    total_timesteps | 3125004  |
# | train/             |          |
# |    actor_loss      | -91.4    |
# |    critic_loss     | 28.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 517504   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 425      |
# |    ep_rew_mean     | 156      |
# |    success_rate    | 0.78     |
# | time/              |          |
# |    episodes        | 5000     |
# |    fps             | 1653     |
# |    time_elapsed    | 78       |
# |    total_timesteps | 3131652  |
# | train/             |          |
# |    actor_loss      | -92.5    |
# |    critic_loss     | 24.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 518528   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 433      |
# |    ep_rew_mean     | 156      |
# |    success_rate    | 0.78     |
# | time/              |          |
# |    episodes        | 5010     |
# |    fps             | 1656     |
# |    time_elapsed    | 82       |
# |    total_timesteps | 3138000  |
# | train/             |          |
# |    actor_loss      | -93.4    |
# |    critic_loss     | 26.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 519552   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 460      |
# |    ep_rew_mean     | 154      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 5020     |
# |    fps             | 1652     |
# |    time_elapsed    | 84       |
# |    total_timesteps | 3141564  |
# | train/             |          |
# |    actor_loss      | -93.6    |
# |    critic_loss     | 26.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 520192   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 462      |
# |    ep_rew_mean     | 157      |
# |    success_rate    | 0.78     |
# | time/              |          |
# |    episodes        | 5030     |
# |    fps             | 1651     |
# |    time_elapsed    | 87       |
# |    total_timesteps | 3146940  |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 12.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 521088   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 453      |
# |    ep_rew_mean     | 157      |
# |    success_rate    | 0.78     |
# | time/              |          |
# |    episodes        | 5040     |
# |    fps             | 1648     |
# |    time_elapsed    | 89       |
# |    total_timesteps | 3149616  |
# | train/             |          |
# |    actor_loss      | -93      |
# |    critic_loss     | 20.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 521600   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 437      |
# |    ep_rew_mean     | 157      |
# |    success_rate    | 0.78     |
# | time/              |          |
# |    episodes        | 5050     |
# |    fps             | 1655     |
# |    time_elapsed    | 91       |
# |    total_timesteps | 3153312  |
# | train/             |          |
# |    actor_loss      | -91.4    |
# |    critic_loss     | 19.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 522112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 425      |
# |    ep_rew_mean     | 155      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 5060     |
# |    fps             | 1654     |
# |    time_elapsed    | 93       |
# |    total_timesteps | 3157032  |
# | train/             |          |
# |    actor_loss      | -93.7    |
# |    critic_loss     | 36.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 522752   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 470      |
# |    ep_rew_mean     | 162      |
# |    success_rate    | 0.79     |
# | time/              |          |
# |    episodes        | 5070     |
# |    fps             | 1656     |
# |    time_elapsed    | 95       |
# |    total_timesteps | 3161016  |
# | train/             |          |
# |    actor_loss      | -94.1    |
# |    critic_loss     | 23.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 523392   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 458      |
# |    ep_rew_mean     | 172      |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 5080     |
# |    fps             | 1654     |
# |    time_elapsed    | 99       |
# |    total_timesteps | 3166140  |
# | train/             |          |
# |    actor_loss      | -94.6    |
# |    critic_loss     | 17.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 524288   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 448      |
# |    ep_rew_mean     | 177      |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 5090     |
# |    fps             | 1650     |
# |    time_elapsed    | 102      |
# |    total_timesteps | 3171144  |
# | train/             |          |
# |    actor_loss      | -94.4    |
# |    critic_loss     | 21.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 525184   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 450      |
# |    ep_rew_mean     | 182      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 5100     |
# |    fps             | 1650     |
# |    time_elapsed    | 105      |
# |    total_timesteps | 3176568  |
# | train/             |          |
# |    actor_loss      | -94.9    |
# |    critic_loss     | 21.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 526080   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 469      |
# |    ep_rew_mean     | 183      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 5110     |
# |    fps             | 1655     |
# |    time_elapsed    | 110      |
# |    total_timesteps | 3185580  |
# | train/             |          |
# |    actor_loss      | -93.5    |
# |    critic_loss     | 23.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 527488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 506      |
# |    ep_rew_mean     | 187      |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 5120     |
# |    fps             | 1652     |
# |    time_elapsed    | 115      |
# |    total_timesteps | 3192852  |
# | train/             |          |
# |    actor_loss      | -94.1    |
# |    critic_loss     | 21.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 528768   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 526      |
# |    ep_rew_mean     | 182      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 5130     |
# |    fps             | 1654     |
# |    time_elapsed    | 119      |
# |    total_timesteps | 3199896  |
# | train/             |          |
# |    actor_loss      | -96.3    |
# |    critic_loss     | 26.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 529920   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 546      |
# |    ep_rew_mean     | 185      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 5140     |
# |    fps             | 1654     |
# |    time_elapsed    | 121      |
# |    total_timesteps | 3203784  |
# | train/             |          |
# |    actor_loss      | -94.2    |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 530560   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 549      |
# |    ep_rew_mean     | 185      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 5150     |
# |    fps             | 1651     |
# |    time_elapsed    | 125      |
# |    total_timesteps | 3209616  |
# | train/             |          |
# |    actor_loss      | -94.2    |
# |    critic_loss     | 19.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 531584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 595      |
# |    ep_rew_mean     | 193      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 5160     |
# |    fps             | 1653     |
# |    time_elapsed    | 127      |
# |    total_timesteps | 3213000  |
# | train/             |          |
# |    actor_loss      | -95.7    |
# |    critic_loss     | 21.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 532096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 553      |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 5170     |
# |    fps             | 1654     |
# |    time_elapsed    | 129      |
# |    total_timesteps | 3216084  |
# | train/             |          |
# |    actor_loss      | -96      |
# |    critic_loss     | 17       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 532608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 554      |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 5180     |
# |    fps             | 1656     |
# |    time_elapsed    | 132      |
# |    total_timesteps | 3220896  |
# | train/             |          |
# |    actor_loss      | -96      |
# |    critic_loss     | 20.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 533376   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 544      |
# |    ep_rew_mean     | 200      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 5190     |
# |    fps             | 1655     |
# |    time_elapsed    | 134      |
# |    total_timesteps | 3224592  |
# | train/             |          |
# |    actor_loss      | -95.2    |
# |    critic_loss     | 26.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 534016   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 525      |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 5200     |
# |    fps             | 1654     |
# |    time_elapsed    | 137      |
# |    total_timesteps | 3229740  |
# | train/             |          |
# |    actor_loss      | -96.4    |
# |    critic_loss     | 19.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 534912   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 509      |
# |    ep_rew_mean     | 196      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 5210     |
# |    fps             | 1653     |
# |    time_elapsed    | 139      |
# |    total_timesteps | 3233424  |
# | train/             |          |
# |    actor_loss      | -94.4    |
# |    critic_loss     | 20.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 535552   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 450      |
# |    ep_rew_mean     | 196      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 5220     |
# |    fps             | 1654     |
# |    time_elapsed    | 143      |
# |    total_timesteps | 3239052  |
# | train/             |          |
# |    actor_loss      | -95.9    |
# |    critic_loss     | 16.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 536448   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0039.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0040.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0041.png
# Eval num_timesteps=3242112, episode_reward=197.64 +/- 4.39
# Episode length: 259.67 +/- 36.74
# Success rate: 100.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 260      |
# |    mean_reward     | 198      |
# |    success_rate    | 1        |
# | time/              |          |
# |    total_timesteps | 3242112  |
# | train/             |          |
# |    actor_loss      | -95.7    |
# |    critic_loss     | 19.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 536960   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 464      |
# |    ep_rew_mean     | 206      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 5230     |
# |    fps             | 1642     |
# |    time_elapsed    | 146      |
# |    total_timesteps | 3242232  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 437      |
# |    ep_rew_mean     | 205      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 5240     |
# |    fps             | 1641     |
# |    time_elapsed    | 148      |
# |    total_timesteps | 3245136  |
# | train/             |          |
# |    actor_loss      | -96.8    |
# |    critic_loss     | 19.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 537472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 437      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 5250     |
# |    fps             | 1643     |
# |    time_elapsed    | 150      |
# |    total_timesteps | 3250020  |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 22.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 538240   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 411      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 5260     |
# |    fps             | 1641     |
# |    time_elapsed    | 154      |
# |    total_timesteps | 3255012  |
# | train/             |          |
# |    actor_loss      | -96.3    |
# |    critic_loss     | 17.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 539136   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 407      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 5270     |
# |    fps             | 1643     |
# |    time_elapsed    | 156      |
# |    total_timesteps | 3259992  |
# | train/             |          |
# |    actor_loss      | -98.5    |
# |    critic_loss     | 19.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 539904   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 412      |
# |    ep_rew_mean     | 206      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 5280     |
# |    fps             | 1643     |
# |    time_elapsed    | 159      |
# |    total_timesteps | 3264636  |
# | train/             |          |
# |    actor_loss      | -98.4    |
# |    critic_loss     | 17.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 540672   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 445      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 5290     |
# |    fps             | 1643     |
# |    time_elapsed    | 164      |
# |    total_timesteps | 3273072  |
# | train/             |          |
# |    actor_loss      | -96.2    |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 542080   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 454      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 5300     |
# |    fps             | 1640     |
# |    time_elapsed    | 168      |
# |    total_timesteps | 3278760  |
# | train/             |          |
# |    actor_loss      | -98.8    |
# |    critic_loss     | 14.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 543104   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 477      |
# |    ep_rew_mean     | 211      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 5310     |
# |    fps             | 1642     |
# |    time_elapsed    | 170      |
# |    total_timesteps | 3282876  |
# | train/             |          |
# |    actor_loss      | -99      |
# |    critic_loss     | 19.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 543744   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 504      |
# |    ep_rew_mean     | 212      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 5320     |
# |    fps             | 1644     |
# |    time_elapsed    | 172      |
# |    total_timesteps | 3286188  |
# | train/             |          |
# |    actor_loss      | -98.5    |
# |    critic_loss     | 25.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 544256   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 467      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 5330     |
# |    fps             | 1641     |
# |    time_elapsed    | 176      |
# |    total_timesteps | 3291072  |
# | train/             |          |
# |    actor_loss      | -99.9    |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 545152   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 473      |
# |    ep_rew_mean     | 212      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 5340     |
# |    fps             | 1643     |
# |    time_elapsed    | 179      |
# |    total_timesteps | 3296760  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 15.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 546048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 476      |
# |    ep_rew_mean     | 213      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 5350     |
# |    fps             | 1643     |
# |    time_elapsed    | 183      |
# |    total_timesteps | 3303660  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 20.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 547200   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 484      |
# |    ep_rew_mean     | 212      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 5360     |
# |    fps             | 1643     |
# |    time_elapsed    | 186      |
# |    total_timesteps | 3308964  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 14.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 548096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 471      |
# |    ep_rew_mean     | 215      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 5370     |
# |    fps             | 1644     |
# |    time_elapsed    | 192      |
# |    total_timesteps | 3318312  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 17.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 549632   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 518      |
# |    ep_rew_mean     | 213      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 5380     |
# |    fps             | 1645     |
# |    time_elapsed    | 195      |
# |    total_timesteps | 3323844  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 18.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 550528   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 533      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 5390     |
# |    fps             | 1643     |
# |    time_elapsed    | 198      |
# |    total_timesteps | 3328668  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 16.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 551424   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 568      |
# |    ep_rew_mean     | 211      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 5400     |
# |    fps             | 1643     |
# |    time_elapsed    | 201      |
# |    total_timesteps | 3333996  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 25.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 552320   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 537      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 5410     |
# |    fps             | 1644     |
# |    time_elapsed    | 204      |
# |    total_timesteps | 3338760  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 28.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 553088   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 526      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 5420     |
# |    fps             | 1644     |
# |    time_elapsed    | 207      |
# |    total_timesteps | 3342600  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 17       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 553728   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 534      |
# |    ep_rew_mean     | 208      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 5430     |
# |    fps             | 1644     |
# |    time_elapsed    | 208      |
# |    total_timesteps | 3345684  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 22.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 554240   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 557      |
# |    ep_rew_mean     | 208      |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 5440     |
# |    fps             | 1644     |
# |    time_elapsed    | 211      |
# |    total_timesteps | 3349524  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 16.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 554880   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 555      |
# |    ep_rew_mean     | 205      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 5450     |
# |    fps             | 1644     |
# |    time_elapsed    | 213      |
# |    total_timesteps | 3352692  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 22.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 555392   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 520      |
# |    ep_rew_mean     | 204      |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 5460     |
# |    fps             | 1646     |
# |    time_elapsed    | 215      |
# |    total_timesteps | 3356148  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 25.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 555904   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 516      |
# |    ep_rew_mean     | 199      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 5470     |
# |    fps             | 1645     |
# |    time_elapsed    | 217      |
# |    total_timesteps | 3360600  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 17.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 556672   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 486      |
# |    ep_rew_mean     | 199      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 5480     |
# |    fps             | 1644     |
# |    time_elapsed    | 220      |
# |    total_timesteps | 3365604  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 557568   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 456      |
# |    ep_rew_mean     | 201      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 5490     |
# |    fps             | 1645     |
# |    time_elapsed    | 223      |
# |    total_timesteps | 3370380  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 558336   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 409      |
# |    ep_rew_mean     | 196      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 5500     |
# |    fps             | 1646     |
# |    time_elapsed    | 226      |
# |    total_timesteps | 3375252  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 18.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 559104   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 408      |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 5510     |
# |    fps             | 1644     |
# |    time_elapsed    | 230      |
# |    total_timesteps | 3380856  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 16.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 560128   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 433      |
# |    ep_rew_mean     | 194      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 5520     |
# |    fps             | 1645     |
# |    time_elapsed    | 234      |
# |    total_timesteps | 3388584  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 17.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 561408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 454      |
# |    ep_rew_mean     | 194      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 5530     |
# |    fps             | 1646     |
# |    time_elapsed    | 238      |
# |    total_timesteps | 3395148  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 15.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 562432   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 421      |
# |    ep_rew_mean     | 194      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 5540     |
# |    fps             | 1645     |
# |    time_elapsed    | 242      |
# |    total_timesteps | 3400908  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 14.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 563456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 455      |
# |    ep_rew_mean     | 198      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 5550     |
# |    fps             | 1646     |
# |    time_elapsed    | 245      |
# |    total_timesteps | 3406476  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 18.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 564352   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 512      |
# |    ep_rew_mean     | 200      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 5560     |
# |    fps             | 1645     |
# |    time_elapsed    | 247      |
# |    total_timesteps | 3409980  |
# | train/             |          |
# ...
# |    n_updates       | 649344   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6610     |
# |    fps             | 1643     |
# |    time_elapsed    | 558      |
# |    total_timesteps | 3919824  |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 6.94     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 649856   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 309      |
# |    ep_rew_mean     | 205      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 6620     |
# |    fps             | 1643     |
# |    time_elapsed    | 560      |
# |    total_timesteps | 3922800  |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 20.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 650368   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 307      |
# |    ep_rew_mean     | 205      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 6630     |
# |    fps             | 1643     |
# |    time_elapsed    | 561      |
# |    total_timesteps | 3925356  |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 11.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 650880   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 303      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6640     |
# |    fps             | 1642     |
# |    time_elapsed    | 563      |
# |    total_timesteps | 3927576  |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 11.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 651264   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 290      |
# |    ep_rew_mean     | 206      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6650     |
# |    fps             | 1643     |
# |    time_elapsed    | 564      |
# |    total_timesteps | 3930372  |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 10.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 651648   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 287      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6660     |
# |    fps             | 1643     |
# |    time_elapsed    | 566      |
# |    total_timesteps | 3933348  |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 19.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 652160   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 290      |
# |    ep_rew_mean     | 208      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6670     |
# |    fps             | 1643     |
# |    time_elapsed    | 568      |
# |    total_timesteps | 3936252  |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 9.07     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 652672   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 294      |
# |    ep_rew_mean     | 208      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6680     |
# |    fps             | 1644     |
# |    time_elapsed    | 569      |
# |    total_timesteps | 3938964  |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 509      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 653056   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 288      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6690     |
# |    fps             | 1644     |
# |    time_elapsed    | 571      |
# |    total_timesteps | 3942072  |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 9.77     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 653568   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 285      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6700     |
# |    fps             | 1643     |
# |    time_elapsed    | 573      |
# |    total_timesteps | 3945372  |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 12.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 654208   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 280      |
# |    ep_rew_mean     | 206      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6710     |
# |    fps             | 1643     |
# |    time_elapsed    | 576      |
# |    total_timesteps | 3949332  |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 11.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 654848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 278      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 6720     |
# |    fps             | 1644     |
# |    time_elapsed    | 577      |
# |    total_timesteps | 3952104  |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 17.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 655232   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 296      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6730     |
# |    fps             | 1644     |
# |    time_elapsed    | 580      |
# |    total_timesteps | 3955740  |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 472      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 655872   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6740     |
# |    fps             | 1644     |
# |    time_elapsed    | 582      |
# |    total_timesteps | 3959700  |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 10.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 656512   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 309      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6750     |
# |    fps             | 1644     |
# |    time_elapsed    | 583      |
# |    total_timesteps | 3962076  |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 13.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 656896   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0048.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0049.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0050.png
# Eval num_timesteps=3962112, episode_reward=203.03 +/- 2.72
# Episode length: 255.00 +/- 5.35
# Success rate: 100.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 255      |
# |    mean_reward     | 203      |
# |    success_rate    | 1        |
# | time/              |          |
# |    total_timesteps | 3962112  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 309      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6760     |
# |    fps             | 1640     |
# |    time_elapsed    | 586      |
# |    total_timesteps | 3965040  |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 11.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 657408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 316      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6770     |
# |    fps             | 1640     |
# |    time_elapsed    | 588      |
# |    total_timesteps | 3967800  |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 360      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 657920   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6780     |
# |    fps             | 1640     |
# |    time_elapsed    | 590      |
# |    total_timesteps | 3970380  |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 658304   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | 211      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6790     |
# |    fps             | 1640     |
# |    time_elapsed    | 591      |
# |    total_timesteps | 3972624  |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 14.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 658688   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 311      |
# |    ep_rew_mean     | 211      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6800     |
# |    fps             | 1639     |
# |    time_elapsed    | 593      |
# |    total_timesteps | 3975480  |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 10.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 659200   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | 211      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6810     |
# |    fps             | 1639     |
# |    time_elapsed    | 595      |
# |    total_timesteps | 3978276  |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 22.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 659712   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6820     |
# |    fps             | 1640     |
# |    time_elapsed    | 596      |
# |    total_timesteps | 3981168  |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 13.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 660096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 289      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6830     |
# |    fps             | 1640     |
# |    time_elapsed    | 598      |
# |    total_timesteps | 3984156  |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 19.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 660608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 289      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6840     |
# |    fps             | 1640     |
# |    time_elapsed    | 601      |
# |    total_timesteps | 3987960  |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 15.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 661248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 289      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6850     |
# |    fps             | 1640     |
# |    time_elapsed    | 602      |
# |    total_timesteps | 3991248  |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 11.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 661760   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 297      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6860     |
# |    fps             | 1640     |
# |    time_elapsed    | 605      |
# |    total_timesteps | 3994740  |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 662400   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 288      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6870     |
# |    fps             | 1639     |
# |    time_elapsed    | 607      |
# |    total_timesteps | 3999048  |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 20.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 663168   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 294      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 6880     |
# |    fps             | 1640     |
# |    time_elapsed    | 609      |
# |    total_timesteps | 4002696  |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 29.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 663680   |
# ---------------------------------

# %%
# > 4M steps, increase spawn radius
spawn_radius=(2.5, 60.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_5M"))
# Out:
# Increasing spawn radius to  (2.5, 60.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | 208      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 6890     |
# |    fps             | 1871     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 4007316  |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 63.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 664448   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 339      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 6900     |
# |    fps             | 1640     |
# |    time_elapsed    | 5        |
# |    total_timesteps | 4012092  |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 13.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 665344   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 360      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 6910     |
# |    fps             | 1657     |
# |    time_elapsed    | 7        |
# |    total_timesteps | 4015308  |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 17       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 665856   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 366      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 6920     |
# |    fps             | 1680     |
# |    time_elapsed    | 10       |
# |    total_timesteps | 4020180  |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 666624   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 371      |
# |    ep_rew_mean     | 213      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 6930     |
# |    fps             | 1661     |
# |    time_elapsed    | 13       |
# |    total_timesteps | 4024584  |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 22.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 667392   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 391      |
# |    ep_rew_mean     | 214      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 6940     |
# |    fps             | 1651     |
# |    time_elapsed    | 16       |
# |    total_timesteps | 4030596  |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 19       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 668416   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 402      |
# |    ep_rew_mean     | 215      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 6950     |
# |    fps             | 1669     |
# |    time_elapsed    | 19       |
# |    total_timesteps | 4035528  |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 20       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 669184   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 426      |
# |    ep_rew_mean     | 217      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 6960     |
# |    fps             | 1667     |
# |    time_elapsed    | 21       |
# |    total_timesteps | 4039320  |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 35.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 669824   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 432      |
# |    ep_rew_mean     | 218      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 6970     |
# |    fps             | 1662     |
# |    time_elapsed    | 26       |
# |    total_timesteps | 4047576  |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 20.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 671232   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 460      |
# |    ep_rew_mean     | 220      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 6980     |
# |    fps             | 1660     |
# |    time_elapsed    | 31       |
# |    total_timesteps | 4055292  |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 27.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 672512   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 492      |
# |    ep_rew_mean     | 223      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 6990     |
# |    fps             | 1664     |
# |    time_elapsed    | 36       |
# |    total_timesteps | 4063008  |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 12.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 673792   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 489      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 7000     |
# |    fps             | 1672     |
# |    time_elapsed    | 39       |
# |    total_timesteps | 4068744  |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 14.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 674688   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 546      |
# |    ep_rew_mean     | 226      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 7010     |
# |    fps             | 1658     |
# |    time_elapsed    | 42       |
# |    total_timesteps | 4073796  |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 20.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 675584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 546      |
# |    ep_rew_mean     | 226      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 7020     |
# |    fps             | 1655     |
# |    time_elapsed    | 45       |
# |    total_timesteps | 4078284  |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 192      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 676352   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 603      |
# |    ep_rew_mean     | 225      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 7030     |
# |    fps             | 1655     |
# |    time_elapsed    | 48       |
# |    total_timesteps | 4083648  |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 11.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 677248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 595      |
# |    ep_rew_mean     | 225      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 7040     |
# |    fps             | 1660     |
# |    time_elapsed    | 52       |
# |    total_timesteps | 4089300  |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 10.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 678144   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 582      |
# |    ep_rew_mean     | 224      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 7050     |
# |    fps             | 1655     |
# |    time_elapsed    | 54       |
# |    total_timesteps | 4093524  |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 83.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 678912   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 559      |
# |    ep_rew_mean     | 223      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 7060     |
# |    fps             | 1656     |
# |    time_elapsed    | 59       |
# |    total_timesteps | 4100724  |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 9.64     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 680064   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 559      |
# |    ep_rew_mean     | 223      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 7070     |
# |    fps             | 1662     |
# |    time_elapsed    | 63       |
# |    total_timesteps | 4108740  |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 15.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 681344   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 626      |
# |    ep_rew_mean     | 223      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 7080     |
# |    fps             | 1658     |
# |    time_elapsed    | 66       |
# |    total_timesteps | 4113012  |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 21       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 682112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 615      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 7090     |
# |    fps             | 1661     |
# |    time_elapsed    | 68       |
# |    total_timesteps | 4117104  |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 17.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 682752   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 593      |
# |    ep_rew_mean     | 220      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 7100     |
# |    fps             | 1655     |
# |    time_elapsed    | 71       |
# |    total_timesteps | 4121268  |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 24.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 683520   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 524      |
# |    ep_rew_mean     | 217      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 7110     |
# |    fps             | 1658     |
# |    time_elapsed    | 74       |
# |    total_timesteps | 4126092  |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 80.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 684288   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 550      |
# |    ep_rew_mean     | 217      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 7120     |
# |    fps             | 1659     |
# |    time_elapsed    | 77       |
# |    total_timesteps | 4130880  |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 17       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 685056   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 494      |
# |    ep_rew_mean     | 218      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 7130     |
# |    fps             | 1657     |
# |    time_elapsed    | 79       |
# |    total_timesteps | 4135380  |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 74.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 685824   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 514      |
# |    ep_rew_mean     | 181      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 7140     |
# |    fps             | 1655     |
# |    time_elapsed    | 83       |
# |    total_timesteps | 4141224  |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 27.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 686848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 517      |
# |    ep_rew_mean     | 181      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 7150     |
# |    fps             | 1661     |
# |    time_elapsed    | 86       |
# |    total_timesteps | 4147176  |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 25.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 687744   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 571      |
# |    ep_rew_mean     | 182      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 7160     |
# |    fps             | 1654     |
# |    time_elapsed    | 89       |
# |    total_timesteps | 4151232  |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 37.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 688512   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 578      |
# |    ep_rew_mean     | 183      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 7170     |
# |    fps             | 1656     |
# |    time_elapsed    | 92       |
# |    total_timesteps | 4155300  |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 18.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 689152   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 498      |
# |    ep_rew_mean     | 181      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 7180     |
# |    fps             | 1660     |
# |    time_elapsed    | 95       |
# |    total_timesteps | 4161024  |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 16.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 690048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 182      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 7190     |
# |    fps             | 1657     |
# |    time_elapsed    | 97       |
# |    total_timesteps | 4164552  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 14       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 690688   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 497      |
# |    ep_rew_mean     | 185      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 7200     |
# |    fps             | 1655     |
# |    time_elapsed    | 100      |
# |    total_timesteps | 4169556  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 19.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 691584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 510      |
# |    ep_rew_mean     | 186      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 7210     |
# |    fps             | 1656     |
# |    time_elapsed    | 105      |
# |    total_timesteps | 4177332  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 245      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 692864   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 511      |
# |    ep_rew_mean     | 189      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 7220     |
# |    fps             | 1656     |
# |    time_elapsed    | 109      |
# |    total_timesteps | 4183356  |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 36.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 693888   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 517      |
# |    ep_rew_mean     | 190      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 7230     |
# |    fps             | 1659     |
# |    time_elapsed    | 111      |
# |    total_timesteps | 4188372  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 18.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 694656   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 525      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 7240     |
# |    fps             | 1660     |
# |    time_elapsed    | 117      |
# |    total_timesteps | 4197612  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 22.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 696192   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 593      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 7250     |
# |    fps             | 1660     |
# |    time_elapsed    | 121      |
# |    total_timesteps | 4203780  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 333      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 697216   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 554      |
# |    ep_rew_mean     | 220      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 7260     |
# |    fps             | 1660     |
# |    time_elapsed    | 125      |
# |    total_timesteps | 4211472  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 27.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 698496   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 589      |
# |    ep_rew_mean     | 211      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 7270     |
# |    fps             | 1660     |
# |    time_elapsed    | 130      |
# |    total_timesteps | 4219896  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 21.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 699904   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 619      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 7280     |
# |    fps             | 1656     |
# |    time_elapsed    | 134      |
# |    total_timesteps | 4225728  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 35       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 700928   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 605      |
# |    ep_rew_mean     | 202      |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 7290     |
# |    fps             | 1660     |
# |    time_elapsed    | 141      |
# |    total_timesteps | 4238472  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 38.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 702976   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0051.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0052.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0053.png
# Eval num_timesteps=4242816, episode_reward=-38.87 +/- 436.23
# Episode length: 1921.67 +/- 1128.26
# Success rate: 33.33%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.92e+03 |
# |    mean_reward     | -38.9    |
# |    success_rate    | 0.333    |
# | time/              |          |
# |    total_timesteps | 4242816  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 55.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 703744   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 700      |
# |    ep_rew_mean     | 201      |
# |    success_rate    | 0.79     |
# | time/              |          |
# |    episodes        | 7300     |
# |    fps             | 1618     |
# |    time_elapsed    | 151      |
# |    total_timesteps | 4248024  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 15.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 704640   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 756      |
# |    ep_rew_mean     | 193      |
# |    success_rate    | 0.74     |
# | time/              |          |
# |    episodes        | 7310     |
# |    fps             | 1619     |
# |    time_elapsed    | 155      |
# |    total_timesteps | 4254000  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 32.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 705664   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 798      |
# |    ep_rew_mean     | 186      |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    episodes        | 7320     |
# |    fps             | 1625     |
# |    time_elapsed    | 164      |
# |    total_timesteps | 4270980  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 18       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 708480   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 176      |
# |    success_rate    | 0.62     |
# | time/              |          |
# |    episodes        | 7330     |
# |    fps             | 1635     |
# |    time_elapsed    | 179      |
# |    total_timesteps | 4296768  |
# | train/             |          |
# |    actor_loss      | -98.4    |
# |    critic_loss     | 50.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 712704   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 179      |
# |    success_rate    | 0.61     |
# | time/              |          |
# |    episodes        | 7340     |
# |    fps             | 1636     |
# |    time_elapsed    | 185      |
# |    total_timesteps | 4306980  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 13.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 714496   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 179      |
# |    success_rate    | 0.61     |
# | time/              |          |
# |    episodes        | 7350     |
# |    fps             | 1641     |
# |    time_elapsed    | 197      |
# |    total_timesteps | 4326336  |
# | train/             |          |
# |    actor_loss      | -98.1    |
# |    critic_loss     | 38.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 717696   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | 168      |
# |    success_rate    | 0.53     |
# | time/              |          |
# |    episodes        | 7360     |
# |    fps             | 1644     |
# |    time_elapsed    | 204      |
# |    total_timesteps | 4338768  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 28.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 719744   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | 175      |
# |    success_rate    | 0.52     |
# | time/              |          |
# |    episodes        | 7370     |
# |    fps             | 1647     |
# |    time_elapsed    | 210      |
# |    total_timesteps | 4349796  |
# | train/             |          |
# |    actor_loss      | -99.6    |
# |    critic_loss     | 21       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 721536   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | 176      |
# |    success_rate    | 0.52     |
# | time/              |          |
# |    episodes        | 7380     |
# |    fps             | 1647     |
# |    time_elapsed    | 213      |
# |    total_timesteps | 4354896  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 16.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 722432   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 175      |
# |    success_rate    | 0.52     |
# | time/              |          |
# |    episodes        | 7390     |
# |    fps             | 1647     |
# |    time_elapsed    | 217      |
# |    total_timesteps | 4361532  |
# | train/             |          |
# |    actor_loss      | -96.6    |
# |    critic_loss     | 24.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 723584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | 173      |
# |    success_rate    | 0.53     |
# | time/              |          |
# |    episodes        | 7400     |
# |    fps             | 1651     |
# |    time_elapsed    | 223      |
# |    total_timesteps | 4371144  |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 13.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 725120   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | 176      |
# |    success_rate    | 0.56     |
# | time/              |          |
# |    episodes        | 7410     |
# |    fps             | 1651     |
# |    time_elapsed    | 227      |
# |    total_timesteps | 4377876  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 17.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 726272   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | 177      |
# |    success_rate    | 0.58     |
# | time/              |          |
# |    episodes        | 7420     |
# |    fps             | 1652     |
# |    time_elapsed    | 230      |
# |    total_timesteps | 4383516  |
# | train/             |          |
# |    actor_loss      | -98.4    |
# |    critic_loss     | 14.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 727168   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 998      |
# |    ep_rew_mean     | 185      |
# |    success_rate    | 0.64     |
# | time/              |          |
# |    episodes        | 7430     |
# |    fps             | 1652     |
# |    time_elapsed    | 234      |
# |    total_timesteps | 4389996  |
# | train/             |          |
# |    actor_loss      | -99.6    |
# |    critic_loss     | 24       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 728320   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 946      |
# |    ep_rew_mean     | 187      |
# |    success_rate    | 0.66     |
# | time/              |          |
# |    episodes        | 7440     |
# |    fps             | 1654     |
# |    time_elapsed    | 238      |
# |    total_timesteps | 4397700  |
# | train/             |          |
# |    actor_loss      | -99.4    |
# |    critic_loss     | 228      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 729600   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 875      |
# |    ep_rew_mean     | 190      |
# |    success_rate    | 0.69     |
# | time/              |          |
# |    episodes        | 7450     |
# |    fps             | 1655     |
# |    time_elapsed    | 243      |
# |    total_timesteps | 4406076  |
# | train/             |          |
# |    actor_loss      | -99.8    |
# |    critic_loss     | 304      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 731008   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 797      |
# |    ep_rew_mean     | 203      |
# |    success_rate    | 0.78     |
# | time/              |          |
# |    episodes        | 7460     |
# |    fps             | 1658     |
# |    time_elapsed    | 248      |
# |    total_timesteps | 4415616  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 15.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 732544   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 724      |
# |    ep_rew_mean     | 205      |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 7470     |
# |    fps             | 1659     |
# |    time_elapsed    | 254      |
# |    total_timesteps | 4425456  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 23.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 734208   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 756      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 7480     |
# |    fps             | 1662     |
# |    time_elapsed    | 259      |
# |    total_timesteps | 4434432  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 20.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 735616   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 775      |
# |    ep_rew_mean     | 214      |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 7490     |
# |    fps             | 1662     |
# |    time_elapsed    | 264      |
# |    total_timesteps | 4443156  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 26.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 737152   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 805      |
# |    ep_rew_mean     | 217      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 7500     |
# |    fps             | 1662     |
# |    time_elapsed    | 270      |
# |    total_timesteps | 4452972  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 19.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 738816   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 851      |
# |    ep_rew_mean     | 224      |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 7510     |
# |    fps             | 1664     |
# |    time_elapsed    | 277      |
# |    total_timesteps | 4464828  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 55.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 740736   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 896      |
# |    ep_rew_mean     | 227      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7520     |
# |    fps             | 1664     |
# |    time_elapsed    | 281      |
# |    total_timesteps | 4470624  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 32.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 741760   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 898      |
# |    ep_rew_mean     | 228      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 7530     |
# |    fps             | 1665     |
# |    time_elapsed    | 283      |
# |    total_timesteps | 4475400  |
# | train/             |          |
# |    actor_loss      | -99.4    |
# |    critic_loss     | 33.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 742528   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 838      |
# |    ep_rew_mean     | 226      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 7540     |
# |    fps             | 1667     |
# |    time_elapsed    | 287      |
# |    total_timesteps | 4482012  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 166      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 743552   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0054.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0055.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0056.png
# Eval num_timesteps=4482816, episode_reward=210.48 +/- 17.91
# Episode length: 274.33 +/- 124.46
# Success rate: 100.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 274      |
# |    mean_reward     | 210      |
# |    success_rate    | 1        |
# | time/              |          |
# |    total_timesteps | 4482816  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 30       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 743680   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 822      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 7550     |
# |    fps             | 1659     |
# |    time_elapsed    | 291      |
# |    total_timesteps | 4486620  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 62       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 744320   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 827      |
# |    ep_rew_mean     | 216      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7560     |
# |    fps             | 1658     |
# |    time_elapsed    | 293      |
# |    total_timesteps | 4489884  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 35       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 744960   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 788      |
# |    ep_rew_mean     | 215      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 7570     |
# |    fps             | 1661     |
# |    time_elapsed    | 299      |
# |    total_timesteps | 4500180  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 34.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 746624   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 748      |
# |    ep_rew_mean     | 216      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 7580     |
# |    fps             | 1662     |
# |    time_elapsed    | 306      |
# |    total_timesteps | 4512336  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 30.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 748672   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 804      |
# |    ep_rew_mean     | 218      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 7590     |
# |    fps             | 1662     |
# |    time_elapsed    | 308      |
# |    total_timesteps | 4515924  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 23.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 749312   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 734      |
# |    ep_rew_mean     | 219      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 7600     |
# |    fps             | 1665     |
# |    time_elapsed    | 314      |
# |    total_timesteps | 4526556  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 23.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 750976   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 734      |
# |    ep_rew_mean     | 220      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 7610     |
# |    fps             | 1665     |
# |    time_elapsed    | 317      |
# |    total_timesteps | 4531008  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 28.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 751744   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 699      |
# |    ep_rew_mean     | 219      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 7620     |
# |    fps             | 1665     |
# |    time_elapsed    | 321      |
# |    total_timesteps | 4538352  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 39.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 753024   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 664      |
# |    ep_rew_mean     | 221      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 7630     |
# |    fps             | 1666     |
# |    time_elapsed    | 324      |
# |    total_timesteps | 4543188  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 23       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 753792   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 687      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 7640     |
# |    fps             | 1668     |
# |    time_elapsed    | 329      |
# |    total_timesteps | 4552500  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 98.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 755328   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 766      |
# |    ep_rew_mean     | 227      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 7650     |
# |    fps             | 1669     |
# |    time_elapsed    | 339      |
# |    total_timesteps | 4569900  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 20       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 758272   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 843      |
# |    ep_rew_mean     | 235      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 7660     |
# |    fps             | 1670     |
# |    time_elapsed    | 342      |
# |    total_timesteps | 4574412  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 38.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 759040   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 825      |
# |    ep_rew_mean     | 234      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 7670     |
# |    fps             | 1671     |
# |    time_elapsed    | 345      |
# |    total_timesteps | 4580052  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 15       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 759936   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 798      |
# |    ep_rew_mean     | 233      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 7680     |
# |    fps             | 1673     |
# |    time_elapsed    | 350      |
# |    total_timesteps | 4589508  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 53.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 761472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 757      |
# |    ep_rew_mean     | 232      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 7690     |
# |    fps             | 1673     |
# |    time_elapsed    | 352      |
# |    total_timesteps | 4593132  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 38       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 762112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 764      |
# |    ep_rew_mean     | 232      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 7700     |
# |    fps             | 1673     |
# |    time_elapsed    | 355      |
# |    total_timesteps | 4598352  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 53.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 763008   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 736      |
# |    ep_rew_mean     | 231      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 7710     |
# |    fps             | 1675     |
# |    time_elapsed    | 359      |
# |    total_timesteps | 4605672  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 92.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 764160   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 740      |
# |    ep_rew_mean     | 234      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 7720     |
# |    fps             | 1674     |
# |    time_elapsed    | 367      |
# |    total_timesteps | 4618080  |
# | train/             |          |
# |    actor_loss      | -99.2    |
# |    critic_loss     | 61.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 766336   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 795      |
# |    ep_rew_mean     | 238      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 7730     |
# |    fps             | 1676     |
# |    time_elapsed    | 368      |
# |    total_timesteps | 4620912  |
# | train/             |          |
# |    actor_loss      | -99.2    |
# ...
# |    ep_rew_mean     | 215      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 8040     |
# |    fps             | 1682     |
# |    time_elapsed    | 508      |
# |    total_timesteps | 4858512  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 24.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 806400   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 637      |
# |    ep_rew_mean     | 214      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 8050     |
# |    fps             | 1682     |
# |    time_elapsed    | 512      |
# |    total_timesteps | 4864740  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 44.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 807424   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 622      |
# |    ep_rew_mean     | 217      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 8060     |
# |    fps             | 1683     |
# |    time_elapsed    | 516      |
# |    total_timesteps | 4872360  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 20.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 808704   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 702      |
# |    ep_rew_mean     | 220      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 8070     |
# |    fps             | 1684     |
# |    time_elapsed    | 523      |
# |    total_timesteps | 4884132  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 9.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 810624   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 783      |
# |    ep_rew_mean     | 225      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 8080     |
# |    fps             | 1684     |
# |    time_elapsed    | 526      |
# |    total_timesteps | 4890144  |
# | train/             |          |
# |    actor_loss      | -99.9    |
# |    critic_loss     | 10       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 811648   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 721      |
# |    ep_rew_mean     | 238      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 8090     |
# |    fps             | 1685     |
# |    time_elapsed    | 529      |
# |    total_timesteps | 4894320  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 19.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 812288   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 738      |
# |    ep_rew_mean     | 239      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 8100     |
# |    fps             | 1684     |
# |    time_elapsed    | 532      |
# |    total_timesteps | 4899900  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 18.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 813312   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 643      |
# |    ep_rew_mean     | 233      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 8110     |
# |    fps             | 1686     |
# |    time_elapsed    | 535      |
# |    total_timesteps | 4905960  |
# | train/             |          |
# |    actor_loss      | -99.6    |
# |    critic_loss     | 13.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 814208   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 666      |
# |    ep_rew_mean     | 233      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 8120     |
# |    fps             | 1685     |
# |    time_elapsed    | 540      |
# |    total_timesteps | 4913760  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 15.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 815616   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 663      |
# |    ep_rew_mean     | 233      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 8130     |
# |    fps             | 1686     |
# |    time_elapsed    | 542      |
# |    total_timesteps | 4917888  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 30.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 816256   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 664      |
# |    ep_rew_mean     | 236      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 8140     |
# |    fps             | 1686     |
# |    time_elapsed    | 544      |
# |    total_timesteps | 4921284  |
# | train/             |          |
# |    actor_loss      | -99.8    |
# |    critic_loss     | 34       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 816768   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 650      |
# |    ep_rew_mean     | 238      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 8150     |
# |    fps             | 1686     |
# |    time_elapsed    | 547      |
# |    total_timesteps | 4925676  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 13.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 817536   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 633      |
# |    ep_rew_mean     | 236      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 8160     |
# |    fps             | 1687     |
# |    time_elapsed    | 550      |
# |    total_timesteps | 4931160  |
# | train/             |          |
# |    actor_loss      | -99.9    |
# |    critic_loss     | 25.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 818432   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 598      |
# |    ep_rew_mean     | 236      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 8170     |
# |    fps             | 1687     |
# |    time_elapsed    | 555      |
# |    total_timesteps | 4939332  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 14.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 819840   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 520      |
# |    ep_rew_mean     | 232      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 8180     |
# |    fps             | 1687     |
# |    time_elapsed    | 559      |
# |    total_timesteps | 4946016  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 10.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 820992   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 510      |
# |    ep_rew_mean     | 231      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 8190     |
# |    fps             | 1688     |
# |    time_elapsed    | 562      |
# |    total_timesteps | 4952616  |
# | train/             |          |
# |    actor_loss      | -99.8    |
# |    critic_loss     | 29.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 822016   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 574      |
# |    ep_rew_mean     | 235      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 8200     |
# |    fps             | 1687     |
# |    time_elapsed    | 566      |
# |    total_timesteps | 4959036  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 12.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 823168   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0060.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0061.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0062.png
# Eval num_timesteps=4962816, episode_reward=228.04 +/- 14.88
# Episode length: 474.33 +/- 167.51
# Success rate: 100.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 474      |
# |    mean_reward     | 228      |
# |    success_rate    | 1        |
# | time/              |          |
# |    total_timesteps | 4962816  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 28       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 823680   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 613      |
# |    ep_rew_mean     | 238      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 8210     |
# |    fps             | 1684     |
# |    time_elapsed    | 570      |
# |    total_timesteps | 4963032  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 10.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 823808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 565      |
# |    ep_rew_mean     | 236      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8220     |
# |    fps             | 1684     |
# |    time_elapsed    | 571      |
# |    total_timesteps | 4966140  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 17.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 824320   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 548      |
# |    ep_rew_mean     | 235      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8230     |
# |    fps             | 1685     |
# |    time_elapsed    | 574      |
# |    total_timesteps | 4970292  |
# | train/             |          |
# |    actor_loss      | -98.6    |
# |    critic_loss     | 23.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 824960   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 540      |
# |    ep_rew_mean     | 235      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8240     |
# |    fps             | 1685     |
# |    time_elapsed    | 576      |
# |    total_timesteps | 4974288  |
# | train/             |          |
# |    actor_loss      | -99.9    |
# |    critic_loss     | 22.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 825600   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 537      |
# |    ep_rew_mean     | 235      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8250     |
# |    fps             | 1685     |
# |    time_elapsed    | 578      |
# |    total_timesteps | 4977564  |
# | train/             |          |
# |    actor_loss      | -98      |
# |    critic_loss     | 13.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 826240   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 544      |
# |    ep_rew_mean     | 235      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8260     |
# |    fps             | 1685     |
# |    time_elapsed    | 580      |
# |    total_timesteps | 4980636  |
# | train/             |          |
# |    actor_loss      | -99.4    |
# |    critic_loss     | 64.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 826752   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 483      |
# |    ep_rew_mean     | 232      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 8270     |
# |    fps             | 1685     |
# |    time_elapsed    | 582      |
# |    total_timesteps | 4985208  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 827520   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 480      |
# |    ep_rew_mean     | 232      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 8280     |
# |    fps             | 1686     |
# |    time_elapsed    | 584      |
# |    total_timesteps | 4988160  |
# | train/             |          |
# |    actor_loss      | -94.4    |
# |    critic_loss     | 14.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 827904   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 483      |
# |    ep_rew_mean     | 230      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 8290     |
# |    fps             | 1686     |
# |    time_elapsed    | 586      |
# |    total_timesteps | 4992552  |
# | train/             |          |
# |    actor_loss      | -98.9    |
# |    critic_loss     | 14       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 828672   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 406      |
# |    ep_rew_mean     | 224      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 8300     |
# |    fps             | 1687     |
# |    time_elapsed    | 588      |
# |    total_timesteps | 4995720  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 14       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 829184   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 363      |
# |    ep_rew_mean     | 221      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 8310     |
# |    fps             | 1687     |
# |    time_elapsed    | 592      |
# |    total_timesteps | 5001624  |
# | train/             |          |
# |    actor_loss      | -95.3    |
# |    critic_loss     | 11       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 830208   |
# ---------------------------------

# %%
# > 5M steps, increase spawn radius
spawn_radius=(2.5, 60.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_6M"))
# Out:
# Increasing spawn radius to  (2.5, 60.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 375      |
# |    ep_rew_mean     | 223      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 8320     |
# |    fps             | 1805     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 5005104  |
# | train/             |          |
# |    actor_loss      | -96.4    |
# |    critic_loss     | 8.4      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 830848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 390      |
# |    ep_rew_mean     | 219      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8330     |
# |    fps             | 1928     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 5008752  |
# | train/             |          |
# |    actor_loss      | -95.5    |
# |    critic_loss     | 15.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 831360   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 390      |
# |    ep_rew_mean     | 218      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8340     |
# |    fps             | 1841     |
# |    time_elapsed    | 5        |
# |    total_timesteps | 5013372  |
# | train/             |          |
# |    actor_loss      | -97.8    |
# |    critic_loss     | 15       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 832128   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 394      |
# |    ep_rew_mean     | 218      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8350     |
# |    fps             | 1806     |
# |    time_elapsed    | 6        |
# |    total_timesteps | 5015652  |
# | train/             |          |
# |    actor_loss      | -99      |
# |    critic_loss     | 26.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 832512   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 382      |
# |    ep_rew_mean     | 216      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8360     |
# |    fps             | 1754     |
# |    time_elapsed    | 8        |
# |    total_timesteps | 5019120  |
# | train/             |          |
# |    actor_loss      | -99.1    |
# |    critic_loss     | 13.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 833152   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 383      |
# |    ep_rew_mean     | 216      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8370     |
# |    fps             | 1785     |
# |    time_elapsed    | 10       |
# |    total_timesteps | 5022624  |
# | train/             |          |
# |    actor_loss      | -95.6    |
# |    critic_loss     | 17.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 833664   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 376      |
# |    ep_rew_mean     | 215      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8380     |
# |    fps             | 1783     |
# |    time_elapsed    | 12       |
# |    total_timesteps | 5024976  |
# | train/             |          |
# |    actor_loss      | -98.1    |
# |    critic_loss     | 25.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 834048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 373      |
# |    ep_rew_mean     | 217      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8390     |
# |    fps             | 1780     |
# |    time_elapsed    | 15       |
# |    total_timesteps | 5030400  |
# | train/             |          |
# |    actor_loss      | -93.4    |
# |    critic_loss     | 19.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 834944   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 385      |
# |    ep_rew_mean     | 217      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8400     |
# |    fps             | 1767     |
# |    time_elapsed    | 16       |
# |    total_timesteps | 5033340  |
# | train/             |          |
# |    actor_loss      | -98.2    |
# |    critic_loss     | 17.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 835456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 378      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 8410     |
# |    fps             | 1763     |
# |    time_elapsed    | 19       |
# |    total_timesteps | 5037924  |
# | train/             |          |
# |    actor_loss      | -96.6    |
# |    critic_loss     | 7.8      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 836224   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 369      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 8420     |
# |    fps             | 1737     |
# |    time_elapsed    | 21       |
# |    total_timesteps | 5041212  |
# | train/             |          |
# |    actor_loss      | -96.2    |
# |    critic_loss     | 13.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 836864   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 358      |
# |    ep_rew_mean     | 214      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 8430     |
# |    fps             | 1759     |
# |    time_elapsed    | 24       |
# |    total_timesteps | 5046288  |
# | train/             |          |
# |    actor_loss      | -98.9    |
# |    critic_loss     | 7.54     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 837632   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 357      |
# |    ep_rew_mean     | 214      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 8440     |
# |    fps             | 1761     |
# |    time_elapsed    | 26       |
# |    total_timesteps | 5049408  |
# | train/             |          |
# |    actor_loss      | -98.9    |
# |    critic_loss     | 10.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 838144   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 363      |
# |    ep_rew_mean     | 213      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 8450     |
# |    fps             | 1744     |
# |    time_elapsed    | 28       |
# |    total_timesteps | 5053512  |
# | train/             |          |
# |    actor_loss      | -98.6    |
# |    critic_loss     | 16.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 838912   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 374      |
# |    ep_rew_mean     | 215      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 8460     |
# |    fps             | 1755     |
# |    time_elapsed    | 30       |
# |    total_timesteps | 5057796  |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 15.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 839552   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 369      |
# |    ep_rew_mean     | 212      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 8470     |
# |    fps             | 1760     |
# |    time_elapsed    | 34       |
# |    total_timesteps | 5064960  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 11.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 840704   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 389      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 8480     |
# |    fps             | 1746     |
# |    time_elapsed    | 37       |
# |    total_timesteps | 5068416  |
# | train/             |          |
# |    actor_loss      | -97      |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 841344   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 413      |
# |    ep_rew_mean     | 211      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 8490     |
# |    fps             | 1745     |
# |    time_elapsed    | 41       |
# |    total_timesteps | 5075256  |
# | train/             |          |
# |    actor_loss      | -96      |
# |    critic_loss     | 21.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 842496   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 421      |
# |    ep_rew_mean     | 210      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 8500     |
# |    fps             | 1754     |
# |    time_elapsed    | 44       |
# |    total_timesteps | 5081040  |
# | train/             |          |
# |    actor_loss      | -97.6    |
# |    critic_loss     | 12.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 843392   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 450      |
# |    ep_rew_mean     | 212      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 8510     |
# |    fps             | 1749     |
# |    time_elapsed    | 47       |
# |    total_timesteps | 5086068  |
# | train/             |          |
# |    actor_loss      | -97.4    |
# |    critic_loss     | 11.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 844288   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 479      |
# |    ep_rew_mean     | 212      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 8520     |
# |    fps             | 1751     |
# |    time_elapsed    | 50       |
# |    total_timesteps | 5092200  |
# | train/             |          |
# |    actor_loss      | -98.3    |
# |    critic_loss     | 12.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 845312   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 478      |
# |    ep_rew_mean     | 212      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 8530     |
# |    fps             | 1754     |
# |    time_elapsed    | 54       |
# |    total_timesteps | 5098524  |
# | train/             |          |
# |    actor_loss      | -95.8    |
# |    critic_loss     | 18.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 846336   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 480      |
# |    ep_rew_mean     | 209      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 8540     |
# |    fps             | 1756     |
# |    time_elapsed    | 56       |
# |    total_timesteps | 5103120  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 20       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 847104   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 546      |
# |    ep_rew_mean     | 212      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 8550     |
# |    fps             | 1755     |
# |    time_elapsed    | 59       |
# |    total_timesteps | 5108304  |
# | train/             |          |
# |    actor_loss      | -97.3    |
# |    critic_loss     | 13.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 848000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 555      |
# |    ep_rew_mean     | 213      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 8560     |
# |    fps             | 1761     |
# |    time_elapsed    | 61       |
# |    total_timesteps | 5112444  |
# | train/             |          |
# |    actor_loss      | -99      |
# |    critic_loss     | 16.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 848640   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 560      |
# |    ep_rew_mean     | 214      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 8570     |
# |    fps             | 1756     |
# |    time_elapsed    | 63       |
# |    total_timesteps | 5115900  |
# | train/             |          |
# |    actor_loss      | -96.4    |
# |    critic_loss     | 12.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 849280   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 537      |
# |    ep_rew_mean     | 212      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 8580     |
# |    fps             | 1753     |
# |    time_elapsed    | 67       |
# |    total_timesteps | 5121840  |
# | train/             |          |
# |    actor_loss      | -95.2    |
# |    critic_loss     | 16.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 850304   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 529      |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 8590     |
# |    fps             | 1762     |
# |    time_elapsed    | 70       |
# |    total_timesteps | 5126988  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 16.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 851072   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 525      |
# |    ep_rew_mean     | 204      |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 8600     |
# |    fps             | 1760     |
# |    time_elapsed    | 73       |
# |    total_timesteps | 5133720  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 10       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 852224   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 524      |
# |    ep_rew_mean     | 204      |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 8610     |
# |    fps             | 1760     |
# |    time_elapsed    | 78       |
# |    total_timesteps | 5141352  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 14.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 853504   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 526      |
# |    ep_rew_mean     | 204      |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 8620     |
# |    fps             | 1759     |
# |    time_elapsed    | 82       |
# |    total_timesteps | 5148144  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 8.13     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 854656   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 573      |
# |    ep_rew_mean     | 201      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 8630     |
# |    fps             | 1758     |
# |    time_elapsed    | 83       |
# |    total_timesteps | 5151252  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 9.09     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 855168   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 586      |
# |    ep_rew_mean     | 202      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 8640     |
# |    fps             | 1763     |
# |    time_elapsed    | 87       |
# |    total_timesteps | 5158584  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 28.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 856320   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 541      |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 8650     |
# |    fps             | 1760     |
# |    time_elapsed    | 90       |
# |    total_timesteps | 5163564  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 14.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 857216   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 552      |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 8660     |
# |    fps             | 1759     |
# |    time_elapsed    | 98       |
# |    total_timesteps | 5176356  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 12.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 859392   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 647      |
# |    ep_rew_mean     | 193      |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 8670     |
# |    fps             | 1764     |
# |    time_elapsed    | 107      |
# |    total_timesteps | 5192916  |
# | train/             |          |
# |    actor_loss      | -97.7    |
# |    critic_loss     | 19.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 862080   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 767      |
# |    ep_rew_mean     | 179      |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    episodes        | 8680     |
# |    fps             | 1765     |
# |    time_elapsed    | 112      |
# |    total_timesteps | 5203032  |
# | train/             |          |
# |    actor_loss      | -96      |
# |    critic_loss     | 29.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 863744   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 801      |
# |    ep_rew_mean     | 176      |
# |    success_rate    | 0.78     |
# | time/              |          |
# |    episodes        | 8690     |
# |    fps             | 1762     |
# |    time_elapsed    | 116      |
# |    total_timesteps | 5209488  |
# | train/             |          |
# |    actor_loss      | -95.5    |
# |    critic_loss     | 13.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 864896   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 823      |
# |    ep_rew_mean     | 177      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 8700     |
# |    fps             | 1762     |
# |    time_elapsed    | 120      |
# |    total_timesteps | 5216460  |
# | train/             |          |
# |    actor_loss      | -94.7    |
# |    critic_loss     | 20.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 866048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 823      |
# |    ep_rew_mean     | 177      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 8710     |
# |    fps             | 1763     |
# |    time_elapsed    | 125      |
# |    total_timesteps | 5224212  |
# | train/             |          |
# |    actor_loss      | -93.2    |
# |    critic_loss     | 15       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 867328   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 846      |
# |    ep_rew_mean     | 179      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 8720     |
# |    fps             | 1765     |
# |    time_elapsed    | 127      |
# |    total_timesteps | 5228232  |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 15.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 867968   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 805      |
# |    ep_rew_mean     | 181      |
# |    success_rate    | 0.79     |
# | time/              |          |
# |    episodes        | 8730     |
# |    fps             | 1765     |
# |    time_elapsed    | 131      |
# |    total_timesteps | 5235240  |
# | train/             |          |
# |    actor_loss      | -96      |
# |    critic_loss     | 20       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 869120   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 821      |
# |    ep_rew_mean     | 184      |
# |    success_rate    | 0.79     |
# | time/              |          |
# |    episodes        | 8740     |
# |    fps             | 1762     |
# |    time_elapsed    | 135      |
# |    total_timesteps | 5242644  |
# | train/             |          |
# |    actor_loss      | -92.9    |
# |    critic_loss     | 16.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 870400   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0063.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0064.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0065.png
# Eval num_timesteps=5243520, episode_reward=220.00 +/- 19.48
# Episode length: 306.67 +/- 57.71
# Success rate: 100.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 307      |
# |    mean_reward     | 220      |
# |    success_rate    | 1        |
# | time/              |          |
# |    total_timesteps | 5243520  |
# | train/             |          |
# |    actor_loss      | -95      |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 870528   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 795      |
# |    ep_rew_mean     | 186      |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 8750     |
# |    fps             | 1746     |
# |    time_elapsed    | 140      |
# |    total_timesteps | 5248368  |
# | train/             |          |
# |    actor_loss      | -93.2    |
# |    critic_loss     | 20.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 871296   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 823      |
# |    ep_rew_mean     | 187      |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    episodes        | 8760     |
# |    fps             | 1743     |
# |    time_elapsed    | 144      |
# |    total_timesteps | 5254896  |
# | train/             |          |
# |    actor_loss      | -98.6    |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 872448   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 736      |
# |    ep_rew_mean     | 191      |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 8770     |
# |    fps             | 1745     |
# |    time_elapsed    | 147      |
# |    total_timesteps | 5260344  |
# | train/             |          |
# |    actor_loss      | -98.7    |
# |    critic_loss     | 23.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 873344   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 665      |
# |    ep_rew_mean     | 212      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 8780     |
# |    fps             | 1745     |
# |    time_elapsed    | 148      |
# |    total_timesteps | 5263476  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 18.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 873856   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 623      |
# |    ep_rew_mean     | 219      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 8790     |
# |    fps             | 1744     |
# |    time_elapsed    | 150      |
# |    total_timesteps | 5266308  |
# | train/             |          |
# |    actor_loss      | -95.9    |
# |    critic_loss     | 8.34     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 874368   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 600      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 8800     |
# |    fps             | 1746     |
# |    time_elapsed    | 153      |
# |    total_timesteps | 5271768  |
# | train/             |          |
# |    actor_loss      | -97.8    |
# |    critic_loss     | 16       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 875264   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 588      |
# |    ep_rew_mean     | 226      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 8810     |
# |    fps             | 1747     |
# |    time_elapsed    | 157      |
# |    total_timesteps | 5277996  |
# | train/             |          |
# |    actor_loss      | -95.2    |
# |    critic_loss     | 28.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 876288   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 551      |
# |    ep_rew_mean     | 226      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 8820     |
# |    fps             | 1750     |
# |    time_elapsed    | 160      |
# |    total_timesteps | 5283660  |
# | train/             |          |
# |    actor_loss      | -97.4    |
# |    critic_loss     | 12.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 877184   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 553      |
# |    ep_rew_mean     | 225      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 8830     |
# |    fps             | 1748     |
# |    time_elapsed    | 163      |
# |    total_timesteps | 5290128  |
# | train/             |          |
# |    actor_loss      | -95.8    |
# |    critic_loss     | 18.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 878336   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 538      |
# |    ep_rew_mean     | 225      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 8840     |
# |    fps             | 1749     |
# |    time_elapsed    | 166      |
# |    total_timesteps | 5294676  |
# | train/             |          |
# |    actor_loss      | -94.5    |
# |    critic_loss     | 7.96     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 879104   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 575      |
# |    ep_rew_mean     | 227      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 8850     |
# |    fps             | 1751     |
# |    time_elapsed    | 170      |
# |    total_timesteps | 5302596  |
# | train/             |          |
# |    actor_loss      | -93.9    |
# |    critic_loss     | 22.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 880384   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 562      |
# |    ep_rew_mean     | 228      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 8860     |
# |    fps             | 1751     |
# |    time_elapsed    | 174      |
# |    total_timesteps | 5308752  |
# | train/             |          |
# |    actor_loss      | -91.9    |
# |    critic_loss     | 13.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 881408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 596      |
# |    ep_rew_mean     | 233      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8870     |
# |    fps             | 1752     |
# |    time_elapsed    | 178      |
# |    total_timesteps | 5315712  |
# | train/             |          |
# |    actor_loss      | -94.2    |
# |    critic_loss     | 7.09     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 882560   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 537      |
# |    ep_rew_mean     | 231      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 8880     |
# |    fps             | 1753     |
# |    time_elapsed    | 183      |
# |    total_timesteps | 5325504  |
# | train/             |          |
# |    actor_loss      | -95.6    |
# |    critic_loss     | 7.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 884224   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 668      |
# |    ep_rew_mean     | 231      |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 8890     |
# |    fps             | 1754     |
# |    time_elapsed    | 195      |
# |    total_timesteps | 5346120  |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 22.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 887680   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 779      |
# |    ep_rew_mean     | 231      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 8900     |
# |    fps             | 1756     |
# |    time_elapsed    | 201      |
# |    total_timesteps | 5357100  |
# | train/             |          |
# |    actor_loss      | -92.1    |
# |    critic_loss     | 9.73     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 889472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 824      |
# |    ep_rew_mean     | 230      |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 8910     |
# |    fps             | 1758     |
# |    time_elapsed    | 208      |
# |    total_timesteps | 5370384  |
# | train/             |          |
# |    actor_loss      | -92.3    |
# |    critic_loss     | 13.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 891648   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 876      |
# |    ep_rew_mean     | 228      |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 8920     |
# |    fps             | 1757     |
# |    time_elapsed    | 215      |
# |    total_timesteps | 5381616  |
# | train/             |          |
# |    actor_loss      | -95.4    |
# |    critic_loss     | 9.42     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 893568   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 956      |
# |    ep_rew_mean     | 228      |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 8930     |
# |    fps             | 1759     |
# |    time_elapsed    | 217      |
# |    total_timesteps | 5385864  |
# | train/             |          |
# |    actor_loss      | -96.4    |
# |    critic_loss     | 10.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 894208   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 986      |
# |    ep_rew_mean     | 227      |
# |    success_rate    | 0.79     |
# | time/              |          |
# |    episodes        | 8940     |
# |    fps             | 1758     |
# |    time_elapsed    | 222      |
# |    total_timesteps | 5394852  |
# | train/             |          |
# |    actor_loss      | -92.8    |
# |    critic_loss     | 13.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 895744   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 956      |
# |    ep_rew_mean     | 223      |
# |    success_rate    | 0.79     |
# | time/              |          |
# |    episodes        | 8950     |
# |    fps             | 1759     |
# |    time_elapsed    | 225      |
# |    total_timesteps | 5401116  |
# | train/             |          |
# |    actor_loss      | -92.9    |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 896768   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 986      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.78     |
# | time/              |          |
# |    episodes        | 8960     |
# |    fps             | 1759     |
# |    time_elapsed    | 229      |
# |    total_timesteps | 5407908  |
# | train/             |          |
# |    actor_loss      | -98.8    |
# |    critic_loss     | 12.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 897920   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 951      |
# |    ep_rew_mean     | 217      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 8970     |
# |    fps             | 1758     |
# |    time_elapsed    | 232      |
# |    total_timesteps | 5413020  |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 10.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 898816   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 981      |
# |    ep_rew_mean     | 217      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 8980     |
# |    fps             | 1760     |
# |    time_elapsed    | 236      |
# |    total_timesteps | 5419488  |
# | train/             |          |
# |    actor_loss      | -94.9    |
# |    critic_loss     | 23.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 899840   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 900      |
# |    ep_rew_mean     | 217      |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    episodes        | 8990     |
# |    fps             | 1760     |
# |    time_elapsed    | 238      |
# |    total_timesteps | 5422656  |
# | train/             |          |
# |    actor_loss      | -98.9    |
# |    critic_loss     | 17.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 900352   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 781      |
# |    ep_rew_mean     | 218      |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 9000     |
# |    fps             | 1759     |
# |    time_elapsed    | 240      |
# |    total_timesteps | 5427084  |
# | train/             |          |
# |    actor_loss      | -94      |
# |    critic_loss     | 18       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 901120   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 727      |
# |    ep_rew_mean     | 218      |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 9010     |
# |    fps             | 1760     |
# |    time_elapsed    | 242      |
# |    total_timesteps | 5430372  |
# | train/             |          |
# |    actor_loss      | -99.3    |
# |    critic_loss     | 10.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 901632   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 654      |
# |    ep_rew_mean     | 218      |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 9020     |
# |    fps             | 1760     |
# |    time_elapsed    | 245      |
# |    total_timesteps | 5434860  |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 9.27     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 902400   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 568      |
# |    ep_rew_mean     | 218      |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 9030     |
# |    fps             | 1759     |
# |    time_elapsed    | 247      |
# |    total_timesteps | 5439432  |
# | train/             |          |
# |    actor_loss      | -97.8    |
# |    critic_loss     | 9.78     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 903168   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 526      |
# |    ep_rew_mean     | 220      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 9040     |
# |    fps             | 1759     |
# |    time_elapsed    | 249      |
# |    total_timesteps | 5443212  |
# | train/             |          |
# |    actor_loss      | -98.4    |
# |    critic_loss     | 11       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 903808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 526      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 9050     |
# |    fps             | 1759     |
# |    time_elapsed    | 252      |
# |    total_timesteps | 5448660  |
# | train/             |          |
# |    actor_loss      | -98.7    |
# |    critic_loss     | 10.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 904704   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 478      |
# |    ep_rew_mean     | 221      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 9060     |
# |    fps             | 1760     |
# |    time_elapsed    | 254      |
# |    total_timesteps | 5451840  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 8.26     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 905216   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 472      |
# |    ep_rew_mean     | 224      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 9070     |
# |    fps             | 1759     |
# |    time_elapsed    | 256      |
# |    total_timesteps | 5455272  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 14       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 905856   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 433      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 9080     |
# |    fps             | 1761     |
# |    time_elapsed    | 258      |
# |    total_timesteps | 5457972  |
# | train/             |          |
# |    actor_loss      | -97.7    |
# |    critic_loss     | 29.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 906240   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 390      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 9090     |
# |    fps             | 1760     |
# |    time_elapsed    | 260      |
# |    total_timesteps | 5461572  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 8.28     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 906880   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 380      |
# |    ep_rew_mean     | 221      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 9100     |
# |    fps             | 1760     |
# |    time_elapsed    | 261      |
# |    total_timesteps | 5464560  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 7.37     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 907392   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 373      |
# |    ep_rew_mean     | 221      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 9110     |
# |    fps             | 1762     |
# |    time_elapsed    | 264      |
# |    total_timesteps | 5468856  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 36.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 908032   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 378      |
# |    ep_rew_mean     | 221      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 9120     |
# |    fps             | 1760     |
# |    time_elapsed    | 265      |
# |    total_timesteps | 5471496  |
# | train/             |          |
# |    actor_loss      | -98.7    |
# |    critic_loss     | 7.79     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 908544   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 375      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 9130     |
# |    fps             | 1761     |
# |    time_elapsed    | 267      |
# |    total_timesteps | 5475504  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 16.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 909184   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 365      |
# |    ep_rew_mean     | 221      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 9140     |
# |    fps             | 1761     |
# |    time_elapsed    | 270      |
# |    total_timesteps | 5480016  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 10.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 909952   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0066.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0067.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0068.png
# Eval num_timesteps=5483520, episode_reward=212.28 +/- 15.78
# Episode length: 234.00 +/- 62.27
# Success rate: 100.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 234      |
# |    mean_reward     | 212      |
# |    success_rate    | 1        |
# | time/              |          |
# |    total_timesteps | 5483520  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 12.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 910464   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 355      |
# |    ep_rew_mean     | 221      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 9150     |
# |    fps             | 1754     |
# |    time_elapsed    | 273      |
# |    total_timesteps | 5483832  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 18.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 910592   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 349      |
# |    ep_rew_mean     | 220      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 9160     |
# |    fps             | 1755     |
# |    time_elapsed    | 275      |
# |    total_timesteps | 5486400  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 10.1     |
# ...
# |    ep_rew_mean     | 193      |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 9980     |
# |    fps             | 1758     |
# |    time_elapsed    | 501      |
# |    total_timesteps | 5885064  |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 13.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 977408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 539      |
# |    ep_rew_mean     | 226      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 9990     |
# |    fps             | 1758     |
# |    time_elapsed    | 503      |
# |    total_timesteps | 5889408  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 13.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 978176   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 550      |
# |    ep_rew_mean     | 227      |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 10000    |
# |    fps             | 1758     |
# |    time_elapsed    | 505      |
# |    total_timesteps | 5893032  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 12.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 978816   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 469      |
# |    ep_rew_mean     | 227      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 10010    |
# |    fps             | 1758     |
# |    time_elapsed    | 507      |
# |    total_timesteps | 5896284  |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 14.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 979328   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 391      |
# |    ep_rew_mean     | 226      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 10020    |
# |    fps             | 1758     |
# |    time_elapsed    | 509      |
# |    total_timesteps | 5899860  |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 6.74     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 979968   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 391      |
# |    ep_rew_mean     | 226      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 10030    |
# |    fps             | 1758     |
# |    time_elapsed    | 512      |
# |    total_timesteps | 5903748  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 6.24     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 980608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 389      |
# |    ep_rew_mean     | 227      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 10040    |
# |    fps             | 1758     |
# |    time_elapsed    | 515      |
# |    total_timesteps | 5910252  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 18.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 981632   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 391      |
# |    ep_rew_mean     | 226      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 10050    |
# |    fps             | 1758     |
# |    time_elapsed    | 518      |
# |    total_timesteps | 5915412  |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 15.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 982528   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 393      |
# |    ep_rew_mean     | 225      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 10060    |
# |    fps             | 1758     |
# |    time_elapsed    | 521      |
# |    total_timesteps | 5920692  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 9.9      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 983424   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 397      |
# |    ep_rew_mean     | 205      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 10070    |
# |    fps             | 1758     |
# |    time_elapsed    | 524      |
# |    total_timesteps | 5925336  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 22.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 984192   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 412      |
# |    ep_rew_mean     | 182      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10080    |
# |    fps             | 1758     |
# |    time_elapsed    | 526      |
# |    total_timesteps | 5929872  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 507      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 984960   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 425      |
# |    ep_rew_mean     | 182      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10090    |
# |    fps             | 1759     |
# |    time_elapsed    | 530      |
# |    total_timesteps | 5936424  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 11.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 985984   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 444      |
# |    ep_rew_mean     | 181      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10100    |
# |    fps             | 1759     |
# |    time_elapsed    | 533      |
# |    total_timesteps | 5942460  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 9.8      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 987008   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 482      |
# |    ep_rew_mean     | 184      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10110    |
# |    fps             | 1759     |
# |    time_elapsed    | 536      |
# |    total_timesteps | 5947368  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 13.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 987776   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 479      |
# |    ep_rew_mean     | 184      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10120    |
# |    fps             | 1758     |
# |    time_elapsed    | 538      |
# |    total_timesteps | 5950680  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 19       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 988416   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 470      |
# |    ep_rew_mean     | 182      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10130    |
# |    fps             | 1759     |
# |    time_elapsed    | 540      |
# |    total_timesteps | 5954604  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 8.41     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 989056   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 468      |
# |    ep_rew_mean     | 181      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10140    |
# |    fps             | 1759     |
# |    time_elapsed    | 542      |
# |    total_timesteps | 5957724  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 12.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 989568   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 446      |
# |    ep_rew_mean     | 180      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10150    |
# |    fps             | 1759     |
# |    time_elapsed    | 544      |
# |    total_timesteps | 5962140  |
# | train/             |          |
# |    actor_loss      | -98.6    |
# |    critic_loss     | 12.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 990336   |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0072.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0073.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0074.png
# Eval num_timesteps=5963520, episode_reward=186.71 +/- 68.55
# Episode length: 1342.00 +/- 1199.57
# Success rate: 66.67%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.34e+03 |
# |    mean_reward     | 187      |
# |    success_rate    | 0.667    |
# | time/              |          |
# |    total_timesteps | 5963520  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 14.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 990464   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 466      |
# |    ep_rew_mean     | 179      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 10160    |
# |    fps             | 1751     |
# |    time_elapsed    | 549      |
# |    total_timesteps | 5965428  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 11.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 990848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 489      |
# |    ep_rew_mean     | 200      |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 10170    |
# |    fps             | 1751     |
# |    time_elapsed    | 551      |
# |    total_timesteps | 5968692  |
# | train/             |          |
# |    actor_loss      | -99.2    |
# |    critic_loss     | 13.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 991360   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 465      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10180    |
# |    fps             | 1751     |
# |    time_elapsed    | 552      |
# |    total_timesteps | 5971596  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 15.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 991872   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 459      |
# |    ep_rew_mean     | 223      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10190    |
# |    fps             | 1751     |
# |    time_elapsed    | 554      |
# |    total_timesteps | 5973900  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 14.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 992256   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 428      |
# |    ep_rew_mean     | 221      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10200    |
# |    fps             | 1751     |
# |    time_elapsed    | 557      |
# |    total_timesteps | 5979216  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 17.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 993152   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 379      |
# |    ep_rew_mean     | 218      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10210    |
# |    fps             | 1751     |
# |    time_elapsed    | 559      |
# |    total_timesteps | 5984004  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 11.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 993920   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 379      |
# |    ep_rew_mean     | 218      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10220    |
# |    fps             | 1752     |
# |    time_elapsed    | 562      |
# |    total_timesteps | 5989536  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 11.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 994816   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 427      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10230    |
# |    fps             | 1752     |
# |    time_elapsed    | 565      |
# |    total_timesteps | 5994792  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 17.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 995712   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 424      |
# |    ep_rew_mean     | 222      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10240    |
# |    fps             | 1751     |
# |    time_elapsed    | 567      |
# |    total_timesteps | 5998128  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 996352   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 440      |
# |    ep_rew_mean     | 223      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10250    |
# |    fps             | 1751     |
# |    time_elapsed    | 570      |
# |    total_timesteps | 6002748  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 13.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 997120   |
# ---------------------------------

# %%
# > 6M steps, increase spawn radius
spawn_radius=(2.5, 80.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_7M"))
# Out:
# Increasing spawn radius to  (2.5, 80.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 430      |
# |    ep_rew_mean     | 225      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 10260    |
# |    fps             | 1815     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6008976  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 247      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 998144   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 408      |
# |    ep_rew_mean     | 225      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 10270    |
# |    fps             | 1781     |
# |    time_elapsed    | 6        |
# |    total_timesteps | 6015792  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 474      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999296   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 482      |
# |    ep_rew_mean     | 231      |
# |    success_rate    | 1        |
# | time/              |          |
# |    episodes        | 10280    |
# |    fps             | 1799     |
# |    time_elapsed    | 12       |
# |    total_timesteps | 6026748  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 9.31     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1001088  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 548      |
# |    ep_rew_mean     | 233      |
# |    success_rate    | 0.99     |
# | time/              |          |
# |    episodes        | 10290    |
# |    fps             | 1796     |
# |    time_elapsed    | 17       |
# |    total_timesteps | 6036084  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 10.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1002624  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 603      |
# |    ep_rew_mean     | 236      |
# |    success_rate    | 0.98     |
# | time/              |          |
# |    episodes        | 10300    |
# |    fps             | 1792     |
# |    time_elapsed    | 25       |
# |    total_timesteps | 6049860  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 20       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1004928  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 677      |
# |    ep_rew_mean     | 238      |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 10310    |
# |    fps             | 1796     |
# |    time_elapsed    | 34       |
# |    total_timesteps | 6066204  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 9.28     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1007616  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 859      |
# |    ep_rew_mean     | 241      |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 10320    |
# |    fps             | 1795     |
# |    time_elapsed    | 46       |
# |    total_timesteps | 6087912  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1011200  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 918      |
# |    ep_rew_mean     | 238      |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 10330    |
# |    fps             | 1787     |
# |    time_elapsed    | 50       |
# |    total_timesteps | 6095124  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 13.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1012480  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 238      |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 10340    |
# |    fps             | 1787     |
# |    time_elapsed    | 55       |
# |    total_timesteps | 6102924  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 18.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1013760  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 236      |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 10350    |
# |    fps             | 1786     |
# |    time_elapsed    | 59       |
# |    total_timesteps | 6109788  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 7.65     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1014912  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 229      |
# |    success_rate    | 0.76     |
# | time/              |          |
# |    episodes        | 10360    |
# |    fps             | 1789     |
# |    time_elapsed    | 71       |
# |    total_timesteps | 6132288  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 22.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1018624  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | 230      |
# |    success_rate    | 0.72     |
# | time/              |          |
# |    episodes        | 10370    |
# |    fps             | 1783     |
# |    time_elapsed    | 78       |
# |    total_timesteps | 6145104  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 94.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1020800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.24e+03 |
# |    ep_rew_mean     | 225      |
# |    success_rate    | 0.68     |
# | time/              |          |
# |    episodes        | 10380    |
# |    fps             | 1782     |
# |    time_elapsed    | 82       |
# |    total_timesteps | 6150420  |
# | train/             |          |
# |    actor_loss      | -98.3    |
# |    critic_loss     | 353      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1021696  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 223      |
# |    success_rate    | 0.69     |
# | time/              |          |
# |    episodes        | 10390    |
# |    fps             | 1787     |
# |    time_elapsed    | 85       |
# |    total_timesteps | 6157824  |
# | train/             |          |
# |    actor_loss      | -97.6    |
# |    critic_loss     | 11.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1022848  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | 219      |
# |    success_rate    | 0.66     |
# | time/              |          |
# |    episodes        | 10400    |
# |    fps             | 1780     |
# |    time_elapsed    | 93       |
# |    total_timesteps | 6170172  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 9.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1025024  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | 219      |
# |    success_rate    | 0.66     |
# | time/              |          |
# |    episodes        | 10410    |
# |    fps             | 1780     |
# |    time_elapsed    | 101      |
# |    total_timesteps | 6185640  |
# | train/             |          |
# |    actor_loss      | -98.8    |
# |    critic_loss     | 8.16     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1027584  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | 217      |
# |    success_rate    | 0.68     |
# | time/              |          |
# |    episodes        | 10420    |
# |    fps             | 1784     |
# |    time_elapsed    | 109      |
# |    total_timesteps | 6199248  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 522      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1029760  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | 159      |
# |    success_rate    | 0.67     |
# | time/              |          |
# |    episodes        | 10430    |
# |    fps             | 1780     |
# |    time_elapsed    | 115      |
# |    total_timesteps | 6209520  |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 10.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1031552  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 161      |
# |    success_rate    | 0.68     |
# | time/              |          |
# |    episodes        | 10440    |
# |    fps             | 1782     |
# |    time_elapsed    | 118      |
# |    total_timesteps | 6215988  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 23.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1032576  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 148      |
# |    success_rate    | 0.65     |
# | time/              |          |
# |    episodes        | 10450    |
# |    fps             | 1782     |
# |    time_elapsed    | 126      |
# |    total_timesteps | 6229020  |
# | train/             |          |
# |    actor_loss      | -96.4    |
# |    critic_loss     | 11.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1034752  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 148      |
# |    success_rate    | 0.65     |
# | time/              |          |
# |    episodes        | 10460    |
# |    fps             | 1781     |
# |    time_elapsed    | 132      |
# |    total_timesteps | 6239556  |
# | train/             |          |
# |    actor_loss      | -99.3    |
# |    critic_loss     | 1.78e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1036544  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0075.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0076.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0077.png
# Eval num_timesteps=6244224, episode_reward=242.09 +/- 41.36
# Episode length: 1205.33 +/- 1269.02
# Success rate: 66.67%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.21e+03 |
# |    mean_reward     | 242      |
# |    success_rate    | 0.667    |
# | time/              |          |
# |    total_timesteps | 6244224  |
# | train/             |          |
# |    actor_loss      | -93.2    |
# |    critic_loss     | 13.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1037312  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 119      |
# |    success_rate    | 0.64     |
# | time/              |          |
# |    episodes        | 10470    |
# |    fps             | 1752     |
# |    time_elapsed    | 139      |
# |    total_timesteps | 6248916  |
# | train/             |          |
# |    actor_loss      | -87.7    |
# |    critic_loss     | 33.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1038080  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 113      |
# |    success_rate    | 0.64     |
# | time/              |          |
# |    episodes        | 10480    |
# |    fps             | 1752     |
# |    time_elapsed    | 144      |
# |    total_timesteps | 6257304  |
# | train/             |          |
# |    actor_loss      | -90.4    |
# |    critic_loss     | 19.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1039488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | 112      |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    episodes        | 10490    |
# |    fps             | 1755     |
# |    time_elapsed    | 158      |
# |    total_timesteps | 6281868  |
# | train/             |          |
# |    actor_loss      | -86.1    |
# |    critic_loss     | 18.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1043584  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | 119      |
# |    success_rate    | 0.62     |
# | time/              |          |
# |    episodes        | 10500    |
# |    fps             | 1756     |
# |    time_elapsed    | 162      |
# |    total_timesteps | 6289536  |
# | train/             |          |
# |    actor_loss      | -89.7    |
# |    critic_loss     | 13.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1044864  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 113      |
# |    success_rate    | 0.61     |
# | time/              |          |
# |    episodes        | 10510    |
# |    fps             | 1758     |
# |    time_elapsed    | 166      |
# |    total_timesteps | 6297576  |
# | train/             |          |
# |    actor_loss      | -80.9    |
# |    critic_loss     | 108      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1046144  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 111      |
# |    success_rate    | 0.64     |
# | time/              |          |
# |    episodes        | 10520    |
# |    fps             | 1758     |
# |    time_elapsed    | 177      |
# |    total_timesteps | 6315696  |
# | train/             |          |
# |    actor_loss      | -83.4    |
# |    critic_loss     | 23.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1049216  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 165      |
# |    success_rate    | 0.67     |
# | time/              |          |
# |    episodes        | 10530    |
# |    fps             | 1758     |
# |    time_elapsed    | 181      |
# |    total_timesteps | 6322560  |
# | train/             |          |
# |    actor_loss      | -77.5    |
# |    critic_loss     | 11.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1050368  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 152      |
# |    success_rate    | 0.61     |
# | time/              |          |
# |    episodes        | 10540    |
# |    fps             | 1757     |
# |    time_elapsed    | 189      |
# |    total_timesteps | 6337728  |
# | train/             |          |
# |    actor_loss      | -75.5    |
# |    critic_loss     | 67.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1052928  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.42e+03 |
# |    ep_rew_mean     | 151      |
# |    success_rate    | 0.58     |
# | time/              |          |
# |    episodes        | 10550    |
# |    fps             | 1759     |
# |    time_elapsed    | 205      |
# |    total_timesteps | 6366300  |
# | train/             |          |
# |    actor_loss      | -72.6    |
# |    critic_loss     | 189      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1057664  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.45e+03 |
# |    ep_rew_mean     | 80.6     |
# |    success_rate    | 0.59     |
# | time/              |          |
# |    episodes        | 10560    |
# |    fps             | 1761     |
# |    time_elapsed    | 218      |
# |    total_timesteps | 6389316  |
# | train/             |          |
# |    actor_loss      | -63.3    |
# |    critic_loss     | 417      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1061504  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.45e+03 |
# |    ep_rew_mean     | 97.1     |
# |    success_rate    | 0.58     |
# | time/              |          |
# |    episodes        | 10570    |
# |    fps             | 1763     |
# |    time_elapsed    | 223      |
# |    total_timesteps | 6398808  |
# | train/             |          |
# |    actor_loss      | -60.3    |
# |    critic_loss     | 17       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1063040  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.6e+03  |
# |    ep_rew_mean     | 98.9     |
# |    success_rate    | 0.55     |
# | time/              |          |
# |    episodes        | 10580    |
# |    fps             | 1763     |
# |    time_elapsed    | 239      |
# |    total_timesteps | 6426504  |
# | train/             |          |
# |    actor_loss      | -45.4    |
# |    critic_loss     | 66.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1067648  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.67e+03 |
# |    ep_rew_mean     | -3.07    |
# |    success_rate    | 0.51     |
# | time/              |          |
# |    episodes        | 10590    |
# |    fps             | 1764     |
# |    time_elapsed    | 247      |
# |    total_timesteps | 6440328  |
# | train/             |          |
# |    actor_loss      | -48.9    |
# |    critic_loss     | 23.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1069952  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.78e+03 |
# |    ep_rew_mean     | -98.7    |
# |    success_rate    | 0.44     |
# | time/              |          |
# |    episodes        | 10600    |
# |    fps             | 1764     |
# |    time_elapsed    | 263      |
# |    total_timesteps | 6470004  |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 35.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1074944  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0078.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0079.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0080.png
# Eval num_timesteps=6484224, episode_reward=298.79 +/- 0.62
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 299      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 6484224  |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 55       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1077248  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.91e+03 |
# |    ep_rew_mean     | -94.8    |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 10610    |
# |    fps             | 1734     |
# |    time_elapsed    | 286      |
# |    total_timesteps | 6501348  |
# | train/             |          |
# |    actor_loss      | -28.3    |
# |    critic_loss     | 38.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1080192  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.1e+03  |
# |    ep_rew_mean     | -96      |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 10620    |
# |    fps             | 1736     |
# |    time_elapsed    | 299      |
# |    total_timesteps | 6523716  |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 217      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1083904  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.29e+03 |
# |    ep_rew_mean     | -93.3    |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 10630    |
# |    fps             | 1739     |
# |    time_elapsed    | 310      |
# |    total_timesteps | 6543996  |
# | train/             |          |
# |    actor_loss      | -24.8    |
# |    critic_loss     | 27.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1087232  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.3e+03  |
# |    ep_rew_mean     | -103     |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 10640    |
# |    fps             | 1742     |
# |    time_elapsed    | 326      |
# |    total_timesteps | 6573264  |
# | train/             |          |
# |    actor_loss      | -20.9    |
# |    critic_loss     | 95.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1092096  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.18e+03 |
# |    ep_rew_mean     | -92.5    |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 10650    |
# |    fps             | 1740     |
# |    time_elapsed    | 330      |
# |    total_timesteps | 6578748  |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 262      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1093120  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.16e+03 |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 10660    |
# |    fps             | 1744     |
# |    time_elapsed    | 346      |
# |    total_timesteps | 6609216  |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 230      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1098112  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.23e+03 |
# |    ep_rew_mean     | -29.3    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 10670    |
# |    fps             | 1744     |
# |    time_elapsed    | 352      |
# |    total_timesteps | 6618948  |
# | train/             |          |
# |    actor_loss      | -21.4    |
# |    critic_loss     | 37.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1099776  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.25e+03 |
# |    ep_rew_mean     | -31.8    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 10680    |
# |    fps             | 1745     |
# |    time_elapsed    | 368      |
# |    total_timesteps | 6648108  |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 30.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1104640  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.24e+03 |
# |    ep_rew_mean     | 69.1     |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 10690    |
# |    fps             | 1746     |
# |    time_elapsed    | 375      |
# |    total_timesteps | 6659436  |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 67.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1106560  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.15e+03 |
# |    ep_rew_mean     | 160      |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 10700    |
# |    fps             | 1747     |
# |    time_elapsed    | 391      |
# |    total_timesteps | 6687840  |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 41.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1111296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.09e+03 |
# |    ep_rew_mean     | 144      |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 10710    |
# |    fps             | 1748     |
# |    time_elapsed    | 398      |
# |    total_timesteps | 6701856  |
# | train/             |          |
# |    actor_loss      | -4.42    |
# |    critic_loss     | 287      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1113600  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.04e+03 |
# |    ep_rew_mean     | 146      |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 10720    |
# |    fps             | 1750     |
# |    time_elapsed    | 411      |
# |    total_timesteps | 6723840  |
# | train/             |          |
# |    actor_loss      | 1.67     |
# |    critic_loss     | 67       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1117184  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0081.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0082.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0083.png
# Eval num_timesteps=6724224, episode_reward=297.66 +/- 1.75
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 298      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 6724224  |
# | train/             |          |
# |    actor_loss      | 7.82     |
# |    critic_loss     | 453      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1117312  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.94e+03 |
# |    ep_rew_mean     | 117      |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 10730    |
# |    fps             | 1729     |
# |    time_elapsed    | 425      |
# |    total_timesteps | 6739428  |
# | train/             |          |
# |    actor_loss      | 11.4     |
# |    critic_loss     | 67.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1119872  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.95e+03 |
# |    ep_rew_mean     | 132      |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 10740    |
# |    fps             | 1730     |
# |    time_elapsed    | 441      |
# |    total_timesteps | 6768804  |
# | train/             |          |
# |    actor_loss      | 18.1     |
# |    critic_loss     | 51       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1124736  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.04e+03 |
# |    ep_rew_mean     | 41.4     |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 10750    |
# |    fps             | 1731     |
# |    time_elapsed    | 456      |
# |    total_timesteps | 6794916  |
# | train/             |          |
# |    actor_loss      | 32.2     |
# |    critic_loss     | 325      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1129088  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.11e+03 |
# |    ep_rew_mean     | 46.8     |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 10760    |
# |    fps             | 1732     |
# |    time_elapsed    | 464      |
# |    total_timesteps | 6809856  |
# | train/             |          |
# |    actor_loss      | 14.1     |
# |    critic_loss     | 85.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1131520  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.07e+03 |
# |    ep_rew_mean     | 48.6     |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 10770    |
# |    fps             | 1732     |
# |    time_elapsed    | 478      |
# |    total_timesteps | 6833016  |
# | train/             |          |
# |    actor_loss      | -1.43    |
# |    critic_loss     | 647      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1135488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.06e+03 |
# |    ep_rew_mean     | 45.9     |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 10780    |
# |    fps             | 1734     |
# |    time_elapsed    | 487      |
# |    total_timesteps | 6850416  |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 3.22e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1138304  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.04e+03 |
# |    ep_rew_mean     | 30.8     |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 10790    |
# |    fps             | 1734     |
# |    time_elapsed    | 499      |
# |    total_timesteps | 6870564  |
# | train/             |          |
# |    actor_loss      | -37.3    |
# |    critic_loss     | 200      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1141760  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.08e+03 |
# |    ep_rew_mean     | 11.9     |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 10800    |
# |    fps             | 1736     |
# |    time_elapsed    | 513      |
# |    total_timesteps | 6895812  |
# | train/             |          |
# |    actor_loss      | -39      |
# |    critic_loss     | 2.29e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1145856  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.14e+03 |
# |    ep_rew_mean     | 23.6     |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 10810    |
# |    fps             | 1737     |
# |    time_elapsed    | 527      |
# |    total_timesteps | 6921600  |
# | train/             |          |
# |    actor_loss      | -60      |
# |    critic_loss     | 83.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1150208  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.14e+03 |
# |    ep_rew_mean     | 12.1     |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 10820    |
# |    fps             | 1738     |
# |    time_elapsed    | 536      |
# |    total_timesteps | 6937248  |
# | train/             |          |
# |    actor_loss      | -68.6    |
# |    critic_loss     | 140      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1152768  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0084.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0085.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0086.png
# Eval num_timesteps=6964224, episode_reward=230.02 +/- 96.62
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 230      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 6964224  |
# | train/             |          |
# |    actor_loss      | -61      |
# |    critic_loss     | 76.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1157248  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.22e+03 |
# |    ep_rew_mean     | 35.1     |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 10830    |
# |    fps             | 1725     |
# |    time_elapsed    | 559      |
# |    total_timesteps | 6969300  |
# | train/             |          |
# |    actor_loss      | -66      |
# |    critic_loss     | 4.53e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1158144  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.19e+03 |
# |    ep_rew_mean     | 34.6     |
# |    success_rate    | 0.14     |
# | time/              |          |
# |    episodes        | 10840    |
# |    fps             | 1726     |
# |    time_elapsed    | 566      |
# |    total_timesteps | 6981648  |
# | train/             |          |
# |    actor_loss      | -76.2    |
# |    critic_loss     | 72.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1160192  |
# ---------------------------------

# %%
# > 7M steps, increase spawn radius
spawn_radius=(2.5, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_8M"))
# Out:
# Increasing spawn radius to  (2.5, 100.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.12e+03 |
# |    ep_rew_mean     | 121      |
# |    success_rate    | 0.14     |
# | time/              |          |
# |    episodes        | 10850    |
# |    fps             | 1795     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7008108  |
# | train/             |          |
# |    actor_loss      | -71.7    |
# |    critic_loss     | 186      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1164672  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.23e+03 |
# |    ep_rew_mean     | 131      |
# |    success_rate    | 0.14     |
# | time/              |          |
# |    episodes        | 10860    |
# |    fps             | 1763     |
# |    time_elapsed    | 20       |
# |    total_timesteps | 7040316  |
# | train/             |          |
# |    actor_loss      | -74.3    |
# |    critic_loss     | 104      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1170048  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.29e+03 |
# |    ep_rew_mean     | 130      |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 10870    |
# |    fps             | 1775     |
# |    time_elapsed    | 27       |
# |    total_timesteps | 7053780  |
# | train/             |          |
# |    actor_loss      | -71.6    |
# |    critic_loss     | 1.77e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1172224  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.26e+03 |
# |    ep_rew_mean     | 128      |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 10880    |
# |    fps             | 1773     |
# |    time_elapsed    | 43       |
# |    total_timesteps | 7081368  |
# | train/             |          |
# |    actor_loss      | -69      |
# |    critic_loss     | 87.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1176832  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.38e+03 |
# |    ep_rew_mean     | 141      |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 10890    |
# |    fps             | 1770     |
# |    time_elapsed    | 62       |
# |    total_timesteps | 7114824  |
# | train/             |          |
# |    actor_loss      | -74.7    |
# |    critic_loss     | 96.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1182464  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.42e+03 |
# |    ep_rew_mean     | 153      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 10900    |
# |    fps             | 1779     |
# |    time_elapsed    | 72       |
# |    total_timesteps | 7133064  |
# | train/             |          |
# |    actor_loss      | -65.3    |
# |    critic_loss     | 102      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1185408  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.44e+03 |
# |    ep_rew_mean     | 140      |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 10910    |
# |    fps             | 1774     |
# |    time_elapsed    | 88       |
# |    total_timesteps | 7161648  |
# | train/             |          |
# |    actor_loss      | -67.9    |
# |    critic_loss     | 90.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1190272  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.48e+03 |
# |    ep_rew_mean     | 153      |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 10920    |
# |    fps             | 1781     |
# |    time_elapsed    | 103      |
# |    total_timesteps | 7189248  |
# | train/             |          |
# |    actor_loss      | -83.7    |
# |    critic_loss     | 106      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1194752  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46e+03 |
# |    ep_rew_mean     | 161      |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 10930    |
# |    fps             | 1781     |
# |    time_elapsed    | 112      |
# |    total_timesteps | 7205304  |
# | train/             |          |
# |    actor_loss      | -87.1    |
# |    critic_loss     | 502      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1197440  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.45e+03 |
# |    ep_rew_mean     | 164      |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 10940    |
# |    fps             | 1781     |
# |    time_elapsed    | 128      |
# |    total_timesteps | 7233648  |
# | train/             |          |
# |    actor_loss      | -98      |
# |    critic_loss     | 92.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1202176  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0087.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0088.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0089.png
# Eval num_timesteps=7244928, episode_reward=74.09 +/- 156.04
# Episode length: 2202.33 +/- 1128.07
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2.2e+03  |
# |    mean_reward     | 74.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 7244928  |
# | train/             |          |
# |    actor_loss      | -94.8    |
# |    critic_loss     | 96.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1204096  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.51e+03 |
# |    ep_rew_mean     | 153      |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 10950    |
# |    fps             | 1734     |
# |    time_elapsed    | 145      |
# |    total_timesteps | 7256664  |
# | train/             |          |
# |    actor_loss      | -98.6    |
# |    critic_loss     | 6.41e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1206016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46e+03 |
# |    ep_rew_mean     | 146      |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 10960    |
# |    fps             | 1735     |
# |    time_elapsed    | 156      |
# |    total_timesteps | 7277064  |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 401      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1209472  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.49e+03 |
# |    ep_rew_mean     | 155      |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 10970    |
# |    fps             | 1740     |
# |    time_elapsed    | 172      |
# |    total_timesteps | 7305876  |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 100      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1214208  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.52e+03 |
# |    ep_rew_mean     | 166      |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 10980    |
# |    fps             | 1742     |
# |    time_elapsed    | 189      |
# |    total_timesteps | 7334388  |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 4.86e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1218944  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.4e+03  |
# |    ep_rew_mean     | 168      |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 10990    |
# |    fps             | 1742     |
# |    time_elapsed    | 195      |
# |    total_timesteps | 7345524  |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 154      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1220864  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.44e+03 |
# |    ep_rew_mean     | 169      |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 11000    |
# |    fps             | 1747     |
# |    time_elapsed    | 214      |
# |    total_timesteps | 7380276  |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 134      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1226624  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.47e+03 |
# |    ep_rew_mean     | 183      |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 11010    |
# |    fps             | 1748     |
# |    time_elapsed    | 233      |
# |    total_timesteps | 7412868  |
# | train/             |          |
# |    actor_loss      | -160     |
# |    critic_loss     | 71.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1232128  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | 183      |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 11020    |
# |    fps             | 1750     |
# |    time_elapsed    | 251      |
# |    total_timesteps | 7445772  |
# | train/             |          |
# |    actor_loss      | -195     |
# |    critic_loss     | 238      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1237632  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.57e+03 |
# |    ep_rew_mean     | 185      |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 11030    |
# |    fps             | 1752     |
# |    time_elapsed    | 262      |
# |    total_timesteps | 7465164  |
# | train/             |          |
# |    actor_loss      | -198     |
# |    critic_loss     | 65.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1240832  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0090.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0091.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0092.png
# Eval num_timesteps=7484928, episode_reward=297.59 +/- 0.49
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 298      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 7484928  |
# | train/             |          |
# |    actor_loss      | -204     |
# |    critic_loss     | 228      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1244032  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.65e+03 |
# |    ep_rew_mean     | 188      |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 11040    |
# |    fps             | 1727     |
# |    time_elapsed    | 281      |
# |    total_timesteps | 7490832  |
# | train/             |          |
# |    actor_loss      | -211     |
# |    critic_loss     | 125      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1245056  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69e+03 |
# |    ep_rew_mean     | 207      |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 11050    |
# |    fps             | 1729     |
# |    time_elapsed    | 300      |
# |    total_timesteps | 7524276  |
# | train/             |          |
# |    actor_loss      | -209     |
# |    critic_loss     | 117      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1250688  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.74e+03 |
# |    ep_rew_mean     | 214      |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 11060    |
# |    fps             | 1731     |
# |    time_elapsed    | 318      |
# |    total_timesteps | 7557156  |
# | train/             |          |
# |    actor_loss      | -212     |
# |    critic_loss     | 270      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1256192  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.74e+03 |
# |    ep_rew_mean     | 219      |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 11070    |
# |    fps             | 1735     |
# |    time_elapsed    | 336      |
# |    total_timesteps | 7589772  |
# | train/             |          |
# |    actor_loss      | -210     |
# |    critic_loss     | 222      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1261568  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.74e+03 |
# |    ep_rew_mean     | 215      |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 11080    |
# |    fps             | 1736     |
# |    time_elapsed    | 346      |
# |    total_timesteps | 7606020  |
# | train/             |          |
# |    actor_loss      | -190     |
# |    critic_loss     | 151      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1264256  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.86e+03 |
# |    ep_rew_mean     | 220      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11090    |
# |    fps             | 1738     |
# |    time_elapsed    | 361      |
# |    total_timesteps | 7633656  |
# | train/             |          |
# |    actor_loss      | -196     |
# |    critic_loss     | 240      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1268864  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.82e+03 |
# |    ep_rew_mean     | 225      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11100    |
# |    fps             | 1739     |
# |    time_elapsed    | 379      |
# |    total_timesteps | 7665648  |
# | train/             |          |
# |    actor_loss      | -189     |
# |    critic_loss     | 166      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1274240  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.82e+03 |
# |    ep_rew_mean     | 223      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11110    |
# |    fps             | 1741     |
# |    time_elapsed    | 397      |
# |    total_timesteps | 7697772  |
# | train/             |          |
# |    actor_loss      | -182     |
# |    critic_loss     | 147      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1279616  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.78e+03 |
# |    ep_rew_mean     | 215      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11120    |
# |    fps             | 1742     |
# |    time_elapsed    | 408      |
# |    total_timesteps | 7716204  |
# | train/             |          |
# |    actor_loss      | -203     |
# |    critic_loss     | 155      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1282688  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0093.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0094.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0095.png
# Eval num_timesteps=7724928, episode_reward=295.64 +/- 3.00
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 296      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 7724928  |
# | train/             |          |
# |    actor_loss      | -203     |
# |    critic_loss     | 85.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1284096  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.75e+03 |
# |    ep_rew_mean     | 211      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11130    |
# |    fps             | 1725     |
# |    time_elapsed    | 427      |
# |    total_timesteps | 7741656  |
# | train/             |          |
# |    actor_loss      | -217     |
# |    critic_loss     | 78.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1286912  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.7e+03  |
# |    ep_rew_mean     | 206      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11140    |
# |    fps             | 1727     |
# |    time_elapsed    | 443      |
# |    total_timesteps | 7770420  |
# | train/             |          |
# |    actor_loss      | -212     |
# |    critic_loss     | 308      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1291648  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.7e+03  |
# |    ep_rew_mean     | 203      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11150    |
# |    fps             | 1727     |
# |    time_elapsed    | 455      |
# |    total_timesteps | 7791516  |
# | train/             |          |
# |    actor_loss      | -219     |
# |    critic_loss     | 36.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1295232  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.6e+03  |
# |    ep_rew_mean     | 190      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11160    |
# |    fps             | 1729     |
# |    time_elapsed    | 467      |
# |    total_timesteps | 7813524  |
# | train/             |          |
# |    actor_loss      | -209     |
# |    critic_loss     | 43       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1298816  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.51e+03 |
# |    ep_rew_mean     | 177      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11170    |
# |    fps             | 1730     |
# |    time_elapsed    | 482      |
# |    total_timesteps | 7840068  |
# | train/             |          |
# |    actor_loss      | -193     |
# |    critic_loss     | 52.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1303296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.51e+03 |
# |    ep_rew_mean     | 176      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11180    |
# |    fps             | 1731     |
# |    time_elapsed    | 489      |
# |    total_timesteps | 7853100  |
# | train/             |          |
# |    actor_loss      | -189     |
# |    critic_loss     | 32.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1305472  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.48e+03 |
# |    ep_rew_mean     | 171      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11190    |
# |    fps             | 1733     |
# |    time_elapsed    | 508      |
# |    total_timesteps | 7886100  |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 32.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1310976  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46e+03 |
# |    ep_rew_mean     | 166      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11200    |
# |    fps             | 1734     |
# |    time_elapsed    | 523      |
# |    total_timesteps | 7912068  |
# | train/             |          |
# |    actor_loss      | -158     |
# |    critic_loss     | 36.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1315328  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.4e+03  |
# |    ep_rew_mean     | 165      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11210    |
# |    fps             | 1735     |
# |    time_elapsed    | 533      |
# |    total_timesteps | 7931376  |
# | train/             |          |
# |    actor_loss      | -148     |
# |    critic_loss     | 28.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1318528  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.45e+03 |
# |    ep_rew_mean     | 171      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11220    |
# |    fps             | 1736     |
# |    time_elapsed    | 549      |
# |    total_timesteps | 7959504  |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 47.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1323136  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0096.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0097.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0098.png
# Eval num_timesteps=7964928, episode_reward=287.16 +/- 14.33
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 287      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 7964928  |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 47.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1324032  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 167      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11230    |
# |    fps             | 1723     |
# |    time_elapsed    | 568      |
# |    total_timesteps | 7985124  |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 41       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1327488  |
# ---------------------------------

# %%
# > 8M steps, stabilize spawn radius
spawn_radius=(2.5, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_9M"))
# Out:
# Increasing spawn radius to  (2.5, 100.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.44e+03 |
# |    ep_rew_mean     | 173      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11240    |
# |    fps             | 1777     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8011056  |
# | train/             |          |
# |    actor_loss      | -84.3    |
# |    critic_loss     | 88.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1331840  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.37e+03 |
# |    ep_rew_mean     | 95.5     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11250    |
# |    fps             | 1804     |
# |    time_elapsed    | 14       |
# |    total_timesteps | 8031432  |
# | train/             |          |
# |    actor_loss      | -43.7    |
# |    critic_loss     | 119      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1335168  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.44e+03 |
# |    ep_rew_mean     | 103      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11260    |
# |    fps             | 1794     |
# |    time_elapsed    | 29       |
# |    total_timesteps | 8058540  |
# | train/             |          |
# |    actor_loss      | -29.1    |
# |    critic_loss     | 86.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1339648  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.45e+03 |
# |    ep_rew_mean     | 103      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11270    |
# |    fps             | 1787     |
# |    time_elapsed    | 39       |
# |    total_timesteps | 8075376  |
# | train/             |          |
# |    actor_loss      | -7.36    |
# |    critic_loss     | 78.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1342464  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | 107      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11280    |
# |    fps             | 1777     |
# |    time_elapsed    | 58       |
# |    total_timesteps | 8108772  |
# | train/             |          |
# |    actor_loss      | 2.55     |
# |    critic_loss     | 6.1e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1348096  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.52e+03 |
# |    ep_rew_mean     | 107      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11290    |
# |    fps             | 1780     |
# |    time_elapsed    | 76       |
# |    total_timesteps | 8141256  |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 87.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1353472  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.52e+03 |
# |    ep_rew_mean     | 41.9     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11300    |
# |    fps             | 1778     |
# |    time_elapsed    | 84       |
# |    total_timesteps | 8155056  |
# | train/             |          |
# |    actor_loss      | 29.4     |
# |    critic_loss     | 48.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1355776  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.52e+03 |
# |    ep_rew_mean     | 39.9     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11310    |
# |    fps             | 1775     |
# |    time_elapsed    | 99       |
# |    total_timesteps | 8183064  |
# | train/             |          |
# |    actor_loss      | 56.6     |
# |    critic_loss     | 46.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1360512  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.51e+03 |
# |    ep_rew_mean     | 39.6     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11320    |
# |    fps             | 1778     |
# |    time_elapsed    | 117      |
# |    total_timesteps | 8214756  |
# | train/             |          |
# |    actor_loss      | 74.6     |
# |    critic_loss     | 65.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1365760  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46e+03 |
# |    ep_rew_mean     | 34.9     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11330    |
# |    fps             | 1778     |
# |    time_elapsed    | 124      |
# |    total_timesteps | 8226468  |
# | train/             |          |
# |    actor_loss      | 87.2     |
# |    critic_loss     | 2.33e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1367680  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0099.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0100.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0101.png
# Eval num_timesteps=8245632, episode_reward=186.42 +/- 157.08
# Episode length: 2101.67 +/- 1270.44
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2.1e+03  |
# |    mean_reward     | 186      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 8245632  |
# | train/             |          |
# |    actor_loss      | 94.1     |
# |    critic_loss     | 845      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1370880  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.49e+03 |
# |    ep_rew_mean     | 31.6     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11340    |
# |    fps             | 1733     |
# |    time_elapsed    | 145      |
# |    total_timesteps | 8257608  |
# | train/             |          |
# |    actor_loss      | 97       |
# |    critic_loss     | 1.18e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1372928  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.45e+03 |
# |    ep_rew_mean     | 102      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11350    |
# |    fps             | 1740     |
# |    time_elapsed    | 158      |
# |    total_timesteps | 8281212  |
# | train/             |          |
# |    actor_loss      | 115      |
# |    critic_loss     | 898      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1376768  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.45e+03 |
# |    ep_rew_mean     | 104      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11360    |
# |    fps             | 1739     |
# |    time_elapsed    | 168      |
# |    total_timesteps | 8299128  |
# | train/             |          |
# |    actor_loss      | 123      |
# |    critic_loss     | 42.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1379840  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46e+03 |
# |    ep_rew_mean     | 107      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11370    |
# |    fps             | 1746     |
# |    time_elapsed    | 183      |
# |    total_timesteps | 8326296  |
# | train/             |          |
# |    actor_loss      | 149      |
# |    critic_loss     | 7.99e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1384320  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 99.2     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 11380    |
# |    fps             | 1746     |
# |    time_elapsed    | 190      |
# |    total_timesteps | 8337708  |
# | train/             |          |
# |    actor_loss      | 156      |
# |    critic_loss     | 6.8e+03  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1386240  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.32e+03 |
# |    ep_rew_mean     | 93.1     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 11390    |
# |    fps             | 1749     |
# |    time_elapsed    | 208      |
# |    total_timesteps | 8369916  |
# | train/             |          |
# |    actor_loss      | 172      |
# |    critic_loss     | 44.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1391616  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 159      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11400    |
# |    fps             | 1750     |
# |    time_elapsed    | 225      |
# |    total_timesteps | 8401200  |
# | train/             |          |
# |    actor_loss      | 189      |
# |    critic_loss     | 503      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1396864  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.33e+03 |
# |    ep_rew_mean     | 157      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11410    |
# |    fps             | 1751     |
# |    time_elapsed    | 231      |
# |    total_timesteps | 8410500  |
# | train/             |          |
# |    actor_loss      | 191      |
# |    critic_loss     | 51.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1398400  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.27e+03 |
# |    ep_rew_mean     | 149      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11420    |
# |    fps             | 1755     |
# |    time_elapsed    | 247      |
# |    total_timesteps | 8439384  |
# | train/             |          |
# |    actor_loss      | 206      |
# |    critic_loss     | 554      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1403136  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 157      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11430    |
# |    fps             | 1754     |
# |    time_elapsed    | 261      |
# |    total_timesteps | 8464908  |
# | train/             |          |
# |    actor_loss      | 219      |
# |    critic_loss     | 164      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1407488  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0102.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0103.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0104.png
# Eval num_timesteps=8485632, episode_reward=54.84 +/- 128.77
# Episode length: 1091.67 +/- 1349.40
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.09e+03 |
# |    mean_reward     | 54.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 8485632  |
# | train/             |          |
# |    actor_loss      | 236      |
# |    critic_loss     | 206      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1410816  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 142      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11440    |
# |    fps             | 1741     |
# |    time_elapsed    | 282      |
# |    total_timesteps | 8497176  |
# | train/             |          |
# |    actor_loss      | 251      |
# |    critic_loss     | 532      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1412864  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.45e+03 |
# |    ep_rew_mean     | 144      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11450    |
# |    fps             | 1744     |
# |    time_elapsed    | 294      |
# |    total_timesteps | 8520048  |
# | train/             |          |
# |    actor_loss      | 265      |
# |    critic_loss     | 201      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1416576  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.44e+03 |
# |    ep_rew_mean     | -1.19    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11460    |
# |    fps             | 1745     |
# |    time_elapsed    | 312      |
# |    total_timesteps | 8550348  |
# | train/             |          |
# |    actor_loss      | 290      |
# |    critic_loss     | 392      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1421696  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.45e+03 |
# |    ep_rew_mean     | 1.06     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11470    |
# |    fps             | 1746     |
# |    time_elapsed    | 322      |
# |    total_timesteps | 8568960  |
# | train/             |          |
# |    actor_loss      | 315      |
# |    critic_loss     | 90       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1424768  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | 5.5      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11480    |
# |    fps             | 1746     |
# |    time_elapsed    | 336      |
# |    total_timesteps | 8593356  |
# | train/             |          |
# |    actor_loss      | 316      |
# |    critic_loss     | 138      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1428864  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.48e+03 |
# |    ep_rew_mean     | 2.41     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11490    |
# |    fps             | 1748     |
# |    time_elapsed    | 349      |
# |    total_timesteps | 8616588  |
# | train/             |          |
# |    actor_loss      | 331      |
# |    critic_loss     | 529      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1432704  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.43e+03 |
# |    ep_rew_mean     | -3.65    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11500    |
# |    fps             | 1748     |
# |    time_elapsed    | 361      |
# |    total_timesteps | 8637060  |
# | train/             |          |
# |    actor_loss      | 359      |
# |    critic_loss     | 82.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1436160  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46e+03 |
# |    ep_rew_mean     | -3.01    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11510    |
# |    fps             | 1750     |
# |    time_elapsed    | 377      |
# |    total_timesteps | 8665836  |
# | train/             |          |
# |    actor_loss      | 364      |
# |    critic_loss     | 164      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1440896  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46e+03 |
# |    ep_rew_mean     | -1.08    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11520    |
# |    fps             | 1751     |
# |    time_elapsed    | 388      |
# |    total_timesteps | 8686032  |
# | train/             |          |
# |    actor_loss      | 389      |
# |    critic_loss     | 119      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1444224  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46e+03 |
# |    ep_rew_mean     | -2.31    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11530    |
# |    fps             | 1750     |
# |    time_elapsed    | 402      |
# |    total_timesteps | 8710692  |
# | train/             |          |
# |    actor_loss      | 413      |
# |    critic_loss     | 222      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1448448  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0105.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0106.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0107.png
# Eval num_timesteps=8725632, episode_reward=183.87 +/- 159.26
# Episode length: 2132.67 +/- 1226.59
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2.13e+03 |
# |    mean_reward     | 184      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 8725632  |
# | train/             |          |
# |    actor_loss      | 407      |
# |    critic_loss     | 264      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1450880  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.42e+03 |
# |    ep_rew_mean     | -51.7    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11540    |
# |    fps             | 1738     |
# |    time_elapsed    | 421      |
# |    total_timesteps | 8737836  |
# | train/             |          |
# |    actor_loss      | 424      |
# |    critic_loss     | 1.32e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1452928  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.45e+03 |
# |    ep_rew_mean     | -49.2    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11550    |
# |    fps             | 1739     |
# |    time_elapsed    | 437      |
# |    total_timesteps | 8766828  |
# | train/             |          |
# |    actor_loss      | 436      |
# |    critic_loss     | 148      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1457792  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.4e+03  |
# |    ep_rew_mean     | 80.6     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11560    |
# |    fps             | 1740     |
# |    time_elapsed    | 448      |
# |    total_timesteps | 8787072  |
# | train/             |          |
# |    actor_loss      | 447      |
# |    critic_loss     | 938      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1461120  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.45e+03 |
# |    ep_rew_mean     | 71.7     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11570    |
# |    fps             | 1742     |
# |    time_elapsed    | 463      |
# |    total_timesteps | 8813856  |
# | train/             |          |
# |    actor_loss      | 486      |
# |    critic_loss     | 421      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1465600  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.51e+03 |
# |    ep_rew_mean     | -14      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11580    |
# |    fps             | 1743     |
# |    time_elapsed    | 481      |
# |    total_timesteps | 8844708  |
# | train/             |          |
# |    actor_loss      | 507      |
# |    critic_loss     | 127      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1470720  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.55e+03 |
# |    ep_rew_mean     | -6.77    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11590    |
# |    fps             | 1744     |
# |    time_elapsed    | 497      |
# |    total_timesteps | 8873856  |
# | train/             |          |
# |    actor_loss      | 520      |
# |    critic_loss     | 192      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1475584  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.58e+03 |
# |    ep_rew_mean     | -2.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11600    |
# |    fps             | 1744     |
# |    time_elapsed    | 512      |
# |    total_timesteps | 8900460  |
# | train/             |          |
# |    actor_loss      | 537      |
# |    critic_loss     | 570      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1480064  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.6e+03  |
# |    ep_rew_mean     | 0.125    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11610    |
# |    fps             | 1745     |
# |    time_elapsed    | 525      |
# |    total_timesteps | 8923008  |
# | train/             |          |
# |    actor_loss      | 539      |
# |    critic_loss     | 115      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1483776  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.65e+03 |
# |    ep_rew_mean     | 7.32     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11620    |
# |    fps             | 1747     |
# |    time_elapsed    | 541      |
# |    total_timesteps | 8952252  |
# | train/             |          |
# |    actor_loss      | 556      |
# |    critic_loss     | 138      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1488640  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0108.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0109.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0110.png
# Eval num_timesteps=8965632, episode_reward=297.07 +/- 2.13
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 297      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 8965632  |
# | train/             |          |
# |    actor_loss      | 549      |
# |    critic_loss     | 94.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1490816  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.58e+03 |
# |    ep_rew_mean     | 5.81     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11630    |
# |    fps             | 1732     |
# |    time_elapsed    | 556      |
# |    total_timesteps | 8970384  |
# | train/             |          |
# |    actor_loss      | 554      |
# |    critic_loss     | 131      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1491712  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.55e+03 |
# |    ep_rew_mean     | 72.9     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 11640    |
# |    fps             | 1733     |
# |    time_elapsed    | 570      |
# |    total_timesteps | 8993856  |
# | train/             |          |
# |    actor_loss      | 580      |
# |    critic_loss     | 138      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1495552  |
# ---------------------------------

# %%
# > 9M steps, stabilize spawn radius
spawn_radius=(2.5, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_10M"))
# Out:
# Increasing spawn radius to  (2.5, 100.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.55e+03 |
# |    ep_rew_mean     | 82.8     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 11650    |
# |    fps             | 1781     |
# |    time_elapsed    | 8        |
# |    total_timesteps | 9021048  |
# | train/             |          |
# |    actor_loss      | 547      |
# |    critic_loss     | 295      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1500160  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.6e+03  |
# |    ep_rew_mean     | 99.8     |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 11660    |
# |    fps             | 1777     |
# |    time_elapsed    | 23       |
# |    total_timesteps | 9048336  |
# | train/             |          |
# |    actor_loss      | 558      |
# |    critic_loss     | 378      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1504640  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.61e+03 |
# |    ep_rew_mean     | 116      |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 11670    |
# |    fps             | 1774     |
# |    time_elapsed    | 36       |
# |    total_timesteps | 9070692  |
# | train/             |          |
# |    actor_loss      | 572      |
# |    critic_loss     | 99.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1508352  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.61e+03 |
# |    ep_rew_mean     | 201      |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 11680    |
# |    fps             | 1769     |
# |    time_elapsed    | 56       |
# |    total_timesteps | 9105744  |
# | train/             |          |
# |    actor_loss      | 573      |
# |    critic_loss     | 290      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1514240  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.58e+03 |
# |    ep_rew_mean     | 126      |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 11690    |
# |    fps             | 1766     |
# |    time_elapsed    | 71       |
# |    total_timesteps | 9131856  |
# | train/             |          |
# |    actor_loss      | 598      |
# |    critic_loss     | 319      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1518592  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.62e+03 |
# |    ep_rew_mean     | 44.3     |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 11700    |
# |    fps             | 1766     |
# |    time_elapsed    | 88       |
# |    total_timesteps | 9162228  |
# | train/             |          |
# |    actor_loss      | 613      |
# |    critic_loss     | 8.82e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1523584  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.57e+03 |
# |    ep_rew_mean     | 35.5     |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 11710    |
# |    fps             | 1761     |
# |    time_elapsed    | 97       |
# |    total_timesteps | 9177876  |
# | train/             |          |
# |    actor_loss      | 597      |
# |    critic_loss     | 4.52e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1526272  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.49e+03 |
# |    ep_rew_mean     | 27       |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 11720    |
# |    fps             | 1762     |
# |    time_elapsed    | 111      |
# |    total_timesteps | 9202536  |
# | train/             |          |
# |    actor_loss      | 604      |
# |    critic_loss     | 248      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1530368  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.54e+03 |
# |    ep_rew_mean     | 24.5     |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 11730    |
# |    fps             | 1761     |
# |    time_elapsed    | 120      |
# |    total_timesteps | 9218700  |
# | train/             |          |
# |    actor_loss      | 620      |
# |    critic_loss     | 139      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1533056  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0111.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0112.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0113.png
# Eval num_timesteps=9246336, episode_reward=233.87 +/- 91.56
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 234      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 9246336  |
# | train/             |          |
# |    actor_loss      | 619      |
# |    critic_loss     | 157      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1537664  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.55e+03 |
# |    ep_rew_mean     | 16       |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 11740    |
# |    fps             | 1706     |
# |    time_elapsed    | 142      |
# |    total_timesteps | 9249480  |
# | train/             |          |
# |    actor_loss      | 628      |
# |    critic_loss     | 106      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1538176  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.54e+03 |
# |    ep_rew_mean     | 8.23     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 11750    |
# |    fps             | 1714     |
# |    time_elapsed    | 159      |
# |    total_timesteps | 9280020  |
# | train/             |          |
# |    actor_loss      | 623      |
# |    critic_loss     | 324      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1543296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.52e+03 |
# |    ep_rew_mean     | 1.19     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11760    |
# |    fps             | 1720     |
# |    time_elapsed    | 173      |
# |    total_timesteps | 9304128  |
# | train/             |          |
# |    actor_loss      | 627      |
# |    critic_loss     | 548      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1547264  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.42e+03 |
# |    ep_rew_mean     | -99.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11770    |
# |    fps             | 1721     |
# |    time_elapsed    | 179      |
# |    total_timesteps | 9315324  |
# | train/             |          |
# |    actor_loss      | 639      |
# |    critic_loss     | 612      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1549184  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | -200     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11780    |
# |    fps             | 1728     |
# |    time_elapsed    | 195      |
# |    total_timesteps | 9343332  |
# | train/             |          |
# |    actor_loss      | 648      |
# |    critic_loss     | 394      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1553792  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.4e+03  |
# |    ep_rew_mean     | -198     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11790    |
# |    fps             | 1733     |
# |    time_elapsed    | 213      |
# |    total_timesteps | 9376368  |
# | train/             |          |
# |    actor_loss      | 672      |
# |    critic_loss     | 314      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1559296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | -118     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11800    |
# |    fps             | 1733     |
# |    time_elapsed    | 227      |
# |    total_timesteps | 9400560  |
# | train/             |          |
# |    actor_loss      | 644      |
# |    critic_loss     | 304      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1563392  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.44e+03 |
# |    ep_rew_mean     | -111     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11810    |
# |    fps             | 1737     |
# |    time_elapsed    | 239      |
# |    total_timesteps | 9423324  |
# | train/             |          |
# |    actor_loss      | 678      |
# |    critic_loss     | 326      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1567104  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.55e+03 |
# |    ep_rew_mean     | -106     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11820    |
# |    fps             | 1739     |
# |    time_elapsed    | 258      |
# |    total_timesteps | 9455952  |
# | train/             |          |
# |    actor_loss      | 690      |
# |    critic_loss     | 275      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1572608  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0114.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0115.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0116.png
# Eval num_timesteps=9486336, episode_reward=165.30 +/- 184.76
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 165      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 9486336  |
# | train/             |          |
# |    actor_loss      | 685      |
# |    critic_loss     | 326      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1577600  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.58e+03 |
# |    ep_rew_mean     | -106     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11830    |
# |    fps             | 1712     |
# |    time_elapsed    | 280      |
# |    total_timesteps | 9487284  |
# | train/             |          |
# |    actor_loss      | 692      |
# |    critic_loss     | 248      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1577856  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.61e+03 |
# |    ep_rew_mean     | -115     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 11840    |
# |    fps             | 1716     |
# |    time_elapsed    | 292      |
# |    total_timesteps | 9508560  |
# | train/             |          |
# |    actor_loss      | 696      |
# |    critic_loss     | 316      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1581312  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.59e+03 |
# |    ep_rew_mean     | -124     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11850    |
# |    fps             | 1717     |
# |    time_elapsed    | 306      |
# |    total_timesteps | 9532188  |
# | train/             |          |
# |    actor_loss      | 708      |
# |    critic_loss     | 265      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1585280  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.6e+03  |
# |    ep_rew_mean     | -126     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11860    |
# |    fps             | 1721     |
# |    time_elapsed    | 323      |
# |    total_timesteps | 9563856  |
# | train/             |          |
# |    actor_loss      | 710      |
# |    critic_loss     | 371      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1590528  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69e+03 |
# |    ep_rew_mean     | -39.8    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11870    |
# |    fps             | 1724     |
# |    time_elapsed    | 339      |
# |    total_timesteps | 9592320  |
# | train/             |          |
# |    actor_loss      | 739      |
# |    critic_loss     | 291      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1595264  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.7e+03  |
# |    ep_rew_mean     | 60.2     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11880    |
# |    fps             | 1724     |
# |    time_elapsed    | 349      |
# |    total_timesteps | 9609444  |
# | train/             |          |
# |    actor_loss      | 736      |
# |    critic_loss     | 353      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1598208  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.68e+03 |
# |    ep_rew_mean     | 132      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11890    |
# |    fps             | 1727     |
# |    time_elapsed    | 365      |
# |    total_timesteps | 9637584  |
# | train/             |          |
# |    actor_loss      | 757      |
# |    critic_loss     | 440      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1602816  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.6e+03  |
# |    ep_rew_mean     | 138      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11900    |
# |    fps             | 1728     |
# |    time_elapsed    | 381      |
# |    total_timesteps | 9665484  |
# | train/             |          |
# |    actor_loss      | 772      |
# |    critic_loss     | 630      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1607552  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.63e+03 |
# |    ep_rew_mean     | 140      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11910    |
# |    fps             | 1729     |
# |    time_elapsed    | 390      |
# |    total_timesteps | 9681744  |
# | train/             |          |
# |    actor_loss      | 804      |
# |    critic_loss     | 544      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1610240  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.63e+03 |
# |    ep_rew_mean     | 148      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11920    |
# |    fps             | 1731     |
# |    time_elapsed    | 410      |
# |    total_timesteps | 9717444  |
# | train/             |          |
# |    actor_loss      | 837      |
# |    critic_loss     | 4.04e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1616128  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0117.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0118.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0119.png
# Eval num_timesteps=9726336, episode_reward=296.97 +/- 2.18
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 297      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 9726336  |
# | train/             |          |
# |    actor_loss      | 833      |
# |    critic_loss     | 417      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1617664  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.62e+03 |
# |    ep_rew_mean     | 152      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11930    |
# |    fps             | 1713     |
# |    time_elapsed    | 431      |
# |    total_timesteps | 9745584  |
# | train/             |          |
# |    actor_loss      | 850      |
# |    critic_loss     | 464      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1620864  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.65e+03 |
# |    ep_rew_mean     | 170      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 11940    |
# |    fps             | 1715     |
# |    time_elapsed    | 448      |
# |    total_timesteps | 9776064  |
# | train/             |          |
# |    actor_loss      | 890      |
# |    critic_loss     | 370      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1625984  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.7e+03  |
# |    ep_rew_mean     | 183      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11950    |
# |    fps             | 1719     |
# |    time_elapsed    | 467      |
# |    total_timesteps | 9809484  |
# | train/             |          |
# |    actor_loss      | 918      |
# |    critic_loss     | 403      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1631488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69e+03 |
# |    ep_rew_mean     | 191      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11960    |
# |    fps             | 1720     |
# |    time_elapsed    | 476      |
# |    total_timesteps | 9825708  |
# | train/             |          |
# |    actor_loss      | 944      |
# |    critic_loss     | 1.85e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1634176  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.64e+03 |
# |    ep_rew_mean     | 197      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11970    |
# |    fps             | 1721     |
# |    time_elapsed    | 491      |
# |    total_timesteps | 9853272  |
# | train/             |          |
# |    actor_loss      | 979      |
# |    critic_loss     | 383      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1638784  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69e+03 |
# |    ep_rew_mean     | 204      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11980    |
# |    fps             | 1723     |
# |    time_elapsed    | 510      |
# |    total_timesteps | 9885852  |
# | train/             |          |
# |    actor_loss      | 1.01e+03 |
# |    critic_loss     | 941      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1644288  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69e+03 |
# |    ep_rew_mean     | 206      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 11990    |
# |    fps             | 1725     |
# |    time_elapsed    | 521      |
# |    total_timesteps | 9905400  |
# | train/             |          |
# |    actor_loss      | 1.02e+03 |
# |    critic_loss     | 446      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1647488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.74e+03 |
# |    ep_rew_mean     | 198      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12000    |
# |    fps             | 1726     |
# |    time_elapsed    | 535      |
# |    total_timesteps | 9931548  |
# | train/             |          |
# |    actor_loss      | 1.06e+03 |
# |    critic_loss     | 811      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1651840  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0120.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0121.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0122.png
# Eval num_timesteps=9966336, episode_reward=111.57 +/- 133.38
# Episode length: 2262.67 +/- 1042.75
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2.26e+03 |
# |    mean_reward     | 112      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 9966336  |
# | train/             |          |
# |    actor_loss      | 1.08e+03 |
# |    critic_loss     | 592      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1657600  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.74e+03 |
# |    ep_rew_mean     | 167      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12010    |
# |    fps             | 1716     |
# |    time_elapsed    | 559      |
# |    total_timesteps | 9966372  |
# | train/             |          |
# |    actor_loss      | 1.09e+03 |
# |    critic_loss     | 825      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1657728  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.68e+03 |
# |    ep_rew_mean     | 128      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12020    |
# |    fps             | 1717     |
# |    time_elapsed    | 572      |
# |    total_timesteps | 9989484  |
# | train/             |          |
# |    actor_loss      | 1.11e+03 |
# |    critic_loss     | 653      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1661568  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69e+03 |
# |    ep_rew_mean     | 114      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12030    |
# |    fps             | 1719     |
# |    time_elapsed    | 581      |
# |    total_timesteps | 10006884 |
# | train/             |          |
# |    actor_loss      | 1.13e+03 |
# |    critic_loss     | 580      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1664384  |
# ---------------------------------

# %%
# > 10M steps, stabilize spawn radius
spawn_radius=(10, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_11M"))
# Out:
# Increasing spawn radius to  (10, 100.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.65e+03 |
# |    ep_rew_mean     | 105      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12040    |
# |    fps             | 1736     |
# |    time_elapsed    | 18       |
# |    total_timesteps | 10039548 |
# | train/             |          |
# |    actor_loss      | 1.15e+03 |
# |    critic_loss     | 662      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1669888  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.65e+03 |
# |    ep_rew_mean     | 102      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12050    |
# |    fps             | 1676     |
# |    time_elapsed    | 38       |
# |    total_timesteps | 10070940 |
# | train/             |          |
# |    actor_loss      | 1.17e+03 |
# |    critic_loss     | 1.06e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1675136  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.7e+03  |
# |    ep_rew_mean     | 105      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12060    |
# |    fps             | 1665     |
# |    time_elapsed    | 58       |
# |    total_timesteps | 10103808 |
# | train/             |          |
# |    actor_loss      | 1.2e+03  |
# |    critic_loss     | 626      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1680512  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.74e+03 |
# |    ep_rew_mean     | 109      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12070    |
# |    fps             | 1653     |
# |    time_elapsed    | 67       |
# |    total_timesteps | 10118712 |
# | train/             |          |
# |    actor_loss      | 1.21e+03 |
# |    critic_loss     | 977      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1683072  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.71e+03 |
# |    ep_rew_mean     | 107      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12080    |
# |    fps             | 1650     |
# |    time_elapsed    | 85       |
# |    total_timesteps | 10148736 |
# | train/             |          |
# |    actor_loss      | 1.21e+03 |
# |    critic_loss     | 1.01e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1688064  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.64e+03 |
# |    ep_rew_mean     | 83.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12090    |
# |    fps             | 1650     |
# |    time_elapsed    | 100      |
# |    total_timesteps | 10173396 |
# | train/             |          |
# |    actor_loss      | 1.25e+03 |
# |    critic_loss     | 3.12e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1692160  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.64e+03 |
# |    ep_rew_mean     | 44.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12100    |
# |    fps             | 1645     |
# |    time_elapsed    | 115      |
# |    total_timesteps | 10196748 |
# | train/             |          |
# |    actor_loss      | 1.31e+03 |
# |    critic_loss     | 864      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1696128  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.66e+03 |
# |    ep_rew_mean     | -38.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12110    |
# |    fps             | 1645     |
# |    time_elapsed    | 132      |
# |    total_timesteps | 10224528 |
# | train/             |          |
# |    actor_loss      | 1.37e+03 |
# |    critic_loss     | 2.5e+03  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1700736  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.61e+03 |
# |    ep_rew_mean     | -10.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12120    |
# |    fps             | 1652     |
# |    time_elapsed    | 144      |
# |    total_timesteps | 10245588 |
# | train/             |          |
# |    actor_loss      | 1.44e+03 |
# |    critic_loss     | 4.22e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1704192  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0123.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0124.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0125.png
# Eval num_timesteps=10247040, episode_reward=201.84 +/- 77.13
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 202      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 10247040 |
# | train/             |          |
# |    actor_loss      | 1.42e+03 |
# |    critic_loss     | 1.42e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1704448  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.6e+03  |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12130    |
# |    fps             | 1604     |
# |    time_elapsed    | 165      |
# |    total_timesteps | 10272984 |
# | train/             |          |
# |    actor_loss      | 1.48e+03 |
# |    critic_loss     | 2.49e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1708800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.58e+03 |
# |    ep_rew_mean     | -44.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12140    |
# |    fps             | 1615     |
# |    time_elapsed    | 179      |
# |    total_timesteps | 10296528 |
# | train/             |          |
# |    actor_loss      | 1.54e+03 |
# |    critic_loss     | 1.84e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1712640  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.57e+03 |
# |    ep_rew_mean     | -42.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12150    |
# |    fps             | 1620     |
# |    time_elapsed    | 196      |
# |    total_timesteps | 10326180 |
# | train/             |          |
# |    actor_loss      | 1.57e+03 |
# |    critic_loss     | 1.71e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1717632  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.49e+03 |
# |    ep_rew_mean     | -48.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12160    |
# |    fps             | 1626     |
# |    time_elapsed    | 208      |
# |    total_timesteps | 10346808 |
# | train/             |          |
# |    actor_loss      | 1.59e+03 |
# |    critic_loss     | 1.87e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1721088  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -47.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12170    |
# |    fps             | 1633     |
# |    time_elapsed    | 226      |
# |    total_timesteps | 10376748 |
# | train/             |          |
# |    actor_loss      | 1.63e+03 |
# |    critic_loss     | 1.65e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1726080  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.53e+03 |
# |    ep_rew_mean     | -47.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12180    |
# |    fps             | 1639     |
# |    time_elapsed    | 242      |
# |    total_timesteps | 10404528 |
# | train/             |          |
# |    actor_loss      | 1.74e+03 |
# |    critic_loss     | 2.74e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1730688  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.58e+03 |
# |    ep_rew_mean     | -29      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12190    |
# |    fps             | 1640     |
# |    time_elapsed    | 256      |
# |    total_timesteps | 10427160 |
# | train/             |          |
# |    actor_loss      | 1.83e+03 |
# |    critic_loss     | 3.03e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1734528  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.53e+03 |
# |    ep_rew_mean     | -14.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12200    |
# |    fps             | 1645     |
# |    time_elapsed    | 270      |
# |    total_timesteps | 10452984 |
# | train/             |          |
# |    actor_loss      | 1.96e+03 |
# |    critic_loss     | 2.9e+03  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1738752  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.49e+03 |
# |    ep_rew_mean     | 95.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12210    |
# |    fps             | 1648     |
# |    time_elapsed    | 287      |
# |    total_timesteps | 10480272 |
# | train/             |          |
# |    actor_loss      | 2.06e+03 |
# |    critic_loss     | 3.02e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1743360  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0126.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0127.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0128.png
# Eval num_timesteps=10487040, episode_reward=171.26 +/- 38.18
# Episode length: 2277.67 +/- 531.83
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2.28e+03 |
# |    mean_reward     | 171      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 10487040 |
# | train/             |          |
# |    actor_loss      | 2.1e+03  |
# |    critic_loss     | 3.31e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1744384  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.51e+03 |
# |    ep_rew_mean     | 98.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12220    |
# |    fps             | 1629     |
# |    time_elapsed    | 298      |
# |    total_timesteps | 10493016 |
# | train/             |          |
# |    actor_loss      | 2.13e+03 |
# |    critic_loss     | 3.58e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1745408  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.44e+03 |
# |    ep_rew_mean     | 144      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12230    |
# |    fps             | 1632     |
# |    time_elapsed    | 312      |
# |    total_timesteps | 10517304 |
# | train/             |          |
# |    actor_loss      | 2.27e+03 |
# |    critic_loss     | 3.27e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1749504  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46e+03 |
# |    ep_rew_mean     | 148      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12240    |
# |    fps             | 1636     |
# |    time_elapsed    | 329      |
# |    total_timesteps | 10545972 |
# | train/             |          |
# |    actor_loss      | 2.4e+03  |
# |    critic_loss     | 3.97e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1754240  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.48e+03 |
# |    ep_rew_mean     | 152      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12250    |
# |    fps             | 1639     |
# |    time_elapsed    | 346      |
# |    total_timesteps | 10575012 |
# | train/             |          |
# |    actor_loss      | 2.42e+03 |
# |    critic_loss     | 2.91e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1759104  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.51e+03 |
# |    ep_rew_mean     | 152      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12260    |
# |    fps             | 1642     |
# |    time_elapsed    | 360      |
# |    total_timesteps | 10598628 |
# | train/             |          |
# |    actor_loss      | 2.47e+03 |
# |    critic_loss     | 4.37e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1763072  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | 17       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12270    |
# |    fps             | 1645     |
# |    time_elapsed    | 371      |
# |    total_timesteps | 10619016 |
# | train/             |          |
# |    actor_loss      | 2.52e+03 |
# |    critic_loss     | 3.52e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1766400  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.39e+03 |
# |    ep_rew_mean     | 5.28     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12280    |
# |    fps             | 1649     |
# |    time_elapsed    | 387      |
# |    total_timesteps | 10646544 |
# | train/             |          |
# |    actor_loss      | 2.63e+03 |
# |    critic_loss     | 3.52e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1771008  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 5.49     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12290    |
# |    fps             | 1651     |
# |    time_elapsed    | 398      |
# |    total_timesteps | 10664364 |
# | train/             |          |
# |    actor_loss      | 2.66e+03 |
# |    critic_loss     | 3.23e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1773952  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.43e+03 |
# |    ep_rew_mean     | 41.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12300    |
# |    fps             | 1653     |
# |    time_elapsed    | 418      |
# |    total_timesteps | 10699572 |
# | train/             |          |
# |    actor_loss      | 2.82e+03 |
# |    critic_loss     | 4.13e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1779840  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.42e+03 |
# |    ep_rew_mean     | 31.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12310    |
# |    fps             | 1653     |
# |    time_elapsed    | 430      |
# |    total_timesteps | 10719012 |
# | train/             |          |
# |    actor_loss      | 2.96e+03 |
# |    critic_loss     | 4.29e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1783168  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0129.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0130.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0131.png
# Eval num_timesteps=10727040, episode_reward=297.31 +/- 1.74
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 297      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 10727040 |
# | train/             |          |
# |    actor_loss      | 2.99e+03 |
# |    critic_loss     | 4.3e+03  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1784448  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.49e+03 |
# |    ep_rew_mean     | 28.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12320    |
# |    fps             | 1638     |
# |    time_elapsed    | 449      |
# |    total_timesteps | 10742628 |
# | train/             |          |
# |    actor_loss      | 3.11e+03 |
# |    critic_loss     | 4.91e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1787008  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.52e+03 |
# |    ep_rew_mean     | 0.709    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12330    |
# |    fps             | 1641     |
# |    time_elapsed    | 465      |
# |    total_timesteps | 10770936 |
# | train/             |          |
# |    actor_loss      | 3.26e+03 |
# |    critic_loss     | 4.47e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1791744  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.49e+03 |
# |    ep_rew_mean     | -56.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12340    |
# |    fps             | 1643     |
# |    time_elapsed    | 479      |
# |    total_timesteps | 10794960 |
# | train/             |          |
# |    actor_loss      | 3.41e+03 |
# |    critic_loss     | 4.65e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1795712  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.44e+03 |
# |    ep_rew_mean     | -68.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12350    |
# |    fps             | 1643     |
# |    time_elapsed    | 492      |
# |    total_timesteps | 10817364 |
# | train/             |          |
# |    actor_loss      | 3.51e+03 |
# |    critic_loss     | 5.69e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1799552  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.4e+03  |
# |    ep_rew_mean     | -69.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12360    |
# |    fps             | 1646     |
# |    time_elapsed    | 507      |
# |    total_timesteps | 10842936 |
# | train/             |          |
# |    actor_loss      | 3.63e+03 |
# |    critic_loss     | 5.67e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1803776  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.38e+03 |
# |    ep_rew_mean     | 59.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12370    |
# |    fps             | 1648     |
# |    time_elapsed    | 518      |
# |    total_timesteps | 10862328 |
# | train/             |          |
# |    actor_loss      | 3.68e+03 |
# |    critic_loss     | 8.42e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1806976  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.44e+03 |
# |    ep_rew_mean     | 60.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12380    |
# |    fps             | 1650     |
# |    time_elapsed    | 534      |
# |    total_timesteps | 10889352 |
# | train/             |          |
# |    actor_loss      | 3.86e+03 |
# |    critic_loss     | 6.38e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1811456  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.4e+03  |
# |    ep_rew_mean     | 44.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12390    |
# |    fps             | 1651     |
# |    time_elapsed    | 543      |
# |    total_timesteps | 10905192 |
# | train/             |          |
# |    actor_loss      | 3.92e+03 |
# |    critic_loss     | 6.12e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1814144  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.34e+03 |
# |    ep_rew_mean     | 40.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12400    |
# |    fps             | 1654     |
# |    time_elapsed    | 560      |
# |    total_timesteps | 10933632 |
# | train/             |          |
# |    actor_loss      | 4.03e+03 |
# |    critic_loss     | 1.02e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1818880  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.38e+03 |
# |    ep_rew_mean     | 56.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12410    |
# |    fps             | 1656     |
# |    time_elapsed    | 573      |
# |    total_timesteps | 10956156 |
# | train/             |          |
# |    actor_loss      | 4.18e+03 |
# |    critic_loss     | 1.26e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1822592  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0132.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0133.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0134.png
# Eval num_timesteps=10967040, episode_reward=234.59 +/- 87.80
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 235      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 10967040 |
# | train/             |          |
# |    actor_loss      | 4.22e+03 |
# |    critic_loss     | 5.37e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1824384  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.32e+03 |
# |    ep_rew_mean     | 57       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12420    |
# |    fps             | 1642     |
# |    time_elapsed    | 590      |
# |    total_timesteps | 10976388 |
# | train/             |          |
# |    actor_loss      | 4.28e+03 |
# |    critic_loss     | 5.92e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1826048  |
# ---------------------------------

# %%
# > 11M steps, stabilize spawn radius
spawn_radius=(10, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_12M"))
# Out:
# Increasing spawn radius to  (10, 100.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.38e+03 |
# |    ep_rew_mean     | 88.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12430    |
# |    fps             | 14803    |
# |    time_elapsed    | 0        |
# |    total_timesteps | 11008236 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.4e+03  |
# |    ep_rew_mean     | 143      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12440    |
# |    fps             | 1748     |
# |    time_elapsed    | 17       |
# |    total_timesteps | 11038428 |
# | train/             |          |
# |    actor_loss      | 4.58e+03 |
# |    critic_loss     | 1.68e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1836288  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.38e+03 |
# |    ep_rew_mean     | 129      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12450    |
# |    fps             | 1712     |
# |    time_elapsed    | 27       |
# |    total_timesteps | 11054832 |
# | train/             |          |
# |    actor_loss      | 4.66e+03 |
# |    critic_loss     | 7.7e+03  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1839104  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.39e+03 |
# |    ep_rew_mean     | 123      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12460    |
# |    fps             | 1720     |
# |    time_elapsed    | 40       |
# |    total_timesteps | 11077632 |
# | train/             |          |
# |    actor_loss      | 4.79e+03 |
# |    critic_loss     | 7.92e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1842816  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.42e+03 |
# |    ep_rew_mean     | 101      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12470    |
# |    fps             | 1713     |
# |    time_elapsed    | 56       |
# |    total_timesteps | 11104188 |
# | train/             |          |
# |    actor_loss      | 4.99e+03 |
# |    critic_loss     | 1.23e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1847296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46e+03 |
# |    ep_rew_mean     | 80.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12480    |
# |    fps             | 1708     |
# |    time_elapsed    | 72       |
# |    total_timesteps | 11130936 |
# | train/             |          |
# |    actor_loss      | 5.15e+03 |
# |    critic_loss     | 9.18e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1851776  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.54e+03 |
# |    ep_rew_mean     | 101      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12490    |
# |    fps             | 1704     |
# |    time_elapsed    | 90       |
# |    total_timesteps | 11162256 |
# | train/             |          |
# |    actor_loss      | 5.32e+03 |
# |    critic_loss     | 1.26e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1857024  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.61e+03 |
# |    ep_rew_mean     | 104      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12500    |
# |    fps             | 1701     |
# |    time_elapsed    | 106      |
# |    total_timesteps | 11188236 |
# | train/             |          |
# |    actor_loss      | 5.35e+03 |
# |    critic_loss     | 1.2e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1861376  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.58e+03 |
# |    ep_rew_mean     | 99.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12510    |
# |    fps             | 1706     |
# |    time_elapsed    | 123      |
# |    total_timesteps | 11217960 |
# | train/             |          |
# |    actor_loss      | 5.45e+03 |
# |    critic_loss     | 9.09e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1866240  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.67e+03 |
# |    ep_rew_mean     | 109      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12520    |
# |    fps             | 1704     |
# |    time_elapsed    | 137      |
# |    total_timesteps | 11242104 |
# | train/             |          |
# |    actor_loss      | 5.65e+03 |
# |    critic_loss     | 1.2e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1870336  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0135.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0136.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0137.png
# Eval num_timesteps=11247744, episode_reward=166.75 +/- 96.70
# Episode length: 3000.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 3e+03    |
# |    mean_reward     | 167      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 11247744 |
# | train/             |          |
# |    actor_loss      | 5.69e+03 |
# |    critic_loss     | 1.11e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1871232  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.66e+03 |
# |    ep_rew_mean     | 113      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12530    |
# |    fps             | 1652     |
# |    time_elapsed    | 160      |
# |    total_timesteps | 11273100 |
# | train/             |          |
# |    actor_loss      | 5.81e+03 |
# |    critic_loss     | 1.16e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1875456  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.62e+03 |
# |    ep_rew_mean     | 90       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12540    |
# |    fps             | 1658     |
# |    time_elapsed    | 173      |
# |    total_timesteps | 11296236 |
# | train/             |          |
# |    actor_loss      | 6e+03    |
# |    critic_loss     | 1.03e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1879296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.66e+03 |
# |    ep_rew_mean     | 113      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12550    |
# |    fps             | 1660     |
# |    time_elapsed    | 188      |
# |    total_timesteps | 11321388 |
# | train/             |          |
# |    actor_loss      | 6.16e+03 |
# |    critic_loss     | 9.48e+03 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1883520  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.71e+03 |
# |    ep_rew_mean     | 123      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12560    |
# |    fps             | 1663     |
# |    time_elapsed    | 204      |
# |    total_timesteps | 11348268 |
# | train/             |          |
# |    actor_loss      | 6.28e+03 |
# |    critic_loss     | 1.73e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1888000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.6e+03  |
# |    ep_rew_mean     | 137      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12570    |
# |    fps             | 1666     |
# |    time_elapsed    | 212      |
# |    total_timesteps | 11362296 |
# | train/             |          |
# |    actor_loss      | 6.32e+03 |
# |    critic_loss     | 1.48e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1890304  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.54e+03 |
# |    ep_rew_mean     | 161      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12580    |
# |    fps             | 1669     |
# |    time_elapsed    | 227      |
# |    total_timesteps | 11387652 |
# | train/             |          |
# |    actor_loss      | 6.46e+03 |
# |    critic_loss     | 1.4e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1894528  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.51e+03 |
# |    ep_rew_mean     | 159      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12590    |
# |    fps             | 1670     |
# |    time_elapsed    | 242      |
# |    total_timesteps | 11412132 |
# | train/             |          |
# |    actor_loss      | 6.6e+03  |
# |    critic_loss     | 1.1e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1898624  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.49e+03 |
# |    ep_rew_mean     | 163      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12600    |
# |    fps             | 1674     |
# |    time_elapsed    | 255      |
# |    total_timesteps | 11434716 |
# | train/             |          |
# |    actor_loss      | 6.69e+03 |
# |    critic_loss     | 1.08e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1902336  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.48e+03 |
# |    ep_rew_mean     | 166      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12610    |
# |    fps             | 1675     |
# |    time_elapsed    | 271      |
# |    total_timesteps | 11463324 |
# | train/             |          |
# |    actor_loss      | 6.79e+03 |
# |    critic_loss     | 1.28e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1907200  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.4e+03  |
# |    ep_rew_mean     | 160      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12620    |
# |    fps             | 1678     |
# |    time_elapsed    | 284      |
# |    total_timesteps | 11485188 |
# | train/             |          |
# |    actor_loss      | 6.8e+03  |
# |    critic_loss     | 1.04e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1910784  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0138.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0139.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0140.png
# Eval num_timesteps=11487744, episode_reward=81.86 +/- 152.09
# Episode length: 1098.67 +/- 1344.45
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.1e+03  |
# |    mean_reward     | 81.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 11487744 |
# | train/             |          |
# |    actor_loss      | 6.83e+03 |
# |    critic_loss     | 1.12e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1911168  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.3e+03  |
# |    ep_rew_mean     | 152      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12630    |
# |    fps             | 1666     |
# |    time_elapsed    | 297      |
# |    total_timesteps | 11502816 |
# | train/             |          |
# |    actor_loss      | 6.97e+03 |
# |    critic_loss     | 1.76e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1913728  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.27e+03 |
# |    ep_rew_mean     | 157      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12640    |
# |    fps             | 1665     |
# |    time_elapsed    | 307      |
# |    total_timesteps | 11520132 |
# | train/             |          |
# |    actor_loss      | 7.07e+03 |
# |    critic_loss     | 1.21e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1916672  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.25e+03 |
# |    ep_rew_mean     | 155      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12650    |
# |    fps             | 1669     |
# |    time_elapsed    | 323      |
# |    total_timesteps | 11548188 |
# | train/             |          |
# |    actor_loss      | 7.2e+03  |
# |    critic_loss     | 1.55e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1921280  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.14e+03 |
# |    ep_rew_mean     | 145      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12660    |
# |    fps             | 1668     |
# |    time_elapsed    | 330      |
# |    total_timesteps | 11560032 |
# | train/             |          |
# |    actor_loss      | 7.19e+03 |
# |    critic_loss     | 1.77e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1923328  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.21e+03 |
# |    ep_rew_mean     | 155      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12670    |
# |    fps             | 1672     |
# |    time_elapsed    | 347      |
# |    total_timesteps | 11589852 |
# | train/             |          |
# |    actor_loss      | 7.36e+03 |
# |    critic_loss     | 1.28e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1928192  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.23e+03 |
# |    ep_rew_mean     | 155      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12680    |
# |    fps             | 1671     |
# |    time_elapsed    | 359      |
# |    total_timesteps | 11608512 |
# | train/             |          |
# |    actor_loss      | 7.27e+03 |
# |    critic_loss     | 1.58e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1931392  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.18e+03 |
# |    ep_rew_mean     | 124      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12690    |
# |    fps             | 1672     |
# |    time_elapsed    | 371      |
# |    total_timesteps | 11629836 |
# | train/             |          |
# |    actor_loss      | 7.44e+03 |
# |    critic_loss     | 1.64e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1934976  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.06e+03 |
# |    ep_rew_mean     | 108      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12700    |
# |    fps             | 1673     |
# |    time_elapsed    | 376      |
# |    total_timesteps | 11637036 |
# | train/             |          |
# |    actor_loss      | 7.46e+03 |
# |    critic_loss     | 1.64e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1936128  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2e+03    |
# |    ep_rew_mean     | 25       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12710    |
# |    fps             | 1675     |
# |    time_elapsed    | 393      |
# |    total_timesteps | 11667684 |
# | train/             |          |
# |    actor_loss      | 7.62e+03 |
# |    critic_loss     | 1.64e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1941248  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.01e+03 |
# |    ep_rew_mean     | 20.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12720    |
# |    fps             | 1677     |
# |    time_elapsed    | 401      |
# |    total_timesteps | 11680512 |
# | train/             |          |
# |    actor_loss      | 7.75e+03 |
# |    critic_loss     | 2.29e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1943296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.01e+03 |
# |    ep_rew_mean     | 20.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12730    |
# |    fps             | 1677     |
# |    time_elapsed    | 415      |
# |    total_timesteps | 11705160 |
# | train/             |          |
# |    actor_loss      | 7.78e+03 |
# |    critic_loss     | 1.8e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1947520  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.02e+03 |
# |    ep_rew_mean     | 33.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12740    |
# |    fps             | 1678     |
# |    time_elapsed    | 422      |
# |    total_timesteps | 11716512 |
# | train/             |          |
# |    actor_loss      | 7.85e+03 |
# |    critic_loss     | 1.31e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1949312  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0141.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0142.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0143.png
# Eval num_timesteps=11727744, episode_reward=210.67 +/- 122.55
# Episode length: 2522.67 +/- 675.05
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2.52e+03 |
# |    mean_reward     | 211      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 11727744 |
# | train/             |          |
# |    actor_loss      | 7.91e+03 |
# |    critic_loss     | 1.95e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1951232  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.99e+03 |
# |    ep_rew_mean     | 29.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12750    |
# |    fps             | 1663     |
# |    time_elapsed    | 443      |
# |    total_timesteps | 11745312 |
# | train/             |          |
# |    actor_loss      | 7.99e+03 |
# |    critic_loss     | 2.05e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1954176  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2e+03    |
# |    ep_rew_mean     | 34       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12760    |
# |    fps             | 1663     |
# |    time_elapsed    | 451      |
# |    total_timesteps | 11758128 |
# | train/             |          |
# |    actor_loss      | 8.04e+03 |
# |    critic_loss     | 1.52e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1956352  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.97e+03 |
# |    ep_rew_mean     | 29.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12770    |
# |    fps             | 1665     |
# |    time_elapsed    | 465      |
# |    total_timesteps | 11783016 |
# | train/             |          |
# |    actor_loss      | 8.18e+03 |
# |    critic_loss     | 1.78e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1960448  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.99e+03 |
# |    ep_rew_mean     | 32.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12780    |
# |    fps             | 1668     |
# |    time_elapsed    | 483      |
# |    total_timesteps | 11813892 |
# | train/             |          |
# |    actor_loss      | 8.35e+03 |
# |    critic_loss     | 2.27e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1965568  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.02e+03 |
# |    ep_rew_mean     | 63.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12790    |
# |    fps             | 1667     |
# |    time_elapsed    | 490      |
# |    total_timesteps | 11825124 |
# | train/             |          |
# |    actor_loss      | 8.44e+03 |
# |    critic_loss     | 2.28e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1967488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.02e+03 |
# |    ep_rew_mean     | 64.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12800    |
# |    fps             | 1669     |
# |    time_elapsed    | 504      |
# |    total_timesteps | 11849892 |
# | train/             |          |
# |    actor_loss      | 8.7e+03  |
# |    critic_loss     | 2.29e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1971584  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.08e+03 |
# |    ep_rew_mean     | 147      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12810    |
# |    fps             | 1670     |
# |    time_elapsed    | 516      |
# |    total_timesteps | 11869656 |
# | train/             |          |
# |    actor_loss      | 8.79e+03 |
# |    critic_loss     | 1.85e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1974912  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.12e+03 |
# |    ep_rew_mean     | 156      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12820    |
# |    fps             | 1671     |
# |    time_elapsed    | 532      |
# |    total_timesteps | 11897124 |
# | train/             |          |
# |    actor_loss      | 8.89e+03 |
# |    critic_loss     | 2.7e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1979520  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.18e+03 |
# |    ep_rew_mean     | 161      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12830    |
# |    fps             | 1673     |
# |    time_elapsed    | 548      |
# |    total_timesteps | 11924724 |
# | train/             |          |
# |    actor_loss      | 9.24e+03 |
# |    critic_loss     | 1.78e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1984000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.13e+03 |
# |    ep_rew_mean     | 157      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12840    |
# |    fps             | 1671     |
# |    time_elapsed    | 556      |
# |    total_timesteps | 11938068 |
# | train/             |          |
# |    actor_loss      | 9.35e+03 |
# |    critic_loss     | 1.76e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1986304  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.14e+03 |
# |    ep_rew_mean     | 159      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12850    |
# |    fps             | 1671     |
# |    time_elapsed    | 571      |
# |    total_timesteps | 11962140 |
# | train/             |          |
# |    actor_loss      | 9.62e+03 |
# |    critic_loss     | 1.98e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1990272  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0144.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0145.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0146.png
# Eval num_timesteps=11967744, episode_reward=107.11 +/- 134.56
# Episode length: 1337.33 +/- 1176.70
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.34e+03 |
# |    mean_reward     | 107      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 11967744 |
# | train/             |          |
# |    actor_loss      | 9.69e+03 |
# |    critic_loss     | 1.73e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1991168  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.16e+03 |
# |    ep_rew_mean     | 160      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12860    |
# |    fps             | 1661     |
# |    time_elapsed    | 584      |
# |    total_timesteps | 11978616 |
# | train/             |          |
# |    actor_loss      | 9.75e+03 |
# |    critic_loss     | 1.97e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1993088  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.17e+03 |
# |    ep_rew_mean     | 162      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12870    |
# |    fps             | 1661     |
# |    time_elapsed    | 599      |
# |    total_timesteps | 12003852 |
# | train/             |          |
# |    actor_loss      | 1.01e+04 |
# |    critic_loss     | 2.35e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1997312  |
# ---------------------------------

# %%
# > 12M steps, stabilize spawn radius
spawn_radius=(10, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_13M"))
# Out:
# Increasing spawn radius to  (10, 100.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.14e+03 |
# |    ep_rew_mean     | 160      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12880    |
# |    fps             | 1688     |
# |    time_elapsed    | 5        |
# |    total_timesteps | 12017088 |
# | train/             |          |
# |    actor_loss      | 1.03e+04 |
# |    critic_loss     | 4.36e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1999488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.02e+03 |
# |    ep_rew_mean     | 95.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12890    |
# |    fps             | 1698     |
# |    time_elapsed    | 12       |
# |    total_timesteps | 12029664 |
# | train/             |          |
# |    actor_loss      | 1.05e+04 |
# |    critic_loss     | 3.26e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2001536  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.02e+03 |
# |    ep_rew_mean     | 96       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12900    |
# |    fps             | 1669     |
# |    time_elapsed    | 24       |
# |    total_timesteps | 12048960 |
# | train/             |          |
# |    actor_loss      | 1.06e+04 |
# |    critic_loss     | 2.2e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2004736  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.9e+03  |
# |    ep_rew_mean     | 84       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12910    |
# |    fps             | 1654     |
# |    time_elapsed    | 30       |
# |    total_timesteps | 12059520 |
# | train/             |          |
# |    actor_loss      | 1.09e+04 |
# |    critic_loss     | 2.52e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2006528  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.83e+03 |
# |    ep_rew_mean     | 75.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12920    |
# |    fps             | 1656     |
# |    time_elapsed    | 46       |
# |    total_timesteps | 12085632 |
# | train/             |          |
# |    actor_loss      | 1.1e+04  |
# |    critic_loss     | 1.98e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2010880  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.79e+03 |
# |    ep_rew_mean     | 68.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12930    |
# |    fps             | 1655     |
# |    time_elapsed    | 53       |
# |    total_timesteps | 12096348 |
# | train/             |          |
# |    actor_loss      | 1.11e+04 |
# |    critic_loss     | 2.12e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2012672  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.84e+03 |
# |    ep_rew_mean     | 70.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12940    |
# |    fps             | 1661     |
# |    time_elapsed    | 70       |
# |    total_timesteps | 12125016 |
# | train/             |          |
# |    actor_loss      | 1.13e+04 |
# |    critic_loss     | 3.24e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2017408  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.8e+03  |
# |    ep_rew_mean     | 65       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12950    |
# |    fps             | 1654     |
# |    time_elapsed    | 75       |
# |    total_timesteps | 12133800 |
# | train/             |          |
# |    actor_loss      | 1.14e+04 |
# |    critic_loss     | 1.91e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2018944  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.73e+03 |
# |    ep_rew_mean     | 56.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12960    |
# |    fps             | 1657     |
# |    time_elapsed    | 87       |
# |    total_timesteps | 12153192 |
# | train/             |          |
# |    actor_loss      | 1.15e+04 |
# |    critic_loss     | 1.87e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2022144  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.78e+03 |
# |    ep_rew_mean     | 60.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12970    |
# |    fps             | 1658     |
# |    time_elapsed    | 100      |
# |    total_timesteps | 12174552 |
# | train/             |          |
# |    actor_loss      | 1.17e+04 |
# |    critic_loss     | 1.77e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2025728  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.67e+03 |
# |    ep_rew_mean     | 47       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12980    |
# |    fps             | 1660     |
# |    time_elapsed    | 109      |
# |    total_timesteps | 12189480 |
# | train/             |          |
# |    actor_loss      | 1.2e+04  |
# |    critic_loss     | 2.98e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2028160  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.65e+03 |
# |    ep_rew_mean     | 100      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12990    |
# |    fps             | 1661     |
# |    time_elapsed    | 115      |
# |    total_timesteps | 12200256 |
# | train/             |          |
# |    actor_loss      | 1.2e+04  |
# |    critic_loss     | 2.29e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2029952  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.62e+03 |
# |    ep_rew_mean     | 96.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13000    |
# |    fps             | 1661     |
# |    time_elapsed    | 119      |
# |    total_timesteps | 12207228 |
# | train/             |          |
# |    actor_loss      | 1.22e+04 |
# |    critic_loss     | 2.18e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2031104  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.65e+03 |
# |    ep_rew_mean     | 50.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13010    |
# |    fps             | 1661     |
# |    time_elapsed    | 132      |
# |    total_timesteps | 12228300 |
# | train/             |          |
# |    actor_loss      | 1.22e+04 |
# |    critic_loss     | 1.82e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2034688  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0147.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0148.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0149.png
# Eval num_timesteps=12248448, episode_reward=88.33 +/- 147.57
# Episode length: 1251.33 +/- 1237.43
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.25e+03 |
# |    mean_reward     | 88.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 12248448 |
# | train/             |          |
# |    actor_loss      | 1.23e+04 |
# |    critic_loss     | 1.79e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2038016  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.71e+03 |
# |    ep_rew_mean     | 52.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13020    |
# |    fps             | 1633     |
# |    time_elapsed    | 147      |
# |    total_timesteps | 12249984 |
# | train/             |          |
# |    actor_loss      | 1.25e+04 |
# |    critic_loss     | 1.83e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2038272  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.71e+03 |
# |    ep_rew_mean     | 52.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13030    |
# |    fps             | 1638     |
# |    time_elapsed    | 163      |
# |    total_timesteps | 12275544 |
# | train/             |          |
# |    actor_loss      | 1.26e+04 |
# |    critic_loss     | 1.8e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2042496  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.72e+03 |
# |    ep_rew_mean     | 52.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13040    |
# |    fps             | 1638     |
# |    time_elapsed    | 173      |
# |    total_timesteps | 12292572 |
# | train/             |          |
# |    actor_loss      | 1.29e+04 |
# |    critic_loss     | 1.62e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2045312  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.69e+03 |
# |    ep_rew_mean     | 54.4     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13050    |
# |    fps             | 1639     |
# |    time_elapsed    | 183      |
# |    total_timesteps | 12309444 |
# | train/             |          |
# |    actor_loss      | 1.3e+04  |
# |    critic_loss     | 1.82e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2048128  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.76e+03 |
# |    ep_rew_mean     | 59.4     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13060    |
# |    fps             | 1638     |
# |    time_elapsed    | 197      |
# |    total_timesteps | 12331548 |
# | train/             |          |
# |    actor_loss      | 1.32e+04 |
# |    critic_loss     | 1.61e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2051840  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.73e+03 |
# |    ep_rew_mean     | 51.9     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13070    |
# |    fps             | 1638     |
# |    time_elapsed    | 206      |
# |    total_timesteps | 12347604 |
# | train/             |          |
# |    actor_loss      | 1.33e+04 |
# |    critic_loss     | 6.41e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2054528  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.9e+03  |
# |    ep_rew_mean     | -24.3    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13080    |
# |    fps             | 1638     |
# |    time_elapsed    | 223      |
# |    total_timesteps | 12375192 |
# | train/             |          |
# |    actor_loss      | 1.38e+04 |
# |    critic_loss     | 1.64e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2059136  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.97e+03 |
# |    ep_rew_mean     | -19.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13090    |
# |    fps             | 1638     |
# |    time_elapsed    | 234      |
# |    total_timesteps | 12392748 |
# | train/             |          |
# |    actor_loss      | 1.37e+04 |
# |    critic_loss     | 3.61e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2062080  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.04e+03 |
# |    ep_rew_mean     | -16.1    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13100    |
# |    fps             | 1638     |
# |    time_elapsed    | 245      |
# |    total_timesteps | 12411192 |
# | train/             |          |
# |    actor_loss      | 1.39e+04 |
# |    critic_loss     | 1.96e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2065152  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.05e+03 |
# |    ep_rew_mean     | 32.4     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13110    |
# |    fps             | 1640     |
# |    time_elapsed    | 254      |
# |    total_timesteps | 12426648 |
# | train/             |          |
# |    actor_loss      | 1.39e+04 |
# |    critic_loss     | 4.31e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2067712  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.02e+03 |
# |    ep_rew_mean     | 30.1     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13120    |
# |    fps             | 1642     |
# |    time_elapsed    | 272      |
# |    total_timesteps | 12455760 |
# | train/             |          |
# |    actor_loss      | 1.4e+04  |
# |    critic_loss     | 2.95e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2072576  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.99e+03 |
# |    ep_rew_mean     | 27.5     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13130    |
# |    fps             | 1642     |
# |    time_elapsed    | 281      |
# |    total_timesteps | 12470352 |
# | train/             |          |
# |    actor_loss      | 1.39e+04 |
# |    critic_loss     | 2.04e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2075008  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.94e+03 |
# |    ep_rew_mean     | 26.5     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 13140    |
# |    fps             | 1643     |
# |    time_elapsed    | 288      |
# |    total_timesteps | 12483192 |
# | train/             |          |
# |    actor_loss      | 1.37e+04 |
# |    critic_loss     | 4.23e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2077184  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0150.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0151.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0152.png
# Eval num_timesteps=12488448, episode_reward=96.57 +/- 141.62
# Episode length: 2046.67 +/- 674.98
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2.05e+03 |
# |    mean_reward     | 96.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 12488448 |
# | train/             |          |
# |    actor_loss      | 1.37e+04 |
# |    critic_loss     | 2.18e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2077952  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.87e+03 |
# |    ep_rew_mean     | 15.6     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13150    |
# |    fps             | 1622     |
# |    time_elapsed    | 300      |
# |    total_timesteps | 12496632 |
# | train/             |          |
# |    actor_loss      | 1.36e+04 |
# |    critic_loss     | 2.23e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2079360  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.79e+03 |
# |    ep_rew_mean     | 10.4     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13160    |
# |    fps             | 1623     |
# |    time_elapsed    | 307      |
# |    total_timesteps | 12508248 |
# | train/             |          |
# |    actor_loss      | 1.36e+04 |
# |    critic_loss     | 6.44e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2081280  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.77e+03 |
# |    ep_rew_mean     | -43      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13170    |
# |    fps             | 1623     |
# |    time_elapsed    | 316      |
# |    total_timesteps | 12521820 |
# | train/             |          |
# |    actor_loss      | 1.38e+04 |
# |    critic_loss     | 3.83e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2083584  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53e+03 |
# |    ep_rew_mean     | 27.4     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13180    |
# |    fps             | 1623     |
# |    time_elapsed    | 322      |
# |    total_timesteps | 12531708 |
# | train/             |          |
# |    actor_loss      | 1.39e+04 |
# |    critic_loss     | 3.14e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2085248  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.55e+03 |
# |    ep_rew_mean     | -60.9    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13190    |
# |    fps             | 1626     |
# |    time_elapsed    | 336      |
# |    total_timesteps | 12555384 |
# | train/             |          |
# |    actor_loss      | 1.38e+04 |
# |    critic_loss     | 4.34e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2089216  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.54e+03 |
# |    ep_rew_mean     | -93.7    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 13200    |
# |    fps             | 1627     |
# |    time_elapsed    | 342      |
# |    total_timesteps | 12566220 |
# | train/             |          |
# |    actor_loss      | 1.39e+04 |
# |    critic_loss     | 5.12e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2091008  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53e+03 |
# |    ep_rew_mean     | -126     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 13210    |
# |    fps             | 1627     |
# |    time_elapsed    | 347      |
# |    total_timesteps | 12574932 |
# | train/             |          |
# |    actor_loss      | 1.41e+04 |
# |    critic_loss     | 5.69e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2092416  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | -137     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 13220    |
# |    fps             | 1628     |
# |    time_elapsed    | 362      |
# |    total_timesteps | 12598092 |
# | train/             |          |
# |    actor_loss      | 1.39e+04 |
# |    critic_loss     | 4.79e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2096256  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.42e+03 |
# |    ep_rew_mean     | -131     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 13230    |
# |    fps             | 1628     |
# |    time_elapsed    | 370      |
# |    total_timesteps | 12612228 |
# | train/             |          |
# |    actor_loss      | 1.41e+04 |
# |    critic_loss     | 7.6e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2098688  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | -134     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 13240    |
# |    fps             | 1628     |
# |    time_elapsed    | 374      |
# |    total_timesteps | 12618336 |
# | train/             |          |
# |    actor_loss      | 1.41e+04 |
# |    critic_loss     | 7.83e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2099712  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.46e+03 |
# |    ep_rew_mean     | -156     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 13250    |
# |    fps             | 1630     |
# |    time_elapsed    | 390      |
# |    total_timesteps | 12644496 |
# | train/             |          |
# |    actor_loss      | 1.44e+04 |
# |    critic_loss     | 1.16e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2104064  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.56e+03 |
# |    ep_rew_mean     | -151     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 13260    |
# |    fps             | 1632     |
# |    time_elapsed    | 398      |
# |    total_timesteps | 12658728 |
# | train/             |          |
# |    actor_loss      | 1.43e+04 |
# |    critic_loss     | 4.06e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2106368  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.48e+03 |
# |    ep_rew_mean     | -102     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 13270    |
# |    fps             | 1632     |
# |    time_elapsed    | 409      |
# |    total_timesteps | 12676044 |
# | train/             |          |
# |    actor_loss      | 1.44e+04 |
# |    critic_loss     | 4.96e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2109312  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.62e+03 |
# |    ep_rew_mean     | -90.1    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 13280    |
# |    fps             | 1632     |
# |    time_elapsed    | 418      |
# |    total_timesteps | 12692076 |
# | train/             |          |
# |    actor_loss      | 1.44e+04 |
# |    critic_loss     | 4.34e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2112000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.56e+03 |
# |    ep_rew_mean     | -4.96    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 13290    |
# |    fps             | 1632     |
# |    time_elapsed    | 427      |
# |    total_timesteps | 12706704 |
# | train/             |          |
# |    actor_loss      | 1.47e+04 |
# |    critic_loss     | 5.07e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2114432  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | 24       |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13300    |
# |    fps             | 1634     |
# |    time_elapsed    | 432      |
# |    total_timesteps | 12715632 |
# | train/             |          |
# |    actor_loss      | 1.46e+04 |
# |    critic_loss     | 1.11e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2115840  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0153.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0154.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0155.png
# Eval num_timesteps=12728448, episode_reward=189.45 +/- 151.38
# Episode length: 2088.33 +/- 1289.29
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2.09e+03 |
# |    mean_reward     | 189      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 12728448 |
# | train/             |          |
# |    actor_loss      | 1.47e+04 |
# |    critic_loss     | 4.58e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2118016  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.49e+03 |
# |    ep_rew_mean     | 54.1     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13310    |
# |    fps             | 1619     |
# |    time_elapsed    | 446      |
# |    total_timesteps | 12731220 |
# | train/             |          |
# |    actor_loss      | 1.47e+04 |
# |    critic_loss     | 4.37e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2118528  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.59e+03 |
# |    ep_rew_mean     | 65.1     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 13320    |
# |    fps             | 1619     |
# |    time_elapsed    | 457      |
# |    total_timesteps | 12749676 |
# | train/             |          |
# |    actor_loss      | 1.49e+04 |
# |    critic_loss     | 4.7e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2121600  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.58e+03 |
# |    ep_rew_mean     | 59.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13330    |
# |    fps             | 1621     |
# |    time_elapsed    | 470      |
# |    total_timesteps | 12771372 |
# | train/             |          |
# |    actor_loss      | 1.52e+04 |
# |    critic_loss     | 5.9e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2125184  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.67e+03 |
# |    ep_rew_mean     | 70.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13340    |
# |    fps             | 1622     |
# |    time_elapsed    | 482      |
# |    total_timesteps | 12790932 |
# | train/             |          |
# |    actor_loss      | 1.53e+04 |
# |    critic_loss     | 7.1e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2128384  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.68e+03 |
# |    ep_rew_mean     | 96.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13350    |
# |    fps             | 1622     |
# |    time_elapsed    | 492      |
# |    total_timesteps | 12807576 |
# | train/             |          |
# |    actor_loss      | 1.51e+04 |
# |    critic_loss     | 6.16e+06 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2131200  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.74e+03 |
# |    ep_rew_mean     | 87.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13360    |
# |    fps             | 1623     |
# |    time_elapsed    | 511      |
# |    total_timesteps | 12838668 |
# | train/             |          |
# |    actor_loss      | 1.52e+04 |
# |    critic_loss     | 4.83e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2136448  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.83e+03 |
# |    ep_rew_mean     | 90.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13370    |
# |    fps             | 1624     |
# |    time_elapsed    | 522      |
# |    total_timesteps | 12857676 |
# | train/             |          |
# |    actor_loss      | 1.55e+04 |
# |    critic_loss     | 7.49e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2139520  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.88e+03 |
# |    ep_rew_mean     | 93.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13380    |
# |    fps             | 1625     |
# |    time_elapsed    | 536      |
# |    total_timesteps | 12879576 |
# | train/             |          |
# |    actor_loss      | 1.57e+04 |
# |    critic_loss     | 1.13e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2143232  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.91e+03 |
# |    ep_rew_mean     | 93.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13390    |
# |    fps             | 1625     |
# |    time_elapsed    | 540      |
# |    total_timesteps | 12886620 |
# | train/             |          |
# |    actor_loss      | 1.56e+04 |
# |    critic_loss     | 5.16e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2144384  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.93e+03 |
# |    ep_rew_mean     | 91.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13400    |
# |    fps             | 1627     |
# |    time_elapsed    | 556      |
# |    total_timesteps | 12913740 |
# | train/             |          |
# |    actor_loss      | 1.57e+04 |
# |    critic_loss     | 3.85e+06 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2148864  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.95e+03 |
# |    ep_rew_mean     | 91.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13410    |
# |    fps             | 1626     |
# |    time_elapsed    | 561      |
# |    total_timesteps | 12921780 |
# | train/             |          |
# |    actor_loss      | 1.57e+04 |
# |    critic_loss     | 4.44e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2150272  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.98e+03 |
# |    ep_rew_mean     | 68.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13420    |
# |    fps             | 1627     |
# |    time_elapsed    | 580      |
# |    total_timesteps | 12953304 |
# | train/             |          |
# |    actor_loss      | 1.6e+04  |
# |    critic_loss     | 4.43e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2155520  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.94e+03 |
# |    ep_rew_mean     | 61.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13430    |
# |    fps             | 1628     |
# |    time_elapsed    | 584      |
# |    total_timesteps | 12959676 |
# | train/             |          |
# |    actor_loss      | 1.61e+04 |
# |    critic_loss     | 6.43e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2156544  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0156.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0157.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0158.png
# Eval num_timesteps=12968448, episode_reward=28.36 +/- 44.63
# Episode length: 1559.67 +/- 1166.88
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.56e+03 |
# |    mean_reward     | 28.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 12968448 |
# | train/             |          |
# |    actor_loss      | 1.6e+04  |
# |    critic_loss     | 6.82e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2157952  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.84e+03 |
# |    ep_rew_mean     | 49.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13440    |
# |    fps             | 1620     |
# |    time_elapsed    | 600      |
# |    total_timesteps | 12981168 |
# | train/             |          |
# |    actor_loss      | 1.61e+04 |
# |    critic_loss     | 6.05e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2160128  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.91e+03 |
# |    ep_rew_mean     | 53.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13450    |
# |    fps             | 1621     |
# |    time_elapsed    | 610      |
# |    total_timesteps | 12998196 |
# | train/             |          |
# |    actor_loss      | 1.62e+04 |
# |    critic_loss     | 1.58e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2162944  |
# ---------------------------------

# %%
# > 13M steps, stabilize spawn radius
spawn_radius=(10, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_14M"))
# Out:
# Increasing spawn radius to  (10, 100.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.81e+03 |
# |    ep_rew_mean     | 57       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13460    |
# |    fps             | 1617     |
# |    time_elapsed    | 5        |
# |    total_timesteps | 13017648 |
# | train/             |          |
# |    actor_loss      | 1.63e+04 |
# |    critic_loss     | 1.41e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2166272  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.81e+03 |
# |    ep_rew_mean     | -63.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13470    |
# |    fps             | 1669     |
# |    time_elapsed    | 17       |
# |    total_timesteps | 13038864 |
# | train/             |          |
# |    actor_loss      | 1.64e+04 |
# |    critic_loss     | 8.69e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2169728  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.73e+03 |
# |    ep_rew_mean     | -69.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13480    |
# |    fps             | 1671     |
# |    time_elapsed    | 24       |
# |    total_timesteps | 13050396 |
# | train/             |          |
# |    actor_loss      | 1.65e+04 |
# |    critic_loss     | 8.43e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2171648  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.74e+03 |
# |    ep_rew_mean     | -106     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13490    |
# |    fps             | 1664     |
# |    time_elapsed    | 36       |
# |    total_timesteps | 13069404 |
# | train/             |          |
# |    actor_loss      | 1.68e+04 |
# |    critic_loss     | 8.39e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2174848  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.73e+03 |
# |    ep_rew_mean     | -104     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13500    |
# |    fps             | 1662     |
# |    time_elapsed    | 43       |
# |    total_timesteps | 13081608 |
# | train/             |          |
# |    actor_loss      | 1.7e+04  |
# |    critic_loss     | 9.71e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2176896  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.74e+03 |
# |    ep_rew_mean     | -100     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13510    |
# |    fps             | 1654     |
# |    time_elapsed    | 59       |
# |    total_timesteps | 13106808 |
# | train/             |          |
# |    actor_loss      | 1.72e+04 |
# |    critic_loss     | 1.15e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2181120  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.79e+03 |
# |    ep_rew_mean     | -77.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13520    |
# |    fps             | 1655     |
# |    time_elapsed    | 68       |
# |    total_timesteps | 13122396 |
# | train/             |          |
# |    actor_loss      | 1.75e+04 |
# |    critic_loss     | 8.15e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2183680  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.9e+03  |
# |    ep_rew_mean     | -69.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13530    |
# |    fps             | 1659     |
# |    time_elapsed    | 87       |
# |    total_timesteps | 13154868 |
# | train/             |          |
# |    actor_loss      | 1.77e+04 |
# |    critic_loss     | 9.41e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2189056  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.94e+03 |
# |    ep_rew_mean     | -64.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13540    |
# |    fps             | 1653     |
# |    time_elapsed    | 95       |
# |    total_timesteps | 13167528 |
# | train/             |          |
# |    actor_loss      | 1.78e+04 |
# |    critic_loss     | 1.09e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2191232  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.83e+03 |
# |    ep_rew_mean     | -71.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13550    |
# |    fps             | 1658     |
# |    time_elapsed    | 103      |
# |    total_timesteps | 13181064 |
# | train/             |          |
# |    actor_loss      | 1.78e+04 |
# |    critic_loss     | 9.37e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2193408  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.86e+03 |
# |    ep_rew_mean     | -61.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13560    |
# |    fps             | 1653     |
# |    time_elapsed    | 119      |
# |    total_timesteps | 13207380 |
# | train/             |          |
# |    actor_loss      | 1.78e+04 |
# |    critic_loss     | 8.78e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2197888  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.79e+03 |
# |    ep_rew_mean     | 60.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13570    |
# |    fps             | 1655     |
# |    time_elapsed    | 126      |
# |    total_timesteps | 13218432 |
# | train/             |          |
# |    actor_loss      | 1.79e+04 |
# |    critic_loss     | 1.28e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2199680  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.75e+03 |
# |    ep_rew_mean     | 59.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13580    |
# |    fps             | 1656     |
# |    time_elapsed    | 131      |
# |    total_timesteps | 13226352 |
# | train/             |          |
# |    actor_loss      | 1.8e+04  |
# |    critic_loss     | 8.2e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2200960  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.68e+03 |
# |    ep_rew_mean     | 93.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13590    |
# |    fps             | 1654     |
# |    time_elapsed    | 136      |
# |    total_timesteps | 13234620 |
# | train/             |          |
# |    actor_loss      | 1.78e+04 |
# |    critic_loss     | 9.09e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2202368  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0159.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0160.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0161.png
# Eval num_timesteps=13249152, episode_reward=-1274.50 +/- 2219.18
# Episode length: 2740.00 +/- 367.70
# Success rate: 0.00%
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 2.74e+03  |
# |    mean_reward     | -1.27e+03 |
# |    success_rate    | 0         |
# | time/              |           |
# |    total_timesteps | 13249152  |
# | train/             |           |
# |    actor_loss      | 1.79e+04  |
# |    critic_loss     | 8.63e+04  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2204800   |
# ----------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.7e+03  |
# |    ep_rew_mean     | 96.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13600    |
# |    fps             | 1601     |
# |    time_elapsed    | 154      |
# |    total_timesteps | 13257156 |
# | train/             |          |
# |    actor_loss      | 1.78e+04 |
# |    critic_loss     | 9.82e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2206080  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.71e+03 |
# |    ep_rew_mean     | 100      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13610    |
# |    fps             | 1602     |
# |    time_elapsed    | 162      |
# |    total_timesteps | 13269984 |
# | train/             |          |
# |    actor_loss      | 1.81e+04 |
# |    critic_loss     | 1.03e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2208256  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.6e+03  |
# |    ep_rew_mean     | 94.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13620    |
# |    fps             | 1606     |
# |    time_elapsed    | 174      |
# |    total_timesteps | 13289112 |
# | train/             |          |
# |    actor_loss      | 1.83e+04 |
# |    critic_loss     | 2.14e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2211456  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.49e+03 |
# |    ep_rew_mean     | 53.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13630    |
# |    fps             | 1607     |
# |    time_elapsed    | 182      |
# |    total_timesteps | 13301964 |
# | train/             |          |
# |    actor_loss      | 1.82e+04 |
# |    critic_loss     | 1.32e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2213632  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.45e+03 |
# |    ep_rew_mean     | 48.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13640    |
# |    fps             | 1611     |
# |    time_elapsed    | 188      |
# |    total_timesteps | 13312416 |
# | train/             |          |
# |    actor_loss      | 1.85e+04 |
# |    critic_loss     | 1.1e+05  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2215296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.45e+03 |
# |    ep_rew_mean     | 48.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13650    |
# |    fps             | 1613     |
# |    time_elapsed    | 199      |
# |    total_timesteps | 13330596 |
# | train/             |          |
# |    actor_loss      | 1.84e+04 |
# |    critic_loss     | 9.18e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2218368  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.43e+03 |
# |    ep_rew_mean     | 41.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13660    |
# |    fps             | 1615     |
# |    time_elapsed    | 208      |
# |    total_timesteps | 13345248 |
# | train/             |          |
# |    actor_loss      | 1.85e+04 |
# |    critic_loss     | 1.56e+06 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2220800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.44e+03 |
# |    ep_rew_mean     | 35.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13670    |
# |    fps             | 1617     |
# |    time_elapsed    | 219      |
# |    total_timesteps | 13364580 |
# | train/             |          |
# |    actor_loss      | 1.87e+04 |
# |    critic_loss     | 9.66e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2224000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | 28.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13680    |
# |    fps             | 1617     |
# |    time_elapsed    | 229      |
# |    total_timesteps | 13381248 |
# | train/             |          |
# |    actor_loss      | 1.88e+04 |
# |    critic_loss     | 2.25e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2226816  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.54e+03 |
# |    ep_rew_mean     | 30.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13690    |
# |    fps             | 1618     |
# |    time_elapsed    | 235      |
# |    total_timesteps | 13390464 |
# | train/             |          |
# |    actor_loss      | 1.88e+04 |
# |    critic_loss     | 9.05e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2228352  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | -4.96    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13700    |
# |    fps             | 1620     |
# |    time_elapsed    | 241      |
# |    total_timesteps | 13400580 |
# | train/             |          |
# |    actor_loss      | 1.89e+04 |
# |    critic_loss     | 1.01e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2230016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.48e+03 |
# |    ep_rew_mean     | -16.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13710    |
# |    fps             | 1627     |
# |    time_elapsed    | 254      |
# |    total_timesteps | 13423800 |
# | train/             |          |
# |    actor_loss      | 1.92e+04 |
# |    critic_loss     | 1.07e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2233856  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.52e+03 |
# |    ep_rew_mean     | -59.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13720    |
# |    fps             | 1629     |
# |    time_elapsed    | 262      |
# |    total_timesteps | 13436580 |
# | train/             |          |
# |    actor_loss      | 1.94e+04 |
# |    critic_loss     | 2e+05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2236032  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.47e+03 |
# |    ep_rew_mean     | -28.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13730    |
# |    fps             | 1632     |
# |    time_elapsed    | 268      |
# |    total_timesteps | 13447368 |
# | train/             |          |
# |    actor_loss      | 1.93e+04 |
# |    critic_loss     | 1.18e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2237824  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.46e+03 |
# |    ep_rew_mean     | -26.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13740    |
# |    fps             | 1634     |
# |    time_elapsed    | 278      |
# |    total_timesteps | 13464708 |
# | train/             |          |
# |    actor_loss      | 1.94e+04 |
# |    critic_loss     | 1.38e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2240768  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.52e+03 |
# |    ep_rew_mean     | -135     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13750    |
# |    fps             | 1637     |
# |    time_elapsed    | 285      |
# |    total_timesteps | 13477164 |
# | train/             |          |
# |    actor_loss      | 1.97e+04 |
# |    critic_loss     | 2.78e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2242816  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0162.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0163.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0164.png
# Eval num_timesteps=13489152, episode_reward=82.77 +/- 149.18
# Episode length: 1219.67 +/- 1259.10
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.22e+03 |
# |    mean_reward     | 82.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 13489152 |
# | train/             |          |
# |    actor_loss      | 1.97e+04 |
# |    critic_loss     | 1.73e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2244736  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.47e+03 |
# |    ep_rew_mean     | -271     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13760    |
# |    fps             | 1627     |
# |    time_elapsed    | 295      |
# |    total_timesteps | 13490328 |
# | train/             |          |
# |    actor_loss      | 1.95e+04 |
# |    critic_loss     | 4.38e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2244992  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | -277     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13770    |
# |    fps             | 1628     |
# |    time_elapsed    | 301      |
# |    total_timesteps | 13500696 |
# | train/             |          |
# |    actor_loss      | 1.95e+04 |
# |    critic_loss     | 1.45e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2246784  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | -330     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13780    |
# |    fps             | 1632     |
# |    time_elapsed    | 310      |
# |    total_timesteps | 13516008 |
# | train/             |          |
# |    actor_loss      | 1.96e+04 |
# |    critic_loss     | 2.06e+06 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2249216  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.42e+03 |
# |    ep_rew_mean     | -327     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13790    |
# |    fps             | 1635     |
# |    time_elapsed    | 321      |
# |    total_timesteps | 13535016 |
# | train/             |          |
# |    actor_loss      | 1.96e+04 |
# |    critic_loss     | 1.38e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2252416  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.48e+03 |
# |    ep_rew_mean     | -390     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13800    |
# |    fps             | 1638     |
# |    time_elapsed    | 332      |
# |    total_timesteps | 13553064 |
# | train/             |          |
# |    actor_loss      | 1.94e+04 |
# |    critic_loss     | 9.46e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2255488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.48e+03 |
# |    ep_rew_mean     | -425     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13810    |
# |    fps             | 1641     |
# |    time_elapsed    | 339      |
# |    total_timesteps | 13566540 |
# | train/             |          |
# |    actor_loss      | 1.92e+04 |
# |    critic_loss     | 1.67e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2257664  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.45e+03 |
# |    ep_rew_mean     | -412     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13820    |
# |    fps             | 1643     |
# |    time_elapsed    | 347      |
# |    total_timesteps | 13581144 |
# | train/             |          |
# |    actor_loss      | 1.92e+04 |
# |    critic_loss     | 1.17e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2260096  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.46e+03 |
# |    ep_rew_mean     | -411     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13830    |
# |    fps             | 1644     |
# |    time_elapsed    | 354      |
# |    total_timesteps | 13592076 |
# | train/             |          |
# |    actor_loss      | 1.92e+04 |
# |    critic_loss     | 2e+06    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2262016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.41e+03 |
# |    ep_rew_mean     | -417     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13840    |
# |    fps             | 1646     |
# |    time_elapsed    | 359      |
# |    total_timesteps | 13600224 |
# | train/             |          |
# |    actor_loss      | 1.93e+04 |
# |    critic_loss     | 5.3e+05  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2263296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | -309     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13850    |
# |    fps             | 1646     |
# |    time_elapsed    | 365      |
# |    total_timesteps | 13611552 |
# | train/             |          |
# |    actor_loss      | 1.92e+04 |
# |    critic_loss     | 1.2e+05  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2265216  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | -179     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13860    |
# |    fps             | 1648     |
# |    time_elapsed    | 376      |
# |    total_timesteps | 13630608 |
# | train/             |          |
# |    actor_loss      | 1.91e+04 |
# |    critic_loss     | 1.28e+06 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2268416  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.44e+03 |
# |    ep_rew_mean     | -201     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13870    |
# |    fps             | 1650     |
# |    time_elapsed    | 385      |
# |    total_timesteps | 13645116 |
# | train/             |          |
# |    actor_loss      | 1.92e+04 |
# |    critic_loss     | 1.29e+06 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2270848  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | -143     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13880    |
# |    fps             | 1651     |
# |    time_elapsed    | 388      |
# |    total_timesteps | 13650876 |
# | train/             |          |
# |    actor_loss      | 1.92e+04 |
# |    critic_loss     | 2.46e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2271744  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | -151     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13890    |
# |    fps             | 1651     |
# |    time_elapsed    | 394      |
# |    total_timesteps | 13660476 |
# | train/             |          |
# |    actor_loss      | 1.96e+04 |
# |    critic_loss     | 8.13e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2273408  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | -57.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13900    |
# |    fps             | 1653     |
# |    time_elapsed    | 401      |
# |    total_timesteps | 13672128 |
# | train/             |          |
# |    actor_loss      | 1.97e+04 |
# |    critic_loss     | 7.3e+05  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2275328  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.23e+03 |
# |    ep_rew_mean     | -17.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13910    |
# |    fps             | 1655     |
# |    time_elapsed    | 407      |
# |    total_timesteps | 13684128 |
# | train/             |          |
# |    actor_loss      | 1.99e+04 |
# |    critic_loss     | 6.39e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2277248  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 9.39     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13920    |
# |    fps             | 1657     |
# |    time_elapsed    | 419      |
# |    total_timesteps | 13703940 |
# | train/             |          |
# |    actor_loss      | 1.94e+04 |
# |    critic_loss     | 2.27e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2280576  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 11.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13930    |
# |    fps             | 1657     |
# |    time_elapsed    | 423      |
# |    total_timesteps | 13712040 |
# | train/             |          |
# |    actor_loss      | 1.96e+04 |
# |    critic_loss     | 1.79e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2281984  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | 15.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13940    |
# |    fps             | 1659     |
# |    time_elapsed    | 428      |
# |    total_timesteps | 13720932 |
# | train/             |          |
# |    actor_loss      | 1.95e+04 |
# |    critic_loss     | 3.24e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2283392  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 15.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13950    |
# |    fps             | 1659     |
# |    time_elapsed    | 433      |
# |    total_timesteps | 13728036 |
# | train/             |          |
# |    actor_loss      | 1.96e+04 |
# |    critic_loss     | 1.84e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2284672  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0165.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0166.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0167.png
# Eval num_timesteps=13729152, episode_reward=100.08 +/- 140.59
# Episode length: 1380.33 +/- 1161.44
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.38e+03 |
# |    mean_reward     | 100      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 13729152 |
# | train/             |          |
# |    actor_loss      | 1.97e+04 |
# |    critic_loss     | 2.16e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2284800  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 13.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13960    |
# |    fps             | 1650     |
# |    time_elapsed    | 440      |
# |    total_timesteps | 13736208 |
# | train/             |          |
# |    actor_loss      | 1.96e+04 |
# |    critic_loss     | 1.79e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2285952  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 24.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13970    |
# |    fps             | 1651     |
# |    time_elapsed    | 446      |
# |    total_timesteps | 13747104 |
# | train/             |          |
# |    actor_loss      | 1.96e+04 |
# |    critic_loss     | 7.51e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2287744  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | -5.53    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13980    |
# |    fps             | 1653     |
# |    time_elapsed    | 452      |
# |    total_timesteps | 13757712 |
# | train/             |          |
# |    actor_loss      | 1.97e+04 |
# |    critic_loss     | 4.88e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2289536  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | -27.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 13990    |
# |    fps             | 1654     |
# |    time_elapsed    | 462      |
# |    total_timesteps | 13775244 |
# | train/             |          |
# |    actor_loss      | 1.98e+04 |
# |    critic_loss     | 4.75e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2292480  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -21.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14000    |
# |    fps             | 1656     |
# |    time_elapsed    | 471      |
# |    total_timesteps | 13790460 |
# | train/             |          |
# |    actor_loss      | 2e+04    |
# |    critic_loss     | 1.38e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2295040  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | -21      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14010    |
# |    fps             | 1657     |
# |    time_elapsed    | 477      |
# |    total_timesteps | 13801404 |
# | train/             |          |
# |    actor_loss      | 2.01e+04 |
# |    critic_loss     | 1.48e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2296832  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | -19.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14020    |
# |    fps             | 1660     |
# |    time_elapsed    | 489      |
# |    total_timesteps | 13821492 |
# | train/             |          |
# |    actor_loss      | 2.05e+04 |
# |    critic_loss     | 2.37e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2300160  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -18.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14030    |
# |    fps             | 1661     |
# |    time_elapsed    | 494      |
# |    total_timesteps | 13830120 |
# | train/             |          |
# |    actor_loss      | 2.06e+04 |
# |    critic_loss     | 1.53e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2301568  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -17.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14040    |
# |    fps             | 1661     |
# |    time_elapsed    | 497      |
# |    total_timesteps | 13836264 |
# | train/             |          |
# |    actor_loss      | 2.06e+04 |
# |    critic_loss     | 4.73e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2302592  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -20.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14050    |
# |    fps             | 1661     |
# |    time_elapsed    | 501      |
# |    total_timesteps | 13841988 |
# | train/             |          |
# |    actor_loss      | 2.07e+04 |
# |    critic_loss     | 1.89e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2303616  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | -20.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14060    |
# |    fps             | 1662     |
# |    time_elapsed    | 504      |
# |    total_timesteps | 13847748 |
# | train/             |          |
# |    actor_loss      | 2.07e+04 |
# |    critic_loss     | 2.77e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2304512  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 3.79     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14070    |
# |    fps             | 1663     |
# |    time_elapsed    | 517      |
# |    total_timesteps | 13869696 |
# | train/             |          |
# |    actor_loss      | 2.07e+04 |
# |    critic_loss     | 2.38e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2308224  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 36       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14080    |
# |    fps             | 1664     |
# |    time_elapsed    | 525      |
# |    total_timesteps | 13883316 |
# | train/             |          |
# |    actor_loss      | 2.07e+04 |
# |    critic_loss     | 3.03e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2310528  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.25e+03 |
# |    ep_rew_mean     | 68.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14090    |
# |    fps             | 1665     |
# |    time_elapsed    | 528      |
# |    total_timesteps | 13888764 |
# | train/             |          |
# |    actor_loss      | 2.08e+04 |
# |    critic_loss     | 2.29e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2311424  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 59       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14100    |
# |    fps             | 1665     |
# |    time_elapsed    | 531      |
# |    total_timesteps | 13894920 |
# | train/             |          |
# |    actor_loss      | 2.11e+04 |
# |    critic_loss     | 3.02e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2312448  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 54.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14110    |
# |    fps             | 1666     |
# |    time_elapsed    | 538      |
# |    total_timesteps | 13907220 |
# | train/             |          |
# |    actor_loss      | 2.11e+04 |
# |    critic_loss     | 9.76e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2314496  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | 56.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14120    |
# |    fps             | 1668     |
# |    time_elapsed    | 545      |
# |    total_timesteps | 13919856 |
# | train/             |          |
# |    actor_loss      | 2.09e+04 |
# |    critic_loss     | 4.47e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2316544  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 58.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14130    |
# |    fps             | 1668     |
# |    time_elapsed    | 552      |
# |    total_timesteps | 13931136 |
# | train/             |          |
# |    actor_loss      | 2.13e+04 |
# |    critic_loss     | 4.66e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2318464  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 54       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14140    |
# |    fps             | 1670     |
# |    time_elapsed    | 557      |
# |    total_timesteps | 13939932 |
# | train/             |          |
# |    actor_loss      | 2.14e+04 |
# |    critic_loss     | 1.67e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2319872  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 66.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14150    |
# |    fps             | 1670     |
# |    time_elapsed    | 568      |
# |    total_timesteps | 13958412 |
# | train/             |          |
# |    actor_loss      | 2.17e+04 |
# |    critic_loss     | 1.64e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2323072  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0168.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0169.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0170.png
# Eval num_timesteps=13969152, episode_reward=42.41 +/- 30.17
# Episode length: 1412.00 +/- 1156.69
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.41e+03 |
# |    mean_reward     | 42.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 13969152 |
# | train/             |          |
# |    actor_loss      | 2.17e+04 |
# |    critic_loss     | 2.69e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2324736  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | 67.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14160    |
# |    fps             | 1663     |
# |    time_elapsed    | 577      |
# |    total_timesteps | 13969692 |
# | train/             |          |
# |    actor_loss      | 2.18e+04 |
# |    critic_loss     | 1.3e+06  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2324864  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 58.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14170    |
# |    fps             | 1663     |
# |    time_elapsed    | 582      |
# |    total_timesteps | 13978464 |
# | train/             |          |
# |    actor_loss      | 2.21e+04 |
# |    critic_loss     | 6.7e+05  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2326400  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 56.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14180    |
# |    fps             | 1664     |
# |    time_elapsed    | 585      |
# |    total_timesteps | 13983984 |
# | train/             |          |
# |    actor_loss      | 2.19e+04 |
# |    critic_loss     | 1.74e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2327296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+03 |
# |    ep_rew_mean     | 46.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14190    |
# |    fps             | 1665     |
# |    time_elapsed    | 591      |
# |    total_timesteps | 13993680 |
# | train/             |          |
# |    actor_loss      | 2.23e+04 |
# |    critic_loss     | 3.21e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2328832  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 47.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14200    |
# |    fps             | 1665     |
# |    time_elapsed    | 597      |
# |    total_timesteps | 14004012 |
# | train/             |          |
# |    actor_loss      | 2.26e+04 |
# |    critic_loss     | 5.01e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2330624  |
# ---------------------------------

# %%
# > 14M steps, stabilize spawn radius
spawn_radius=(10, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_15M"))
# Out:
# Increasing spawn radius to  (10, 100.0)
# Logging to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 48.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14210    |
# |    fps             | 1937     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 14015052 |
# | train/             |          |
# |    actor_loss      | 2.25e+04 |
# |    critic_loss     | 1.53e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2332416  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 43.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14220    |
# |    fps             | 1805     |
# |    time_elapsed    | 7        |
# |    total_timesteps | 14023476 |
# | train/             |          |
# |    actor_loss      | 2.26e+04 |
# |    critic_loss     | 1.68e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2333824  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 38.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14230    |
# |    fps             | 1737     |
# |    time_elapsed    | 14       |
# |    total_timesteps | 14034564 |
# | train/             |          |
# |    actor_loss      | 2.27e+04 |
# |    critic_loss     | 2.48e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2335744  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 44.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14240    |
# |    fps             | 1745     |
# |    time_elapsed    | 27       |
# |    total_timesteps | 14057844 |
# | train/             |          |
# |    actor_loss      | 2.3e+04  |
# |    critic_loss     | 1.42e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2339584  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 36.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14250    |
# |    fps             | 1751     |
# |    time_elapsed    | 33       |
# |    total_timesteps | 14068872 |
# | train/             |          |
# |    actor_loss      | 2.32e+04 |
# |    critic_loss     | 5.25e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2341376  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 43       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14260    |
# |    fps             | 1751     |
# |    time_elapsed    | 47       |
# |    total_timesteps | 14092608 |
# | train/             |          |
# |    actor_loss      | 2.38e+04 |
# |    critic_loss     | 3.69e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2345344  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.25e+03 |
# |    ep_rew_mean     | 43.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14270    |
# |    fps             | 1742     |
# |    time_elapsed    | 54       |
# |    total_timesteps | 14104596 |
# | train/             |          |
# |    actor_loss      | 2.38e+04 |
# |    critic_loss     | 1.05e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2347392  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | 43.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14280    |
# |    fps             | 1747     |
# |    time_elapsed    | 57       |
# |    total_timesteps | 14110332 |
# | train/             |          |
# |    actor_loss      | 2.38e+04 |
# |    critic_loss     | 1.19e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2348288  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+03 |
# |    ep_rew_mean     | 45.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14290    |
# |    fps             | 1740     |
# |    time_elapsed    | 65       |
# |    total_timesteps | 14123844 |
# | train/             |          |
# |    actor_loss      | 2.38e+04 |
# |    critic_loss     | 1.29e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2350592  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 54.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14300    |
# |    fps             | 1738     |
# |    time_elapsed    | 75       |
# |    total_timesteps | 14140596 |
# | train/             |          |
# |    actor_loss      | 2.41e+04 |
# |    critic_loss     | 9.86e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2353408  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.46e+03 |
# |    ep_rew_mean     | 61.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14310    |
# |    fps             | 1738     |
# |    time_elapsed    | 84       |
# |    total_timesteps | 14157372 |
# | train/             |          |
# |    actor_loss      | 2.42e+04 |
# |    critic_loss     | 2.09e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2356224  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.43e+03 |
# |    ep_rew_mean     | 62.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14320    |
# |    fps             | 1743     |
# |    time_elapsed    | 91       |
# |    total_timesteps | 14170128 |
# | train/             |          |
# |    actor_loss      | 2.4e+04  |
# |    critic_loss     | 1.29e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2358272  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.44e+03 |
# |    ep_rew_mean     | 64.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14330    |
# |    fps             | 1739     |
# |    time_elapsed    | 98       |
# |    total_timesteps | 14181216 |
# | train/             |          |
# |    actor_loss      | 2.41e+04 |
# |    critic_loss     | 9.23e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2360192  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | 57.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14340    |
# |    fps             | 1745     |
# |    time_elapsed    | 100      |
# |    total_timesteps | 14185704 |
# | train/             |          |
# |    actor_loss      | 2.41e+04 |
# |    critic_loss     | 3.89e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2360832  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | 53       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14350    |
# |    fps             | 1742     |
# |    time_elapsed    | 103      |
# |    total_timesteps | 14190156 |
# | train/             |          |
# |    actor_loss      | 2.41e+04 |
# |    critic_loss     | 1.23e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2361600  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 43.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14360    |
# |    fps             | 1741     |
# |    time_elapsed    | 111      |
# |    total_timesteps | 14204436 |
# | train/             |          |
# |    actor_loss      | 2.43e+04 |
# |    critic_loss     | 9.27e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2364032  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 47.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14370    |
# |    fps             | 1744     |
# |    time_elapsed    | 120      |
# |    total_timesteps | 14220252 |
# | train/             |          |
# |    actor_loss      | 2.43e+04 |
# |    critic_loss     | 1.1e+05  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2366592  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 50.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14380    |
# |    fps             | 1741     |
# |    time_elapsed    | 128      |
# |    total_timesteps | 14233188 |
# | train/             |          |
# |    actor_loss      | 2.45e+04 |
# |    critic_loss     | 1.02e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2368768  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 52.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14390    |
# |    fps             | 1738     |
# |    time_elapsed    | 136      |
# |    total_timesteps | 14247300 |
# | train/             |          |
# |    actor_loss      | 2.45e+04 |
# |    critic_loss     | 1.07e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2371200  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0171.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0172.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0173.png
# Eval num_timesteps=14249856, episode_reward=-5.68 +/- 18.51
# Episode length: 1173.67 +/- 1291.82
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.17e+03 |
# |    mean_reward     | -5.68    |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 14249856 |
# | train/             |          |
# |    actor_loss      | 2.46e+04 |
# |    critic_loss     | 1.09e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2371584  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 48       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14400    |
# |    fps             | 1705     |
# |    time_elapsed    | 143      |
# |    total_timesteps | 14254896 |
# | train/             |          |
# |    actor_loss      | 2.46e+04 |
# |    critic_loss     | 1.31e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2372480  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 38.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14410    |
# |    fps             | 1708     |
# |    time_elapsed    | 147      |
# |    total_timesteps | 14261316 |
# | train/             |          |
# |    actor_loss      | 2.47e+04 |
# |    critic_loss     | 4.59e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2373504  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 36.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14420    |
# |    fps             | 1710     |
# |    time_elapsed    | 163      |
# |    total_timesteps | 14289528 |
# | train/             |          |
# |    actor_loss      | 2.5e+04  |
# |    critic_loss     | 1.16e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2378240  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 38.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14430    |
# |    fps             | 1713     |
# |    time_elapsed    | 167      |
# |    total_timesteps | 14296992 |
# | train/             |          |
# |    actor_loss      | 2.49e+04 |
# |    critic_loss     | 1.23e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2379392  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | 46.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14440    |
# |    fps             | 1713     |
# |    time_elapsed    | 171      |
# |    total_timesteps | 14304516 |
# | train/             |          |
# |    actor_loss      | 2.48e+04 |
# |    critic_loss     | 9.11e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2380672  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 51.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14450    |
# |    fps             | 1712     |
# |    time_elapsed    | 176      |
# |    total_timesteps | 14312100 |
# | train/             |          |
# |    actor_loss      | 2.49e+04 |
# |    critic_loss     | 9.44e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2381952  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | 59.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14460    |
# |    fps             | 1715     |
# |    time_elapsed    | 186      |
# |    total_timesteps | 14330556 |
# | train/             |          |
# |    actor_loss      | 2.51e+04 |
# |    critic_loss     | 9.49e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2385024  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.24e+03 |
# |    ep_rew_mean     | 55.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14470    |
# |    fps             | 1713     |
# |    time_elapsed    | 194      |
# |    total_timesteps | 14343996 |
# | train/             |          |
# |    actor_loss      | 2.49e+04 |
# |    critic_loss     | 3.39e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2387328  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.23e+03 |
# |    ep_rew_mean     | 53.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14480    |
# |    fps             | 1715     |
# |    time_elapsed    | 200      |
# |    total_timesteps | 14354112 |
# | train/             |          |
# |    actor_loss      | 2.51e+04 |
# |    critic_loss     | 1.29e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2388992  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | 49       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14490    |
# |    fps             | 1716     |
# |    time_elapsed    | 207      |
# |    total_timesteps | 14366340 |
# | train/             |          |
# |    actor_loss      | 2.5e+04  |
# |    critic_loss     | 1e+05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2391040  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 49.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14500    |
# |    fps             | 1718     |
# |    time_elapsed    | 214      |
# |    total_timesteps | 14377896 |
# | train/             |          |
# |    actor_loss      | 2.49e+04 |
# |    critic_loss     | 7.92e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2392960  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.24e+03 |
# |    ep_rew_mean     | 53.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14510    |
# |    fps             | 1719     |
# |    time_elapsed    | 220      |
# |    total_timesteps | 14388144 |
# | train/             |          |
# |    actor_loss      | 2.47e+04 |
# |    critic_loss     | 7.68e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2394624  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | 59.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14520    |
# |    fps             | 1719     |
# |    time_elapsed    | 231      |
# |    total_timesteps | 14408700 |
# | train/             |          |
# |    actor_loss      | 2.48e+04 |
# |    critic_loss     | 8.68e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2398080  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | 63.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14530    |
# |    fps             | 1720     |
# |    time_elapsed    | 238      |
# |    total_timesteps | 14419776 |
# | train/             |          |
# |    actor_loss      | 2.45e+04 |
# |    critic_loss     | 1.01e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2399872  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | 46.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14540    |
# |    fps             | 1720     |
# |    time_elapsed    | 247      |
# |    total_timesteps | 14436492 |
# | train/             |          |
# |    actor_loss      | 2.46e+04 |
# |    critic_loss     | 1.16e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2402688  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.34e+03 |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14550    |
# |    fps             | 1721     |
# |    time_elapsed    | 254      |
# |    total_timesteps | 14447520 |
# | train/             |          |
# |    actor_loss      | 2.47e+04 |
# |    critic_loss     | 9.99e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2404480  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | -28.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14560    |
# |    fps             | 1721     |
# |    time_elapsed    | 259      |
# |    total_timesteps | 14456484 |
# | train/             |          |
# |    actor_loss      | 2.46e+04 |
# |    critic_loss     | 1.59e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2406016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.24e+03 |
# |    ep_rew_mean     | -30.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14570    |
# |    fps             | 1722     |
# |    time_elapsed    | 262      |
# |    total_timesteps | 14461296 |
# | train/             |          |
# |    actor_loss      | 2.44e+04 |
# |    critic_loss     | 2.55e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2406784  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -32.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14580    |
# |    fps             | 1722     |
# |    time_elapsed    | 264      |
# |    total_timesteps | 14465832 |
# | train/             |          |
# |    actor_loss      | 2.44e+04 |
# |    critic_loss     | 1.06e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2407552  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | -76      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14590    |
# |    fps             | 1722     |
# |    time_elapsed    | 274      |
# |    total_timesteps | 14483352 |
# | train/             |          |
# |    actor_loss      | 2.42e+04 |
# |    critic_loss     | 1.06e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2410496  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0174.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0175.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0176.png
# Eval num_timesteps=14489856, episode_reward=44.23 +/- 15.87
# Episode length: 878.67 +/- 404.77
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 879      |
# |    mean_reward     | 44.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 14489856 |
# | train/             |          |
# |    actor_loss      | 2.44e+04 |
# |    critic_loss     | 1.15e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2411520  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | -204     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14600    |
# |    fps             | 1711     |
# |    time_elapsed    | 284      |
# |    total_timesteps | 14497368 |
# | train/             |          |
# |    actor_loss      | 2.44e+04 |
# |    critic_loss     | 1.02e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2412800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -243     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14610    |
# |    fps             | 1710     |
# |    time_elapsed    | 287      |
# |    total_timesteps | 14502300 |
# | train/             |          |
# |    actor_loss      | 2.41e+04 |
# |    critic_loss     | 1.21e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2413696  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -283     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14620    |
# |    fps             | 1710     |
# |    time_elapsed    | 290      |
# |    total_timesteps | 14506836 |
# | train/             |          |
# |    actor_loss      | 2.39e+04 |
# |    critic_loss     | 3.92e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2414464  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -292     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14630    |
# |    fps             | 1712     |
# |    time_elapsed    | 292      |
# |    total_timesteps | 14511204 |
# | train/             |          |
# |    actor_loss      | 2.4e+04  |
# |    critic_loss     | 1.38e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2415104  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 913      |
# |    ep_rew_mean     | -285     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14640    |
# |    fps             | 1711     |
# |    time_elapsed    | 297      |
# |    total_timesteps | 14518596 |
# | train/             |          |
# |    actor_loss      | 2.37e+04 |
# |    critic_loss     | 1.32e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2416384  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 801      |
# |    ep_rew_mean     | -215     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14650    |
# |    fps             | 1712     |
# |    time_elapsed    | 302      |
# |    total_timesteps | 14527872 |
# | train/             |          |
# |    actor_loss      | 2.34e+04 |
# |    critic_loss     | 1.72e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2417920  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 790      |
# |    ep_rew_mean     | -218     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14660    |
# |    fps             | 1713     |
# |    time_elapsed    | 308      |
# |    total_timesteps | 14538768 |
# | train/             |          |
# |    actor_loss      | 2.33e+04 |
# |    critic_loss     | 8.78e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2419712  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 796      |
# |    ep_rew_mean     | -217     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14670    |
# |    fps             | 1713     |
# |    time_elapsed    | 313      |
# |    total_timesteps | 14546484 |
# | train/             |          |
# |    actor_loss      | 2.34e+04 |
# |    critic_loss     | 9.37e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2420992  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 814      |
# |    ep_rew_mean     | -217     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14680    |
# |    fps             | 1713     |
# |    time_elapsed    | 317      |
# |    total_timesteps | 14554548 |
# | train/             |          |
# |    actor_loss      | 2.32e+04 |
# |    critic_loss     | 9.66e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2422400  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 836      |
# |    ep_rew_mean     | -169     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14690    |
# |    fps             | 1713     |
# |    time_elapsed    | 320      |
# |    total_timesteps | 14559000 |
# | train/             |          |
# |    actor_loss      | 2.3e+04  |
# |    critic_loss     | 1.16e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2423168  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 775      |
# |    ep_rew_mean     | -44.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14700    |
# |    fps             | 1715     |
# |    time_elapsed    | 328      |
# |    total_timesteps | 14572536 |
# | train/             |          |
# |    actor_loss      | 2.29e+04 |
# |    critic_loss     | 8.7e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2425344  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 786      |
# |    ep_rew_mean     | -7.63    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14710    |
# |    fps             | 1716     |
# |    time_elapsed    | 338      |
# |    total_timesteps | 14591136 |
# | train/             |          |
# |    actor_loss      | 2.29e+04 |
# |    critic_loss     | 8.61e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2428416  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 845      |
# |    ep_rew_mean     | 25.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14720    |
# |    fps             | 1717     |
# |    time_elapsed    | 342      |
# |    total_timesteps | 14598108 |
# | train/             |          |
# |    actor_loss      | 2.29e+04 |
# |    critic_loss     | 1.66e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2429568  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 901      |
# |    ep_rew_mean     | 30.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14730    |
# |    fps             | 1717     |
# |    time_elapsed    | 348      |
# |    total_timesteps | 14608536 |
# | train/             |          |
# |    actor_loss      | 2.28e+04 |
# |    critic_loss     | 1.26e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2431360  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 978      |
# |    ep_rew_mean     | 32.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14740    |
# |    fps             | 1717     |
# |    time_elapsed    | 356      |
# |    total_timesteps | 14622288 |
# | train/             |          |
# |    actor_loss      | 2.3e+04  |
# |    critic_loss     | 1.36e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2433664  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+03 |
# |    ep_rew_mean     | 30.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14750    |
# |    fps             | 1718     |
# |    time_elapsed    | 362      |
# |    total_timesteps | 14632380 |
# | train/             |          |
# |    actor_loss      | 2.27e+04 |
# |    critic_loss     | 2.43e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2435328  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.05e+03 |
# |    ep_rew_mean     | 33.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14760    |
# |    fps             | 1719     |
# |    time_elapsed    | 367      |
# |    total_timesteps | 14642580 |
# | train/             |          |
# |    actor_loss      | 2.31e+04 |
# |    critic_loss     | 2.21e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2436992  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 21.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14770    |
# |    fps             | 1718     |
# |    time_elapsed    | 374      |
# |    total_timesteps | 14653500 |
# | train/             |          |
# |    actor_loss      | 2.29e+04 |
# |    critic_loss     | 1.46e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2438912  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 20.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14780    |
# |    fps             | 1719     |
# |    time_elapsed    | 377      |
# |    total_timesteps | 14659128 |
# | train/             |          |
# |    actor_loss      | 2.28e+04 |
# |    critic_loss     | 1.29e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2439808  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 16.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14790    |
# |    fps             | 1720     |
# |    time_elapsed    | 385      |
# |    total_timesteps | 14672208 |
# | train/             |          |
# |    actor_loss      | 2.26e+04 |
# |    critic_loss     | 8.8e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2441984  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 15.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14800    |
# |    fps             | 1720     |
# |    time_elapsed    | 389      |
# |    total_timesteps | 14680140 |
# | train/             |          |
# |    actor_loss      | 2.27e+04 |
# |    critic_loss     | 1.11e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2443264  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 11.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14810    |
# |    fps             | 1719     |
# |    time_elapsed    | 391      |
# |    total_timesteps | 14683440 |
# | train/             |          |
# |    actor_loss      | 2.26e+04 |
# |    critic_loss     | 9.9e+04  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2443904  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 954      |
# |    ep_rew_mean     | 10.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14820    |
# |    fps             | 1719     |
# |    time_elapsed    | 394      |
# |    total_timesteps | 14688384 |
# | train/             |          |
# |    actor_loss      | 2.27e+04 |
# |    critic_loss     | 7.17e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2444672  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 895      |
# |    ep_rew_mean     | 5.07     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14830    |
# |    fps             | 1719     |
# |    time_elapsed    | 396      |
# |    total_timesteps | 14692080 |
# | train/             |          |
# |    actor_loss      | 2.28e+04 |
# |    critic_loss     | 3.39e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2445312  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 844      |
# |    ep_rew_mean     | 6.2      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14840    |
# |    fps             | 1720     |
# |    time_elapsed    | 398      |
# |    total_timesteps | 14696364 |
# | train/             |          |
# |    actor_loss      | 2.26e+04 |
# |    critic_loss     | 6.41e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2445952  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 801      |
# |    ep_rew_mean     | 7.97     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14850    |
# |    fps             | 1720     |
# |    time_elapsed    | 405      |
# |    total_timesteps | 14707248 |
# | train/             |          |
# |    actor_loss      | 2.24e+04 |
# |    critic_loss     | 7.63e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2447872  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 739      |
# |    ep_rew_mean     | 2.53     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14860    |
# |    fps             | 1721     |
# |    time_elapsed    | 411      |
# |    total_timesteps | 14717868 |
# | train/             |          |
# |    actor_loss      | 2.25e+04 |
# |    critic_loss     | 3.18e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2449536  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 652      |
# |    ep_rew_mean     | 10.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14870    |
# |    fps             | 1720     |
# |    time_elapsed    | 413      |
# |    total_timesteps | 14721924 |
# | train/             |          |
# |    actor_loss      | 2.23e+04 |
# |    critic_loss     | 2.12e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2450304  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 670      |
# |    ep_rew_mean     | 9.66     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14880    |
# |    fps             | 1721     |
# |    time_elapsed    | 415      |
# |    total_timesteps | 14725536 |
# | train/             |          |
# |    actor_loss      | 2.23e+04 |
# |    critic_loss     | 6.66e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2450816  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 617      |
# |    ep_rew_mean     | 5.27     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14890    |
# |    fps             | 1721     |
# |    time_elapsed    | 417      |
# |    total_timesteps | 14729400 |
# | train/             |          |
# |    actor_loss      | 2.23e+04 |
# |    critic_loss     | 1.15e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2451456  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0177.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0178.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0179.png
# Eval num_timesteps=14729856, episode_reward=71.09 +/- 81.40
# Episode length: 2208.67 +/- 1119.11
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2.21e+03 |
# |    mean_reward     | 71.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 14729856 |
# | train/             |          |
# |    actor_loss      | 2.22e+04 |
# |    critic_loss     | 7.57e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2451584  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 582      |
# |    ep_rew_mean     | -1.14    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14900    |
# |    fps             | 1705     |
# |    time_elapsed    | 424      |
# |    total_timesteps | 14734572 |
# | train/             |          |
# |    actor_loss      | 2.21e+04 |
# |    critic_loss     | 9.71e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2452352  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 575      |
# |    ep_rew_mean     | -3.73    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14910    |
# |    fps             | 1705     |
# |    time_elapsed    | 427      |
# |    total_timesteps | 14738412 |
# | train/             |          |
# |    actor_loss      | 2.2e+04  |
# |    critic_loss     | 2.32e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2452992  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 571      |
# |    ep_rew_mean     | -2.51    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14920    |
# |    fps             | 1705     |
# |    time_elapsed    | 429      |
# |    total_timesteps | 14742672 |
# | train/             |          |
# |    actor_loss      | 2.17e+04 |
# |    critic_loss     | 7.64e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2453760  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 544      |
# |    ep_rew_mean     | -5.41    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14930    |
# |    fps             | 1705     |
# |    time_elapsed    | 432      |
# |    total_timesteps | 14747352 |
# | train/             |          |
# |    actor_loss      | 2.18e+04 |
# |    critic_loss     | 8.33e+04 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2454528  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 504      |
# |    ep_rew_mean     | -8.34    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14940    |
# |    fps             | 1706     |
# |    time_elapsed    | 436      |
# |    total_timesteps | 14754684 |
# | train/             |          |
# |    actor_loss      | 2.15e+04 |
# |    critic_loss     | 1.76e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2455680  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 553      |
# |    ep_rew_mean     | -3.63    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14950    |
# |    fps             | 1706     |
# |    time_elapsed    | 440      |
# |    total_timesteps | 14761860 |
# | train/             |          |
# |    actor_loss      | 2.15e+04 |
# |    critic_loss     | 1.77e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2456960  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 526      |
# |    ep_rew_mean     | -2.84    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14960    |
# |    fps             | 1707     |
# |    time_elapsed    | 444      |
# |    total_timesteps | 14768400 |
# | train/             |          |
# |    actor_loss      | 2.16e+04 |
# |    critic_loss     | 2.22e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2457984  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 534      |
# |    ep_rew_mean     | -37.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14970    |
# |    fps             | 1706     |
# |    time_elapsed    | 446      |
# |    total_timesteps | 14772528 |
# | train/             |          |
# |    actor_loss      | 2.17e+04 |
# |    critic_loss     | 3.1e+05  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2458752  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 438      |
# |    ep_rew_mean     | -39.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14980    |
# |    fps             | 1707     |
# |    time_elapsed    | 448      |
# |    total_timesteps | 14776032 |
# | train/             |          |
# |    actor_loss      | 2.22e+04 |
# |    critic_loss     | 4.72e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2459264  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 468      |
# |    ep_rew_mean     | -34.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 14990    |
# |    fps             | 1707     |
# |    time_elapsed    | 450      |
# |    total_timesteps | 14779620 |
# | train/             |          |
# |    actor_loss      | 2.22e+04 |
# |    critic_loss     | 1.82e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2459904  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 511      |
# |    ep_rew_mean     | -235     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15000    |
# |    fps             | 1706     |
# |    time_elapsed    | 453      |
# |    total_timesteps | 14783388 |
# | train/             |          |
# |    actor_loss      | 2.25e+04 |
# |    critic_loss     | 3.17e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2460544  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 514      |
# |    ep_rew_mean     | -234     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15010    |
# |    fps             | 1707     |
# |    time_elapsed    | 456      |
# |    total_timesteps | 14789688 |
# | train/             |          |
# |    actor_loss      | 2.3e+04  |
# |    critic_loss     | 4.18e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2461568  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 539      |
# |    ep_rew_mean     | -236     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15020    |
# |    fps             | 1707     |
# |    time_elapsed    | 459      |
# |    total_timesteps | 14794344 |
# | train/             |          |
# |    actor_loss      | 2.3e+04  |
# |    critic_loss     | 4.85e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2462336  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 540      |
# |    ep_rew_mean     | -236     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15030    |
# |    fps             | 1707     |
# |    time_elapsed    | 461      |
# |    total_timesteps | 14798004 |
# | train/             |          |
# |    actor_loss      | 2.27e+04 |
# |    critic_loss     | 3.23e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2462976  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 557      |
# ...
# |    ep_rew_mean     | -0.974   |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15250    |
# |    fps             | 1711     |
# |    time_elapsed    | 520      |
# |    total_timesteps | 14900436 |
# | train/             |          |
# |    actor_loss      | 1.95e+04 |
# |    critic_loss     | 2.03e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2480000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 563      |
# |    ep_rew_mean     | -15.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15260    |
# |    fps             | 1711     |
# |    time_elapsed    | 521      |
# |    total_timesteps | 14903112 |
# | train/             |          |
# |    actor_loss      | 1.94e+04 |
# |    critic_loss     | 4.76e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2480512  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 545      |
# |    ep_rew_mean     | -17      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15270    |
# |    fps             | 1712     |
# |    time_elapsed    | 522      |
# |    total_timesteps | 14905152 |
# | train/             |          |
# |    actor_loss      | 1.97e+04 |
# |    critic_loss     | 7.56e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2480768  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 522      |
# |    ep_rew_mean     | -16.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15280    |
# |    fps             | 1712     |
# |    time_elapsed    | 524      |
# |    total_timesteps | 14907432 |
# | train/             |          |
# |    actor_loss      | 1.92e+04 |
# |    critic_loss     | 4.51e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2481152  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 462      |
# |    ep_rew_mean     | -18.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15290    |
# |    fps             | 1711     |
# |    time_elapsed    | 526      |
# |    total_timesteps | 14910360 |
# | train/             |          |
# |    actor_loss      | 1.95e+04 |
# |    critic_loss     | 1.26e+06 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2481664  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 376      |
# |    ep_rew_mean     | -17.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15300    |
# |    fps             | 1712     |
# |    time_elapsed    | 527      |
# |    total_timesteps | 14913756 |
# | train/             |          |
# |    actor_loss      | 1.95e+04 |
# |    critic_loss     | 3.9e+05  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2482176  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 334      |
# |    ep_rew_mean     | -17.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15310    |
# |    fps             | 1711     |
# |    time_elapsed    | 529      |
# |    total_timesteps | 14915664 |
# | train/             |          |
# |    actor_loss      | 1.95e+04 |
# |    critic_loss     | 5.37e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2482560  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | -17.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15320    |
# |    fps             | 1712     |
# |    time_elapsed    | 530      |
# |    total_timesteps | 14918964 |
# | train/             |          |
# |    actor_loss      | 1.92e+04 |
# |    critic_loss     | 6.34e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2483072  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 290      |
# |    ep_rew_mean     | -18      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15330    |
# |    fps             | 1711     |
# |    time_elapsed    | 533      |
# |    total_timesteps | 14923044 |
# | train/             |          |
# |    actor_loss      | 1.89e+04 |
# |    critic_loss     | 1.96e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2483840  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | -16.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15340    |
# |    fps             | 1712     |
# |    time_elapsed    | 534      |
# |    total_timesteps | 14925312 |
# | train/             |          |
# |    actor_loss      | 1.89e+04 |
# |    critic_loss     | 2.44e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2484096  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 283      |
# |    ep_rew_mean     | -15.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15350    |
# |    fps             | 1712     |
# |    time_elapsed    | 536      |
# |    total_timesteps | 14928624 |
# | train/             |          |
# |    actor_loss      | 1.9e+04  |
# |    critic_loss     | 4.98e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2484736  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 286      |
# |    ep_rew_mean     | 0.0665   |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15360    |
# |    fps             | 1712     |
# |    time_elapsed    | 538      |
# |    total_timesteps | 14932128 |
# | train/             |          |
# |    actor_loss      | 1.87e+04 |
# |    critic_loss     | 1.94e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2485248  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | 1.83     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15370    |
# |    fps             | 1712     |
# |    time_elapsed    | 540      |
# |    total_timesteps | 14935860 |
# | train/             |          |
# |    actor_loss      | 1.9e+04  |
# |    critic_loss     | 2.54e+07 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2485888  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | 2.17     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15380    |
# |    fps             | 1712     |
# |    time_elapsed    | 541      |
# |    total_timesteps | 14937972 |
# | train/             |          |
# |    actor_loss      | 1.88e+04 |
# |    critic_loss     | 4.56e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2486272  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 307      |
# |    ep_rew_mean     | 4.58     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15390    |
# |    fps             | 1712     |
# |    time_elapsed    | 543      |
# |    total_timesteps | 14940756 |
# | train/             |          |
# |    actor_loss      | 1.88e+04 |
# |    critic_loss     | 3.11e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2486784  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | 3.14     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15400    |
# |    fps             | 1712     |
# |    time_elapsed    | 544      |
# |    total_timesteps | 14943144 |
# | train/             |          |
# |    actor_loss      | 1.85e+04 |
# |    critic_loss     | 2.88e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2487168  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 3.73     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15410    |
# |    fps             | 1713     |
# |    time_elapsed    | 548      |
# |    total_timesteps | 14948916 |
# | train/             |          |
# |    actor_loss      | 1.85e+04 |
# |    critic_loss     | 3.1e+05  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2488064  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 329      |
# |    ep_rew_mean     | 4.43     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15420    |
# |    fps             | 1712     |
# |    time_elapsed    | 550      |
# |    total_timesteps | 14952252 |
# | train/             |          |
# |    actor_loss      | 1.87e+04 |
# |    critic_loss     | 3.96e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2488704  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 326      |
# |    ep_rew_mean     | 4.07     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15430    |
# |    fps             | 1713     |
# |    time_elapsed    | 551      |
# |    total_timesteps | 14954688 |
# | train/             |          |
# |    actor_loss      | 1.84e+04 |
# |    critic_loss     | 3.86e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2489088  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 324      |
# |    ep_rew_mean     | 2.98     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15440    |
# |    fps             | 1713     |
# |    time_elapsed    | 553      |
# |    total_timesteps | 14958660 |
# | train/             |          |
# |    actor_loss      | 1.83e+04 |
# |    critic_loss     | 4.18e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2489728  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 332      |
# |    ep_rew_mean     | 2.82     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15450    |
# |    fps             | 1713     |
# |    time_elapsed    | 555      |
# |    total_timesteps | 14962668 |
# | train/             |          |
# |    actor_loss      | 1.86e+04 |
# |    critic_loss     | 2.58e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2490368  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 1.06     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15460    |
# |    fps             | 1713     |
# |    time_elapsed    | 557      |
# |    total_timesteps | 14964960 |
# | train/             |          |
# |    actor_loss      | 1.81e+04 |
# |    critic_loss     | 8.46e+06 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2490752  |
# ---------------------------------
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0180.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0181.png
# Saved trajectory image to runs/td3_arpod_20250912_121710_20kg_256x1024x64/logs/trajectory_0182.png
# Eval num_timesteps=14969856, episode_reward=12.26 +/- 52.19
# Episode length: 624.67 +/- 652.18
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 625      |
# |    mean_reward     | 12.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 14969856 |
# | train/             |          |
# |    actor_loss      | 1.83e+04 |
# |    critic_loss     | 2.71e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2491520  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 343      |
# |    ep_rew_mean     | 1.05     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15470    |
# |    fps             | 1708     |
# |    time_elapsed    | 562      |
# |    total_timesteps | 14970780 |
# | train/             |          |
# |    actor_loss      | 1.81e+04 |
# |    critic_loss     | 2.12e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2491776  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 360      |
# |    ep_rew_mean     | 0.884    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15480    |
# |    fps             | 1708     |
# |    time_elapsed    | 565      |
# |    total_timesteps | 14975688 |
# | train/             |          |
# |    actor_loss      | 1.82e+04 |
# |    critic_loss     | 3.94e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2492544  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 392      |
# |    ep_rew_mean     | 3.48     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15490    |
# |    fps             | 1708     |
# |    time_elapsed    | 570      |
# |    total_timesteps | 14985504 |
# | train/             |          |
# |    actor_loss      | 1.81e+04 |
# |    critic_loss     | 1.88e+06 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2494208  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 436      |
# |    ep_rew_mean     | 7.06     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15500    |
# |    fps             | 1708     |
# |    time_elapsed    | 574      |
# |    total_timesteps | 14990616 |
# | train/             |          |
# |    actor_loss      | 1.82e+04 |
# |    critic_loss     | 2.74e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2495104  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 464      |
# |    ep_rew_mean     | 8.63     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15510    |
# |    fps             | 1709     |
# |    time_elapsed    | 577      |
# |    total_timesteps | 14996664 |
# | train/             |          |
# |    actor_loss      | 1.81e+04 |
# |    critic_loss     | 3.89e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2496000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 481      |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 15520    |
# |    fps             | 1709     |
# |    time_elapsed    | 582      |
# |    total_timesteps | 15006516 |
# | train/             |          |
# |    actor_loss      | 1.85e+04 |
# |    critic_loss     | 5.94e+05 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2497664  |
# ---------------------------------

# %%
# > 15M steps, stabilize spawn radius
spawn_radius=(10, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_16M"))

# %%
# > 16M steps, stabilize spawn radius
spawn_radius=(10, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_17M"))

# %%
# > 17M steps, stabilize spawn radius
spawn_radius=(10, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_18M"))

# %%
# > 18M steps, stabilize spawn radius
spawn_radius=(10, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_19M"))

# %%
# > 19M steps, stabilize spawn radius
spawn_radius=(10, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)
for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(1e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_20M"))

# %%
# > 20M steps, stabilize spawn radius
spawn_radius=(10, 100.0)
eval_env = Monitor(HCWSE2Env(seed=seed,render_mode="rgb_array",render_folder=logs_dir,spawn_radius=spawn_radius), logs_dir)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=best_dir,
    log_path=logs_dir,
    eval_freq=20_000,
    n_eval_episodes=3,
    deterministic=True,
    render=True,
    verbose=1,
)

for e in env.envs:
    e.unwrapped.spawn_radius=spawn_radius
print("Increasing spawn radius to ", env.envs[0].unwrapped.spawn_radius)    
model.learn(total_timesteps=int(5e6), log_interval=10, callback=[eval_callback],reset_num_timesteps=False)   
model.save(os.path.join(out_dir, "model_25M"))
